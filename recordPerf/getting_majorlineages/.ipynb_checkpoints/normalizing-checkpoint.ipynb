# %%
import pandas as pd
infile="/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/genepromdelta.7/Randomforest/developing/onPBMC/corr/major_lineage/fornormalizing/both.txt"


remove='mNeu'
indf=pd.read_csv(infile,sep="\t",index_col=0)

indf.head()
# Out:
#                                CD4       CD8        Mn      mNeu  CD4_real  \
# Mixture
# mel-123-P-Bulk            0.306381  0.175175  0.067457  0.083396  0.341700
# mel-159-P-Bulk            0.326038  0.118448  0.062676  0.106824  0.318100
# TWCY-1313-1313-BULK-PBMC  0.307635  0.191715  0.093243  0.021078  0.296299
# TWCY-1382-1382-BULK-PBMC  0.071427  0.021850  0.014618  0.625527  0.182791
# TWCY-1389-1389-BULK-PBMC  0.236169  0.193073  0.107133  0.083796  0.138679
#
#                           CD8_real   Mn_real  mNeu_real
# Mixture
# mel-123-P-Bulk            0.093800  0.215000          0
# mel-159-P-Bulk            0.100900  0.208800          0
# TWCY-1313-1313-BULK-PBMC  0.090083  0.370081          0
# TWCY-1382-1382-BULK-PBMC  0.072937  0.539643          0
# TWCY-1389-1389-BULK-PBMC  0.093819  0.485881          0
