# %%
import pandas as pd

infile=#"/Users/irffanalahi/Research/Research_update/SoftRD/using13cref/HardRC/corr/combine_b_cell/deconresult/ref13ct_mincpg2_q0.5_q0.01_diff0.05_hypo_top150dmr_t1_0.15_t2_0.15.txt_result_nocov_mincpg2_ABSreadcount_divisioned.txt_CSxOut.txt"


column_mapping={"Lymph":["nB","mB","CD4","CD8","NK","Tr","m4","m8"]}





indf=pd.read_csv(infile,sep="\t",index_col=0)

indf.head()
# Out:
#                                 cB       CD4       CD8       iDC        M0  \
# Mixture
# F-1393-T-Bulk             0.065844  0.183284  0.076545  0.150659  0.163366
# F-1697-T-Bulk             0.060753  0.147858  0.058691  0.160600  0.244828
# mel-123-P-Bulk            0.059761  0.281634  0.120273  0.165957  0.070796
# mel-159-P-Bulk            0.049133  0.322424  0.102441  0.113953  0.063291
# TWCY-1313-1313-BULK-PBMC  0.035142  0.152018  0.056371  0.093617  0.026455
#
#                                 M1        M2       mDC        Mn        mN  \
# Mixture
# F-1393-T-Bulk             0.110119  0.120359  0.441176  0.115841  0.062931
# F-1697-T-Bulk             0.164179  0.106408  0.260163  0.111913  0.041806
# mel-123-P-Bulk            0.060811  0.026803  0.168966  0.064081  0.051354
# mel-159-P-Bulk            0.046980  0.021614  0.183453  0.055686  0.061743
# TWCY-1313-1313-BULK-PBMC  0.020408  0.017507  0.100000  0.042709  0.004887
#
# ...

# %%
for key in column_mapping:
 
    indf[key]=indf[column_mapping[key]].sum(axis=1)

# %%
indf.head()
# Out:
#                                 cB       CD4       CD8       iDC        M0  \
# Mixture
# F-1393-T-Bulk             0.065844  0.183284  0.076545  0.150659  0.163366
# F-1697-T-Bulk             0.060753  0.147858  0.058691  0.160600  0.244828
# mel-123-P-Bulk            0.059761  0.281634  0.120273  0.165957  0.070796
# mel-159-P-Bulk            0.049133  0.322424  0.102441  0.113953  0.063291
# TWCY-1313-1313-BULK-PBMC  0.035142  0.152018  0.056371  0.093617  0.026455
#
#                                 M1        M2       mDC        Mn        mN  \
# Mixture
# F-1393-T-Bulk             0.110119  0.120359  0.441176  0.115841  0.062931
# F-1697-T-Bulk             0.164179  0.106408  0.260163  0.111913  0.041806
# mel-123-P-Bulk            0.060811  0.026803  0.168966  0.064081  0.051354
# mel-159-P-Bulk            0.046980  0.021614  0.183453  0.055686  0.061743
# TWCY-1313-1313-BULK-PBMC  0.020408  0.017507  0.100000  0.042709  0.004887
#
# ...

# %%
indf.to_csv(infile+"_RENAME",sep="\t")
