# %%
import pandas as pd

infile="/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/corr/Morecelltypes/withDC/deconresult_prep/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkladjustedScore_minus_avgctporportion_CSxOut.txt"


#column_mapping={"Lymph":["nB","mB","CD4","CD8","NK","Tr","m4","m8"]}


#for CBC
#column_mapping={"Mono_maccombined":["Monocytes","Macrophages M0","Macrophages M1","Macrophages M2"],"Lymph":["B cells naive","B cells memory","Plasma cells","T cells CD8","T cells CD4 naive","T cells CD4 memory resting","T cells CD4 memory activated","T cells follicular helper","T cells regulatory (Tregs)","T cells gamma delta","NK cells resting","NK cells activated"]}


###BL22 to BL14 like
#column_mapping={'m4':['cm4','em4'],'m8':['cm8','em8'],'DC':['iDC','mDC']}


#CD8_comine
#column_mapping={'CD8':['cm8','em8','ed8']}

#major lineage

#column_mapping={'CD4':['NaiveCD4','m4'],'CD8':['NaiveCD8','m8'],'B_cell':['nB','mB']}



###DC
column_mapping={'DC':['iDC','mDC']}

indf=pd.read_csv(infile,sep="\t",index_col=0)

indf.head()
# Out:
#                                Eo        Er        M0        M1        M2  \
# Mixture
# healthy_NU-03-bulk-PBMC  0.024844  0.016732  0.020705  0.017688  0.017338
# healthy_NU-14-bulk-PBMC  0.025710  0.017516  0.016671  0.017736  0.022433
# healthy_NU-24-bulk-PBMC  0.025049  0.016297  0.020536  0.017161  0.020658
# healthy_NU-31-bulk-PBMC  0.024061  0.020010  0.020680  0.018768  0.018290
# healthy_NU-49-bulk-PBMC  0.026111  0.018333  0.019472  0.017671  0.017982
#
#                                Mg      Mono        NK  NaiveCD4  NaiveCD8  \
# Mixture
# healthy_NU-03-bulk-PBMC  0.018092  0.043115  0.064246  0.075723  0.051390
# healthy_NU-14-bulk-PBMC  0.016348  0.042733  0.087384  0.089255  0.088672
# healthy_NU-24-bulk-PBMC  0.015092  0.047040  0.058852  0.116013  0.060992
# healthy_NU-31-bulk-PBMC  0.026565  0.041409  0.107179  0.085949  0.063026
# healthy_NU-49-bulk-PBMC  0.014173  0.035624  0.057370  0.095303  0.074013
#
# ...

# %%
for key in column_mapping:
 
    indf[key]=indf[column_mapping[key]].sum(axis=1)

# %%
indf.head()
# Out:
#                                Eo        Er        M0        M1        M2  \
# Mixture
# healthy_NU-03-bulk-PBMC  0.024844  0.016732  0.020705  0.017688  0.017338
# healthy_NU-14-bulk-PBMC  0.025710  0.017516  0.016671  0.017736  0.022433
# healthy_NU-24-bulk-PBMC  0.025049  0.016297  0.020536  0.017161  0.020658
# healthy_NU-31-bulk-PBMC  0.024061  0.020010  0.020680  0.018768  0.018290
# healthy_NU-49-bulk-PBMC  0.026111  0.018333  0.019472  0.017671  0.017982
#
#                                Mg      Mono        NK  NaiveCD4  NaiveCD8  \
# Mixture
# healthy_NU-03-bulk-PBMC  0.018092  0.043115  0.064246  0.075723  0.051390
# healthy_NU-14-bulk-PBMC  0.016348  0.042733  0.087384  0.089255  0.088672
# healthy_NU-24-bulk-PBMC  0.015092  0.047040  0.058852  0.116013  0.060992
# healthy_NU-31-bulk-PBMC  0.026565  0.041409  0.107179  0.085949  0.063026
# healthy_NU-49-bulk-PBMC  0.014173  0.035624  0.057370  0.095303  0.074013
#
# ...

# %%
indf.to_csv(infile+"_MAJORlineageRENAME",sep="\t")
