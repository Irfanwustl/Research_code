# %%
import pandas as pd

infile="/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/genepromdelta.7/Randomforest/developing/onCRC_WB/corr/gt_prepare/WB/CIBERSORTx_Job11_Results_HealthyRNASeq.txt"


#column_mapping={"Lymph":["nB","mB","CD4","CD8","NK","Tr","m4","m8"]}

column_mapping={"Mono_maccombined":["Monocytes","Macrophages M0","Macrophages M1","Macrophages M2"],"Lymph":["B cells naive","B cells memory","Plasma cells","T cells CD8","T cells CD4 naive","T cells CD4 memory resting","T cells CD4 memory activated","T cells follicular helper","T cells regulatory (Tregs)","T cells gamma delta","NK cells resting","NK cells activated"]}



indf=pd.read_csv(infile,sep="\t",index_col=0)

indf.head()
# Out:
#          B cells naive  B cells memory  Plasma cells  T cells CD8  \
# Mixture
# NU20          0.023284        0.010132      0.000000     0.168857
# NU44          0.072654        0.000000      0.000000     0.122385
# NU47          0.037556        0.000000      0.000000     0.109016
# NU05          0.041299        0.000000      0.000000     0.121103
# NU24          0.029527        0.000000      0.002232     0.082473
#
#          T cells CD4 naive  T cells CD4 memory resting  \
# Mixture
# NU20              0.000000                    0.233782
# NU44              0.000000                    0.131317
# NU47              0.028162                    0.133693
# NU05              0.048311                    0.065937
# NU24              0.000000                    0.290417
#
#          T cells CD4 memory activated  T cells follicular helper  \
# Mixture
# NU20                         0.019438                          0
# NU44                         0.036110                          0
# NU47                         0.010667                          0
# NU05                         0.021553                          0
# NU24                         0.004535                          0
#
#          T cells regulatory (Tregs)  T cells gamma delta  ...  Macrophages M2  \
# Mixture                                                   ...
# NU20                              0                    0  ...        0.024953
# NU44                              0                    0  ...        0.025860
# NU47                              0                    0  ...        0.030432
# NU05                              0                    0  ...        0.028911
# NU24                              0                    0  ...        0.011788
#
#          Dendritic cells resting  Dendritic cells activated  \
# Mixture
# NU20                    0.000182                   0.000000
# NU44                    0.000000                   0.002789
# NU47                    0.000000                   0.000000
# NU05                    0.000000                   0.000000
# NU24                    0.000000                   0.001978
#
#          Mast cells resting  Mast cells activated  Eosinophils  Neutrophils  \
# Mixture
# NU20               0.028275                     0          0.0     0.318106
# NU44               0.000000                     0          0.0     0.436770
# NU47               0.009285                     0          0.0     0.559158
# NU05               0.013387                     0          0.0     0.312602
# NU24               0.019851                     0          0.0     0.195017
#
#          P-value  Correlation      RMSE
# Mixture
# NU20           0     0.721972  0.708319
# NU44           0     0.744219  0.678616
# NU47           0     0.797443  0.609557
# NU05           0     0.781705  0.658380
# NU24           0     0.757978  0.690918
#
# [5 rows x 25 columns]

# %%
for key in column_mapping:
 
    indf[key]=indf[column_mapping[key]].sum(axis=1)

# %%
indf.head()
# Out:
#          B cells naive  B cells memory  Plasma cells  T cells CD8  \
# Mixture
# NU20          0.023284        0.010132      0.000000     0.168857
# NU44          0.072654        0.000000      0.000000     0.122385
# NU47          0.037556        0.000000      0.000000     0.109016
# NU05          0.041299        0.000000      0.000000     0.121103
# NU24          0.029527        0.000000      0.002232     0.082473
#
#          T cells CD4 naive  T cells CD4 memory resting  \
# Mixture
# NU20              0.000000                    0.233782
# NU44              0.000000                    0.131317
# NU47              0.028162                    0.133693
# NU05              0.048311                    0.065937
# NU24              0.000000                    0.290417
#
#          T cells CD4 memory activated  T cells follicular helper  \
# Mixture
# NU20                         0.019438                          0
# NU44                         0.036110                          0
# NU47                         0.010667                          0
# NU05                         0.021553                          0
# NU24                         0.004535                          0
#
#          T cells regulatory (Tregs)  T cells gamma delta  ...  \
# Mixture                                                   ...
# NU20                              0                    0  ...
# NU44                              0                    0  ...
# NU47                              0                    0  ...
# NU05                              0                    0  ...
# NU24                              0                    0  ...
#
#          Dendritic cells activated  Mast cells resting  Mast cells activated  \
# Mixture
# NU20                      0.000000            0.028275                     0
# NU44                      0.002789            0.000000                     0
# NU47                      0.000000            0.009285                     0
# NU05                      0.000000            0.013387                     0
# NU24                      0.001978            0.019851                     0
#
#          Eosinophils  Neutrophils  P-value  Correlation      RMSE  \
# Mixture
# NU20             0.0     0.318106        0     0.721972  0.708319
# NU44             0.0     0.436770        0     0.744219  0.678616
# NU47             0.0     0.559158        0     0.797443  0.609557
# NU05             0.0     0.312602        0     0.781705  0.658380
# NU24             0.0     0.195017        0     0.757978  0.690918
#
#          Mono_maccombined     Lymph
# Mixture
# NU20             0.048049  0.605387
# NU44             0.068238  0.492203
# NU47             0.038809  0.392747
# NU05             0.238003  0.436008
# NU24             0.173105  0.610048
#
# [5 rows x 27 columns]

# %%
indf.to_csv(infile+"_MAJORlineageRENAME",sep="\t")
