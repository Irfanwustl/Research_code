# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/OurCD8TIL_ranked/compare_BSseq_EMseq_result/cross_correlation_divideby_mappedreads/cross_corr_divide_by_avilable_fragmens/raw_score_divby_testedfrag_rename/divbyCtFRAG_BS_melanoma_cfDNA_onlybad.txt'

indf=pd.read_csv(infile,sep='\t',index_col='Mixture')
indf.head()
# Out:
#               Naive CD4 T  Naive CD8   Naive B        NK      Mono  Mac (M0)  \
# Mixture
# Y-3674-cfDNA     0.076035   0.063475  0.071380  0.112455  0.144496  0.122516
# Y-3688-cfDNA     0.093531   0.083502  0.087285  0.111724  0.121506  0.160289
# Y-3694-cfDNA     0.076375   0.071567  0.078272  0.120061  0.202111  0.161017
# Y-3703-cfDNA     0.089548   0.070786  0.075269  0.118511  0.124122  0.137418
# Y-3707-cfDNA     0.106949   0.070634  0.077416  0.125093  0.143496  0.108053
#
#               Mac (M1)  Mac (M2)       iDC       mDC  ...   CD8 TEM  \
# Mixture                                               ...
# Y-3674-cfDNA  0.106063  0.077397  0.132250  0.119803  ...  0.076486
# Y-3688-cfDNA  0.143139  0.110011  0.142293  0.140211  ...  0.115158
# Y-3694-cfDNA  0.119738  0.098639  0.148215  0.136292  ...  0.090927
# Y-3703-cfDNA  0.115769  0.109580  0.133386  0.133705  ...  0.105490
# Y-3707-cfDNA  0.124504  0.089468  0.137565  0.147431  ...  0.095709
#
# ...

# %%
droppedindf=indf.drop(['Toxicity','Response','YU ID'],errors='ignore',axis=1)
droppedindf.head()
# Out:
#               Naive CD4 T  Naive CD8   Naive B        NK      Mono  Mac (M0)  \
# Mixture
# Y-3674-cfDNA     0.076035   0.063475  0.071380  0.112455  0.144496  0.122516
# Y-3688-cfDNA     0.093531   0.083502  0.087285  0.111724  0.121506  0.160289
# Y-3694-cfDNA     0.076375   0.071567  0.078272  0.120061  0.202111  0.161017
# Y-3703-cfDNA     0.089548   0.070786  0.075269  0.118511  0.124122  0.137418
# Y-3707-cfDNA     0.106949   0.070634  0.077416  0.125093  0.143496  0.108053
#
#               Mac (M1)  Mac (M2)       iDC       mDC  ...   CD8 TEM  \
# Mixture                                               ...
# Y-3674-cfDNA  0.106063  0.077397  0.132250  0.119803  ...  0.076486
# Y-3688-cfDNA  0.143139  0.110011  0.142293  0.140211  ...  0.115158
# Y-3694-cfDNA  0.119738  0.098639  0.148215  0.136292  ...  0.090927
# Y-3703-cfDNA  0.115769  0.109580  0.133386  0.133705  ...  0.105490
# Y-3707-cfDNA  0.124504  0.089468  0.137565  0.147431  ...  0.095709
#
# ...

# %%
corr = droppedindf.corr(method='pearson')

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,cmap='viridis',vmin=-.5,vmax=1)
plt.savefig(infile + '_CT_crosscorrelation.pdf', bbox_inches='tight')
