# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/OurCD8TIL_ranked/melanoma_EMseq_firstlane/RC_result/cor/csxout_toxgt/method1Fract_CD8TIL_pbl_tum_all_matrix_allout_ranked_SM_top100_SM_unique_result_dupindex_binnedstats.pkl_maxscore_CSxOut.txt_toxicity.txt'

celltype='em4'



indf=pd.read_csv(infile,sep="\t",index_col=0)


indf.head()
# Out:
#                            NaiveCD4    NaiveCD8         nB          NK  \
# Mixture
# healthy_NU-03-bulk-PBMC  426.272052   72.323616  49.742895  361.665501
# healthy_NU-14-bulk-PBMC  477.972932  118.712490  43.151935  467.951141
# healthy_NU-24-bulk-PBMC  639.671016   84.073688  40.998135  324.499712
# healthy_NU-31-bulk-PBMC  476.608171   87.374142  42.654327  594.338083
# healthy_NU-49-bulk-PBMC  531.930500  103.275266  41.871135  320.210369
#
#                                 PC        Mono          M0         M1  \
# Mixture
# healthy_NU-03-bulk-PBMC  19.269655  121.355239  116.558845  24.893288
# healthy_NU-14-bulk-PBMC  21.432662  114.420894   89.275187  23.744648
# healthy_NU-24-bulk-PBMC  16.794414  129.683513  113.231812  23.656056
# healthy_NU-31-bulk-PBMC  26.684424  114.812973  114.678223  26.017875
# healthy_NU-49-bulk-PBMC  20.927356   99.416938  108.680213  24.658069
#
#                                  M2        iDC  ...  nB_real  NaiveCD4_real  \
# ...

# %%
indf.boxplot(by ='Tox_grade', column =[celltype], grid = False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
sns.boxplot(x = 'Tox_grade', y = celltype, data = indf)
plt.savefig(infile+"_"+celltype+'_boxplot.pdf')
