# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/OurCD8TIL_ranked/compare_BSseq_EMseq_result/BS_melanoma_cfDNA_relative.txt'

celltype='CD4 TEM'



indf=pd.read_csv(infile,sep="\t",index_col=0)


indf.head()
# Out:
#                            Mixture  Naive CD4 T  Naive CD8   Naive B  \
# YU ID
# YUCLUE    tot-YUCLUE_20-3998-cfDNA     2.493639   2.464160  2.490712
# YUMARS    tot-YUMARS_15-3443-cfDNA     2.494741   2.525881  2.529701
# YUMICRO  tot-YUMICRO_20-4006-cfDNA     3.328265   3.491512  3.306904
# YUMOTE    tot-YUMOTE_17-3755-cfDNA     2.728999   2.936065  2.912076
# YUPRAF    tot-YUPRAF_19-3925-cfDNA     2.680527   2.696936  2.587731
#
#                NK      Mono  Mac (M0)  Mac (M1)  Mac (M2)       iDC  ...  \
# YU ID                                                                ...
# YUCLUE   3.141181  4.396388  4.806204  4.119200  3.264635  4.716480  ...
# YUMARS   3.624588  5.597168  5.382108  4.511471  3.157593  4.364970  ...
# YUMICRO  2.868509  4.253649  5.836782  5.787147  4.643044  4.217909  ...
# YUMOTE   2.629696  5.241654  5.774284  5.465563  3.550091  3.929663  ...
# YUPRAF   3.112085  5.621401  4.968412  4.521435  3.304701  4.160581  ...
#
# ...

# %%
indf.boxplot(by ='Toxicity', column =[celltype], grid = False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
sns.boxplot(x = 'Toxicity', y = celltype, data = indf,color='white')
sns.stripplot(x = 'Toxicity', y = celltype, data = indf,color = 'black')
plt.savefig(infile+"_"+celltype+'_boxplot.pdf')
