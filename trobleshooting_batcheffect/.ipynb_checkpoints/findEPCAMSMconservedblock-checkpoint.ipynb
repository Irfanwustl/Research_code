# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/Epcam_blue/TowardsnonoverfitSM/PDAC.txt'
indf=pd.read_csv(infile,sep='\t',index_col=['chrom','start','end'])
celltype='EPCAM-others'
assumedother_meth=.98 ############
maxmethylation_threshold=0.3 ###################
total_compartments=['chrom','start','NaiveCD4-others','NaiveCD8-others','nB-others','NK-others','PC-others','Mono-others','M0-others','M1-others','M2-others','iDC-others','mDC-others','PMN-others','cm8-others','em8-others','Eo-others','Tregs-others','em4-others','ed8-others','Mg-others','cm4-others','Er-others','mB-others','EPCAM-others']
total_compartments_set=set(total_compartments)
finalcompartmentshouldbe=len(total_compartments)
indf.head()
# Out:
#                          GSM4928782_PDAC1-Ep.bed  GSM4928783_PDAC2-Ep.bed  \
# chrom start    end
# chr1  1715610  1715612                      0.70                   0.3665
#       11225710 11225712                     1.00                   1.0000
#       12130653 12130655                     0.75                   0.8690
#       12282656 12282658                     1.00                   0.9160
#       12289371 12289373                     1.00                   0.8330
#
#                          GSM4928784_PDAC3-Ep.bed  GSM4928785_PDAC4-Ep.bed  \
# chrom start    end
# chr1  1715610  1715612                       0.2                   0.5645
#       11225710 11225712                      1.0                   0.7500
#       12130653 12130655                      1.0                   0.8660
#       12282656 12282658                      1.0                   0.8120
#       12289371 12289373                      1.0                   0.8750
#
#                          GSM4928786_PDAC5-Ep.bed  GSM4928787_PDAC6-Ep.bed  \
# chrom start    end
# chr1  1715610  1715612                    0.5945                    0.557
#       11225710 11225712                   0.8180                    0.937
#       12130653 12130655                   0.9330                    0.916
#       12282656 12282658                   0.8330                    1.000
#       12289371 12289373                   0.8820                    0.800
#
#                          GSM4928788_PDAC7-Ep.bed
# chrom start    end
# chr1  1715610  1715612                     0.833
#       11225710 11225712                    0.857
#       12130653 12130655                    1.000
#       12282656 12282658                    1.000
#       12289371 12289373                    1.000

# %%
indf['maxvalue']=indf.max(axis=1)
indf['meanvalue']=indf.mean(axis=1)
indf.head()
# Out:
#                          GSM4928782_PDAC1-Ep.bed  GSM4928783_PDAC2-Ep.bed  \
# chrom start    end
# chr1  1715610  1715612                      0.70                   0.3665
#       11225710 11225712                     1.00                   1.0000
#       12130653 12130655                     0.75                   0.8690
#       12282656 12282658                     1.00                   0.9160
#       12289371 12289373                     1.00                   0.8330
#
#                          GSM4928784_PDAC3-Ep.bed  GSM4928785_PDAC4-Ep.bed  \
# chrom start    end
# chr1  1715610  1715612                       0.2                   0.5645
#       11225710 11225712                      1.0                   0.7500
#       12130653 12130655                      1.0                   0.8660
#       12282656 12282658                      1.0                   0.8120
#       12289371 12289373                      1.0                   0.8750
#
#                          GSM4928786_PDAC5-Ep.bed  GSM4928787_PDAC6-Ep.bed  \
# chrom start    end
# chr1  1715610  1715612                    0.5945                    0.557
#       11225710 11225712                   0.8180                    0.937
#       12130653 12130655                   0.9330                    0.916
#       12282656 12282658                   0.8330                    1.000
#       12289371 12289373                   0.8820                    0.800
#
#                          GSM4928788_PDAC7-Ep.bed  maxvalue  meanvalue
# chrom start    end
# chr1  1715610  1715612                     0.833     0.833   0.581063
#       11225710 11225712                    0.857     1.000   0.920250
#       12130653 12130655                    1.000     1.000   0.916750
#       12282656 12282658                    1.000     1.000   0.945125
#       12289371 12289373                    1.000     1.000   0.923750

# %%
indf.sort_values(by=['maxvalue'])
# Out:
#                            GSM4928782_PDAC1-Ep.bed  GSM4928783_PDAC2-Ep.bed  \
# chrom start     end
# chr15 85589663  85589665                     0.000                    0.000
# chr2  127454954 127454956                    0.000                    0.000
# chr12 31103859  31103861                     0.000                    0.000
# chr2  201149612 201149614                    0.000                    0.000
# chr8  144263016 144263018                    0.000                    0.000
# ...                                            ...                      ...
# chr17 7568327   7568329                      1.000                    1.000
#       7568334   7568336                      0.800                    0.777
#       7568376   7568378                      1.000                    1.000
#       78686208  78686210                     0.785                    0.923
# chrX  151563043 151563045                    0.909                    1.000
#
#                            GSM4928784_PDAC3-Ep.bed  GSM4928785_PDAC4-Ep.bed  \
# chrom start     end
# chr15 85589663  85589665                     0.000                    0.000
# chr2  127454954 127454956                    0.000                    0.000
# chr12 31103859  31103861                     0.000                    0.000
# chr2  201149612 201149614                    0.000                    0.000
# chr8  144263016 144263018                    0.000                    0.000
# ...                                            ...                      ...
# chr17 7568327   7568329                      0.466                    0.800
#       7568334   7568336                      0.533                    0.636
#       7568376   7568378                      0.900                    1.000
#       78686208  78686210                     0.818                    0.588
# chrX  151563043 151563045                    0.875                    0.750
#
#                            GSM4928786_PDAC5-Ep.bed  GSM4928787_PDAC6-Ep.bed  \
# chrom start     end
# chr15 85589663  85589665                     0.000                      0.0
# chr2  127454954 127454956                    0.000                      0.0
# chr12 31103859  31103861                     0.000                      0.0
# chr2  201149612 201149614                    0.000                      0.0
# chr8  144263016 144263018                    0.000                      NaN
# ...                                            ...                      ...
# chr17 7568327   7568329                      1.000                      1.0
#       7568334   7568336                      1.000                      1.0
#       7568376   7568378                      0.928                      1.0
#       78686208  78686210                     0.833                      1.0
# chrX  151563043 151563045                    1.000                      1.0
#
#                            GSM4928788_PDAC7-Ep.bed  maxvalue  meanvalue
# chrom start     end
# chr15 85589663  85589665                     0.000       0.0   0.000000
# chr2  127454954 127454956                    0.000       0.0   0.000000
# chr12 31103859  31103861                     0.000       0.0   0.000000
# chr2  201149612 201149614                    0.000       0.0   0.000000
# chr8  144263016 144263018                    0.000       0.0   0.000000
# ...                                            ...       ...        ...
# chr17 7568327   7568329                      0.714       1.0   0.872500
#       7568334   7568336                      0.857       1.0   0.825375
#       7568376   7568378                      1.000       1.0   0.978500
#       78686208  78686210                     0.750       1.0   0.837125
# chrX  151563043 151563045                    0.600       1.0   0.891750
#
# [1000 rows x 9 columns]

# %%
indf.sort_values(by=['meanvalue'])
# Out:
#                            GSM4928782_PDAC1-Ep.bed  GSM4928783_PDAC2-Ep.bed  \
# chrom start     end
# chr2  127454954 127454956                      0.0                      0.0
# chr17 66229449  66229451                       0.0                      0.0
# chr2  201149612 201149614                      0.0                      0.0
# chr15 85589663  85589665                       0.0                      0.0
# chr12 31103859  31103861                       0.0                      0.0
# ...                                            ...                      ...
# chr19 1009995   1009997                        1.0                      1.0
# chr8  106758656 106758658                      1.0                      1.0
# chr2  29138547  29138549                       1.0                      1.0
# chr5  227635    227637                         1.0                      1.0
# chr4  87312614  87312616                       1.0                      1.0
#
#                            GSM4928784_PDAC3-Ep.bed  GSM4928785_PDAC4-Ep.bed  \
# chrom start     end
# chr2  127454954 127454956                      0.0                      0.0
# chr17 66229449  66229451                       0.0                      0.0
# chr2  201149612 201149614                      0.0                      0.0
# chr15 85589663  85589665                       0.0                      0.0
# chr12 31103859  31103861                       0.0                      0.0
# ...                                            ...                      ...
# chr19 1009995   1009997                        1.0                      1.0
# chr8  106758656 106758658                      NaN                      1.0
# chr2  29138547  29138549                       1.0                      1.0
# chr5  227635    227637                         1.0                      1.0
# chr4  87312614  87312616                       1.0                      1.0
#
#                            GSM4928786_PDAC5-Ep.bed  GSM4928787_PDAC6-Ep.bed  \
# chrom start     end
# chr2  127454954 127454956                      0.0                      0.0
# chr17 66229449  66229451                       0.0                      0.0
# chr2  201149612 201149614                      0.0                      0.0
# chr15 85589663  85589665                       0.0                      0.0
# chr12 31103859  31103861                       0.0                      0.0
# ...                                            ...                      ...
# chr19 1009995   1009997                        1.0                      1.0
# chr8  106758656 106758658                      1.0                      1.0
# chr2  29138547  29138549                       1.0                      1.0
# chr5  227635    227637                         1.0                      1.0
# chr4  87312614  87312616                       NaN                      NaN
#
#                            GSM4928788_PDAC7-Ep.bed  maxvalue  meanvalue
# chrom start     end
# chr2  127454954 127454956                      0.0       0.0        0.0
# chr17 66229449  66229451                       0.0       0.0        0.0
# chr2  201149612 201149614                      0.0       0.0        0.0
# chr15 85589663  85589665                       0.0       0.0        0.0
# chr12 31103859  31103861                       0.0       0.0        0.0
# ...                                            ...       ...        ...
# chr19 1009995   1009997                        1.0       1.0        1.0
# chr8  106758656 106758658                      1.0       1.0        1.0
# chr2  29138547  29138549                       1.0       1.0        1.0
# chr5  227635    227637                         1.0       1.0        1.0
# chr4  87312614  87312616                       1.0       1.0        1.0
#
# [1000 rows x 9 columns]

# %%
hist =indf['meanvalue'].hist()

# %%
outdf=indf[indf['meanvalue']<=maxmethylation_threshold].copy()

# %%
outdf[celltype]=outdf['meanvalue'].mean()-assumedother_meth

# %%
outdf=outdf[[celltype]]
outdf.reset_index(inplace=True)
outdf.head()
# Out:
#   chrom      start        end  EPCAM-others
# 0  chr1   19287649   19287651     -0.865333
# 1  chr1   52869286   52869288     -0.865333
# 2  chr1   61184054   61184056     -0.865333
# 3  chr1  150668192  150668194     -0.865333
# 4  chr1  151541880  151541882     -0.865333

# %%
outdfcolumns=set(outdf.columns.tolist())
missingcols=total_compartments_set-outdfcolumns
missingcolslist=list(missingcols)
missingcolslist
for micol in missingcolslist:
    outdf[micol]=0.9

# %%
outdf=outdf.drop(['end'], axis=1)
if outdf.shape[1]!=finalcompartmentshouldbe:
   # print(infile)
    print("error. Exiting")
    sys.exit(1)

# %%
outdf=outdf[total_compartments]

# %%
outdf.head()
# Out:
#   chrom      start  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# 0  chr1   19287649              0.9              0.9        0.9        0.9
# 1  chr1   52869286              0.9              0.9        0.9        0.9
# 2  chr1   61184054              0.9              0.9        0.9        0.9
# 3  chr1  150668192              0.9              0.9        0.9        0.9
# 4  chr1  151541880              0.9              0.9        0.9        0.9
#
#    PC-others  Mono-others  M0-others  M1-others  ...  em8-others  Eo-others  \
# 0        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 1        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 2        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 3        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 4        0.9          0.9        0.9        0.9  ...         0.9        0.9
#
#    Tregs-others  em4-others  ed8-others  Mg-others  cm4-others  Er-others  \
# 0           0.9         0.9         0.9        0.9         0.9        0.9
# 1           0.9         0.9         0.9        0.9         0.9        0.9
# 2           0.9         0.9         0.9        0.9         0.9        0.9
# 3           0.9         0.9         0.9        0.9         0.9        0.9
# 4           0.9         0.9         0.9        0.9         0.9        0.9
#
#    mB-others  EPCAM-others
# 0        0.9     -0.865333
# 1        0.9     -0.865333
# 2        0.9     -0.865333
# 3        0.9     -0.865333
# 4        0.9     -0.865333
#
# [5 rows x 25 columns]
