# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import pearsonr, spearmanr
import seaborn as sns
import matplotlib.pyplot as plt
DMRfile="BL14_all_matrixCin_nr0.4_imputed_g1_CD4_3_g2_others_33.txt"
mixturegtfile='CD4mixture_output_1000000_highestCD430percent.txt'
mixturegtdf=pd.read_csv(mixturegtfile,sep="\t",index_col=0)

celltype='CD4' #################################
DMRdf=pd.read_csv(DMRfile,sep="\t",index_col=['chrom','start','end'])

DMRdf['1-'+celltype]=1-DMRdf[celltype]
DMRdf['1-others']=1-DMRdf['others']
DMRdf.head()
# Out:
#                                     q      diff  #cpg        p(MWU)  \
# chrom start    end
# chr1  32387133 32387499  1.785900e-12 -0.584534    11  4.363200e-14
# chr10 5754070  5754515   1.133300e-13 -0.583604    13  4.496400e-14
# chr11 64490608 64490797  3.732800e-10 -0.555806    10  4.196600e-14
# chr12 3905651  3906251   2.642700e-10 -0.658527     8  5.173600e-14
# chr14 77029428 77029733  1.273400e-14 -0.587526    11  4.607400e-14
#
#                               p(2dks)      CD4   others     CD4.1       CD8  \
# chrom start    end
# chr1  32387133 32387499  9.452200e-17  0.35261  0.93714  0.352606  0.886636
# chr10 5754070  5754515   4.844000e-18  0.30687  0.89048  0.306872  0.745462
# chr11 64490608 64490797  3.598000e-14  0.19153  0.74734  0.191533  0.567433
# chr12 3905651  3906251   2.418200e-14  0.17879  0.83732  0.178792  0.680625
# chr14 77029428 77029733  4.440900e-19  0.18803  0.77556  0.188030  0.554576
#
#                                nB  ...    CD4-Eo    CD4-Tr    CD4-m4  \
# chrom start    end                 ...
# chr1  32387133 32387499  0.971727  ... -0.584754 -0.501935 -0.452617
# chr10 5754070  5754515   0.968974  ... -0.611245 -0.352938 -0.337668
# chr11 64490608 64490797  0.777767  ... -0.602220 -0.519620 -0.316970
# chr12 3905651  3906251   0.966458  ... -0.317085 -0.674397 -0.467648
# chr14 77029428 77029733  0.837364  ... -0.569470 -0.372152 -0.406061
#
#                            CD4-Mg    CD4-Er    CD4-mB  \
# chrom start    end
# chr1  32387133 32387499 -0.601208 -0.608663 -0.614178
# chr10 5754070  5754515  -0.662784 -0.663015 -0.661489
# chr11 64490608 64490797 -0.726920 -0.669520 -0.539303
# chr12 3905651  3906251  -0.630022 -0.632148 -0.704043
# chr14 77029428 77029733 -0.703652 -0.691561 -0.399818
#
#                          maxCompartmentwisedelta  minCompartmentwiseDelta  \
# chrom start    end
# chr1  32387133 32387499                -0.452617                -0.635087
# chr10 5754070  5754515                 -0.337668                -0.675412
# chr11 64490608 64490797                -0.316970                -0.726920
# chr12 3905651  3906251                 -0.317085                -0.790710
# chr14 77029428 77029733                -0.366546                -0.744940
#
#                            1-CD4  1-others
# chrom start    end
# chr1  32387133 32387499  0.64739   0.06286
# chr10 5754070  5754515   0.69313   0.10952
# chr11 64490608 64490797  0.80847   0.25266
# chr12 3905651  3906251   0.82121   0.16268
# chr14 77029428 77029733  0.81197   0.22444
#
# [5 rows x 39 columns]

# %%
DMRdf.plot.scatter(x='1-others',y='1-'+celltype)

# %%
mixturegtdf.head()
# Out:
#                                   CD4_real        CD8         nB         NK  \
# Mixture
# CD4allrange_NR_1000000_insilmix1    0.0010  15.130581   6.549795   2.520113
# CD4allrange_NR_1000000_insilmix2    0.0010   7.889197   0.139814   4.502655
# CD4allrange_NR_1000000_insilmix3    0.0010  11.134076  11.332065  10.310223
# CD4allrange_NR_1000000_insilmix4    0.0015   0.563823  15.085903   1.743170
# CD4allrange_NR_1000000_insilmix5    0.0015   4.321027  10.280554   3.859671
#
#                                         Mn       mNeu         m8         DC  \
# Mixture
# CD4allrange_NR_1000000_insilmix1  2.125096   3.652364  17.371882   4.150787
# CD4allrange_NR_1000000_insilmix2  8.466055  28.994228   1.305132   4.240528
# CD4allrange_NR_1000000_insilmix3  7.306791  13.036470   9.752954   3.163723
# CD4allrange_NR_1000000_insilmix4  5.081503   8.321133  13.542942   9.127465
# CD4allrange_NR_1000000_insilmix5  9.166718  11.053749   9.091109  12.889172
#
#                                          Eo        Tr         m4         Mg  \
# Mixture
# CD4allrange_NR_1000000_insilmix1   3.904976  6.341485  14.306244  10.983494
# CD4allrange_NR_1000000_insilmix2   9.992709  0.685469   5.727678  11.272038
# CD4allrange_NR_1000000_insilmix3  11.701545  2.309071   3.907681   1.537214
# CD4allrange_NR_1000000_insilmix4   4.780691  9.983499  19.703788   3.882455
# CD4allrange_NR_1000000_insilmix5   1.183944  6.149850   1.665803  16.875359
#
#                                          Er        mB
# Mixture
# CD4allrange_NR_1000000_insilmix1   3.043937  9.918246
# CD4allrange_NR_1000000_insilmix2   8.458354  8.325141
# CD4allrange_NR_1000000_insilmix3  13.598139  0.909049
# CD4allrange_NR_1000000_insilmix4   0.196108  7.986019
# CD4allrange_NR_1000000_insilmix5   4.591560  8.869982

# %%
#mixturegtdf=mixturegtdf/100
mixturegtdf.head()
# Out:
#                                   CD4_real        CD8         nB         NK  \
# Mixture
# CD4allrange_NR_1000000_insilmix1    0.0010  15.130581   6.549795   2.520113
# CD4allrange_NR_1000000_insilmix2    0.0010   7.889197   0.139814   4.502655
# CD4allrange_NR_1000000_insilmix3    0.0010  11.134076  11.332065  10.310223
# CD4allrange_NR_1000000_insilmix4    0.0015   0.563823  15.085903   1.743170
# CD4allrange_NR_1000000_insilmix5    0.0015   4.321027  10.280554   3.859671
#
#                                         Mn       mNeu         m8         DC  \
# Mixture
# CD4allrange_NR_1000000_insilmix1  2.125096   3.652364  17.371882   4.150787
# CD4allrange_NR_1000000_insilmix2  8.466055  28.994228   1.305132   4.240528
# CD4allrange_NR_1000000_insilmix3  7.306791  13.036470   9.752954   3.163723
# CD4allrange_NR_1000000_insilmix4  5.081503   8.321133  13.542942   9.127465
# CD4allrange_NR_1000000_insilmix5  9.166718  11.053749   9.091109  12.889172
#
#                                          Eo        Tr         m4         Mg  \
# Mixture
# CD4allrange_NR_1000000_insilmix1   3.904976  6.341485  14.306244  10.983494
# CD4allrange_NR_1000000_insilmix2   9.992709  0.685469   5.727678  11.272038
# CD4allrange_NR_1000000_insilmix3  11.701545  2.309071   3.907681   1.537214
# CD4allrange_NR_1000000_insilmix4   4.780691  9.983499  19.703788   3.882455
# CD4allrange_NR_1000000_insilmix5   1.183944  6.149850   1.665803  16.875359
#
#                                          Er        mB
# Mixture
# CD4allrange_NR_1000000_insilmix1   3.043937  9.918246
# CD4allrange_NR_1000000_insilmix2   8.458354  8.325141
# CD4allrange_NR_1000000_insilmix3  13.598139  0.909049
# CD4allrange_NR_1000000_insilmix4   0.196108  7.986019
# CD4allrange_NR_1000000_insilmix5   4.591560  8.869982

# %%
allct=mixturegtdf.columns.tolist()
allct.remove(celltype+"_real")
allct
# Out:
# ['CD8',
#  'nB',
#  'NK',
#  'Mn',
#  'mNeu',
#  'm8',
#  'DC',
#  'Eo',
#  'Tr',
#  'm4',
#  'Mg',
#  'Er',
#  'mB']

# %%
DMRdfct=DMRdf[allct]
DMRdfct.head()
# Out:
#                               CD8        nB        NK        Mn      mNeu  \
# chrom start    end
# chr1  32387133 32387499  0.886636  0.971727  0.949818  0.987697  0.928364
# chr10 5754070  5754515   0.745462  0.968974  0.941256  0.982282  0.952231
# chr11 64490608 64490797  0.567433  0.777767  0.731033  0.882000  0.819467
# chr12 3905651  3906251   0.680625  0.966458  0.924917  0.969500  0.939083
# chr14 77029428 77029733  0.554576  0.837364  0.837758  0.932970  0.883879
#
#                                m8        DC        Eo        Tr        m4  \
# chrom start    end
# chr1  32387133 32387499  0.943273  0.980515  0.937364  0.854545  0.805227
# chr10 5754070  5754515   0.741769  0.967487  0.918115  0.659808  0.644538
# chr11 64490608 64490797  0.546000  0.819600  0.793750  0.711150  0.508500
# chr12 3905651  3906251   0.731000  0.949583  0.495875  0.853187  0.646437
# chr14 77029428 77029733  0.818227  0.895879  0.757500  0.560182  0.594091
#
#                                Mg        Er        mB
# chrom start    end
# chr1  32387133 32387499  0.953818  0.961273  0.966788
# chr10 5754070  5754515   0.969654  0.969885  0.968359
# chr11 64490608 64490797  0.918450  0.861050  0.730833
# chr12 3905651  3906251   0.808812  0.810937  0.882833
# chr14 77029428 77029733  0.891682  0.879591  0.587848

# %%
DMRdfct=1-DMRdfct
DMRdfct.head()
# Out:
#                               CD8        nB        NK        Mn      mNeu  \
# chrom start    end
# chr1  32387133 32387499  0.113364  0.028273  0.050182  0.012303  0.071636
# chr10 5754070  5754515   0.254538  0.031026  0.058744  0.017718  0.047769
# chr11 64490608 64490797  0.432567  0.222233  0.268967  0.118000  0.180533
# chr12 3905651  3906251   0.319375  0.033542  0.075083  0.030500  0.060917
# chr14 77029428 77029733  0.445424  0.162636  0.162242  0.067030  0.116121
#
#                                m8        DC        Eo        Tr        m4  \
# chrom start    end
# chr1  32387133 32387499  0.056727  0.019485  0.062636  0.145455  0.194773
# chr10 5754070  5754515   0.258231  0.032513  0.081885  0.340192  0.355462
# chr11 64490608 64490797  0.454000  0.180400  0.206250  0.288850  0.491500
# chr12 3905651  3906251   0.269000  0.050417  0.504125  0.146813  0.353563
# chr14 77029428 77029733  0.181773  0.104121  0.242500  0.439818  0.405909
#
#                                Mg        Er        mB
# chrom start    end
# chr1  32387133 32387499  0.046182  0.038727  0.033212
# chr10 5754070  5754515   0.030346  0.030115  0.031641
# chr11 64490608 64490797  0.081550  0.138950  0.269167
# chr12 3905651  3906251   0.191188  0.189063  0.117167
# chr14 77029428 77029733  0.108318  0.120409  0.412152

# %%
print(DMRdfct.shape)
print(mixturegtdf.shape)
mixturegtdfT=mixturegtdf.transpose(copy=True)
mixturegtdfT=mixturegtdfT.rename(index={celltype+"_real":celltype})
mixturegtdfT.head()
# Out:
# (21, 13)
# (60, 14)
# Mixture  CD4allrange_NR_1000000_insilmix1  CD4allrange_NR_1000000_insilmix2  \
# CD4                              0.001000                          0.001000
# CD8                             15.130581                          7.889197
# nB                               6.549795                          0.139814
# NK                               2.520113                          4.502655
# Mn                               2.125096                          8.466055
#
# Mixture  CD4allrange_NR_1000000_insilmix3  CD4allrange_NR_1000000_insilmix4  \
# CD4                              0.001000                          0.001500
# CD8                             11.134076                          0.563823
# nB                              11.332065                         15.085903
# NK                              10.310223                          1.743170
# Mn                               7.306791                          5.081503
#
# Mixture  CD4allrange_NR_1000000_insilmix5  CD4allrange_NR_1000000_insilmix6  \
# CD4                              0.001500                          0.001500
# CD8                              4.321027                         10.330939
# nB                              10.280554                          1.902784
# NK                               3.859671                          2.027602
# Mn                               9.166718                         10.571175
#
# Mixture  CD4allrange_NR_1000000_insilmix7  CD4allrange_NR_1000000_insilmix8  \
# CD4                              0.002500                          0.002500
# CD8                             14.482959                          2.969129
# nB                               6.652268                          8.086823
# NK                               3.657562                          8.331542
# Mn                               4.068936                          1.534118
#
# Mixture  CD4allrange_NR_1000000_insilmix9  CD4allrange_NR_1000000_insilmix10  \
# CD4                              0.002500                           0.004300
# CD8                              2.115642                           8.869877
# nB                               7.497602                           8.489052
# NK                              11.108044                           3.870452
# Mn                               1.874326                           8.350543
#
# Mixture  ...  CD4allrange_NR_1000000_insilmix51  \
# CD4      ...                           5.499911
# CD8      ...                           7.176114
# nB       ...                           3.767208
# NK       ...                           1.017102
# Mn       ...                           7.110714
#
# Mixture  CD4allrange_NR_1000000_insilmix52  CD4allrange_NR_1000000_insilmix53  \
# CD4                              10.001540                          10.001180
# CD8                               8.396085                           6.676087
# nB                               10.251249                          13.416773
# NK                                6.283314                           0.247700
# Mn                                0.978033                           7.006886
#
# Mixture  CD4allrange_NR_1000000_insilmix54  CD4allrange_NR_1000000_insilmix55  \
# CD4                              10.001590                          10.000690
# CD8                               0.401616                           1.984799
# nB                               13.672933                          11.150831
# NK                                7.858406                           2.748960
# Mn                                0.313312                           1.054446
#
# Mixture  CD4allrange_NR_1000000_insilmix56  CD4allrange_NR_1000000_insilmix57  \
# CD4                              10.001740                          10.002060
# CD8                               0.151508                           5.320858
# nB                                7.700816                           0.321328
# NK                               11.111000                           7.874577
# Mn                               12.159857                           9.900851
#
# Mixture  CD4allrange_NR_1000000_insilmix58  CD4allrange_NR_1000000_insilmix59  \
# CD4                              30.000790                          30.001840
# CD8                               1.816478                           1.013579
# nB                               10.293143                           0.320725
# NK                                1.845879                           3.955309
# Mn                                5.047417                           9.133212
#
# Mixture  CD4allrange_NR_1000000_insilmix60
# CD4                              30.003070
# CD8                               0.570268
# nB                                5.069703
# NK                                1.343460
# Mn                                1.985036
#
# [5 rows x 60 columns]

# %%
mixturegtdfTForTPR=mixturegtdfT.loc[celltype,:]

# %%
mixturegtdfTForFPR=mixturegtdfT.drop([celltype])

# %%
DMRwiseFPR=DMRdfct.dot(mixturegtdfTForFPR)
DMRwiseFPR.head()
# Out:
# Mixture                  CD4allrange_NR_1000000_insilmix1  \
# chrom start    end
# chr1  32387133 32387499                          8.289011
# chr10 5754070  5754515                          17.336799
# chr11 64490608 64490797                         31.881144
# chr12 3905651  3906251                          22.206095
# chr14 77029428 77029733                         27.557255
#
# Mixture                  CD4allrange_NR_1000000_insilmix2  \
# chrom start    end
# chr1  32387133 32387499                          6.427949
# chr10 5754070  5754515                           8.234489
# chr11 64490608 64490797                         21.655201
# chr12 3905651  3906251                          17.344658
# chr14 77029428 77029733                         19.600673
#
# Mixture                  CD4allrange_NR_1000000_insilmix3  \
# chrom start    end
# chr1  32387133 32387499                          6.196376
# chr10 5754070  5754515                          10.782532
# chr11 64490608 64490797                         25.582545
# chr12 3905651  3906251                          19.101168
# chr14 77029428 77029733                         20.198841
#
# Mixture                  CD4allrange_NR_1000000_insilmix4  \
# chrom start    end
# chr1  32387133 32387499                          8.224104
# chr10 5754070  5754515                          16.163579
# chr11 64490608 64490797                         30.009882
# chr12 3905651  3906251                          18.139407
# chr14 77029428 77029733                         24.990240
#
# Mixture                  CD4allrange_NR_1000000_insilmix5  \
# chrom start    end
# chr1  32387133 32387499                          5.190557
# chr10 5754070  5754515                           8.814913
# chr11 64490608 64490797                         21.962751
# chr12 3905651  3906251                          13.285344
# chr14 77029428 77029733                         18.820097
#
# Mixture                  CD4allrange_NR_1000000_insilmix6  \
# chrom start    end
# chr1  32387133 32387499                          7.394810
# chr10 5754070  5754515                          13.239342
# chr11 64490608 64490797                         25.311490
# chr12 3905651  3906251                          18.966513
# chr14 77029428 77029733                         24.119225
#
# Mixture                  CD4allrange_NR_1000000_insilmix7  \
# chrom start    end
# chr1  32387133 32387499                          8.386961
# chr10 5754070  5754515                          16.962413
# chr11 64490608 64490797                         29.318945
# chr12 3905651  3906251                          21.158344
# chr14 77029428 77029733                         27.361947
#
# Mixture                  CD4allrange_NR_1000000_insilmix8  \
# chrom start    end
# chr1  32387133 32387499                          6.854615
# chr10 5754070  5754515                          11.352383
# chr11 64490608 64490797                         24.985937
# chr12 3905651  3906251                          18.399236
# chr14 77029428 77029733                         22.173316
#
# Mixture                  CD4allrange_NR_1000000_insilmix9  \
# chrom start    end
# chr1  32387133 32387499                          6.216102
# chr10 5754070  5754515                          10.914094
# chr11 64490608 64490797                         24.367233
# chr12 3905651  3906251                          18.099315
# chr14 77029428 77029733                         20.479741
#
# Mixture                  CD4allrange_NR_1000000_insilmix10  ...  \
# chrom start    end                                          ...
# chr1  32387133 32387499                           6.752824  ...
# chr10 5754070  5754515                           12.850722  ...
# chr11 64490608 64490797                          26.577188  ...
# chr12 3905651  3906251                           19.951366  ...
# chr14 77029428 77029733                          23.939151  ...
#
# Mixture                  CD4allrange_NR_1000000_insilmix51  \
# chrom start    end
# chr1  32387133 32387499                           6.698367
# chr10 5754070  5754515                           12.047949
# chr11 64490608 64490797                          24.713121
# chr12 3905651  3906251                           19.913767
# chr14 77029428 77029733                          22.281080
#
# Mixture                  CD4allrange_NR_1000000_insilmix52  \
# chrom start    end
# chr1  32387133 32387499                           7.167412
# chr10 5754070  5754515                           13.559815
# chr11 64490608 64490797                          25.865696
# chr12 3905651  3906251                           17.955795
# chr14 77029428 77029733                          24.430543
#
# Mixture                  CD4allrange_NR_1000000_insilmix53  \
# chrom start    end
# chr1  32387133 32387499                           5.087664
# chr10 5754070  5754515                            7.002263
# chr11 64490608 64490797                          19.153647
# chr12 3905651  3906251                           13.324925
# chr14 77029428 77029733                          17.388956
#
# Mixture                  CD4allrange_NR_1000000_insilmix54  \
# chrom start    end
# chr1  32387133 32387499                           4.369233
# chr10 5754070  5754515                            6.845860
# chr11 64490608 64490797                          21.318292
# chr12 3905651  3906251                           14.102270
# chr14 77029428 77029733                          17.614733
#
# Mixture                  CD4allrange_NR_1000000_insilmix55  \
# chrom start    end
# chr1  32387133 32387499                           5.362535
# chr10 5754070  5754515                           10.684429
# chr11 64490608 64490797                          21.895112
# chr12 3905651  3906251                           15.244667
# chr14 77029428 77029733                          20.943049
#
# Mixture                  CD4allrange_NR_1000000_insilmix56  \
# chrom start    end
# chr1  32387133 32387499                           4.396650
# chr10 5754070  5754515                            7.775458
# chr11 64490608 64490797                          20.606800
# chr12 3905651  3906251                           12.094007
# chr14 77029428 77029733                          16.984582
#
# Mixture                  CD4allrange_NR_1000000_insilmix57  \
# chrom start    end
# chr1  32387133 32387499                           5.927953
# chr10 5754070  5754515                            8.955314
# chr11 64490608 64490797                          21.228216
# chr12 3905651  3906251                           18.153488
# chr14 77029428 77029733                          19.361440
#
# Mixture                  CD4allrange_NR_1000000_insilmix58  \
# chrom start    end
# chr1  32387133 32387499                           4.373884
# chr10 5754070  5754515                            7.759870
# chr11 64490608 64490797                          17.942692
# chr12 3905651  3906251                           11.677313
# chr14 77029428 77029733                          16.139478
#
# Mixture                  CD4allrange_NR_1000000_insilmix59  \
# chrom start    end
# chr1  32387133 32387499                           5.078580
# chr10 5754070  5754515                            8.178290
# chr11 64490608 64490797                          15.725180
# chr12 3905651  3906251                           13.436249
# chr14 77029428 77029733                          15.888029
#
# Mixture                  CD4allrange_NR_1000000_insilmix60
# chrom start    end
# chr1  32387133 32387499                           4.385112
# chr10 5754070  5754515                            8.774542
# chr11 64490608 64490797                          17.464143
# chr12 3905651  3906251                           11.183863
# chr14 77029428 77029733                          15.195038
#
# [5 rows x 60 columns]

# %%
DMRdfforTPR=1-DMRdf[celltype].to_frame()
DMRdfforTPR.head()
# Out:
#                              CD4
# chrom start    end
# chr1  32387133 32387499  0.64739
# chr10 5754070  5754515   0.69313
# chr11 64490608 64490797  0.80847
# chr12 3905651  3906251   0.82121
# chr14 77029428 77029733  0.81197

# %%
mixturegtdfforTPR=(mixturegtdf[celltype+"_real"].to_frame())
mixturegtdfforTPR=mixturegtdfforTPR.rename(columns={celltype+"_real":celltype})
mixturegtdfTforTPR=mixturegtdfforTPR.transpose(copy=True)
mixturegtdfTforTPR.shape
# Out:
# (1, 60)

# %%
mixturegtdfTforTPR
# Out:
# Mixture  CD4allrange_NR_1000000_insilmix1  CD4allrange_NR_1000000_insilmix2  \
# CD4                                 0.001                             0.001
#
# Mixture  CD4allrange_NR_1000000_insilmix3  CD4allrange_NR_1000000_insilmix4  \
# CD4                                 0.001                            0.0015
#
# Mixture  CD4allrange_NR_1000000_insilmix5  CD4allrange_NR_1000000_insilmix6  \
# CD4                                0.0015                            0.0015
#
# Mixture  CD4allrange_NR_1000000_insilmix7  CD4allrange_NR_1000000_insilmix8  \
# CD4                                0.0025                            0.0025
#
# Mixture  CD4allrange_NR_1000000_insilmix9  CD4allrange_NR_1000000_insilmix10  \
# CD4                                0.0025                             0.0043
#
# Mixture  ...  CD4allrange_NR_1000000_insilmix51  \
# CD4      ...                           5.499911
#
# Mixture  CD4allrange_NR_1000000_insilmix52  CD4allrange_NR_1000000_insilmix53  \
# CD4                               10.00154                           10.00118
#
# Mixture  CD4allrange_NR_1000000_insilmix54  CD4allrange_NR_1000000_insilmix55  \
# CD4                               10.00159                           10.00069
#
# Mixture  CD4allrange_NR_1000000_insilmix56  CD4allrange_NR_1000000_insilmix57  \
# CD4                               10.00174                           10.00206
#
# Mixture  CD4allrange_NR_1000000_insilmix58  CD4allrange_NR_1000000_insilmix59  \
# CD4                               30.00079                           30.00184
#
# Mixture  CD4allrange_NR_1000000_insilmix60
# CD4                               30.00307
#
# [1 rows x 60 columns]

# %%
DMRwiseTPR=DMRdfforTPR.dot(mixturegtdfTforTPR)
DMRwiseTPR.head()
# Out:
# Mixture                  CD4allrange_NR_1000000_insilmix1  \
# chrom start    end
# chr1  32387133 32387499                          0.000647
# chr10 5754070  5754515                           0.000693
# chr11 64490608 64490797                          0.000809
# chr12 3905651  3906251                           0.000821
# chr14 77029428 77029733                          0.000812
#
# Mixture                  CD4allrange_NR_1000000_insilmix2  \
# chrom start    end
# chr1  32387133 32387499                          0.000647
# chr10 5754070  5754515                           0.000693
# chr11 64490608 64490797                          0.000809
# chr12 3905651  3906251                           0.000821
# chr14 77029428 77029733                          0.000812
#
# Mixture                  CD4allrange_NR_1000000_insilmix3  \
# chrom start    end
# chr1  32387133 32387499                          0.000647
# chr10 5754070  5754515                           0.000693
# chr11 64490608 64490797                          0.000808
# chr12 3905651  3906251                           0.000821
# chr14 77029428 77029733                          0.000812
#
# Mixture                  CD4allrange_NR_1000000_insilmix4  \
# chrom start    end
# chr1  32387133 32387499                          0.000971
# chr10 5754070  5754515                           0.001040
# chr11 64490608 64490797                          0.001213
# chr12 3905651  3906251                           0.001232
# chr14 77029428 77029733                          0.001218
#
# Mixture                  CD4allrange_NR_1000000_insilmix5  \
# chrom start    end
# chr1  32387133 32387499                          0.000971
# chr10 5754070  5754515                           0.001040
# chr11 64490608 64490797                          0.001213
# chr12 3905651  3906251                           0.001232
# chr14 77029428 77029733                          0.001218
#
# Mixture                  CD4allrange_NR_1000000_insilmix6  \
# chrom start    end
# chr1  32387133 32387499                          0.000971
# chr10 5754070  5754515                           0.001040
# chr11 64490608 64490797                          0.001213
# chr12 3905651  3906251                           0.001232
# chr14 77029428 77029733                          0.001218
#
# Mixture                  CD4allrange_NR_1000000_insilmix7  \
# chrom start    end
# chr1  32387133 32387499                          0.001618
# chr10 5754070  5754515                           0.001733
# chr11 64490608 64490797                          0.002021
# chr12 3905651  3906251                           0.002053
# chr14 77029428 77029733                          0.002030
#
# Mixture                  CD4allrange_NR_1000000_insilmix8  \
# chrom start    end
# chr1  32387133 32387499                          0.001619
# chr10 5754070  5754515                           0.001733
# chr11 64490608 64490797                          0.002021
# chr12 3905651  3906251                           0.002053
# chr14 77029428 77029733                          0.002030
#
# Mixture                  CD4allrange_NR_1000000_insilmix9  \
# chrom start    end
# chr1  32387133 32387499                          0.001619
# chr10 5754070  5754515                           0.001733
# chr11 64490608 64490797                          0.002021
# chr12 3905651  3906251                           0.002053
# chr14 77029428 77029733                          0.002030
#
# Mixture                  CD4allrange_NR_1000000_insilmix10  ...  \
# chrom start    end                                          ...
# chr1  32387133 32387499                           0.002784  ...
# chr10 5754070  5754515                            0.002981  ...
# chr11 64490608 64490797                           0.003477  ...
# chr12 3905651  3906251                            0.003531  ...
# chr14 77029428 77029733                           0.003492  ...
#
# Mixture                  CD4allrange_NR_1000000_insilmix51  \
# chrom start    end
# chr1  32387133 32387499                           3.560587
# chr10 5754070  5754515                            3.812153
# chr11 64490608 64490797                           4.446513
# chr12 3905651  3906251                            4.516582
# chr14 77029428 77029733                           4.465763
#
# Mixture                  CD4allrange_NR_1000000_insilmix52  \
# chrom start    end
# chr1  32387133 32387499                           6.474897
# chr10 5754070  5754515                            6.932367
# chr11 64490608 64490797                           8.085945
# chr12 3905651  3906251                            8.213365
# chr14 77029428 77029733                           8.120950
#
# Mixture                  CD4allrange_NR_1000000_insilmix53  \
# chrom start    end
# chr1  32387133 32387499                           6.474664
# chr10 5754070  5754515                            6.932118
# chr11 64490608 64490797                           8.085654
# chr12 3905651  3906251                            8.213069
# chr14 77029428 77029733                           8.120658
#
# Mixture                  CD4allrange_NR_1000000_insilmix54  \
# chrom start    end
# chr1  32387133 32387499                           6.474929
# chr10 5754070  5754515                            6.932402
# chr11 64490608 64490797                           8.085986
# chr12 3905651  3906251                            8.213406
# chr14 77029428 77029733                           8.120991
#
# Mixture                  CD4allrange_NR_1000000_insilmix55  \
# chrom start    end
# chr1  32387133 32387499                           6.474347
# chr10 5754070  5754515                            6.931778
# chr11 64490608 64490797                           8.085258
# chr12 3905651  3906251                            8.212667
# chr14 77029428 77029733                           8.120260
#
# Mixture                  CD4allrange_NR_1000000_insilmix56  \
# chrom start    end
# chr1  32387133 32387499                           6.475027
# chr10 5754070  5754515                            6.932506
# chr11 64490608 64490797                           8.086107
# chr12 3905651  3906251                            8.213529
# chr14 77029428 77029733                           8.121113
#
# Mixture                  CD4allrange_NR_1000000_insilmix57  \
# chrom start    end
# chr1  32387133 32387499                           6.475234
# chr10 5754070  5754515                            6.932728
# chr11 64490608 64490797                           8.086366
# chr12 3905651  3906251                            8.213792
# chr14 77029428 77029733                           8.121373
#
# Mixture                  CD4allrange_NR_1000000_insilmix58  \
# chrom start    end
# chr1  32387133 32387499                          19.422211
# chr10 5754070  5754515                           20.794448
# chr11 64490608 64490797                          24.254739
# chr12 3905651  3906251                           24.636949
# chr14 77029428 77029733                          24.359741
#
# Mixture                  CD4allrange_NR_1000000_insilmix59  \
# chrom start    end
# chr1  32387133 32387499                          19.422891
# chr10 5754070  5754515                           20.795175
# chr11 64490608 64490797                          24.255588
# chr12 3905651  3906251                           24.637811
# chr14 77029428 77029733                          24.360594
#
# Mixture                  CD4allrange_NR_1000000_insilmix60
# chrom start    end
# chr1  32387133 32387499                          19.423688
# chr10 5754070  5754515                           20.796028
# chr11 64490608 64490797                          24.256582
# chr12 3905651  3906251                           24.638821
# chr14 77029428 77029733                          24.361593
#
# [5 rows x 60 columns]

# %%
DMRwiseTPRavg=DMRwiseTPR.mean(axis=1) ############

# %%
mixturegtTN=100-mixturegtdf[celltype+"_real"].to_frame()
mixturegtTN.rename(columns={celltype+"_real":'TN'},inplace=True)
mixturegtTN=mixturegtTN.transpose()
mixturegtTN.head()
# Out:
# Mixture  CD4allrange_NR_1000000_insilmix1  CD4allrange_NR_1000000_insilmix2  \
# TN                                 99.999                            99.999
#
# Mixture  CD4allrange_NR_1000000_insilmix3  CD4allrange_NR_1000000_insilmix4  \
# TN                                 99.999                           99.9985
#
# Mixture  CD4allrange_NR_1000000_insilmix5  CD4allrange_NR_1000000_insilmix6  \
# TN                                99.9985                           99.9985
#
# Mixture  CD4allrange_NR_1000000_insilmix7  CD4allrange_NR_1000000_insilmix8  \
# TN                                99.9975                           99.9975
#
# Mixture  CD4allrange_NR_1000000_insilmix9  CD4allrange_NR_1000000_insilmix10  \
# TN                                99.9975                            99.9957
#
# Mixture  ...  CD4allrange_NR_1000000_insilmix51  \
# TN       ...                          94.500089
#
# Mixture  CD4allrange_NR_1000000_insilmix52  CD4allrange_NR_1000000_insilmix53  \
# TN                                89.99846                           89.99882
#
# Mixture  CD4allrange_NR_1000000_insilmix54  CD4allrange_NR_1000000_insilmix55  \
# TN                                89.99841                           89.99931
#
# Mixture  CD4allrange_NR_1000000_insilmix56  CD4allrange_NR_1000000_insilmix57  \
# TN                                89.99826                           89.99794
#
# Mixture  CD4allrange_NR_1000000_insilmix58  CD4allrange_NR_1000000_insilmix59  \
# TN                                69.99921                           69.99816
#
# Mixture  CD4allrange_NR_1000000_insilmix60
# TN                                69.99693
#
# [1 rows x 60 columns]

# %%
DMRwiseFPRavg=DMRwiseFPR/mixturegtTN.loc['TN']
DMRwiseFPRavg=DMRwiseFPRavg.mean(axis=1)
DMRwiseFPRavg
# Out:
# chrom  start      end
# chr1   32387133   32387499     0.066965
# chr10  5754070    5754515      0.119813
# chr11  64490608   64490797     0.255852
# chr12  3905651    3906251      0.183297
# chr14  77029428   77029733     0.229002
#        90385110   90385156     0.170937
#        98229364   98229588     0.143528
# chr15  101698062  101698225    0.053857
# chr16  50550239   50550307     0.131756
# chr17  2280325    2280388      0.085547
#        42306042   42306424     0.128548
#        82120430   82120503     0.178453
# chr19  9857310    9857442      0.078183
# chr2   15162551   15162685     0.116220
#        84907808   84907879     0.086418
#        197839405  197839610    0.130698
# chr22  19884272   19884493     0.062825
# chr3   125002174  125002672    0.164729
# chr6   33630045   33630328     0.141749
# chr8   23221861   23222002     0.158036
#        66026537   66026883     0.115924
# dtype: float64

# %%
def plt_corr(x, y,combined):
    fig = plt.figure()
    lm = sns.lmplot(x=x, y=y, data=combined)
    ax = lm.axes[0, 0]
    p_corr = np.around(corrdf_pearson[x][y], decimals=3)
    s_corr = np.around(corrdf_spearman[x][y], decimals=3)
    p_val_pearson = np.around(pearsonr(combined[x], combined[y])[1], decimals=8)
    p_val_spearman = np.around(spearmanr(combined[x], combined[y])[1], decimals=8)
    txt = 'r = ' + str(p_corr) + ', p-val = ' + str(p_val_pearson) + '\nrho = ' + str(s_corr) + ', p-val = ' + str(p_val_spearman)
    ax.text(np.array(combined[x].sort_values())[0], np.array(combined[y].sort_values())[-2], txt, horizontalalignment='left', verticalalignment='bottom')
    return lm

# %%
RDstats='mincpg1_feature_significance_Allfile_DMRwise_avg.txt_stats.txt'

RDstatsdf=pd.read_csv(RDstats,sep="\t",index_col=['chrom','start','end'])
RDstatsdf.head()
# Out:
#                          #TP_fragment  #FP_fragment  #TN_fragment  \
# chrom start    end
# chr1  32387133 32387499      0.822727      2.109091    123.093939
# chr10 5754070  5754515       1.392308      5.670513    131.166667
# chr11 64490608 64490797      4.360000     51.411667    282.495000
# chr12 3905651  3906251       3.587500     30.597917    182.606250
# chr14 77029428 77029733      2.050000     23.165152    201.709091
#
#                          #FN_fragment  #Total_Fragment       TPR       FPR  \
# chrom start    end
# chr1  32387133 32387499      1.772727       127.798485  0.624073  0.013452
# chr10 5754070  5754515       1.261538       139.491026  0.344499  0.042307
# chr11 64490608 64490797      3.370000       341.636667  0.427657  0.153829
# chr12 3905651  3906251       1.950000       218.741667  0.568029  0.125205
# chr14 77029428 77029733      1.345455       228.269697  0.399051  0.108957
#
#                               FDR             q      diff  ...    CD4-m4  \
# chrom start    end                                         ...
# chr1  32387133 32387499  0.851987  1.785900e-12 -0.584534  ... -0.452617
# chr10 5754070  5754515   0.885537  1.133300e-13 -0.583604  ... -0.337668
# chr11 64490608 64490797  0.937214  3.732800e-10 -0.555806  ... -0.316970
# chr12 3905651  3906251   0.882720  2.642700e-10 -0.658527  ... -0.467648
# chr14 77029428 77029733  0.935254  1.273400e-14 -0.587526  ... -0.406061
#
#                            CD4-Mg    CD4-Er    CD4-mB  \
# chrom start    end
# chr1  32387133 32387499 -0.601208 -0.608663 -0.614178
# chr10 5754070  5754515  -0.662784 -0.663015 -0.661489
# chr11 64490608 64490797 -0.726920 -0.669520 -0.539303
# chr12 3905651  3906251  -0.630022 -0.632148 -0.704043
# chr14 77029428 77029733 -0.703652 -0.691561 -0.399818
#
#                          maxCompartmentwisedelta  minCompartmentwiseDelta  \
# chrom start    end
# chr1  32387133 32387499                -0.452617                -0.635087
# chr10 5754070  5754515                 -0.337668                -0.675412
# chr11 64490608 64490797                -0.316970                -0.726920
# chr12 3905651  3906251                 -0.317085                -0.790710
# chr14 77029428 77029733                -0.366546                -0.744940
#
#                          DMRlength  #cpg/DMRlength  DMRlength/#Total_Fragment  \
# chrom start    end
# chr1  32387133 32387499        366        0.030055                   2.863884
# chr10 5754070  5754515         445        0.029213                   3.190169
# chr11 64490608 64490797        189        0.052910                   0.553219
# chr12 3905651  3906251         600        0.013333                   2.742962
# chr14 77029428 77029733        305        0.036066                   1.336139
#
#                          #Total_Fragment/DMRlength
# chrom start    end
# chr1  32387133 32387499                   0.349176
# chr10 5754070  5754515                    0.313463
# chr11 64490608 64490797                   1.807601
# chr12 3905651  3906251                    0.364569
# chr14 77029428 77029733                   0.748425
#
# [5 rows x 49 columns]

# %%
RDstatsdf=RDstatsdf.merge(DMRwiseFPRavg.rename('SMestimatedFPR'),on=['chrom','start','end'])
RDstatsdf.head()
# Out:
#                          #TP_fragment  #FP_fragment  #TN_fragment  \
# chrom start    end
# chr1  32387133 32387499      0.822727      2.109091    123.093939
# chr10 5754070  5754515       1.392308      5.670513    131.166667
# chr11 64490608 64490797      4.360000     51.411667    282.495000
# chr12 3905651  3906251       3.587500     30.597917    182.606250
# chr14 77029428 77029733      2.050000     23.165152    201.709091
#
#                          #FN_fragment  #Total_Fragment       TPR       FPR  \
# chrom start    end
# chr1  32387133 32387499      1.772727       127.798485  0.624073  0.013452
# chr10 5754070  5754515       1.261538       139.491026  0.344499  0.042307
# chr11 64490608 64490797      3.370000       341.636667  0.427657  0.153829
# chr12 3905651  3906251       1.950000       218.741667  0.568029  0.125205
# chr14 77029428 77029733      1.345455       228.269697  0.399051  0.108957
#
#                               FDR             q      diff  ...    CD4-Mg  \
# chrom start    end                                         ...
# chr1  32387133 32387499  0.851987  1.785900e-12 -0.584534  ... -0.601208
# chr10 5754070  5754515   0.885537  1.133300e-13 -0.583604  ... -0.662784
# chr11 64490608 64490797  0.937214  3.732800e-10 -0.555806  ... -0.726920
# chr12 3905651  3906251   0.882720  2.642700e-10 -0.658527  ... -0.630022
# chr14 77029428 77029733  0.935254  1.273400e-14 -0.587526  ... -0.703652
#
#                            CD4-Er    CD4-mB  maxCompartmentwisedelta  \
# chrom start    end
# chr1  32387133 32387499 -0.608663 -0.614178                -0.452617
# chr10 5754070  5754515  -0.663015 -0.661489                -0.337668
# chr11 64490608 64490797 -0.669520 -0.539303                -0.316970
# chr12 3905651  3906251  -0.632148 -0.704043                -0.317085
# chr14 77029428 77029733 -0.691561 -0.399818                -0.366546
#
#                          minCompartmentwiseDelta  DMRlength  #cpg/DMRlength  \
# chrom start    end
# chr1  32387133 32387499                -0.635087        366        0.030055
# chr10 5754070  5754515                 -0.675412        445        0.029213
# chr11 64490608 64490797                -0.726920        189        0.052910
# chr12 3905651  3906251                 -0.790710        600        0.013333
# chr14 77029428 77029733                -0.744940        305        0.036066
#
#                          DMRlength/#Total_Fragment  #Total_Fragment/DMRlength  \
# chrom start    end
# chr1  32387133 32387499                   2.863884                   0.349176
# chr10 5754070  5754515                    3.190169                   0.313463
# chr11 64490608 64490797                   0.553219                   1.807601
# chr12 3905651  3906251                    2.742962                   0.364569
# chr14 77029428 77029733                   1.336139                   0.748425
#
#                          SMestimatedFPR
# chrom start    end
# chr1  32387133 32387499        0.066965
# chr10 5754070  5754515         0.119813
# chr11 64490608 64490797        0.255852
# chr12 3905651  3906251         0.183297
# chr14 77029428 77029733        0.229002
#
# [5 rows x 50 columns]

# %%
RDstatsdf.plot.scatter(x='FPR',y='SMestimatedFPR')

# %%
RDstatsdf=RDstatsdf.merge(DMRdfforTPR,on=['chrom','start','end'])
RDstatsdf.head()
# Out:
#                          #TP_fragment  #FP_fragment  #TN_fragment  \
# chrom start    end
# chr1  32387133 32387499      0.822727      2.109091    123.093939
# chr10 5754070  5754515       1.392308      5.670513    131.166667
# chr11 64490608 64490797      4.360000     51.411667    282.495000
# chr12 3905651  3906251       3.587500     30.597917    182.606250
# chr14 77029428 77029733      2.050000     23.165152    201.709091
#
#                          #FN_fragment  #Total_Fragment       TPR       FPR  \
# chrom start    end
# chr1  32387133 32387499      1.772727       127.798485  0.624073  0.013452
# chr10 5754070  5754515       1.261538       139.491026  0.344499  0.042307
# chr11 64490608 64490797      3.370000       341.636667  0.427657  0.153829
# chr12 3905651  3906251       1.950000       218.741667  0.568029  0.125205
# chr14 77029428 77029733      1.345455       228.269697  0.399051  0.108957
#
#                               FDR             q      diff  ...    CD4-Er  \
# chrom start    end                                         ...
# chr1  32387133 32387499  0.851987  1.785900e-12 -0.584534  ... -0.608663
# chr10 5754070  5754515   0.885537  1.133300e-13 -0.583604  ... -0.663015
# chr11 64490608 64490797  0.937214  3.732800e-10 -0.555806  ... -0.669520
# chr12 3905651  3906251   0.882720  2.642700e-10 -0.658527  ... -0.632148
# chr14 77029428 77029733  0.935254  1.273400e-14 -0.587526  ... -0.691561
#
#                            CD4-mB  maxCompartmentwisedelta  \
# chrom start    end
# chr1  32387133 32387499 -0.614178                -0.452617
# chr10 5754070  5754515  -0.661489                -0.337668
# chr11 64490608 64490797 -0.539303                -0.316970
# chr12 3905651  3906251  -0.704043                -0.317085
# chr14 77029428 77029733 -0.399818                -0.366546
#
#                          minCompartmentwiseDelta  DMRlength  #cpg/DMRlength  \
# chrom start    end
# chr1  32387133 32387499                -0.635087        366        0.030055
# chr10 5754070  5754515                 -0.675412        445        0.029213
# chr11 64490608 64490797                -0.726920        189        0.052910
# chr12 3905651  3906251                 -0.790710        600        0.013333
# chr14 77029428 77029733                -0.744940        305        0.036066
#
#                          DMRlength/#Total_Fragment  #Total_Fragment/DMRlength  \
# chrom start    end
# chr1  32387133 32387499                   2.863884                   0.349176
# chr10 5754070  5754515                    3.190169                   0.313463
# chr11 64490608 64490797                   0.553219                   1.807601
# chr12 3905651  3906251                    2.742962                   0.364569
# chr14 77029428 77029733                   1.336139                   0.748425
#
#                          SMestimatedFPR    CD4_y
# chrom start    end
# chr1  32387133 32387499        0.066965  0.64739
# chr10 5754070  5754515         0.119813  0.69313
# chr11 64490608 64490797        0.255852  0.80847
# chr12 3905651  3906251         0.183297  0.82121
# chr14 77029428 77029733        0.229002  0.81197
#
# [5 rows x 51 columns]

# %%
RDstatsdf.plot.scatter(x='SMestimatedFPR',y='CD4_y')

# %%
RDstatsdf.plot.scatter(x='FPR',y='CD4_y')

# %%
RDstatsdf.plot.scatter(x='FPR',y='TPR')

# %%
# sns.scatterplot(combined['FDR'], combined['FPR'])
corrdf_pearson=RDstatsdf.corr(method='pearson')
corrdf_spearman=RDstatsdf.corr(method='spearman')

# %%
x = 'FPR'
y = 'SMestimatedFPR'
fig = plt_corr(x, y,RDstatsdf)

# %%
x = 'others'
y = 'FPR'
fig = plt_corr(x, y,RDstatsdf)

# %%
x = 'TPR'
y = 'CD4_y'
fig = plt_corr(x, y,RDstatsdf)

# %%
RDstatsdf.boxplot(column=['TPR', 'CD4_y'])

# %%
x = 'TPR'
y = 'CD4-nB'
fig = plt_corr(x, y,RDstatsdf)

# %%
RDstatsdf.plot.scatter(x='FPR',y='TPR')

# %%
forColorcodeRDstatsdf=(RDstatsdf.sort_values('TPR')).reset_index()

forColorcodeRDstatsdf.index.name ='IndexName'
forColorcodeRDstatsdf['DMRindex']=forColorcodeRDstatsdf.index
forColorcodeRDstatsdf.head()
# Out:
#            chrom      start        end  #TP_fragment  #FP_fragment  \
# IndexName
# 0          chr15  101698062  101698225      0.600000      1.566667
# 1          chr22   19884272   19884493      3.105556      8.535185
# 2           chr2  197839405  197839610      1.910000     17.156667
# 3           chr2   84907808   84907879      1.166667      2.375000
# 4          chr19    9857310    9857442      1.833333      6.588889
#
#            #TN_fragment  #FN_fragment  #Total_Fragment       TPR       FPR  \
# IndexName
# 0            141.197619      2.628571       145.992857  0.088372  0.010444
# 1            382.233333      4.427778       398.301852  0.180925  0.021954
# 2            142.050000      1.220000       162.336667  0.200131  0.100744
# 3             73.638889      2.116667        79.297222  0.218939  0.030416
# 4            269.681481      3.833333       281.937037  0.256398  0.023249
#
#            ...    CD4-mB  maxCompartmentwisedelta  minCompartmentwiseDelta  \
# IndexName  ...
# 0          ... -0.403639                -0.302163                -0.423258
# 1          ... -0.506144                -0.333237                -0.512329
# 2          ... -0.482663                -0.450430                -0.690330
# 3          ... -0.412777                -0.308943                -0.459193
# 4          ... -0.547440                -0.317181                -0.584921
#
#            DMRlength  #cpg/DMRlength  DMRlength/#Total_Fragment  \
# IndexName
# 0                163        0.042945                   1.116493
# 1                221        0.040724                   0.554856
# 2                205        0.024390                   1.262808
# 3                 71        0.084507                   0.895366
# 4                132        0.068182                   0.468190
#
#            #Total_Fragment/DMRlength  SMestimatedFPR    CD4_y  DMRindex
# IndexName
# 0                           0.895662        0.053857  0.43902         0
# 1                           1.802271        0.062825  0.53907         1
# 2                           0.791886        0.130698  0.72073         2
# 3                           1.116862        0.086418  0.49511         3
# 4                           2.135887        0.078183  0.60544         4
#
# [5 rows x 55 columns]

# %%
forColorcodeRDstatsdf.plot.scatter(x='FPR',y='TPR')

# %%
ax = sns.scatterplot(x='FPR',y='TPR', data=forColorcodeRDstatsdf, hue='TPR',palette="viridis", hue_norm=(0.0, 0.9))
ax.legend(loc=(1.03, 0.6))

# %%
ax = sns.scatterplot(x='SMestimatedFPR',y='TPR', data=forColorcodeRDstatsdf, hue='TPR',palette="viridis", hue_norm=(0.0, 0.9))
ax.legend(loc=(1.03, 0.6))

# %%
ax = sns.scatterplot(x='SMestimatedFPR',y='CD4_y', data=forColorcodeRDstatsdf, hue='TPR',palette="viridis", hue_norm=(0.0, 0.9))
ax.legend(loc=(1.03, 0.6))
