# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import pearsonr, spearmanr
import seaborn as sns
import matplotlib.pyplot as plt

DMRcpgfile='/Users/irffanalahi/Research/Research_update/SM/ShowcaseSM/BL17_14/BL14_feature_significance/mNeu/fromReftoPerfomance_singlecpgbased/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_intesectedwith_BL14mNeuDMRs_CW.7.txt'#'/Users/irffanalahi/Research/Research_update/SM/ShowcaseSM/BL17_14/BL14_feature_significance/CD4/fromReftoPerfomance/singleCpGbased/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_intesectedwith_CD4DMRofBL14atleast.2SM.txt'
RDstatfile='/Users/irffanalahi/Research/Research_update/SM/ShowcaseSM/BL17_14/BL14_feature_significance/mNeu/fromReftoPerfomance_singlecpgbased/BL14_atleast.2_top-1_singleCpG_final_assignedref_uniq.txt_result_final.txt_folder_mincpg1_feature_significance_Allfile_DMRwise_avg.txt_stats.txt_withSMestimated.txt' #'/Users/irffanalahi/Research/Research_update/SM/ShowcaseSM/BL17_14/BL14_feature_significance/CD4/fromReftoPerfomance/singleCpGbased/mincpg1_feature_significance_Allfile_DMRwise_avg.txt_stats.txt_withSMestimated.txt'
celltype='mNeu' #################################
cpgdf=pd.read_csv(DMRcpgfile,sep="\t",index_col=['chrom','start','end'])
cpgdf.head()
# Out:
#                               CD4       CD8        nB        NK        Mn  \
# chrom start    end
# chr1  13711400 13711402  1.000000  0.958000  0.982333  0.954000  0.947333
#       13711460 13711462  0.980000  0.915000  0.983000  0.955000  0.954333
#       13711468 13711470  0.970000  0.950667  0.993333  0.946667  0.934667
#       13711601 13711603  0.966000  0.940667  0.973333  0.951000  0.915333
#       21459674 21459676  0.962667  0.926000  0.977667  0.962000  0.745000
#
#                           mNeu      m8        DC      Eo      Tr     m4  \
# chrom start    end
# chr1  13711400 13711402  0.018  1.0000  0.971667  0.7655  0.9815  0.982
#       13711460 13711462  0.005  0.9785  0.894333  0.7255  0.9875  0.973
#       13711468 13711470  0.005  0.9590  0.926333  0.7575  1.0000  0.960
#       13711601 13711603  0.036  0.9750  0.833333  0.7875  0.9505  0.963
#       21459674 21459676  0.017  1.0000  0.675333  0.5925  0.9375  0.963
#
#                              Mg      Er        mB shouldbechrom       pos  \
# chrom start    end
# chr1  13711400 13711402  0.9680  0.9250  0.913000          chr1  13711401
#       13711460 13711462  0.9425  0.9035  0.990667          chr1  13711461
#       13711468 13711470  0.9330  0.8295  0.976333          chr1  13711469
#       13711601 13711603  0.8890  0.8130  0.947000          chr1  13711602
#       21459674 21459676  0.9640  0.9440  0.972000          chr1  21459675
#
#                         DMRchr  DMRstart    DMRend DMRname
# chrom start    end
# chr1  13711400 13711402   chr1  13711401  13711603    DMR1
#       13711460 13711462   chr1  13711401  13711603    DMR1
#       13711468 13711470   chr1  13711401  13711603    DMR1
#       13711601 13711603   chr1  13711401  13711603    DMR1
#       21459674 21459676   chr1  21459675  21459830    DMR2

# %%
RDstatdf=pd.read_csv(RDstatfile,sep="\t")
RDstatdf.rename(columns={'chrom':'DMRchr','start':'DMRstart','end':'DMRend'},inplace=True)
RDstatdf.head()
# Out:
#   DMRchr  DMRstart    DMRend  #TP_fragment  #FP_fragment  #TN_fragment  \
# 0   chr1  13711401  13711603       17.0500      8.233333    150.545833
# 1   chr1  21459675  21459830       20.8625     10.095833    226.662500
# 2   chr1  36418604  36418987       15.2750      5.722917    135.335417
# 3   chr1  38493747  38493790       18.6375      2.879167    113.470833
# 4   chr1  44333641  44333776       20.4625      6.862500    188.150000
#
#    #FN_fragment  #Total_Fragment       TPR       FPR  ...   mNeu-mB  \
# 0        0.2000       176.029167  0.995020  0.059892  ... -0.940750
# 1       10.1000       267.720833  0.524111  0.040167  ... -0.859837
# 2        2.9375       159.270833  0.848367  0.042439  ... -0.820297
# 3        0.4250       135.412500  0.973060  0.023897  ... -0.879917
# 4        4.3375       219.812500  0.890746  0.033740  ... -0.883834
#
#    maxCompartmentwisedelta  minCompartmentwiseDelta  DMRlength  \
# 0                -0.743000                -0.967000        202
# 1                -0.709920                -0.883420        155
# 2                -0.719692                -0.860672        383
# 3                -0.778750                -0.942750         43
# 4                -0.789792                -0.892334        135
#
#    #cpg/DMRlength  DMRlength/#Total_Fragment  #Total_Fragment/DMRlength  \
# 0        0.019802                   1.147537                   0.871432
# 1        0.025806                   0.578961                   1.727231
# 2        0.020888                   2.404709                   0.415851
# 3        0.093023                   0.317548                   3.149128
# 4        0.029630                   0.614160                   1.628241
#
#    SMestimatedFPR    mNeu_y  1-others
# 0        0.064447  0.984000   0.06236
# 1        0.051739  0.893420   0.05353
# 2        0.066533  0.880880   0.06418
# 3        0.116558  0.984250   0.11373
# 4        0.050377  0.912667   0.05130
#
# [5 rows x 55 columns]

# %%
cpgdf=cpgdf.drop(['shouldbechrom','pos'],axis=1)
cpgdf.head()
# Out:
#                               CD4       CD8        nB        NK        Mn  \
# chrom start    end
# chr1  13711400 13711402  1.000000  0.958000  0.982333  0.954000  0.947333
#       13711460 13711462  0.980000  0.915000  0.983000  0.955000  0.954333
#       13711468 13711470  0.970000  0.950667  0.993333  0.946667  0.934667
#       13711601 13711603  0.966000  0.940667  0.973333  0.951000  0.915333
#       21459674 21459676  0.962667  0.926000  0.977667  0.962000  0.745000
#
#                           mNeu      m8        DC      Eo      Tr     m4  \
# chrom start    end
# chr1  13711400 13711402  0.018  1.0000  0.971667  0.7655  0.9815  0.982
#       13711460 13711462  0.005  0.9785  0.894333  0.7255  0.9875  0.973
#       13711468 13711470  0.005  0.9590  0.926333  0.7575  1.0000  0.960
#       13711601 13711603  0.036  0.9750  0.833333  0.7875  0.9505  0.963
#       21459674 21459676  0.017  1.0000  0.675333  0.5925  0.9375  0.963
#
#                              Mg      Er        mB DMRchr  DMRstart    DMRend  \
# chrom start    end
# chr1  13711400 13711402  0.9680  0.9250  0.913000   chr1  13711401  13711603
#       13711460 13711462  0.9425  0.9035  0.990667   chr1  13711401  13711603
#       13711468 13711470  0.9330  0.8295  0.976333   chr1  13711401  13711603
#       13711601 13711603  0.8890  0.8130  0.947000   chr1  13711401  13711603
#       21459674 21459676  0.9640  0.9440  0.972000   chr1  21459675  21459830
#
#                         DMRname
# chrom start    end
# chr1  13711400 13711402    DMR1
#       13711460 13711462    DMR1
#       13711468 13711470    DMR1
#       13711601 13711603    DMR1
#       21459674 21459676    DMR2

# %%
colnames=cpgdf.columns.tolist()
otherct=colnames[0:colnames.index('DMRchr')]
otherct.remove(celltype)
len(otherct)
# Out:
# 13

# %%
otherct
# Out:
# ['CD4',
#  'CD8',
#  'nB',
#  'NK',
#  'Mn',
#  'm8',
#  'DC',
#  'Eo',
#  'Tr',
#  'm4',
#  'Mg',
#  'Er',
#  'mB']

# %%
othermean=cpgdf[otherct].mean(axis=1)
cpgdf['othermean']=othermean

# %%
cpgdf.head()
# Out:
#                               CD4       CD8        nB        NK        Mn  \
# chrom start    end
# chr1  13711400 13711402  1.000000  0.958000  0.982333  0.954000  0.947333
#       13711460 13711462  0.980000  0.915000  0.983000  0.955000  0.954333
#       13711468 13711470  0.970000  0.950667  0.993333  0.946667  0.934667
#       13711601 13711603  0.966000  0.940667  0.973333  0.951000  0.915333
#       21459674 21459676  0.962667  0.926000  0.977667  0.962000  0.745000
#
#                           mNeu      m8        DC      Eo      Tr     m4  \
# chrom start    end
# chr1  13711400 13711402  0.018  1.0000  0.971667  0.7655  0.9815  0.982
#       13711460 13711462  0.005  0.9785  0.894333  0.7255  0.9875  0.973
#       13711468 13711470  0.005  0.9590  0.926333  0.7575  1.0000  0.960
#       13711601 13711603  0.036  0.9750  0.833333  0.7875  0.9505  0.963
#       21459674 21459676  0.017  1.0000  0.675333  0.5925  0.9375  0.963
#
#                              Mg      Er        mB DMRchr  DMRstart    DMRend  \
# chrom start    end
# chr1  13711400 13711402  0.9680  0.9250  0.913000   chr1  13711401  13711603
#       13711460 13711462  0.9425  0.9035  0.990667   chr1  13711401  13711603
#       13711468 13711470  0.9330  0.8295  0.976333   chr1  13711401  13711603
#       13711601 13711603  0.8890  0.8130  0.947000   chr1  13711401  13711603
#       21459674 21459676  0.9640  0.9440  0.972000   chr1  21459675  21459830
#
#                         DMRname  othermean
# chrom start    end
# chr1  13711400 13711402    DMR1   0.949872
#       13711460 13711462    DMR1   0.937141
#       13711468 13711470    DMR1   0.933615
#       13711601 13711603    DMR1   0.915744
#       21459674 21459676    DMR2   0.893974

# %%
cpgdf['1-othermean']=1-cpgdf['othermean']
cpgdf['1-'+celltype]=1-cpgdf[celltype]
cpgdf.head()
# Out:
#                               CD4       CD8        nB        NK        Mn  \
# chrom start    end
# chr1  13711400 13711402  1.000000  0.958000  0.982333  0.954000  0.947333
#       13711460 13711462  0.980000  0.915000  0.983000  0.955000  0.954333
#       13711468 13711470  0.970000  0.950667  0.993333  0.946667  0.934667
#       13711601 13711603  0.966000  0.940667  0.973333  0.951000  0.915333
#       21459674 21459676  0.962667  0.926000  0.977667  0.962000  0.745000
#
#                           mNeu      m8        DC      Eo      Tr  ...      Mg  \
# chrom start    end                                                ...
# chr1  13711400 13711402  0.018  1.0000  0.971667  0.7655  0.9815  ...  0.9680
#       13711460 13711462  0.005  0.9785  0.894333  0.7255  0.9875  ...  0.9425
#       13711468 13711470  0.005  0.9590  0.926333  0.7575  1.0000  ...  0.9330
#       13711601 13711603  0.036  0.9750  0.833333  0.7875  0.9505  ...  0.8890
#       21459674 21459676  0.017  1.0000  0.675333  0.5925  0.9375  ...  0.9640
#
#                              Er        mB  DMRchr  DMRstart    DMRend  \
# chrom start    end
# chr1  13711400 13711402  0.9250  0.913000    chr1  13711401  13711603
#       13711460 13711462  0.9035  0.990667    chr1  13711401  13711603
#       13711468 13711470  0.8295  0.976333    chr1  13711401  13711603
#       13711601 13711603  0.8130  0.947000    chr1  13711401  13711603
#       21459674 21459676  0.9440  0.972000    chr1  21459675  21459830
#
#                          DMRname othermean  1-othermean  1-mNeu
# chrom start    end
# chr1  13711400 13711402     DMR1  0.949872     0.050128   0.982
#       13711460 13711462     DMR1  0.937141     0.062859   0.995
#       13711468 13711470     DMR1  0.933615     0.066385   0.995
#       13711601 13711603     DMR1  0.915744     0.084256   0.964
#       21459674 21459676     DMR2  0.893974     0.106026   0.983
#
# [5 rows x 21 columns]

# %%
cpgdf.plot.scatter(x='1-othermean',y='1-'+celltype)

# %%
cpgdf=cpgdf.merge(RDstatdf,on=['DMRchr','DMRstart','DMRend'])
cpgdf.head()
# Out:
#       CD4_x     CD8_x      nB_x      NK_x      Mn_x   mNeu    m8_x      DC_x  \
# 0  1.000000  0.958000  0.982333  0.954000  0.947333  0.018  1.0000  0.971667
# 1  0.980000  0.915000  0.983000  0.955000  0.954333  0.005  0.9785  0.894333
# 2  0.970000  0.950667  0.993333  0.946667  0.934667  0.005  0.9590  0.926333
# 3  0.966000  0.940667  0.973333  0.951000  0.915333  0.036  0.9750  0.833333
# 4  0.962667  0.926000  0.977667  0.962000  0.745000  0.017  1.0000  0.675333
#
#      Eo_x    Tr_x  ...   mNeu-mB  maxCompartmentwisedelta  \
# 0  0.7655  0.9815  ... -0.940750                 -0.74300
# 1  0.7255  0.9875  ... -0.940750                 -0.74300
# 2  0.7575  1.0000  ... -0.940750                 -0.74300
# 3  0.7875  0.9505  ... -0.940750                 -0.74300
# 4  0.5925  0.9375  ... -0.859837                 -0.70992
#
#    minCompartmentwiseDelta  DMRlength #cpg/DMRlength  \
# 0                 -0.96700        202       0.019802
# 1                 -0.96700        202       0.019802
# 2                 -0.96700        202       0.019802
# 3                 -0.96700        202       0.019802
# 4                 -0.88342        155       0.025806
#
#    DMRlength/#Total_Fragment  #Total_Fragment/DMRlength SMestimatedFPR  \
# 0                   1.147537                   0.871432       0.064447
# 1                   1.147537                   0.871432       0.064447
# 2                   1.147537                   0.871432       0.064447
# 3                   1.147537                   0.871432       0.064447
# 4                   0.578961                   1.727231       0.051739
#
#     mNeu_y  1-others
# 0  0.98400   0.06236
# 1  0.98400   0.06236
# 2  0.98400   0.06236
# 3  0.98400   0.06236
# 4  0.89342   0.05353
#
# [5 rows x 73 columns]

# %%
ax=sns.scatterplot(x='FPR',y='TPR', data=cpgdf, hue='TPR',palette="viridis")
ax.legend(loc=(1.03, 0.6))

# %%
ax=sns.scatterplot(x='1-othermean',y='1-'+celltype, data=cpgdf, hue='TPR',palette="viridis")
ax.legend(loc=(1.03, 0.6))

# %%
cpgtodmr=cpgdf.groupby('DMRname').mean()
cpgtodmr.head()
# Out:
#             CD4_x     CD8_x      nB_x      NK_x      Mn_x      mNeu      m8_x  \
# DMRname
# DMR1     0.979000  0.941083  0.983000  0.951667  0.937917  0.016000  0.978125
# DMR10    0.972000  0.940778  0.968389  0.977556  0.881667  0.127278  0.956417
# DMR11    0.967083  0.965417  0.974083  0.963000  0.887167  0.085167  0.972875
# DMR12    0.986917  0.960833  0.966208  0.948458  0.978833  0.132542  0.950375
# DMR13    0.926167  0.909917  0.912000  0.881417  0.838333  0.024000  0.884750
#
#              DC_x      Eo_x      Tr_x  ...   mNeu-mB  maxCompartmentwisedelta  \
# DMRname                                ...
# DMR1     0.906417  0.759000  0.979875  ... -0.940750                -0.743000
# DMR10    0.907222  0.907000  0.958083  ... -0.831664                -0.754387
# DMR11    0.873083  0.787375  0.966625  ... -0.845833                -0.702208
# DMR12    0.982583  0.934250  0.926250  ... -0.779710                -0.779710
# DMR13    0.758417  0.845250  0.839750  ... -0.846000                -0.700375
#
#          minCompartmentwiseDelta  DMRlength  #cpg/DMRlength  \
# DMRname
# DMR1                   -0.967000        202        0.019802
# DMR10                  -0.850276        119        0.050420
# DMR11                  -0.890208        166        0.024096
# DMR12                  -0.854377        186        0.021505
# DMR13                  -0.902167         31        0.129032
#
#          DMRlength/#Total_Fragment  #Total_Fragment/DMRlength  SMestimatedFPR  \
# DMRname
# DMR1                      1.147537                   0.871432        0.064447
# DMR10                     0.387076                   2.583473        0.052013
# DMR11                     1.268386                   0.788404        0.064436
# DMR12                     0.537883                   1.859140        0.044170
# DMR13                     0.118242                   8.457258        0.148184
#
#            mNeu_y  1-others
# DMRname
# DMR1     0.984000   0.06236
# DMR10    0.872720   0.05376
# DMR11    0.914833   0.06538
# DMR12    0.867460   0.04269
# DMR13    0.976000   0.14566
#
# [5 rows x 71 columns]

# %%
ax=sns.scatterplot(x='1-othermean',y='1-'+celltype, data=cpgtodmr, hue='TPR',palette="viridis")
ax.legend(loc=(1.03, 0.6))

# %%
def plt_corr(x, y,combined):
    fig = plt.figure()
    lm = sns.lmplot(x=x, y=y, data=combined)
    ax = lm.axes[0, 0]
    p_corr = np.around(corrdf_pearson[x][y], decimals=3)
    s_corr = np.around(corrdf_spearman[x][y], decimals=3)
    p_val_pearson = np.around(pearsonr(combined[x], combined[y])[1], decimals=8)
    p_val_spearman = np.around(spearmanr(combined[x], combined[y])[1], decimals=8)
    txt = 'r = ' + str(p_corr) + ', p-val = ' + str(p_val_pearson) + '\nrho = ' + str(s_corr) + ', p-val = ' + str(p_val_spearman)
    ax.text(np.array(combined[x].sort_values())[0], np.array(combined[y].sort_values())[-2], txt, horizontalalignment='left', verticalalignment='bottom')
    return lm

# %%
# sns.scatterplot(combined['FDR'], combined['FPR'])
corrdf_pearson=cpgtodmr.corr(method='pearson')
corrdf_spearman=cpgtodmr.corr(method='spearman')

# %%
x = '1-others'
y = '1-othermean'
fig = plt_corr(x, y,cpgtodmr)

# %%
x = celltype+'_y'
y = '1-'+celltype
fig = plt_corr(x, y,cpgtodmr)

# %%
cpgtodmrstd=cpgdf.groupby('DMRname').std()
cpgtodmrstd.head()
# Out:
#             CD4_x     CD8_x      nB_x      NK_x      Mn_x      mNeu      m8_x  \
# DMRname
# DMR1     0.015188  0.018784  0.008179  0.003742  0.017115  0.014674  0.016874
# DMR10    0.008746  0.016625  0.020214  0.011908  0.028317  0.028157  0.010768
# DMR11    0.040206  0.024818  0.013739  0.035960  0.103213  0.064121  0.024645
# DMR12    0.006274  0.022411  0.017500  0.008612  0.009367  0.187380  0.024978
# DMR13    0.036022  0.063870  0.066578  0.055868  0.087681  0.006218  0.097079
#
#              DC_x      Eo_x      Tr_x  ...  mNeu-mB  maxCompartmentwisedelta  \
# DMRname                                ...
# DMR1     0.058142  0.025684  0.021045  ...      0.0                      0.0
# DMR10    0.050024  0.023770  0.018427  ...      0.0                      0.0
# DMR11    0.164612  0.223563  0.026443  ...      0.0                      0.0
# DMR12    0.012191  0.026641  0.075109  ...      0.0                      0.0
# DMR13    0.064185  0.107227  0.124529  ...      0.0                      0.0
#
#          minCompartmentwiseDelta  DMRlength  #cpg/DMRlength  \
# DMRname
# DMR1                         0.0        0.0             0.0
# DMR10                        0.0        0.0             0.0
# DMR11                        0.0        0.0             0.0
# DMR12                        0.0        0.0             0.0
# DMR13                        0.0        0.0             0.0
#
#          DMRlength/#Total_Fragment  #Total_Fragment/DMRlength  SMestimatedFPR  \
# DMRname
# DMR1                           0.0                        0.0             0.0
# DMR10                          0.0                        0.0             0.0
# DMR11                          0.0                        0.0             0.0
# DMR12                          0.0                        0.0             0.0
# DMR13                          0.0                        0.0             0.0
#
#          mNeu_y  1-others
# DMRname
# DMR1        0.0       0.0
# DMR10       0.0       0.0
# DMR11       0.0       0.0
# DMR12       0.0       0.0
# DMR13       0.0       0.0
#
# [5 rows x 71 columns]

# %%
cpgdf.to_csv(DMRcpgfile+"_cpgdf.txt",sep="\t")
cpgtodmr.to_csv(DMRcpgfile+"_cpgtodmrmean.txt",sep="\t")
cpgtodmrstd.to_csv(DMRcpgfile+"_cpgtodmrstd.txt",sep="\t")
