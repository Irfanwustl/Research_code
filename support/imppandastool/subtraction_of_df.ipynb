# %%
import pandas as pd

f1='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/rankspace_idea/GSEA_run/Bugfixed/othertest/BL22_all_matrix_promdata_intwith_SMNaiveCD4_22pos'

f2='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/rankspace_idea/GSEA_run/Bugfixed/othertest/NaiveCD4_CpGdelta_info_faster.txt_V1hypo_rankedtop5000_head104.txt'


df1=pd.read_csv(f1,sep='\t',index_col=[0,1,2])
df2=pd.read_csv(f2,sep='\t',index_col=[0,1,2])

df1.head()
# Out:
#                          aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  12456809 12456811                                              0.250
#       13790852 13790854                                              0.000
#       23040377 23040379                                              0.250
#       25667462 25667464                                              0.267
#       32387376 32387378                                              0.200
#
#                          aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  12456809 12456811                                              0.096
#       13790852 13790854                                              0.000
#       23040377 23040379                                                NaN
#       25667462 25667464                                              0.182
# ...

# %%
df2.head()
# Out:
#                            NaiveCD4-Bcell  NaiveCD4-Myloid  NaiveCD4-NK  \
# chrom start     end
# chr16 27233119  27233121         0.530125         0.945750     0.961333
# chr8  1792266   1792268          0.855250         0.952750     0.925000
# chr19 1072193   1072195          0.939625         0.941063     0.845500
# chr2  171081668 171081670        0.905625         0.911000     0.868333
# chr5  134964628 134964630        0.939250         0.943312     0.431500
#
#                            NaiveCD4-NaiveCD8  NaiveCD4-PMNlike  \
# chrom start     end
# chr16 27233119  27233121            0.395000          0.886333
# chr8  1792266   1792268             0.547333          0.901375
# chr19 1072193   1072195             0.462167          0.915833
# chr2  171081668 171081670           0.438000          0.829667
# chr5  134964628 134964630           0.492167          0.910056
#
#                            NaiveCD4-Tregs  NaiveCD4-cm4  NaiveCD4-cm8  \
# chrom start     end
# ...

# %%
df1unique=df1[~df1.index.isin(df2.index)]
df1unique.shape
# Out:
# (87, 54)

# %%
df2unque=df2[~df2.index.isin(df1.index)]
df2unque.shape
# Out:
# (87, 50)

# %%
df1unique.to_csv(f1+"_comparedunique.txt",sep='\t',na_rep='NA')
df2unque.to_csv(f2+"_comparedunique.txt",sep='\t',na_rep='NA')
