# %%
import pandas as pd

f1='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/rankspace_idea/debug/comparewithprevgood/comparewithunique/BL22_all_matrix_promdata_intwith_SMTregs_51pos'

f2='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/rankspace_idea/debug/comparewithprevgood/comparewithunique/BL22_all_matrix_promdata_intwith_Tregs_CpGdelta_info_faster.txt_3000_forheatunderlyingdata_ranked_pos.txt_sorted_500.txt'


df1=pd.read_csv(f1,sep='\t',index_col=[0,1,2])
df2=pd.read_csv(f2,sep='\t',index_col=[0,1,2])

df1.head()
# Out:
#                          aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  12128144 12128146                                              0.926
#       12128203 12128205                                              0.906
#       12169464 12169466                                              0.500
#       12169648 12169650                                              0.903
#       12170588 12170590                                              0.929
#
#                          aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  12128144 12128146                                              0.852
#       12128203 12128205                                              0.900
#       12169464 12169466                                                NaN
#       12169648 12169650                                              0.947
# ...

# %%
df2.head()
# Out:
#                            aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start     end
# chrX  49260634  49260636                                               1.000
# chr5  180312122 180312124                                              0.886
# chr18 3898035   3898037                                                0.972
# chr2  235763066 235763068                                              0.941
# chrX  49260621  49260623                                               0.870
#
#                            aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start     end
# chrX  49260634  49260636                                               0.929
# chr5  180312122 180312124                                              0.909
# chr18 3898035   3898037                                                0.976
# ...

# %%
df1unique=df1[~df1.index.isin(df2.index)]
df1unique.shape
# Out:
# (240, 54)

# %%
df2unque=df2[~df2.index.isin(df1.index)]
df2unque.shape
# Out:
# (228, 54)

# %%
df1unique.to_csv(f1+"_comparedunique.txt",sep='\t',na_rep='NA')
df2unque.to_csv(f2+"_comparedunique.txt",sep='\t',na_rep='NA')
