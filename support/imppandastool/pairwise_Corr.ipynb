# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/corr/firstvirsiongtformoreCT/per_ctcorr/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkladjustedScore_minus_avg_CSxOut.txt_7pbmc_cytof.txt'


indf=pd.read_csv(infile,sep="\t",index_col=0)
indf.head()
# Out:
#                            NaiveCD4    NaiveCD8         nB          NK  \
# Mixture
# healthy_NU-03-bulk-PBMC  426.272052   72.323616  49.742895  361.665501
# healthy_NU-14-bulk-PBMC  477.972932  118.712490  43.151935  467.951141
# healthy_NU-24-bulk-PBMC  639.671016   84.073688  40.998135  324.499712
# healthy_NU-31-bulk-PBMC  476.608171   87.374142  42.654327  594.338083
# healthy_NU-49-bulk-PBMC  531.930500  103.275266  41.871135  320.210369
#
#                                 PC        Mono          M0         M1  \
# Mixture
# healthy_NU-03-bulk-PBMC  19.269655  121.355239  116.558845  24.893288
# healthy_NU-14-bulk-PBMC  21.432662  114.420894   89.275187  23.744648
# healthy_NU-24-bulk-PBMC  16.794414  129.683513  113.231812  23.656056
# healthy_NU-31-bulk-PBMC  26.684424  114.812973  114.678223  26.017875
# healthy_NU-49-bulk-PBMC  20.927356   99.416938  108.680213  24.658069
#
#                                  M2        iDC  ...  mB_real  nB_real  \
# ...

# %%
corr = indf.corr(method='spearman')
# plot the heatmap
plt.rcParams['figure.figsize'] = [25, 10]
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,annot=True)

# %%
allcols=indf.columns
allcols
# Out:
# Index(['NaiveCD4', 'NaiveCD8', 'nB', 'NK', 'PC', 'Mono', 'M0', 'M1', 'M2',
#        'iDC', 'mDC', 'PMN', 'cm8', 'em8', 'Eo', 'Tregs', 'em4', 'ed8', 'Mg',
#        'cm4', 'Er', 'mB', 'NaiveCD4_real', 'NaiveCD8_real', 'Tregs_real',
#        'mB_real', 'nB_real', 'cm4_real', 'em4_real', 'cm8_real', 'em8_real',
#        'Mono_real', 'NK_real', 'PC_real', 'ed8_real'],
#       dtype='object')

# %%
estlist=[]
reallist=[]

for cl in allcols:
    if '_real' in allcols:
        reallist.append(cl)
    else:
        estlist.append(cl)

print(estlist)
print(reallist)
# Out:
# ['NaiveCD4', 'NaiveCD8', 'nB', 'NK', 'PC', 'Mono', 'M0', 'M1', 'M2', 'iDC', 'mDC', 'PMN', 'cm8', 'em8', 'Eo', 'Tregs', 'em4', 'ed8', 'Mg', 'cm4', 'Er', 'mB', 'NaiveCD4_real', 'NaiveCD8_real', 'Tregs_real', 'mB_real', 'nB_real', 'cm4_real', 'em4_real', 'cm8_real', 'em8_real', 'Mono_real', 'NK_real', 'PC_real', 'ed8_real']
# []
