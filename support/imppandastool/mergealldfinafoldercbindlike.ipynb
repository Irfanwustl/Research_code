# %%
import pandas as pd
import glob, os

# %%
infolder="/Users/irffanalahi/rest_summer_2019/support/results/BulkPBMC/prevpbmc"
out=infolder+"_column_combined.txt"

# %%
files = glob.glob(infolder+'/*.txt')
filesdf=[pd.read_csv(fp,sep="\t",index_col=0) for fp in files]

# %%
df_combined = pd.concat(filesdf, axis=1)
df_combined.head()
# Out:
#                           01st_ptle  05th_ptle  25th_ptle  50th_ptle  \
# TWCY-1389-1389-BULK-PBMC          3          7         13         17
# TWCY-1382-1382-BULK-PBMC          3          7         12         16
# TWCY-1313-1313-BULK-PBMC          2          5         10         15
#
#                           75th_ptle  95th_ptle  99th_ptle  Unnamed: 8  \
# TWCY-1389-1389-BULK-PBMC         21         28         39         NaN
# TWCY-1382-1382-BULK-PBMC         20         28         37         NaN
# TWCY-1313-1313-BULK-PBMC         19         27         37         NaN
#
#                               total  secondary  ...  \
# TWCY-1389-1389-BULK-PBMC  479478857    2580853  ...
# TWCY-1382-1382-BULK-PBMC  455176820    2749845  ...
# TWCY-1313-1313-BULK-PBMC  439296503    2102836  ...
#
#                           with_mate_mapped_to_a_different_chr  \
# TWCY-1389-1389-BULK-PBMC                              3781878
# TWCY-1382-1382-BULK-PBMC                              4054460
# TWCY-1313-1313-BULK-PBMC                              2920154
#
#                           with_mate_mapped_to_a_different_chr_mapQ>=5  \
# TWCY-1389-1389-BULK-PBMC                                      1704891
# TWCY-1382-1382-BULK-PBMC                                      1770839
# TWCY-1313-1313-BULK-PBMC                                      1309959
#
#                           01st_ptle  05th_ptle  25th_ptle  50th_ptle  \
# TWCY-1389-1389-BULK-PBMC         39         95        159        215
# TWCY-1382-1382-BULK-PBMC         34         97        156        207
# TWCY-1313-1313-BULK-PBMC         36        106        152        194
#
#                           75th_ptle  95th_ptle  99th_ptle  Unnamed: 8
# TWCY-1389-1389-BULK-PBMC        289        430        559         NaN
# TWCY-1382-1382-BULK-PBMC        284        447        605         NaN
# TWCY-1313-1313-BULK-PBMC        257        395        532         NaN
#
# [3 rows x 31 columns]

# %%
df_combined.to_csv(out,sep="\t",na_rep="NA")
