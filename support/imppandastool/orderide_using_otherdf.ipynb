# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/chromosome_Y_analysis/EM_first_batch_txt.txt'

refindex='/Users/irffanalahi/Research/Research_update/chromosome_Y_analysis/Yale_abul_order.txt'

refindexdf=pd.read_csv(refindex,sep="\t",index_col=0)
indf=pd.read_csv(infile,sep="\t",index_col=0)

indf.head()
# Out:
#                  01st_ptle  05th_ptle  25th_ptle  50th_ptle  75th_ptle  \
# sample
# YUALOE-20-4117   13.668039  14.902850   16.26805   17.38860  18.724925
# YUCADA-14-3260    1.631636   1.734840    2.15330    3.48040   5.497500
# YUMEDIC-14-3303   1.970478   2.978115    5.64210    6.88815   9.183275
# YURADIO-14-3253  16.425498  17.552850   19.03420   20.27530  21.649650
# YURAISE-13-2954  11.928876  12.684680   13.78330   14.88420  16.325350
#
#                   95th_ptle   99th_ptle  Unnamed: 8
# sample
# YUALOE-20-4117    55.709165  415.471750         NaN
# YUCADA-14-3260   121.780960  351.580924         NaN
# YUMEDIC-14-3303  146.590805  511.694055         NaN
# YURADIO-14-3253   48.318380  364.556936         NaN
# YURAISE-13-2954   40.724400  241.355686         NaN

# %%
refindexdf.head()
# Out:
#                 Sample Date  Sequencing Batch Sequencing Status  CBC  \
# sample
# YUMEDIC-14-3303    11/18/14               1.0         Sequenced   No
# YURAISE-13-2954     5/19/13               1.0         Sequenced   No
# YUARGE-14-3173      6/26/14               1.0         Sequenced  Yes
# YUJADE-14-3169      6/24/14               1.0         Sequenced   No
# YULAMB-15-3410      6/16/15               1.0         Sequenced   No
#
#                  Input cfDNA (ng)  Unmeth lambda DNA 1% (ng)  \
# sample
# YUMEDIC-14-3303              10.0                        0.1
# YURAISE-13-2954              10.0                        0.1
# YUARGE-14-3173               10.0                        0.1
# YUJADE-14-3169               10.0                        0.1
# YULAMB-15-3410               10.0                        0.1
#
#                  cfDNA concentration (ng/ul)  cfDNA vol (ul)  \
# sample
# YUMEDIC-14-3303                         0.46           21.90
# ...

# %%
outdf=indf.reindex(refindexdf.index)
outdf.head()
# Out:
#                  01st_ptle  05th_ptle  25th_ptle  50th_ptle  75th_ptle  \
# sample
# YUMEDIC-14-3303   1.970478   2.978115   5.642100    6.88815   9.183275
# YURAISE-13-2954  11.928876  12.684680  13.783300   14.88420  16.325350
# YUARGE-14-3173   10.483440  11.925200  13.332200   14.23870  15.325700
# YUJADE-14-3169   11.640711  12.525660  13.528200   14.31970  15.378850
# YULAMB-15-3410   13.520085  14.341120  15.600225   16.53725  17.706150
#
#                   95th_ptle   99th_ptle  Unnamed: 8
# sample
# YUMEDIC-14-3303  146.590805  511.694055         NaN
# YURAISE-13-2954   40.724400  241.355686         NaN
# YUARGE-14-3173    38.103800  290.853300         NaN
# YUJADE-14-3169    36.903805  351.982477         NaN
# YULAMB-15-3410    64.102450  301.932141         NaN

# %%
outdf.to_csv(infile+"_indexordered.txt",sep="\t",na_rep='NA')
