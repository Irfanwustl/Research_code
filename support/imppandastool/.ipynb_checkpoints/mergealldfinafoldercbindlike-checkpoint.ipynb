# %%
import pandas as pd
import glob, os

# %%
infolder="/Users/irffanalahi/Research/weekly/for_3_17_21/MLmodel/dataprepare/combineall/readytocombine"
out=infolder+"_column_combined.txt"

# %%
files = glob.glob(infolder+'/*.txt')
filesdf=[pd.read_csv(fp,sep="\t",index_col=0) for fp in files]

# %%
df_combined = pd.concat(filesdf, axis=1)
df_combined.head()
# Out:
#                              Time point Noah_response  MEL_TUMOR_cpg3  \
# tot-YUCLUE_20-3998-cfDNA.bg      pre tx           NDB        0.046632
# tot-YUMARS_15-3443-cfDNA.bg      pre tx           DCB        0.025862
# tot-YUMICRO_20-4006-cfDNA.bg     pre tx           NDB        0.535211
# tot-YUMOTE_17-3755-cfDNA.bg      pre tx           NDB        0.274854
# tot-YUPRAF_19-3925-cfDNA.bg      pre tx           DCB        0.055921
#
#                               PBL_cpg3  TIL_cpg3  MEL_TUMOR_cpg5  PBL_cpg5  \
# tot-YUCLUE_20-3998-cfDNA.bg   0.760073  0.043873        0.040816  0.786207
# tot-YUMARS_15-3443-cfDNA.bg   0.759791  0.075786        0.020833  0.740741
# tot-YUMICRO_20-4006-cfDNA.bg  0.294606  0.018868        0.666667  0.269841
# tot-YUMOTE_17-3755-cfDNA.bg   0.569767  0.052632        0.340426  0.688525
# tot-YUPRAF_19-3925-cfDNA.bg   0.752336  0.066508        0.052632  0.772727
#
#                               TIL_cpg5  MEL_TUMOR_cpg4  PBL_cpg4  TIL_cpg4  \
# tot-YUCLUE_20-3998-cfDNA.bg   0.037975        0.046875  0.780576  0.034803
# tot-YUMARS_15-3443-cfDNA.bg   0.042683        0.025000  0.779412  0.097403
# tot-YUMICRO_20-4006-cfDNA.bg  0.022222        0.558621  0.286260  0.011940
# tot-YUMOTE_17-3755-cfDNA.bg   0.022346        0.269939  0.633745  0.052632
# tot-YUPRAF_19-3925-cfDNA.bg   0.050360        0.034014  0.755556  0.083019
#
#                               MEL_TUMOR_cpg1  PBL_cpg1  TIL_cpg1  \
# tot-YUCLUE_20-3998-cfDNA.bg         0.100000  0.644090  0.103912
# tot-YUMARS_15-3443-cfDNA.bg         0.079151  0.685073  0.113707
# tot-YUMICRO_20-4006-cfDNA.bg        0.507953  0.321168  0.076403
# tot-YUMOTE_17-3755-cfDNA.bg         0.293362  0.516184  0.097692
# tot-YUPRAF_19-3925-cfDNA.bg         0.142534  0.660211  0.122807
#
#                               MEL_TUMOR_cpg2  PBL_cpg2  TIL_cpg2
# tot-YUCLUE_20-3998-cfDNA.bg         0.045723  0.712994  0.054002
# tot-YUMARS_15-3443-cfDNA.bg         0.039655  0.739130  0.079268
# tot-YUMICRO_20-4006-cfDNA.bg        0.516699  0.306778  0.040437
# tot-YUMOTE_17-3755-cfDNA.bg         0.269725  0.544056  0.060459
# tot-YUPRAF_19-3925-cfDNA.bg         0.070727  0.738397  0.077793

# %%
df_combined.to_csv(out,sep="\t",na_rep="NA")
