# %%
import  pandas  as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/irAE/benchmark_withcelfie/boxplots/celfie-on-melanoma_CSxOut.txt_irAEgt_PreTX.txt'

indf=pd.read_csv(infile,sep='\t',index_col=0)

# %%
standardnamedict={"Macrophage.M0":"Mac (M0)","Macrophage.M1":"Mac (M1)","Macrophage.M2":"Mac (M2)","T.CD4.naive":"Naive CD4 T","T.CD8.naive":"Naive CD8","CD4": "Naive CD4", "CD8": "Naive CD8 T","B.Cell.memory":"Memory B",'Mn':'Mono','CD14':'Mono','CD19':'B Cell','B.Cell.naive':'Naive B','Plasma.Cell':'PC','T.CD8.central.memory':'CD8 TCM','T.CD8.effector.memory':'CD8 TEM','m8':'CD8 memory','T.CD8.effector.memory.terminal':'CD8 TEMRA','T.CD4.central.memory':'CD4 TCM','em4':'CD4 TEM','m4':'CD4 memory','mNeu':'PMN','Eo':'Eosinophil','Treg':'Tregs','Mg':'Megakaryocyte','Er':'Erythrocyte','NK.Cell':'NK','Dendtritic.immature':'iDC','Dendtritic.mature':'mDC','Neutrophil':'PMN'}

# %%
outdf=indf.copy()
outdf.rename(columns=standardnamedict,inplace=True)
outdf.head()
# Out:
#                           Naive CD4 T       CD4 TCM       CD4 TEM  Naive CD8  \
# Mixture
# Y-3674-cfDNA                 0.026325  1.226120e-03  2.039940e-04   0.000543
# Y-3707-cfDNA                 0.004941  4.790000e-08  3.830000e-09   0.013712
# y4-YUPARK_18_3832-cfDNA      0.001427  2.045164e-03  6.504700e-04   0.004056
# tot-YUPRAF_19-3925-cfDNA     0.003500  5.110292e-03  2.918389e-02   0.012681
# tot-YUTHEA_20-4000-cfDNA     0.000398  9.917290e-04  8.606900e-03   0.012861
#
#                                CD8 TCM       CD8 TEM     CD8 TEMRA     Tregs  \
# Mixture
# Y-3674-cfDNA              9.970000e-05  1.795570e-04  2.070000e-06  0.006706
# Y-3707-cfDNA              2.860000e-08  4.730000e-10  9.480000e-11  0.000016
# y4-YUPARK_18_3832-cfDNA   3.590000e-06  3.870000e-05  2.200000e-06  0.034115
# tot-YUPRAF_19-3925-cfDNA  9.618836e-03  2.241896e-03  7.952742e-03  0.017252
# tot-YUTHEA_20-4000-cfDNA  5.988140e-03  9.970000e-06  5.180366e-03  0.008534
#
#                                 NK   Naive B  ...  Mac (M0)  Mac (M1)  \
# Mixture                                       ...
# Y-3674-cfDNA              0.033223  0.013947  ...  0.002628  0.030993
# Y-3707-cfDNA              0.079011  0.000004  ...  0.000975  0.002622
# y4-YUPARK_18_3832-cfDNA   0.036186  0.013948  ...  0.040347  0.005203
# tot-YUPRAF_19-3925-cfDNA  0.068945  0.013447  ...  0.067602  0.008421
# tot-YUTHEA_20-4000-cfDNA  0.053668  0.000097  ...  0.021735  0.038560
#
#                           Mac (M2)       iDC       mDC       PMN  Eosinophil  \
# Mixture
# Y-3674-cfDNA              0.025516  0.003596  0.002600  0.515463    0.069854
# Y-3707-cfDNA              0.000131  0.010171  0.126143  0.329549    0.069615
# y4-YUPARK_18_3832-cfDNA   0.040933  0.001092  0.006202  0.400931    0.018345
# tot-YUPRAF_19-3925-cfDNA  0.009274  0.072569  0.021773  0.245548    0.099955
# tot-YUTHEA_20-4000-cfDNA  0.021640  0.009438  0.074949  0.200351    0.062859
#
#                           Megakaryocyte  Erythroblast  em4_real
# Mixture
# Y-3674-cfDNA                   0.181888      0.055276         0
# Y-3707-cfDNA                   0.223249      0.137665         0
# y4-YUPARK_18_3832-cfDNA        0.243306      0.079347         0
# tot-YUPRAF_19-3925-cfDNA       0.129723      0.063849         1
# tot-YUTHEA_20-4000-cfDNA       0.140574      0.248520         1
#
# [5 rows x 23 columns]

# %%
outdf.to_csv(infile+"_ctrename.txt",sep="\t")
