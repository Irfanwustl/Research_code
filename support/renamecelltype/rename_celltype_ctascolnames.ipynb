# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_code/visualization/boxplot_allct/allct_towardsSM_dummy_mean_SM.txt_unique_withmincol.txtEPCAM_mean_SM_top1000.txt_result_dupindex_binnedstats.pkl_maxscore_ctporportion_CSxOut_per.txt'



##cell type as index###

indf=pd.read_csv(infile,sep="\t",index_col=0)
indf.head()
# Out:
#                     EPCAM        Eo        Er        M0        M1        M2  \
# Mixture
# BS-Seq_01-spike  2.568323  2.022796  1.934127  2.652317  2.901582  2.150131
# BS-Seq_03-spike  1.421512  1.696073  1.450041  2.292119  2.229439  1.717806
# BS-Seq_04-spike  1.285967  1.708439  1.221364  2.244072  2.220381  1.628505
# BS-Seq_05-spike  1.228885  1.633989  1.209955  2.245713  2.155078  1.690769
# BS-Seq_06-spike  1.193630  1.650655  1.315635  2.237639  2.152262  1.606511
#
#                        Mg      Mono        NK   NaiveCD4  ...     Tregs  \
# Mixture                                                   ...
# BS-Seq_01-spike  2.507758  3.211536  3.227744   9.398010  ...  7.940810
# BS-Seq_03-spike  1.960925  3.292114  3.386494  10.502142  ...  8.552390
# BS-Seq_04-spike  1.790627  3.334569  3.360755  10.624555  ...  8.823499
# BS-Seq_05-spike  1.779728  3.213254  3.433114  11.051540  ...  8.734257
# BS-Seq_06-spike  1.773730  3.348896  3.357969  11.120706  ...  8.754222
#
#                        cm4       cm8       ed8       em4       em8       iDC  \
# Mixture
# BS-Seq_01-spike   9.619219  8.008528  5.614712  9.018711  7.969168  2.492954
# BS-Seq_03-spike  10.392768  8.224834  5.831532  8.968518  8.345698  2.168622
# BS-Seq_04-spike  10.097011  8.577277  5.991402  9.327443  7.985063  2.256903
# BS-Seq_05-spike  10.073534  8.269248  6.006382  9.356504  8.225221  2.252334
# BS-Seq_06-spike  10.397721  8.531313  5.953745  9.239170  8.226249  2.083085
#
#                        mB       mDC        nB
# Mixture
# BS-Seq_01-spike  1.940824  2.904817  2.534281
# BS-Seq_03-spike  1.936801  2.418415  2.632272
# BS-Seq_04-spike  1.878933  2.372625  2.539192
# BS-Seq_05-spike  1.937661  2.247790  2.658668
# BS-Seq_06-spike  1.942108  2.255123  2.517772
#
# [5 rows x 22 columns]

# %%
standardnamedict={"M0":"Mac (M0)","M1":"Mac (M1)","M2":"Mac (M2)","NaiveCD4":"Naive CD4 T","NaiveCD8":"Naive CD8","CD4": "Naive CD4", "CD8": "Naive CD8 T","mB":"Memory B",'Mn':'Mono','CD14':'Mono','CD19':'B Cell','nB':'Naive B','PC':'PC','cm8':'CD8 TCM','em8':'CD8 TEM','m8':'CD8 memory','ed8':'CD8 TEMRA','cm4':'CD4 TCM','em4':'CD4 TEM','m4':'CD4 memory','mNeu':'PMN','Eo':'Eosinophil','Tr':'Tregs','Mg':'Megakaryocyte','Er':'Erythrocyte'}

# %%
outdf=indf.copy()
outdf.rename(columns=standardnamedict,inplace=True)
outdf.head()
# Out:
#                     EPCAM  Eosinophil  Erythrocyte  Mac (M0)  Mac (M1)  \
# Mixture
# BS-Seq_01-spike  2.568323    2.022796     1.934127  2.652317  2.901582
# BS-Seq_03-spike  1.421512    1.696073     1.450041  2.292119  2.229439
# BS-Seq_04-spike  1.285967    1.708439     1.221364  2.244072  2.220381
# BS-Seq_05-spike  1.228885    1.633989     1.209955  2.245713  2.155078
# BS-Seq_06-spike  1.193630    1.650655     1.315635  2.237639  2.152262
#
#                  Mac (M2)  Megakaryocyte      Mono        NK  Naive CD4 T  \
# Mixture
# BS-Seq_01-spike  2.150131       2.507758  3.211536  3.227744     9.398010
# BS-Seq_03-spike  1.717806       1.960925  3.292114  3.386494    10.502142
# BS-Seq_04-spike  1.628505       1.790627  3.334569  3.360755    10.624555
# BS-Seq_05-spike  1.690769       1.779728  3.213254  3.433114    11.051540
# BS-Seq_06-spike  1.606511       1.773730  3.348896  3.357969    11.120706
#
#                  ...     Tregs    CD4 TCM   CD8 TCM  CD8 TEMRA   CD4 TEM  \
# Mixture          ...
# BS-Seq_01-spike  ...  7.940810   9.619219  8.008528   5.614712  9.018711
# BS-Seq_03-spike  ...  8.552390  10.392768  8.224834   5.831532  8.968518
# BS-Seq_04-spike  ...  8.823499  10.097011  8.577277   5.991402  9.327443
# BS-Seq_05-spike  ...  8.734257  10.073534  8.269248   6.006382  9.356504
# BS-Seq_06-spike  ...  8.754222  10.397721  8.531313   5.953745  9.239170
#
#                   CD8 TEM       iDC  Memory B       mDC   Naive B
# Mixture
# BS-Seq_01-spike  7.969168  2.492954  1.940824  2.904817  2.534281
# BS-Seq_03-spike  8.345698  2.168622  1.936801  2.418415  2.632272
# BS-Seq_04-spike  7.985063  2.256903  1.878933  2.372625  2.539192
# BS-Seq_05-spike  8.225221  2.252334  1.937661  2.247790  2.658668
# BS-Seq_06-spike  8.226249  2.083085  1.942108  2.255123  2.517772
#
# [5 rows x 22 columns]

# %%
outdf.to_csv(infile+"_ctrename.txt",sep="\t")
