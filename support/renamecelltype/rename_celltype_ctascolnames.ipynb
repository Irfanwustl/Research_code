# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/OurCD8TIL_ranked/compare_BSseq_EMseq_result/cross_correlation_divideby_mappedreads/cross_corr_divide_by_avilable_fragmens/tested_frag/EM_melanoma_cfDNA_v3.txt'



##cell type as index###

indf=pd.read_csv(infile,sep="\t",index_col=0)
indf.head()
# Out:
#                      NaiveCD4  NaiveCD8     nB     NK   Mono    M0     M1  \
# Mixture
# YUALOE-20-4117-auto      8229      5975  16805  14100  17449  5843  15933
# YUARGE-14-3173-auto      5916      4282  12429  10579  12937  4071  11360
# YUBAIX-15-3422-auto      9261      6824  18895  16448  20488  6721  18731
# YUBIFO-15-3368-auto      6323      4817  13158  11450  14198  4560  12373
# YUCADA-14-3260-auto      5563      4136  11494   9997  12378  3993  11045
#
#                         M2   iDC   mDC  ...    em8     Eo  Tregs    em4  \
# Mixture                                 ...
# YUALOE-20-4117-auto  17666  6061  6896  ...  12246  63552   6347  14732
# YUARGE-14-3173-auto  12015  4110  4695  ...   9290  52237   4973  11954
# YUBAIX-15-3422-auto  20609  6837  7831  ...  14276  74602   7175  16965
# YUBIFO-15-3368-auto  13842  4773  5495  ...   9891  52966   4937  12110
# YUCADA-14-3260-auto  12268  4305  5027  ...   8871  44833   4455  10648
#
#                        ed8     Mg   cm4     Er     mB  CD8TIL
# Mixture
# YUALOE-20-4117-auto  20297   9602  8265  11513  26566    1520
# YUARGE-14-3173-auto  14707   8158  6384   9044  19538    1108
# YUBAIX-15-3422-auto  23413  11321  9305  13151  30587    1649
# YUBIFO-15-3368-auto  16707   8828  6603   9696  21070    1247
# YUCADA-14-3260-auto  14257   7082  5837   8083  18518    1009
#
# [5 rows x 22 columns]

# %%
standardnamedict={"M0":"Mac (M0)","M1":"Mac (M1)","M2":"Mac (M2)","NaiveCD4":"Naive CD4 T","NaiveCD8":"Naive CD8","CD4": "Naive CD4", "CD8": "Naive CD8 T","mB":"Memory B",'Mn':'Mono','CD14':'Mono','CD19':'B Cell','nB':'Naive B','PC':'PC','cm8':'CD8 TCM','em8':'CD8 TEM','m8':'CD8 memory','ed8':'CD8 TEMRA','cm4':'CD4 TCM','em4':'CD4 TEM','m4':'CD4 memory','mNeu':'PMN','Eo':'Eosinophil','Tr':'Tregs','Mg':'Megakaryocyte','Er':'Erythrocyte'}

# %%
outdf=indf.copy()
outdf.rename(columns=standardnamedict,inplace=True)
outdf.head()
# Out:
#                      Naive CD4 T  Naive CD8  Naive B     NK   Mono  Mac (M0)  \
# Mixture
# YUALOE-20-4117-auto         8229       5975    16805  14100  17449      5843
# YUARGE-14-3173-auto         5916       4282    12429  10579  12937      4071
# YUBAIX-15-3422-auto         9261       6824    18895  16448  20488      6721
# YUBIFO-15-3368-auto         6323       4817    13158  11450  14198      4560
# YUCADA-14-3260-auto         5563       4136    11494   9997  12378      3993
#
#                      Mac (M1)  Mac (M2)   iDC   mDC  ...  CD8 TEM  Eosinophil  \
# Mixture                                              ...
# YUALOE-20-4117-auto     15933     17666  6061  6896  ...    12246       63552
# YUARGE-14-3173-auto     11360     12015  4110  4695  ...     9290       52237
# YUBAIX-15-3422-auto     18731     20609  6837  7831  ...    14276       74602
# YUBIFO-15-3368-auto     12373     13842  4773  5495  ...     9891       52966
# YUCADA-14-3260-auto     11045     12268  4305  5027  ...     8871       44833
#
#                      Tregs  CD4 TEM  CD8 TEMRA  Megakaryocyte  CD4 TCM  \
# Mixture
# YUALOE-20-4117-auto   6347    14732      20297           9602     8265
# YUARGE-14-3173-auto   4973    11954      14707           8158     6384
# YUBAIX-15-3422-auto   7175    16965      23413          11321     9305
# YUBIFO-15-3368-auto   4937    12110      16707           8828     6603
# YUCADA-14-3260-auto   4455    10648      14257           7082     5837
#
#                      Erythrocyte  Memory B  CD8TIL
# Mixture
# YUALOE-20-4117-auto        11513     26566    1520
# YUARGE-14-3173-auto         9044     19538    1108
# YUBAIX-15-3422-auto        13151     30587    1649
# YUBIFO-15-3368-auto         9696     21070    1247
# YUCADA-14-3260-auto         8083     18518    1009
#
# [5 rows x 22 columns]

# %%
outdf.to_csv(infile+"_ctrename.txt",sep="\t")
