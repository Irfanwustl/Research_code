# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_code/Bilge/boxplots/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkladjustedScore_minus_avgdivbyCTFRAG_CSxOut.txt_irAEgt.txt'



##cell type as index###

indf=pd.read_csv(infile,sep="\t",index_col=0)
indf.head()
# Out:
#                           NaiveCD4  NaiveCD8        nB        NK        PC  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.051588  0.069508  0.065360  0.113798  0.052444
# tot-YUTAUR_19-3926-cfDNA  0.040885  0.023596  0.038292  0.060977  0.059791
# tot-YUTHEA_20-4000-cfDNA  0.055914  0.058524  0.054953  0.103133  0.108493
# Y-3674-cfDNA              0.043760  0.024630  0.065414  0.085665  0.075339
# Y-3688-cfDNA              0.057362  0.046655  0.044115  0.080198  0.070375
#
#                               Mono        M0        M1        M2       iDC  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.127384  0.085173  0.083226  0.078528  0.088162
# tot-YUTAUR_19-3926-cfDNA  0.062151  0.046403  0.035177  0.043406  0.051047
# tot-YUTHEA_20-4000-cfDNA  0.086785  0.091219  0.085925  0.084632  0.087027
# Y-3674-cfDNA              0.052723  0.065758  0.040855  0.057082  0.064706
# Y-3688-cfDNA              0.058068  0.092349  0.105148  0.086074  0.079564
#
#                           ...       em8        Eo     Tregs       em4  \
# Mixture                   ...
# tot-YUPRAF_19-3925-cfDNA  ...  0.080193  0.138554  0.063134  0.084466
# tot-YUTAUR_19-3926-cfDNA  ...  0.038995  0.067405  0.038230  0.023246
# tot-YUTHEA_20-4000-cfDNA  ...  0.036822  0.120978  0.085872  0.085402
# Y-3674-cfDNA              ...  0.002568  0.099576  0.059566  0.037973
# Y-3688-cfDNA              ...  0.030585  0.066583  0.083938  0.066338
#
#                                ed8        Mg       cm4        Er        mB  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.082407  0.180821  0.077413  0.155470  0.053942
# tot-YUTAUR_19-3926-cfDNA  0.066276  0.151325  0.033961  0.110148  0.071457
# tot-YUTHEA_20-4000-cfDNA  0.091146  0.404789  0.046982  0.321342  0.053298
# Y-3674-cfDNA              0.032232  0.245207  0.007761  0.155339  0.059898
# Y-3688-cfDNA              0.075597  0.223682  0.039389  0.256827  0.047222
#
#                           Toxicity
# Mixture
# tot-YUPRAF_19-3925-cfDNA         1
# tot-YUTAUR_19-3926-cfDNA         3
# tot-YUTHEA_20-4000-cfDNA         1
# Y-3674-cfDNA                     0
# Y-3688-cfDNA                     3
#
# [5 rows x 23 columns]

# %%
standardnamedict={"NaiveCD4":"Naive CD4","NaiveCD8":"Naive CD8","CD4": "Naive CD4", "CD8": "Naive CD8","mB":"Memory B cell",'Mn':'Mono','CD14':'Mono','CD19':'B Cell','nB':'Naive B cell','PC':'Plasma','cm8':'CD8 central memory','em8':'CD8 effector memory','m8':'CD8 memory','ed8':'CD8 effector','cm4':'CD4 central memory','em4':'CD4 effector memory','m4':'CD4 memory','mNeu':'PMN','Eo':'Eosinophil','Tr':'Tregs','Mg':'Megakaryocyte','Er':'Erythrocyte'}

# %%
outdf=indf.copy()
outdf.rename(columns=standardnamedict,inplace=True)
outdf.head()
# Out:
#                           Naive CD4  Naive CD8  Naive B cell        NK  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA   0.051588   0.069508      0.065360  0.113798
# tot-YUTAUR_19-3926-cfDNA   0.040885   0.023596      0.038292  0.060977
# tot-YUTHEA_20-4000-cfDNA   0.055914   0.058524      0.054953  0.103133
# Y-3674-cfDNA               0.043760   0.024630      0.065414  0.085665
# Y-3688-cfDNA               0.057362   0.046655      0.044115  0.080198
#
#                             Plasma      Mono        M0        M1        M2  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.052444  0.127384  0.085173  0.083226  0.078528
# tot-YUTAUR_19-3926-cfDNA  0.059791  0.062151  0.046403  0.035177  0.043406
# tot-YUTHEA_20-4000-cfDNA  0.108493  0.086785  0.091219  0.085925  0.084632
# Y-3674-cfDNA              0.075339  0.052723  0.065758  0.040855  0.057082
# Y-3688-cfDNA              0.070375  0.058068  0.092349  0.105148  0.086074
#
#                                iDC  ...  CD8 effector memory  Eosinophil  \
# Mixture                             ...
# tot-YUPRAF_19-3925-cfDNA  0.088162  ...             0.080193    0.138554
# tot-YUTAUR_19-3926-cfDNA  0.051047  ...             0.038995    0.067405
# tot-YUTHEA_20-4000-cfDNA  0.087027  ...             0.036822    0.120978
# Y-3674-cfDNA              0.064706  ...             0.002568    0.099576
# Y-3688-cfDNA              0.079564  ...             0.030585    0.066583
#
#                              Tregs  CD4 effector memory  CD8 effector  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.063134             0.084466      0.082407
# tot-YUTAUR_19-3926-cfDNA  0.038230             0.023246      0.066276
# tot-YUTHEA_20-4000-cfDNA  0.085872             0.085402      0.091146
# Y-3674-cfDNA              0.059566             0.037973      0.032232
# Y-3688-cfDNA              0.083938             0.066338      0.075597
#
#                           Megakaryocyte  CD4 central memory  Erythrocyte  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA       0.180821            0.077413     0.155470
# tot-YUTAUR_19-3926-cfDNA       0.151325            0.033961     0.110148
# tot-YUTHEA_20-4000-cfDNA       0.404789            0.046982     0.321342
# Y-3674-cfDNA                   0.245207            0.007761     0.155339
# Y-3688-cfDNA                   0.223682            0.039389     0.256827
#
#                           Memory B cell  Toxicity
# Mixture
# tot-YUPRAF_19-3925-cfDNA       0.053942         1
# tot-YUTAUR_19-3926-cfDNA       0.071457         3
# tot-YUTHEA_20-4000-cfDNA       0.053298         1
# Y-3674-cfDNA                   0.059898         0
# Y-3688-cfDNA                   0.047222         3
#
# [5 rows x 23 columns]

# %%
outdf.to_csv(infile+"_ctrename.txt",sep="\t")
