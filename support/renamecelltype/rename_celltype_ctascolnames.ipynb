# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/OurCD8TIL_ranked/melanoma_EMseq_thirdbatch/combined_result/deconresult_gt/method1Fract_BLU2_majorrankedV1_index.txt_inflectionSM.txt_result_posscore.txt_CSxOut.txt_yale3rdbatch_gt.txt'



##cell type as index###

indf=pd.read_csv(infile,sep="\t",index_col=0)
indf.head()
# Out:
#                            Mono      Bcell        CD4        CD8         NK  \
# Mixture
# YUAMPLE-21-4224-auto  47.110225  13.858250  11.185586  10.546810  17.299130
# YUBOISE-21-4256-auto  40.519527  15.350854  16.624770  11.577880  15.926969
# YUBROMO-18-3798-auto  45.044526  14.872779  11.366829  11.248157  17.467710
# YUDUCO-21-4244-auto   39.901264  13.297252  17.146953  12.951430  16.703101
# YUGIRL-18-3842-auto   43.311273  12.912803  16.916614  10.373048  16.486261
#
#                      Response  Toxicity
# Mixture
# YUAMPLE-21-4224-auto      DCB       NaN
# YUBOISE-21-4256-auto      NDB       NaN
# YUBROMO-18-3798-auto      NaN       3.0
# YUDUCO-21-4244-auto       DCB       NaN
# YUGIRL-18-3842-auto       NaN       0.0

# %%
standardnamedict={"M0":"Mac (M0)","M1":"Mac (M1)","M2":"Mac (M2)","NaiveCD4":"Naive CD4 T","NaiveCD8":"Naive CD8","CD4": "Naive CD4", "CD8": "Naive CD8 T","mB":"Memory B",'Mn':'Mono','CD14':'Mono','CD19':'B Cell','nB':'Naive B','PC':'PC','cm8':'CD8 TCM','em8':'CD8 TEM','m8':'CD8 memory','ed8':'CD8 TEMRA','cm4':'CD4 TCM','em4':'CD4 TEM','m4':'CD4 memory','mNeu':'PMN','Eo':'Eosinophil','Tr':'Tregs','Mg':'Megakaryocyte','Er':'Erythrocyte'}

# %%
outdf=indf.copy()
outdf.rename(columns=standardnamedict,inplace=True)
outdf.head()
# Out:
#                            Mono      Bcell  Naive CD4  Naive CD8 T         NK  \
# Mixture
# YUAMPLE-21-4224-auto  47.110225  13.858250  11.185586    10.546810  17.299130
# YUBOISE-21-4256-auto  40.519527  15.350854  16.624770    11.577880  15.926969
# YUBROMO-18-3798-auto  45.044526  14.872779  11.366829    11.248157  17.467710
# YUDUCO-21-4244-auto   39.901264  13.297252  17.146953    12.951430  16.703101
# YUGIRL-18-3842-auto   43.311273  12.912803  16.916614    10.373048  16.486261
#
#                      Response  Toxicity
# Mixture
# YUAMPLE-21-4224-auto      DCB       NaN
# YUBOISE-21-4256-auto      NDB       NaN
# YUBROMO-18-3798-auto      NaN       3.0
# YUDUCO-21-4244-auto       DCB       NaN
# YUGIRL-18-3842-auto       NaN       0.0

# %%
outdf.to_csv(infile+"_ctrename.txt",sep="\t")
