# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/OurCD8TIL_ranked/melanoma_EMseq_secondlane/EM_seconbatch_result/merging/deconresult_tosend_gtto_send/method1Fract_CD8TIL_pbl_tum_all_matrix_allout_ranked_SM_top100_SM_unique_result_dupindex_binnedstats.pkl_maxscore_CSxOut.txt_gtto_send.txt'



##cell type as index###

indf=pd.read_csv(infile,sep="\t",index_col=0)
indf.head()
# Out:
#                       NaiveCD4  NaiveCD8        nB        NK  PC      Mono  \
# Mixture
# YUBLIT-11-2164-auto   2.789613  3.594492  3.304648  3.470132   0  5.545010
# YUBRET-15-3411-auto   3.355530  3.658127  3.662609  3.878924   0  4.447035
# YUBUMP-14-3166-auto   3.623301  2.921395  3.776146  3.814303   0  4.433174
# YUCEVO-20-4119-auto   3.290976  2.998540  3.554726  3.506960   0  3.660463
# YUCONFE-14-3261-auto  3.123962  3.294694  3.656501  4.282633   0  5.644905
#
#                             M0        M1        M2       iDC  ...     Tregs  \
# Mixture                                                       ...
# YUBLIT-11-2164-auto   5.382506  4.622957  3.776820  4.690597  ...  3.577598
# YUBRET-15-3411-auto   4.306827  3.987767  3.705169  4.143537  ...  3.644886
# YUBUMP-14-3166-auto   4.615345  4.321107  4.249944  4.691179  ...  3.114092
# YUCEVO-20-4119-auto   3.941154  3.798624  3.698900  4.122373  ...  3.438098
# YUCONFE-14-3261-auto  4.633997  4.320666  3.969558  4.854613  ...  3.160537
#
#                            em4       ed8         Mg       cm4        Er  \
# Mixture
# YUBLIT-11-2164-auto   3.746580  3.703385   9.274178  3.608610  8.199986
# YUBRET-15-3411-auto   3.545147  3.617759   9.845234  3.371908  7.732538
# YUBUMP-14-3166-auto   3.008823  3.413882   9.830042  3.248598  8.779211
# YUCEVO-20-4119-auto   3.821051  3.539166  12.178349  3.670086  9.871005
# YUCONFE-14-3261-auto  3.364284  3.789457   7.193714  2.962658  6.483081
#
#                             mB    CD8TIL  Toxicity  ICI.response.status
# Mixture
# YUBLIT-11-2164-auto   2.740111  4.518322       2.0                  DCB
# YUBRET-15-3411-auto   3.326680  4.065404       2.0                  DCB
# YUBUMP-14-3166-auto   3.113404  4.779995       0.0                  NDB
# YUCEVO-20-4119-auto   2.751290  4.873366       1.0                  DCB
# YUCONFE-14-3261-auto  2.804695  5.132291       NaN                  DCB
#
# [5 rows x 25 columns]

# %%
standardnamedict={"M0":"Mac (M0)","M1":"Mac (M1)","M2":"Mac (M2)","NaiveCD4":"Naive CD4 T","NaiveCD8":"Naive CD8","CD4": "Naive CD4", "CD8": "Naive CD8 T","mB":"Memory B",'Mn':'Mono','CD14':'Mono','CD19':'B Cell','nB':'Naive B','PC':'PC','cm8':'CD8 TCM','em8':'CD8 TEM','m8':'CD8 memory','ed8':'CD8 TEMRA','cm4':'CD4 TCM','em4':'CD4 TEM','m4':'CD4 memory','mNeu':'PMN','Eo':'Eosinophil','Tr':'Tregs','Mg':'Megakaryocyte','Er':'Erythrocyte'}

# %%
outdf=indf.copy()
outdf.rename(columns=standardnamedict,inplace=True)
outdf.head()
# Out:
#                       Naive CD4 T  Naive CD8   Naive B        NK  PC  \
# Mixture
# YUBLIT-11-2164-auto      2.789613   3.594492  3.304648  3.470132   0
# YUBRET-15-3411-auto      3.355530   3.658127  3.662609  3.878924   0
# YUBUMP-14-3166-auto      3.623301   2.921395  3.776146  3.814303   0
# YUCEVO-20-4119-auto      3.290976   2.998540  3.554726  3.506960   0
# YUCONFE-14-3261-auto     3.123962   3.294694  3.656501  4.282633   0
#
#                           Mono  Mac (M0)  Mac (M1)  Mac (M2)       iDC  ...  \
# Mixture                                                                 ...
# YUBLIT-11-2164-auto   5.545010  5.382506  4.622957  3.776820  4.690597  ...
# YUBRET-15-3411-auto   4.447035  4.306827  3.987767  3.705169  4.143537  ...
# YUBUMP-14-3166-auto   4.433174  4.615345  4.321107  4.249944  4.691179  ...
# YUCEVO-20-4119-auto   3.660463  3.941154  3.798624  3.698900  4.122373  ...
# YUCONFE-14-3261-auto  5.644905  4.633997  4.320666  3.969558  4.854613  ...
#
#                          Tregs   CD4 TEM  CD8 TEMRA  Megakaryocyte   CD4 TCM  \
# Mixture
# YUBLIT-11-2164-auto   3.577598  3.746580   3.703385       9.274178  3.608610
# YUBRET-15-3411-auto   3.644886  3.545147   3.617759       9.845234  3.371908
# YUBUMP-14-3166-auto   3.114092  3.008823   3.413882       9.830042  3.248598
# YUCEVO-20-4119-auto   3.438098  3.821051   3.539166      12.178349  3.670086
# YUCONFE-14-3261-auto  3.160537  3.364284   3.789457       7.193714  2.962658
#
#                       Erythrocyte  Memory B    CD8TIL  Toxicity  \
# Mixture
# YUBLIT-11-2164-auto      8.199986  2.740111  4.518322       2.0
# YUBRET-15-3411-auto      7.732538  3.326680  4.065404       2.0
# YUBUMP-14-3166-auto      8.779211  3.113404  4.779995       0.0
# YUCEVO-20-4119-auto      9.871005  2.751290  4.873366       1.0
# YUCONFE-14-3261-auto     6.483081  2.804695  5.132291       NaN
#
#                       ICI.response.status
# Mixture
# YUBLIT-11-2164-auto                   DCB
# YUBRET-15-3411-auto                   DCB
# YUBUMP-14-3166-auto                   NDB
# YUCEVO-20-4119-auto                   DCB
# YUCONFE-14-3261-auto                  DCB
#
# [5 rows x 25 columns]

# %%
outdf.to_csv(infile+"_ctrename.txt",sep="\t")
