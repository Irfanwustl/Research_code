# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22_tiered/irAE/ALLctReference/forbarplot/allct_towardsSM_dummy_mean_SM.txt_unique_result_dupindex_binnedstats.pkl_maxscore_ctporportion_CSxOut.txtMergedResponseRC_pretx.txt'



##cell type as index###

indf=pd.read_csv(infile,sep="\t",index_col=0)
indf.head()
# Out:
#                     Eo        Er        M0        M1        M2        Mg  \
# Mixture
# Y-3688-cfDNA  0.051168  0.092592  0.062468  0.053787  0.033517  0.125528
# Y-3703-cfDNA  0.051390  0.104722  0.055247  0.045195  0.036792  0.112878
# Y-3715-cfDNA  0.058233  0.087549  0.049412  0.046058  0.033999  0.102446
# Y-3918-cfDNA  0.059931  0.049578  0.056697  0.050255  0.039778  0.078565
# Y-3920-cfDNA  0.054407  0.084027  0.053386  0.040411  0.032590  0.111758
#
#                   Mono        NK  NaiveCD4  NaiveCD8  ...       cm4       cm8  \
# Mixture                                               ...
# Y-3688-cfDNA  0.041508  0.031229  0.029916  0.029847  ...  0.036146  0.034623
# Y-3703-cfDNA  0.043369  0.033510  0.030785  0.023097  ...  0.034040  0.035271
# Y-3715-cfDNA  0.050453  0.033438  0.025228  0.028891  ...  0.032847  0.031455
# Y-3918-cfDNA  0.048568  0.029731  0.036899  0.030494  ...  0.047930  0.036928
# Y-3920-cfDNA  0.062688  0.034095  0.031340  0.027098  ...  0.037138  0.027417
#
#                    ed8       em4       em8       iDC        mB       mDC  \
# Mixture
# Y-3688-cfDNA  0.032303  0.051322  0.041882  0.046104  0.022810  0.040750
# Y-3703-cfDNA  0.036097  0.043447  0.039912  0.040795  0.021538  0.042971
# Y-3715-cfDNA  0.028270  0.032198  0.028867  0.048250  0.020398  0.040545
# Y-3918-cfDNA  0.036764  0.050751  0.036070  0.048196  0.023477  0.042912
# Y-3920-cfDNA  0.037369  0.040342  0.037997  0.032475  0.016948  0.039085
#
#                     nB  Toxicity
# Mixture
# Y-3688-cfDNA  0.026933         3
# Y-3703-cfDNA  0.023958         3
# Y-3715-cfDNA  0.025890         3
# Y-3918-cfDNA  0.031547         3
# Y-3920-cfDNA  0.032585         3
#
# [5 rows x 22 columns]

# %%
standardnamedict={"M0":"Mac (M0)","M1":"Mac (M1)","M2":"Mac (M2)","NaiveCD4":"Naive CD4 T","NaiveCD8":"Naive CD8","CD4": "Naive CD4", "CD8": "Naive CD8 T","mB":"Memory B",'Mn':'Mono','CD14':'Mono','CD19':'B Cell','nB':'Naive B','PC':'PC','cm8':'CD8 TCM','em8':'CD8 TEM','m8':'CD8 memory','ed8':'CD8 TEMRA','cm4':'CD4 TCM','em4':'CD4 TEM','m4':'CD4 memory','mNeu':'PMN','Eo':'Eosinophil','Tr':'Tregs','Mg':'Megakaryocyte','Er':'Erythrocyte'}

# %%
outdf=indf.copy()
outdf.rename(columns=standardnamedict,inplace=True)
outdf.head()
# Out:
#               Eosinophil  Erythrocyte  Mac (M0)  Mac (M1)  Mac (M2)  \
# Mixture
# Y-3688-cfDNA    0.051168     0.092592  0.062468  0.053787  0.033517
# Y-3703-cfDNA    0.051390     0.104722  0.055247  0.045195  0.036792
# Y-3715-cfDNA    0.058233     0.087549  0.049412  0.046058  0.033999
# Y-3918-cfDNA    0.059931     0.049578  0.056697  0.050255  0.039778
# Y-3920-cfDNA    0.054407     0.084027  0.053386  0.040411  0.032590
#
#               Megakaryocyte      Mono        NK  Naive CD4 T  Naive CD8  ...  \
# Mixture                                                                  ...
# Y-3688-cfDNA       0.125528  0.041508  0.031229     0.029916   0.029847  ...
# Y-3703-cfDNA       0.112878  0.043369  0.033510     0.030785   0.023097  ...
# Y-3715-cfDNA       0.102446  0.050453  0.033438     0.025228   0.028891  ...
# Y-3918-cfDNA       0.078565  0.048568  0.029731     0.036899   0.030494  ...
# Y-3920-cfDNA       0.111758  0.062688  0.034095     0.031340   0.027098  ...
#
#                CD4 TCM   CD8 TCM  CD8 TEMRA   CD4 TEM   CD8 TEM       iDC  \
# Mixture
# Y-3688-cfDNA  0.036146  0.034623   0.032303  0.051322  0.041882  0.046104
# Y-3703-cfDNA  0.034040  0.035271   0.036097  0.043447  0.039912  0.040795
# Y-3715-cfDNA  0.032847  0.031455   0.028270  0.032198  0.028867  0.048250
# Y-3918-cfDNA  0.047930  0.036928   0.036764  0.050751  0.036070  0.048196
# Y-3920-cfDNA  0.037138  0.027417   0.037369  0.040342  0.037997  0.032475
#
#               Memory B       mDC   Naive B  Toxicity
# Mixture
# Y-3688-cfDNA  0.022810  0.040750  0.026933         3
# Y-3703-cfDNA  0.021538  0.042971  0.023958         3
# Y-3715-cfDNA  0.020398  0.040545  0.025890         3
# Y-3918-cfDNA  0.023477  0.042912  0.031547         3
# Y-3920-cfDNA  0.016948  0.039085  0.032585         3
#
# [5 rows x 22 columns]

# %%
outdf.to_csv(infile+"_ctrename.txt",sep="\t")
