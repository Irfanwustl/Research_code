# %%
import pandas as pd

oursequence='/Users/irffanalahi/Research/Research_update/troubleshootoffbyoneissue/promdatareadyfolder_thatCD8TIL_.6.2_andothercpgs/that.6_.2_fixed.txt_missing.txt'

othersequene='/Users/irffanalahi/Research/Research_update/troubleshootoffbyoneissue/BL22promfolder_thatCD8TIL_.6.2_andothercpgs/BL22_all_matrix_promdata_intwith_thatCD8TIL.6_.2_fixed.txt_missing_pad10pos.txt'


ourseqdf=pd.read_csv(oursequence,sep='\t')
ourseqdf.head()
# Out:
#   chrom    start      end  \
# 0  chr1   934930   934932
# 1  chr1  2259183  2259185
# 2  chr1  2259191  2259193
# 3  chr1  3181422  3181424
# 4  chr1  3874649  3874651
#
#    aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                                NaN
# 1                                              0.073
# 2                                              0.064
# 3                                              0.753
# 4                                                NaN
#
#    aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.400
# 1                                              0.020
# 2                                              0.019
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
otherseqdf=pd.read_csv(othersequene,sep='\t')
otherseqdf.head()
# Out:
#   chrom    start      end  \
# 0  chr1   934930   934932
# 1  chr1   934939   934941
# 2  chr1  2259183  2259185
# 3  chr1  2259191  2259193
# 4  chr1  2259197  2259199
#
#    aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                                NaN
# 1                                                NaN
# 2                                              0.073
# 3                                              0.064
# 4                                              0.061
#
#    aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.400
# 1                                              0.429
# 2                                              0.020
# 3                                              0.019
# 4                                              0.000
#
# ...

# %%
lessthanone=[]
greaterthanone=[]
forwhichthisishappenning=[]
for index, row in ourseqdf.iterrows():
    currentchrom=row['chrom']
    currentstart=row['start']
    templessthanone=otherseqdf[(otherseqdf['chrom']==currentchrom) & (otherseqdf['start']==currentstart-1)]
    tempgreaterthanone=otherseqdf[(otherseqdf['chrom']==currentchrom) & (otherseqdf['start']==currentstart+1)]
    
    lessthanone.append(templessthanone)
    greaterthanone.append(tempgreaterthanone)
    
    if templessthanone.shape[0]>0 or tempgreaterthanone.shape[0]>0:
        forwhichthisishappenning.append(row)

# %%
lessthanoneDF=pd.concat(lessthanone)
print(lessthanoneDF.shape)
lessthanoneDF.head()
# Out:
# (10, 57)
#      chrom      start        end  \
# 68    chr1  160803554  160803555
# 102   chr1  236842090  236842091
# 219  chr11   71602274   71602275
# 238  chr11  117086545  117086546
# 381  chr13   49370123   49370124
#
#      aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 68                                                 NaN
# 102                                                NaN
# 219                                                NaN
# 238                                                1.0
# 381                                                NaN
#
#      aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 68                                                 NaN
# 102                                                NaN
# 219                                                1.0
# 238                                                NaN
# ...

# %%
greaterthanoneDF=pd.concat(greaterthanone)
print(greaterthanoneDF.shape)
greaterthanoneDF.head()
# Out:
# (10, 57)
#      chrom      start        end  \
# 70    chr1  160803556  160803557
# 104   chr1  236842092  236842093
# 221  chr11   71602276   71602277
# 240  chr11  117086547  117086548
# 383  chr13   49370125   49370126
#
#      aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 70                                                 NaN
# 104                                                NaN
# 221                                                1.0
# 240                                                NaN
# 383                                                NaN
#
#      aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 70                                                 NaN
# 104                                                NaN
# 221                                                NaN
# 240                                                NaN
# ...

# %%
lessthanoneDF.to_csv(othersequene+"_lessthanone.txt",sep='\t',index=False)
greaterthanoneDF.to_csv(othersequene+"_greaterthanone.txt",sep='\t',index=False)
