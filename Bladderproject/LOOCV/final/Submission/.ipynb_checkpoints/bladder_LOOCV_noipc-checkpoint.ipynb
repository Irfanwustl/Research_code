# %%
from sklearn.model_selection import train_test_split, LeaveOneOut, cross_val_score
from sklearn.linear_model import LinearRegression
from numpy import mean
from numpy import absolute
from numpy import sqrt
import numpy as np 
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, roc_auc_score, roc_curve, f1_score, auc

# %%
testfile = 'Bladder Project pCR Prediction Data (Updated 030222).txt'
df=pd.read_csv(testfile,sep='\t',index_col=0)
display(df)
# Out:
#          pCR  Age  Sex  Race  Urothelial  Smoking  NAC  MIBC  Incidental PC  \
# ID
# WBC1045    0   63    1     1           1        1    1     1              1
# WBC1050    1   63    2     1           1        1    1     1              0
# WBC1058    0   78    1     1           1        0    0     1              0
# WBC1062    0   77    1     1           0        1    1     1              0
# WBC1063    1   67    1     1           1        0    1     1              0
# ...      ...  ...  ...   ...         ...      ...  ...   ...            ...
# WBC1312    1   61    1     1           1        0    1     0              0
# WBC1313    0   48    1     1           0        0    1     1              0
# WBC1314    1   73    2     1           1        1    1     1              0
# WBC1315    0   76    1     2           1        0    1     1              1
# WBC1316    1   60    1     1           0        0    1     1              1
#
#          utDNA    TF99
# ID
# WBC1045    2.4   2.400
# WBC1050    0.0   2.500
# WBC1058    5.9   2.400
# WBC1062    2.4   1.600
# WBC1063    0.0   1.700
# ...        ...     ...
# WBC1312    0.0   0.000
# WBC1313    1.9  18.300
# WBC1314    0.3   0.000
# WBC1315   31.3  21.060
# WBC1316    1.8   1.421
#
# [74 rows x 11 columns]

# %%
def perform_cv(operation, cols):
    df_test = df.copy()
    df_test['Operation'] = operation
    df_test = df_test[cols]

    # create loocv procedure
    cv = LeaveOneOut()
    X=df_test.drop(['pCR'],axis=1).to_numpy()
    y=df_test["pCR"].copy().to_numpy()

    # enumerate splits
    y_true, y_pred, y_proba = list(), list(), list()
    X_df = df_test.drop(['pCR'],axis=1)
    df_features = pd.DataFrame(index=X_df.columns)
    df_std = pd.DataFrame(index=X_df.columns)
    i = 0
    for train_ix, test_ix in cv.split(X):
        # split data
        X_train, X_test = X[train_ix, :], X[test_ix, :]
        y_train, y_test = y[train_ix], y[test_ix]

        # fit model
        model = RandomForestClassifier(n_estimators=2000, random_state=1)
        model.fit(X_train, y_train)
        
        # find the best threshold
        pred_train = model.predict_proba(X_train)[:,1]
        
        fpr_train, tpr_train, thresholds_train = roc_curve(y_train, pred_train)
        sens_train_arr = tpr_train
        spec_train_arr = 1 - fpr_train
        gmeans_train = np.sqrt(sens_train_arr * spec_train_arr)
        ix_train = np.argmax(gmeans_train)
        thresh = thresholds_train[ix_train]

        # evaluate model
        yprob = model.predict_proba(X_test)[:,1]
        yhat = list((yprob >= thresh).astype(int))

        y_proba.append(yprob[0])
        y_true.append(y_test[0])
        y_pred.append(yhat[0])
        std = np.std([tree.feature_importances_ for tree in model.estimators_], axis=0)
        importances = model.feature_importances_
        df_features['Trial ' + str(i)] = importances
        df_std['Trial ' + str(i)] = std
        i += 1

    return y_proba, y_true, y_pred, df_features, df_std

# %%
cols = ['pCR', 'Age', 'Sex', 'Race', 'Smoking', 'Urothelial', 'NAC', 'MIBC', 'Operation']
y_proba, y_true, y_pred, df_feat, df_std = perform_cv(np.power((np.array(df['utDNA']) + 1) * (np.array(df['TF99']) + 1), 0.5), cols)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f26d7c27bc1d> in <module>
#       1 cols = ['pCR', 'Age', 'Sex', 'Race', 'Smoking', 'Urothelial', 'NAC', 'MIBC', 'Operation']
# ----> 2 y_proba, y_true, y_pred, df_feat, df_std = perform_cv(np.power((np.array(df['utDNA']) + 1) * (np.array(df['TF99']) + 1), 0.5), cols)
#
# <ipython-input-3-85ff9aee2a02> in perform_cv(operation, cols)
#      22         # fit model
#      23         model = RandomForestClassifier(n_estimators=2000, random_state=1)
# ---> 24         model.fit(X_train, y_train)
#      25
#      26         # find the best threshold
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     377             trees = [self._make_estimator(append=False,
#     378                                           random_state=random_state)
# --> 379                      for i in range(n_more_estimators)]
#     380
#     381             # Parallel loop: we prefer the threading backend as the Cython code
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/ensemble/_forest.py in <listcomp>(.0)
#     377             trees = [self._make_estimator(append=False,
#     378                                           random_state=random_state)
# --> 379                      for i in range(n_more_estimators)]
#     380
#     381             # Parallel loop: we prefer the threading backend as the Cython code
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/ensemble/_base.py in _make_estimator(self, append, random_state)
#     148         sub-estimators.
#     149         """
# --> 150         estimator = clone(self.base_estimator_)
#     151         estimator.set_params(**{p: getattr(self, p)
#     152                                 for p in self.estimator_params})
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/base.py in clone(estimator, safe)
#      72
#      73     klass = estimator.__class__
# ---> 74     new_object_params = estimator.get_params(deep=False)
#      75     for name, param in new_object_params.items():
#      76         new_object_params[name] = clone(param, safe=False)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/base.py in get_params(self, deep)
#     192         """
#     193         out = dict()
# --> 194         for key in self._get_param_names():
#     195             value = getattr(self, key)
#     196             if deep and hasattr(value, 'get_params'):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/base.py in _get_param_names(cls)
#     161         # introspect the constructor arguments to find the model parameters
#     162         # to represent
# --> 163         init_signature = inspect.signature(init)
#     164         # Consider the constructor parameters excluding 'self'
#     165         parameters = [p for p in init_signature.parameters.values()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py in signature(obj, follow_wrapped)
#    3055 def signature(obj, *, follow_wrapped=True):
#    3056     """Get a signature object for the passed callable."""
# -> 3057     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3058
#    3059
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2805         """Constructs Signature for the given callable object."""
#    2806         return _signature_from_callable(obj, sigcls=cls,
# -> 2807                                         follow_wrapper_chains=follow_wrapped)
#    2808
#    2809     @property
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2265         # If it's a pure Python function, or an object that is duck type
#    2266         # of a Python function (Cython functions, for instance), then:
# -> 2267         return _signature_from_function(sigcls, obj)
#    2268
#    2269     if _signature_is_builtin(obj):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/inspect.py in _signature_from_function(cls, func)
#    2138
#    2139     # ... w/ defaults.
# -> 2140     for offset, name in enumerate(positional[non_default_count:]):
#    2141         annotation = annotations.get(name, _empty)
#    2142         parameters.append(Parameter(name, annotation=annotation,
#
# KeyboardInterrupt:

# %%
df_prob = pd.DataFrame([y_true, y_proba], index=['pCR', 'Probability'], columns=df.index).T
df_prob.to_csv(testfile + '_prob_LOOCV.txt', sep='\t')

# %%
df_pred = pd.DataFrame([y_true, y_pred], index=['pCR', 'Prediction'], columns=df.index).T
df_pred.to_csv(testfile + '_pred_LOOCV.txt', sep='\t')

# %%
# calculate accuracy
acc = accuracy_score(y_true, y_pred)
print('Accuracy: %.3f' % acc)

# %%
cm1 = confusion_matrix(y_true, y_pred)
spec_pred = cm1[0,0]/(cm1[0,0]+cm1[0,1])
sens_pred = cm1[1,1]/(cm1[1,0]+cm1[1,1])
df_ss = pd.DataFrame([[sens_pred, spec_pred]], columns=['Sensitivity', 'Specificity'])
df_ss.to_csv(testfile + '_sens_spec_LOOCV.txt', sep='\t', index=None)
display(df_ss)

# %%
fpr, tpr, thresholds = roc_curve(y_true, y_proba)
auc_test = metrics.roc_auc_score(y_true, y_proba)
fig, ax = plt.subplots(1, 1, figsize=(7, 7))
ax.plot(fpr, tpr, label='Auc = ' + str(np.around(auc_test, decimals=2)))
ax.set_xlabel('False Positive Rate', fontsize=13)
ax.set_ylabel('True Positive Rate', fontsize=13)
ax.set_title('ROC Curve for Test Data', fontsize=14)
plt.legend(fontsize=13)
plt.savefig(testfile + '_roc_test_LOOCV.pdf', bbox_inches='tight')

# %%
feat_vals = np.mean(df_feat.to_numpy(), axis=1)

std_vals = np.mean(df_std.to_numpy(), axis=1)

feature_names = np.array(df_feat.index)

# %%
forest_importances = pd.DataFrame([feature_names, feat_vals, std_vals], index=['Features', 'Importances', 'STD'])
forest_importances = forest_importances.T
forest_importances.sort_values(by=['Importances'], inplace=True, ascending=False)
fig, ax = plt.subplots()
bar = sns.barplot(x='Features', y='Importances', yerr=forest_importances['STD'], ax=ax, data=forest_importances, color='tab:blue')
ax.set_title("Feature importances using MDI", fontsize=14)
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
plt.savefig(testfile + '_feature_importance_LOOCV.pdf', bbox_inches='tight')

# %%
df_importances = pd.DataFrame([feature_names, feat_vals, std_vals], \
                              index=['Features', 'Importances', 'STD']).T
df_importances.to_csv(testfile + '_importances_LOOCV.txt', index=None,sep='\t')
df_importances
