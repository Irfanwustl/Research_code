# %%
import pandas as pd
canofile="/Users/irffanalahi/Research/Research_update/GENE/processingWithUCSC/v2/UCSC_canonicalGene.txt"
tobe_cano="/Users/irffanalahi/Research/Research_update/GENE/processingWithUCSC/v2/intron_genecode_v36_modified.txt"
outfile=tobe_cano+"_canonical.txt"



canodf=pd.read_csv(canofile,sep="\t")
tobe_canodf=pd.read_csv(tobe_cano,sep="\t")

canodf.head()
# Out:
#   #hg38.knownCanonical.chrom  hg38.knownCanonical.chromStart  \
# 0                       chr1                       169849630
# 1                       chr1                       169795039
# 2                       chr1                        27612063
# 3                       chr1                       196652042
# 4                       chr1                        24356998
#
#    hg38.knownCanonical.chromEnd hg38.knownCanonical.transcript  \
# 0                     169893896             ENST00000367771.11
# 1                     169854080              ENST00000359326.9
# 2                      27635185              ENST00000374005.8
# 3                     196747504              ENST00000367429.9
# 4                      24415097              ENST00000374409.5
#
#   hg38.kgXref.geneSymbol
# 0                  SCYL3
# 1               C1orf112
# 2                    FGR
# 3                    CFH
# 4                  STPG1

# %%
tobe_canodf.head()
# Out:
#   #hg38.knownCanonical.chrom  hg38.knownCanonical.chromStart  \
# 0                       chr1                           12227
# 1                       chr1                           12721
# 2                       chr1                           12057
# 3                       chr1                           12227
# 4                       chr1                           12697
#
#    hg38.knownCanonical.chromEnd hg38.knownCanonical.transcript  transcriptno  \
# 0                         12612              ENST00000456328.2             0
# 1                         13220              ENST00000456328.2             1
# 2                         12178              ENST00000450305.2             0
# 3                         12612              ENST00000450305.2             1
# 4                         12974              ENST00000450305.2             2
#
#   direction
# 0         +
# 1         +
# 2         +
# 3         +
# 4         +

# %%
outdf=tobe_canodf.merge(canodf,how='inner',on=['hg38.knownCanonical.transcript'])
outdf.head()
# Out:
#   #hg38.knownCanonical.chrom_x  hg38.knownCanonical.chromStart_x  \
# 0                         chr1                             12227
# 1                         chr1                             12721
# 2                         chr1                             14501
# 3                         chr1                             15038
# 4                         chr1                             15947
#
#    hg38.knownCanonical.chromEnd_x hg38.knownCanonical.transcript  \
# 0                           12612              ENST00000456328.2
# 1                           13220              ENST00000456328.2
# 2                           15004              ENST00000488147.1
# 3                           15795              ENST00000488147.1
# 4                           16606              ENST00000488147.1
#
#    transcriptno direction #hg38.knownCanonical.chrom_y  \
# 0             0         +                         chr1
# 1             1         +                         chr1
# ...

# %%
outdf.to_csv(outfile,sep="\t",index=False)
