# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/GENE/processingWithUCSC/v2/intron_genecode_v36_modified.txt_canonical.txt_proteinCodingGene.txt'

indf=pd.read_csv(infile,sep="\t")

indf.head()
# Out:
#   #hg38.knownCanonical.chrom_x  hg38.knownCanonical.chromStart_x  \
# 0                         chr1                            925800
# 1                         chr1                            926013
# 2                         chr1                            930336
# 3                         chr1                            931089
# 4                         chr1                            935896
#
#    hg38.knownCanonical.chromEnd_x hg38.knownCanonical.transcript  \
# 0                          925921              ENST00000342066.8
# 1                          930154              ENST00000342066.8
# 2                          931038              ENST00000342066.8
# 3                          935771              ENST00000342066.8
# 4                          939039              ENST00000342066.8
#
#    transcriptno direction #hg38.knownCanonical.chrom_y  \
# 0             0         +                         chr1
# 1             1         +                         chr1
# ...

# %%
indf=indf.rename(columns={'transcriptno':'prevtranscriptno'})
indf['transcriptno']=-1
indf.head()
# Out:
#   #hg38.knownCanonical.chrom_x  hg38.knownCanonical.chromStart_x  \
# 0                         chr1                            925800
# 1                         chr1                            926013
# 2                         chr1                            930336
# 3                         chr1                            931089
# 4                         chr1                            935896
#
#    hg38.knownCanonical.chromEnd_x hg38.knownCanonical.transcript  \
# 0                          925921              ENST00000342066.8
# 1                          930154              ENST00000342066.8
# 2                          931038              ENST00000342066.8
# 3                          935771              ENST00000342066.8
# 4                          939039              ENST00000342066.8
#
#    prevtranscriptno direction #hg38.knownCanonical.chrom_y  \
# 0                 0         +                         chr1
# 1                 1         +                         chr1
# ...

# %%
grouped=indf.groupby(['hg38.knownCanonical.transcript'])

fixedoutdflist=[]
dynamicoutdflist=[]

for name, group in grouped:
    print(group)
    break
# Out:
#       #hg38.knownCanonical.chrom_x  hg38.knownCanonical.chromStart_x  \
# 74497                         chr7                         127588565
# 74498                         chr7                         127589163
# 74499                         chr7                         127589594
# 74500                         chr7                         127590137
# 74501                         chr7                         127591088
#
#        hg38.knownCanonical.chromEnd_x hg38.knownCanonical.transcript  \
# 74497                       127589082             ENST00000000233.10
# 74498                       127589484             ENST00000000233.10
# 74499                       127590065             ENST00000000233.10
# 74500                       127590962             ENST00000000233.10
# 74501                       127591212             ENST00000000233.10
#
#        prevtranscriptno direction #hg38.knownCanonical.chrom_y  \
# 74497                 0         +                         chr7
# ...
