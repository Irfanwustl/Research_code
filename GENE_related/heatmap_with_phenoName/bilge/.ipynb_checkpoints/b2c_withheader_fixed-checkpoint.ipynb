# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/rankspace_idea/heatmap/BL22promfolder_int_rankedbasedtry1_sortedby_rankedbasedtry1_more/BL22_all_matrix_promdata_intwith_Tregs_CpGdelta_info_faster.txt_3000_forheatunderlyingdata_ranked_pos.txt_sorted_50.txt'
outfile=infile
indf=pd.read_csv(infile,sep='\t')
indf.head()
# Out:
#    chrom      start        end  \
# 0   chrX   49260634   49260636
# 1   chr5  180312122  180312124
# 2  chr18    3898035    3898037
# 3   chr2  235763066  235763068
# 4   chrX   49260621   49260623
#
#    aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              1.000
# 1                                              0.886
# 2                                              0.972
# 3                                              0.941
# 4                                              0.870
#
#    aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.929
# 1                                              0.909
# 2                                              0.976
# 3                                              0.923
# 4                                              0.917
#
# ...

# %%
indf['forpos']=indf['start']+1
indf.head()
# Out:
#    chrom      start        end  \
# 0   chrX   49260634   49260636
# 1   chr5  180312122  180312124
# 2  chr18    3898035    3898037
# 3   chr2  235763066  235763068
# 4   chrX   49260621   49260623
#
#    aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              1.000
# 1                                              0.886
# 2                                              0.972
# 3                                              0.941
# 4                                              0.870
#
#    aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.929
# 1                                              0.909
# 2                                              0.976
# 3                                              0.923
# 4                                              0.917
#
# ...

# %%
indf['position']=indf['chrom']+':'+indf['forpos'].astype(str)
indf.head()
# Out:
#    chrom      start        end  \
# 0   chrX   49260634   49260636
# 1   chr5  180312122  180312124
# 2  chr18    3898035    3898037
# 3   chr2  235763066  235763068
# 4   chrX   49260621   49260623
#
#    aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              1.000
# 1                                              0.886
# 2                                              0.972
# 3                                              0.941
# 4                                              0.870
#
#    aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.929
# 1                                              0.909
# 2                                              0.976
# 3                                              0.923
# 4                                              0.917
#
# ...

# %%
indf.drop(['chrom','start','end','forpos'],inplace=True,axis=1)

# %%
indf.set_index('position',inplace=True)
indf.head()
# Out:
#                 aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# position
# chrX:49260635                                               1.000
# chr5:180312123                                              0.886
# chr18:3898036                                               0.972
# chr2:235763067                                              0.941
# chrX:49260622                                               0.870
#
#                 aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# position
# chrX:49260635                                               0.929
# chr5:180312123                                              0.909
# chr18:3898036                                               0.976
# chr2:235763067                                              0.923
# chrX:49260622                                               0.917
#
# ...

# %%
indf.to_csv(outfile+'_cyberin',sep='\t',na_rep='NA')
