# %%
import pandas as pd
from itertools import chain

# %%
cin="/Users/irffanalahi/Research/weekly/for_9_10_20/mhb_wgbs_dmr/cpg2/default/uncollapse/heatmap/smdata_bg_allmat_cyberin_header_ref_myfix.txt"
mhb="/Users/irffanalahi/Research/Research_code/MONOD2/UseTheirMHB/mond2_mhb_hg38_sorted_merged.bed"
outname=cin+"_mhb"
cindf=pd.read_csv(cin,index_col=0,sep="\t")
mhbdf=pd.read_csv(mhb,sep="\t",header=None)
mhbdf=mhbdf.rename(columns={0: "chr",1:"start",2:"end" })

# %%
cindf.head()
# Out:
#                 S01BHIA1_mono.bw.bg  S01MAPA1_mono.bw.bg  S01E03A1_mono.bw.bg  \
# position
# chr4:56774445                 38.90                79.65                55.85
# chr5:179775941                93.90               100.00                76.80
# chr2:207698632                90.45                90.00                92.50
# chr8:41590620                 95.85               100.00                98.50
# chr5:107894123               100.00               100.00               100.00
#
#                 S017RE51_memb.bw.bg  S01ECGA1_naiveb.bw.bg  \
# position
# chr4:56774445                  0.00                   2.00
# chr5:179775941                 0.00                   4.50
# chr2:207698632                 0.00                   0.00
# chr8:41590620                 13.60                  13.25
# chr5:107894123                 2.15                   3.50
#
#                 NBC_NC11_41_naiveb.bw.bg  C002CTA1bs_cytnk.bw.bg  \
# position
# chr4:56774445                       0.00                    3.75
# chr5:179775941                      0.00                    8.40
# chr2:207698632                      0.00                    8.50
# chr8:41590620                       4.30                    0.00
# chr5:107894123                      5.55                    2.65
#
#                 C0067N51_cytnk.bw.bg  S01E8O51_cytnk.bw.bg  \
# position
# chr4:56774445                   0.00                  2.40
# chr5:179775941                  7.15                  1.65
# chr2:207698632                  1.40                  0.00
# chr8:41590620                   3.05                  1.35
# chr5:107894123                  7.70                  4.95
#
#                 S009W451_CD4.bw.bg  S008H151_CD4.bw.bg  C0066P51_CD8.bw.bg  \
# position
# chr4:56774445                12.90                0.00                 0.0
# chr5:179775941                0.00                0.00                15.5
# chr2:207698632                6.25                6.25                13.6
# chr8:41590620                 0.00                4.85                 7.7
# chr5:107894123                0.00                0.00                 0.0
#
#                 C003VO55_CD8.bw.bg  C00256A1bs_CD8.bw.bg
# position
# chr4:56774445                 0.00                  3.10
# chr5:179775941                5.00                  4.15
# chr2:207698632                2.45                  7.80
# chr8:41590620                 0.00                  0.00
# chr5:107894123                6.65                 11.35

# %%
def c2mhb(clist,mdf,oname):
    allmhb=[]
    
    for c in clist:
        strlist=c.split(":")
        current_chr=strlist[0]
        current_end=int(strlist[1])+1
        
        
        corresmhb=(mdf.loc[(mdf['chr'] == current_chr) & (mdf["end"] ==current_end)]).values.tolist()
      
        if len(corresmhb)!=1:
            print("errrrrrrrooorrrr: not unique mhb")
        corresmhb=list(chain.from_iterable(corresmhb))
        
        allmhb.append(corresmhb)
        
    outdf=pd.DataFrame(allmhb)
    if outdf.shape[0]!=len(clist):
        print("error:length mismatch")
    outdf.to_csv(oname,sep="\t",index=False,header = False)

# %%
cinlist=cindf.index.tolist()
c2mhb(cinlist,mhbdf,outname)
