# %%
import pandas as pd

# %%
filename="/Users/irffanalahi/Research/weekly/for_8_20_20/variance_analysis/stdcal/global_test/hdata_all_matrix_NO_NA_std.txt"
df=pd.read_csv(filename,sep="\t")
g1=["med-H1-cfD.bedgraph_rolled"]
g2=["med-H2-cfD.bedgraph_rolled"]
g3=["med-H3-cfD.bedgraph_rolled"]
g4=["med-H4-cfD.bedgraph_rolled"]
outfilename=filename+"_std.txt"

# %%
g1Std=df[g1].std(axis = 0)
g1Std
# Out:
# med-H1-cfD.bedgraph_rolled    0.283739
# dtype: float64

# %%
g1Mean=df[g1].mean(axis = 0)
g1Mean
# Out:
# med-H1-cfD.bedgraph_rolled    0.809528
# dtype: float64

# %%
g2Std=df[g2].std(axis = 0)
g2Std
# Out:
# med-H2-cfD.bedgraph_rolled    0.285241
# dtype: float64

# %%
g2Mean=df[g2].mean(axis = 0)
g2Mean
# Out:
# med-H2-cfD.bedgraph_rolled    0.800921
# dtype: float64

# %%
g3Std=df[g3].std(axis = 0)
g3Std
# Out:
# med-H3-cfD.bedgraph_rolled    0.282818
# dtype: float64

# %%
g3Mean=df[g3].mean(axis = 0)
g3Mean
# Out:
# med-H3-cfD.bedgraph_rolled    0.803334
# dtype: float64

# %%
g4Std=df[g4].std(axis = 0)
g4Std
# Out:
# med-H4-cfD.bedgraph_rolled    0.274033
# dtype: float64

# %%
g4Mean=df[g4].mean(axis = 0)
g4Mean
# Out:
# med-H4-cfD.bedgraph_rolled    0.80838
# dtype: float64

# %%
#dfStdcol1 = '+'.join(g1)
#dfStdcol2='+'.join(g2)

# %%
#dfStd=pd.DataFrame({dfStdcol1:g1Std,dfStdcol2:g2Std})

#outdf = pd.concat([df, dfStd], axis=1)


#outdf.to_csv(outfilename,sep="\t",index=False)
#dfStd.to_csv(outfilename+"_only.txt",sep="\t",index=False)
