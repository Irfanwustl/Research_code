# %%
import pandas as pd
metdmr="/Users/irffanalahi/Research/Research_update/SM/melcfdref/LargerLTME/BluOurPBL/Dashboard/BlOurPBLourCD8TIL_out_mincpg2_q0.5_addedcol_q0.00001_diff0.1_hypo_noheader_genomic_feature_withrepeat_header_celltypeseperated/PELT/QC/try1/BlOurPBLourCD8TIL_out_mincpg2_cutoff_hypo_ready_PELT_minsegesize_3_penaltyvalue_3.5_percoreMetDMR_1000_segmentinfo/BlOurPBLourCD8TILsm_record/BlOurPBLourCD8TIL_maxcompperc75percetile_top-1_singleCpG_final_recorduniq.txt"
peltdmr="/Users/irffanalahi/Research/Research_update/SM/melcfdref/LargerLTME/BluOurPBL/Dashboard/BlOurPBLourCD8TIL_out_mincpg2_q0.5_addedcol_q0.00001_diff0.1_hypo_noheader_genomic_feature_withrepeat_header_celltypeseperated/PELT/QC/try1/BlOurPBLourCD8TIL_out_mincpg2_cutoff_hypo_ready_PELT_minsegesize_3_penaltyvalue_3.5_percoreMetDMR_1000_segmentinfo/BluOurPBLOurCD8til_wg_all_matrixCin_nr0.5_imputed_g1_CD8TIL_3_g2_others_36.txt_q0.00001_diff0.1_hypo_cosgreater0.txt"
out=metdmr+"_correspelt"

metdmrdf=pd.read_csv(metdmr,sep="\t")
peltdmrdf=pd.read_csv(peltdmr,sep="\t")

metdmrdf.head()
# Out:
#   DMRchr  DMRstart   DMRend  celltype
# 0   chr1   2894358  2895138  [CD8TIL]
# 1   chr1   7932658  7933198  [CD8TIL]
# 2   chr1   7935721  7937725  [CD8TIL]
# 3   chr1   7938763  7939569  [CD8TIL]
# 4   chr1   7949418  7949614  [CD8TIL]

# %%
peltdmrdf.head()
# Out:
#   chrom     start       end parentDMRchrom  parentDMRstart  parentDMRend  \
# 0  chr1   9715523   9715928           chr1         9715523       9717162
# 1  chr1   9715929   9716473           chr1         9715523       9717162
# 2  chr1   9716474   9717162           chr1         9715523       9717162
# 3  chr1  24962841  24964208           chr1        24962841      24964591
# 4  chr1  24964209  24964591           chr1        24962841      24964591
#
#    cos_distance  euclid_distance  correlation_distance  CD8TIL-CD4bluourPBL  \
# 0      0.000913         0.214210              0.006765            -0.206211
# 1      0.017478         0.464426              0.117549            -0.148483
# 2      0.002753         0.141148              0.016749            -0.118274
# 3      0.006875         0.324671              0.044764            -0.574388
# 4      0.003863         0.308437              0.020249            -0.783980
#
#    ...  CD8TIL-mDC  CD8TIL-mNeu  CD8TIL-cB  CD8TIL-MEL_TUMOR  parentDMRmax  \
# 0  ...   -0.734207    -0.744023  -0.689121         -0.761943     -0.116304
# 1  ...   -0.526937    -0.687292  -0.261281         -0.641687     -0.116304
# 2  ...   -0.676383    -0.681150  -0.676783         -0.631000     -0.116304
# 3  ...   -0.680202    -0.661535  -0.103333         -0.556211     -0.091244
# 4  ...   -0.872750    -0.872300  -0.232875         -0.779683     -0.091244
#
#    parentDMRmin   PELTmax   PELTmin  PELTmax-parentDMRmax  \
# 0     -0.710713 -0.143791 -0.807080             -0.027486
# 1     -0.710713 -0.110858 -0.687292              0.005446
# 2     -0.710713 -0.080806 -0.716050              0.035499
# 3     -0.783176 -0.100751 -0.686000             -0.009506
# 4     -0.783176 -0.082213 -0.889833              0.009031
#
#    PELTmin-parentDMRmin
# 0             -0.096368
# 1              0.023421
# 2             -0.005337
# 3              0.097176
# 4             -0.106657
#
# [5 rows x 25 columns]

# %%
merged=peltdmrdf.merge(metdmrdf,how='inner',left_on=['parentDMRchrom','parentDMRstart','parentDMRend'],right_on=['DMRchr','DMRstart','DMRend'])
merged.head()
# Out:
#   chrom      start        end parentDMRchrom  parentDMRstart  parentDMRend  \
# 0  chr1   40387569   40387812           chr1        40387569      40388459
# 1  chr1   40387813   40388459           chr1        40387569      40388459
# 2  chr1   40388726   40388992           chr1        40388726      40389391
# 3  chr1   40388993   40389391           chr1        40388726      40389391
# 4  chr1  116807997  116808135           chr1       116807997     116809395
#
#    cos_distance  euclid_distance  correlation_distance  CD8TIL-CD4bluourPBL  \
# 0      0.015025         0.385959              0.102447            -0.621525
# 1      0.001284         0.110274              0.041113            -0.617855
# 2      0.012685         0.406078              0.048579            -0.319271
# 3      0.006402         0.406078              0.095157            -0.550781
# 4      0.008945         0.514429              0.254073            -0.341052
#
#    ...  parentDMRmax  parentDMRmin   PELTmax   PELTmin  PELTmax-parentDMRmax  \
# 0  ...     -0.427029     -0.775522 -0.264354 -0.859875              0.162675
# 1  ...     -0.427029     -0.775522 -0.435095 -0.751421             -0.008065
# 2  ...     -0.265218     -0.834014 -0.186656 -0.822444              0.078562
# 3  ...     -0.265218     -0.834014 -0.343781 -0.845583             -0.078562
# 4  ...     -0.413594     -0.765656 -0.305052 -0.567222              0.108542
#
#    PELTmin-parentDMRmin  DMRchr   DMRstart     DMRend  celltype
# 0             -0.084353    chr1   40387569   40388459  [CD8TIL]
# 1              0.024101    chr1   40387569   40388459  [CD8TIL]
# 2              0.011569    chr1   40388726   40389391  [CD8TIL]
# 3             -0.011569    chr1   40388726   40389391  [CD8TIL]
# 4              0.198434    chr1  116807997  116809395  [CD8TIL]
#
# [5 rows x 29 columns]

# %%
mergedSMlike=(merged[['chrom','start','end','celltype']]).copy()
mergedSMlike.rename(columns={'chrom':'DMRchr','start':'DMRstart','end':'DMRend'},inplace=True)
mergedSMlike.head()
# Out:
#   DMRchr   DMRstart     DMRend  celltype
# 0   chr1   40387569   40387812  [CD8TIL]
# 1   chr1   40387813   40388459  [CD8TIL]
# 2   chr1   40388726   40388992  [CD8TIL]
# 3   chr1   40388993   40389391  [CD8TIL]
# 4   chr1  116807997  116808135  [CD8TIL]

# %%
merged.to_csv(out+"_allinfo.txt",sep="\t",index=False)
mergedSMlike.to_csv(out+"_smlike.txt",sep="\t",index=False)
