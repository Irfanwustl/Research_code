# %%
import numpy as np
import pandas as pd
import random as ran
import os

# %%
file_cn = 'Data/pbltilMELtumor_abulmelMGI_PHENOCLASS.txt'

transpose = True
header = None
index_col= True



lower_lim = 0.9
upper_lim = 0.1


'''
lower_lim = -5
upper_lim = -2
'''

repetition = 3

mix_num = 10

outfol = file_cn+"_from_"+str(lower_lim)+"_to_"+str(upper_lim)+'_proportions'

# %%
if transpose:
    data_cn = pd.read_csv(file_cn, sep='\t', index_col=0, header=header)
else:
    data_cn = pd.read_csv(file_cn, sep='\t', header=header)

df_cn = pd.DataFrame(data_cn)

if transpose:
    df_cn = df_cn.T

df_cn.columns
# Out:
# Index(['PBL', 'TIL', 'MEL_TUMOR'], dtype='object', name=0)

# %%
def generate_list(cell_name, cell_list, val):
    length = len(cell_list)
    vals = np.zeros(length)
    r = [ran.random() for i in range(1,length)]
    s = sum(r)
    r = [ (i/s) * (100 - val) for i in r ]
    name_seen = False
    for i in range(length):
        if cell_list[i] != cell_name:
            if name_seen == False:
                vals[i] = r[i]
            elif name_seen:
                vals[i] = r[i - 1]
        elif cell_list[i] == cell_name:
            vals[i] = val
            name_seen = True
    return vals

# %%
mixtures = np.linspace(lower_lim, upper_lim, num=mix_num) * 100
#mixtures = np.logspace(lower_lim, upper_lim, num=mix_num) * 100
mixtures
# Out:
# array([90.        , 81.11111111, 72.22222222, 63.33333333, 54.44444444,
#        45.55555556, 36.66666667, 27.77777778, 18.88888889, 10.        ])

# %%
os.mkdir(outfol)
df_final = pd.DataFrame(columns = list(df_cn.columns))

# %%
# os.mkdir(outfol)

for cell in list(df_cn.columns):
    df_out = pd.DataFrame(columns = list(df_cn.columns))
    for val in mixtures:
        for i in range(repetition):
            arr = generate_list(cell, list(df_cn.columns), val)
            while 0.0 in arr:
                arr = generate_list(cell, list(df_cn.columns), val)
            df_out.loc[len(df_out.index)] = arr
    display(df_out)
    df_out=df_out.round(6)
    df_final = pd.concat([df_final, df_out])
    
    
    df_out.to_csv(outfol + '/' + cell + '.txt', sep='\t', index=False)
# Out:
#           PBL        TIL  MEL_TUMOR
# 0   90.000000   5.183131   4.816869
# 1   90.000000   4.985085   5.014915
# 2   90.000000   7.521632   2.478368
# 3   81.111111   7.029267  11.859622
# 4   81.111111   2.605117  16.283772
# 5   81.111111   7.243547  11.645342
# 6   72.222222   3.429195  24.348583
# 7   72.222222  20.038681   7.739097
# 8   72.222222  16.001680  11.776098
# 9   63.333333   1.034951  35.631715
# 10  63.333333  22.668923  13.997743
# 11  63.333333  16.878869  19.787798
# 12  54.444444  17.461662  28.093894
# 13  54.444444  18.506067  27.049489
# 14  54.444444  37.309650   8.245906
# 15  45.555556   4.637915  49.806530
# 16  45.555556  26.725724  27.718720
# 17  45.555556  21.426323  33.018122
# 18  36.666667  62.308462   1.024872
# 19  36.666667   8.790789  54.542544
# 20  36.666667   2.376210  60.957123
# 21  27.777778  33.157115  39.065108
# 22  27.777778   5.330734  66.891489
