# %%
import numpy as np
import pandas as pd
import random as ran
import os

# %%
file_cn = 'Data/BL22_Phenoclass.txt'

transpose = True
header = None
index_col= 0

mix_num = 10

outfile = file_cn+'_cell_files_random.txt'

# %%
data_cn = pd.read_csv(file_cn, sep='\t', index_col=index_col, header=header)

df_cn = pd.DataFrame(data_cn)

if transpose:
    df_cn = df_cn.T

df_cn.columns
# Out:
# Index(['NaiveCD4', 'NaiveCD8', 'nB', 'NK', 'PC', 'Mono', 'M0', 'M1', 'M2',
#        'iDC', 'mDC', 'PMN', 'cm8', 'em8', 'Eo', 'Tregs', 'em4', 'ed8', 'Mg',
#        'cm4', 'Er', 'mB'],
#       dtype='object', name=0)

# %%
def generate_list(cell_list):
    length = len(cell_list)
    vals = np.zeros(length)
    r = [ran.random() for i in range(length)]
    s = sum(r)
    r = [ (i/s) * 100 for i in r ]
    return r

# %%
# os.mkdir(outfol)

# for cell in list(df_cn.columns):
df_out = pd.DataFrame(columns = list(df_cn.columns))
for j in range(mix_num):
    arr = generate_list(list(df_cn.columns))
    while 0.0 in arr:
        arr = generate_list(list(df_cn.columns))
    print(np.sum(arr))
    df_out.loc[len(df_out.index)] = arr
display(df_out)
df_out.to_csv(outfile, sep='\t', index=False)
# Out:
# 100.00000000000004
# 100.00000000000001
# 100.00000000000001
# 100.00000000000004
# 99.99999999999999
# 100.00000000000001
# 100.00000000000001
# 99.99999999999997
# 99.99999999999999
# 99.99999999999997
#    NaiveCD4  NaiveCD8        nB        NK        PC      Mono        M0  \
# 0  0.157712  0.892721  9.018364  6.190193  5.030796  9.816330  9.682943
# 1  1.971135  6.725183  7.910413  0.821091  8.608822  3.236905  9.041654
# 2  1.672735  6.339844  2.750193  3.074064  3.594503  2.175042  0.006895
# 3  2.564333  7.726644  2.532436  3.995197  7.025377  5.713552  6.296076
# 4  7.511714  5.229643  4.661408  5.488333  6.119395  0.315649  1.433479
# 5  1.444466  0.929114  9.216943  6.673872  1.372121  4.288464  1.340241
# 6  2.421301  3.627966  6.913494  7.701909  3.175599  0.243551  6.550211
# 7  3.192988  3.013499  4.086512  3.067045  2.953850  1.654701  3.093265
# 8  2.697384  2.274817  1.147840  8.809849  3.064714  0.572552  4.900623
# 9  4.566733  3.234505  0.458878  0.622936  2.477759  6.428497  7.488143
#
#          M1         M2        iDC  ...       cm8       em8        Eo  \
# 0  1.522232   2.078196   3.883812  ...  3.454115  9.767558  5.087161
# 1  8.169693   3.066596   4.066123  ...  2.529694  9.440482  9.779316
# 2  5.808652   0.877139   8.144034  ...  0.209721  6.397255  1.615582
# 3  6.465579   4.412109   1.959487  ...  5.859637  2.126949  3.171630
# 4  8.553324   1.224294  10.389429  ...  1.813621  1.444362  2.967423
# 5  1.977916   2.711925   9.310825  ...  2.238564  5.319282  0.838915
# 6  5.187202   5.696997   5.844214  ...  1.161351  4.408457  5.285818
# 7  0.819049   3.332660   4.910029  ...  8.753341  8.403161  7.070285
# 8  3.973162  10.524799   4.503886  ...  1.028654  1.155158  3.087160
# 9  1.977003   5.866071   7.528651  ...  4.531285  3.355273  7.225862
#
#       Tregs       em4       ed8        Mg       cm4         Er        mB
# 0  0.959752  8.190977  3.630529  3.038584  1.204013   0.127267  5.207994
# 1  1.632046  0.689942  0.241457  7.083785  0.754745   0.163552  3.905452
# 2  6.924520  6.196576  8.152888  6.958752  8.086063   1.766000  8.646648
# 3  2.630927  6.646621  7.970364  6.983647  8.564263   2.270891  1.427113
# 4  5.573236  3.168610  9.573597  0.214809  7.612584   9.165136  2.371403
# 5  7.295876  6.775887  5.280135  8.353294  6.898305   4.461365  3.636171
# 6  6.684461  7.242884  7.817461  4.430858  4.145630   3.093815  1.094012
# 7  1.357473  3.237956  8.342059  8.580009  2.223810   3.211545  8.473731
# 8  3.882597  8.784592  5.191557  0.788701  9.552298  10.840537  1.576595
# 9  5.575411  3.180202  3.815802  5.749433  6.664345   5.739881  3.173242
#
# [10 rows x 22 columns]
