# %%
import numpy as np
import pandas as pd
import random as ran
import os

# %%
file_cn = 'BL14_PhenoClass.txt'

transpose = True
header = None
index_col= 0

mix_num = 25

outfile = 'cell_files_random.txt'

# %%
data_cn = pd.read_csv(file_cn, sep='\t', index_col=index_col, header=header)

df_cn = pd.DataFrame(data_cn)

if transpose:
    df_cn = df_cn.T

df_cn.columns
# Out:
# Index(['CD4', 'CD8', 'nB', 'NK', 'Mn', 'mNeu', 'm8', 'DC', 'Eo', 'Tr', 'm4',
#        'Mg', 'Er', 'mB'],
#       dtype='object', name=0)

# %%
def generate_list(cell_list):
    length = len(cell_list)
    vals = np.zeros(length)
    r = [ran.random() for i in range(length)]
    s = sum(r)
    r = [ (i/s) * 100 for i in r ]
    return r

# %%
# os.mkdir(outfol)

# for cell in list(df_cn.columns):
df_out = pd.DataFrame(columns = list(df_cn.columns))
for j in range(mix_num):
    arr = generate_list(list(df_cn.columns))
    while 0.0 in arr:
        arr = generate_list(list(df_cn.columns))
    print(np.sum(arr))
    df_out.loc[len(df_out.index)] = arr
display(df_out)
df_out.to_csv(outfile, sep='\t', index=False)
# Out:
# 100.0
# 99.99999999999999
# 100.0
# 99.99999999999999
# 100.0
# 100.0
# 99.99999999999997
# 100.0
# 99.99999999999999
# 99.99999999999996
# 100.0
# 100.0
# 100.00000000000001
# 99.99999999999996
# 100.0
# 99.99999999999997
# 100.00000000000003
# 100.00000000000001
# 100.0
# 100.0
# 100.0
# 100.00000000000001
# 99.99999999999999
# 99.99999999999999
# 100.0
#           CD4        CD8         nB         NK         Mn       mNeu  \
# 0   11.652347  16.835548   7.447695   2.513465   2.185028   1.120616
# 1    1.085701  11.601176   5.763920  11.732239   3.413369  11.385823
# 2    9.466021   5.723605  14.685579  16.830409   0.323018   1.896020
# 3    0.764625   3.656543   9.272795   0.291151   7.371932   7.422188
# 4    5.513863   9.290193  13.476323   5.111104   0.517401  11.664329
# 5    0.394461  13.729008   4.573097   7.965099   0.501796  12.492755
# 6    3.840584   0.978458   6.978032   6.122533   9.090739  12.705178
# 7   12.065339  13.961187   4.993111   6.433854   0.642772   1.680527
# 8    6.114151   9.962394   3.747854   4.097035   7.390286   1.532191
# 9   10.564820   5.530026  11.993444   8.614121   8.030606   9.196102
# 10   7.164912  14.587824   0.820782   7.335616   7.375928  13.502991
# 11   6.813638   1.586707   5.407453  13.870266  12.137957   2.831857
# 12  11.330971   5.637970   0.371678   4.172136   7.758946  10.731139
# 13   8.010334   5.221970   8.255088   4.645677   3.380653   7.919239
# 14   9.604331  14.269643   1.733115   4.471069   1.357828   0.740982
# 15  11.540610   0.679712   5.465085   0.364536   7.565134  10.156965
# 16  10.542957  11.128893   8.797371   4.435911   5.571091  10.861275
# 17   5.542562  10.113177   0.409115  13.275876  11.471087   4.380488
# 18   6.540889   9.650717   4.459697  11.247574   4.909397   4.245732
