# %%
import pandas as pd
import glob, os

infolder='/Users/irffanalahi/Research/Research_update/for_backgroundcalculation/try1/distribution_of_Hyper/allsmdistribution/sm.5'
out=infolder

# %%
files = glob.glob(infolder+'/*.txt')
filesdf=[]
for fp in files:
    tmpdf=pd.read_csv(fp,sep="\t",index_col=['chrom','start','end'])
    tmpdf['filename']=os.path.basename(fp)
    filesdf.append(tmpdf)

# %%
df_combined = pd.concat(filesdf, axis=0)
df_combined.head()
# Out:
#                          aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              0.963
# chr9  92069123 92069125                                              1.000
# chr16 88750402 88750404                                              0.986
# chr19 8315710  8315712                                               0.963
# chr7  75039383 75039385                                              0.966
#
#                          aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              0.935
# chr9  92069123 92069125                                              0.984
# chr16 88750402 88750404                                              0.960
# chr19 8315710  8315712                                               1.000
# chr7  75039383 75039385                                              0.976
#
#                          aS009W451.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              0.947
# chr9  92069123 92069125                                              1.000
# chr16 88750402 88750404                                              0.956
# chr19 8315710  8315712                                               0.941
# chr7  75039383 75039385                                              0.990
#
#                          bC00256A1bs.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              0.972
# chr9  92069123 92069125                                              0.948
# chr16 88750402 88750404                                              0.962
# chr19 8315710  8315712                                               0.953
# chr7  75039383 75039385                                              0.954
#
#                          bC003VO55.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              1.000
# chr9  92069123 92069125                                              0.946
# chr16 88750402 88750404                                              0.972
# chr19 8315710  8315712                                               0.944
# chr7  75039383 75039385                                              0.983
#
#                          bC0066P51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              1.000
# chr9  92069123 92069125                                              0.925
# chr16 88750402 88750404                                              1.000
# chr19 8315710  8315712                                               0.889
# chr7  75039383 75039385                                              0.957
#
#                          cC0068L51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive_B_cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              0.968
# chr9  92069123 92069125                                              1.000
# chr16 88750402 88750404                                              1.000
# chr19 8315710  8315712                                               0.968
# chr7  75039383 75039385                                              0.985
#
#                          cNBC_NC11_41.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive_B_cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              0.940
# chr9  92069123 92069125                                              0.957
# chr16 88750402 88750404                                              0.926
# chr19 8315710  8315712                                               1.000
# chr7  75039383 75039385                                              0.960
#
#                          cS01ECGA1.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive_B_cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              1.000
# chr9  92069123 92069125                                              1.000
# chr16 88750402 88750404                                              0.938
# chr19 8315710  8315712                                               1.000
# chr7  75039383 75039385                                              0.938
#
#                          dC002CTA1bs.CPG_methylation_calls.bs_call.GRCh38.20160531-P-NK_cell.bw.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                              0.973
# chr9  92069123 92069125                                              0.934
# chr16 88750402 88750404                                              0.960
# chr19 8315710  8315712                                               0.981
# chr7  75039383 75039385                                              0.973
#
#                          ...  zCD4-Tumor-1382.bedgraph_rolled  \
# chrom start    end       ...
# chr7  27738791 27738793  ...                              1.0
# chr9  92069123 92069125  ...                              1.0
# chr16 88750402 88750404  ...                              1.0
# chr19 8315710  8315712   ...                              1.0
# chr7  75039383 75039385  ...                              1.0
#
#                          zCD56-Tumor-1382.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                               1.0
# chr9  92069123 92069125                               1.0
# chr16 88750402 88750404                               1.0
# chr19 8315710  8315712                                1.0
# chr7  75039383 75039385                               1.0
#
#                          zCD8-Tumor-1382.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                              1.0
# chr9  92069123 92069125                              1.0
# chr16 88750402 88750404                              1.0
# chr19 8315710  8315712                               1.0
# chr7  75039383 75039385                              1.0
#
#                          zEpcam-Tumor-1313.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                0.5
# chr9  92069123 92069125                                1.0
# chr16 88750402 88750404                                1.0
# chr19 8315710  8315712                                 1.0
# chr7  75039383 75039385                                1.0
#
#                          zEpcam-Tumor-1382.bedgraph_rolled  \
# chrom start    end
# chr7  27738791 27738793                                1.0
# chr9  92069123 92069125                                1.0
# chr16 88750402 88750404                                1.0
# chr19 8315710  8315712                                 1.0
# chr7  75039383 75039385                                1.0
#
#                          zEpcam-Tumor-1389.bedgraph_rolled  Minimum Value  \
# chrom start    end
# chr7  27738791 27738793                              0.802          0.500
# chr9  92069123 92069125                              1.000          0.854
# chr16 88750402 88750404                              1.000          0.750
# chr19 8315710  8315712                               1.000          0.622
# chr7  75039383 75039385                              1.000          0.885
#
#                          EPCAM-others  FakeCell-others  \
# chrom start    end
# chr7  27738791 27738793         -0.98              0.9
# chr9  92069123 92069125         -0.98              0.9
# chr16 88750402 88750404         -0.98              0.9
# chr19 8315710  8315712          -0.98              0.9
# chr7  75039383 75039385         -0.98              0.9
#
#                                                                   filename
# chrom start    end
# chr7  27738791 27738793  BL22EPCAM_prom_all_matrix_NO_NA_withmincol.txt...
# chr9  92069123 92069125  BL22EPCAM_prom_all_matrix_NO_NA_withmincol.txt...
# chr16 88750402 88750404  BL22EPCAM_prom_all_matrix_NO_NA_withmincol.txt...
# chr19 8315710  8315712   BL22EPCAM_prom_all_matrix_NO_NA_withmincol.txt...
# chr7  75039383 75039385  BL22EPCAM_prom_all_matrix_NO_NA_withmincol.txt...
#
# [5 rows x 69 columns]

# %%
df_combined_onerow=df_combined.drop(['Minimum Value','EPCAM-others','FakeCell-others','filename'])
