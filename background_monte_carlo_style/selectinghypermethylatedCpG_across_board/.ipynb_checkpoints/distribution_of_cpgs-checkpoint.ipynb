# %%
import pandas as pd 
from collections import defaultdict
infile='/Users/irffanalahi/Research/Research_update/for_backgroundcalculation/try1/distribution_of_Hyper/BL22EPCAM_prom_all_matrix_NO_NA_head.txt'

distributiondelta=[0,.3,.5,.7,.9]


indf=pd.read_csv(infile,sep='\t')
indf.head()
# Out:
#   chrom   start     end  \
# 0  chr1  927039  927041
# 1  chr1  927090  927092
# 2  chr1  927125  927127
# 3  chr1  927374  927376
# 4  chr1  927387  927389
#
#    aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.941
# 1                                              0.909
# 2                                              0.952
# 3                                              0.878
# 4                                              0.962
#
#    aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.971
# 1                                              0.950
# 2                                              0.875
# 3                                              0.865
# 4                                              0.892
#
#    aS009W451.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.909
# 1                                              0.944
# 2                                              0.952
# 3                                              0.784
# 4                                              0.943
#
#    bC00256A1bs.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# 0                                              0.829
# 1                                              0.828
# 2                                              0.931
# 3                                              0.800
# 4                                              0.969
#
#    bC003VO55.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# 0                                              0.889
# 1                                              0.957
# 2                                              0.926
# 3                                              0.727
# 4                                              0.773
#
#    bC0066P51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# 0                                              0.882
# 1                                              0.833
# 2                                              0.882
# 3                                              0.952
# 4                                              0.952
#
#    cC0068L51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive_B_cell.bw.bedgraph_rolled  \
# 0                                              0.929
# 1                                              0.958
# 2                                              0.933
# 3                                              0.968
# 4                                              0.931
#
#    ...  ymel-1457-T-CD8.bedgraph_rolled  ymel-960-T-CD8.bedgraph_rolled  \
# 0  ...                            0.571                           0.791
# 1  ...                            1.000                           0.950
# 2  ...                            1.000                           0.891
# 3  ...                            0.602                           0.936
# 4  ...                            0.859                           0.670
#
#    zCD14-Tumor-1382.bedgraph_rolled  zCD19-Tumor-1382.bedgraph_rolled  \
# 0                              0.44                             0.670
# 1                              1.00                             0.667
# 2                              1.00                             1.000
# 3                              1.00                             1.000
# 4                              1.00                             1.000
#
#    zCD4-Tumor-1382.bedgraph_rolled  zCD56-Tumor-1382.bedgraph_rolled  \
# 0                             0.43                             0.503
# 1                             1.00                             1.000
# 2                             1.00                             1.000
# 3                             1.00                             0.876
# 4                             0.00                             0.800
#
#    zCD8-Tumor-1382.bedgraph_rolled  zEpcam-Tumor-1313.bedgraph_rolled  \
# 0                                1                              0.200
# 1                                1                              0.797
# 2                                1                              0.331
# 3                                1                              0.750
# 4                                0                              0.750
#
#    zEpcam-Tumor-1382.bedgraph_rolled  zEpcam-Tumor-1389.bedgraph_rolled
# 0                                  0                              0.591
# 1                                  1                              0.646
# 2                                  1                              0.521
# 3                                  0                              0.125
# 4                                  0                              0.625
#
# [5 rows x 68 columns]

# %%
outdf=indf.copy()

# %%
outdf['Minimum Value']=indf.min(axis = 1)
outdf.head()
# Out:
#   chrom   start     end  \
# 0  chr1  927039  927041
# 1  chr1  927090  927092
# 2  chr1  927125  927127
# 3  chr1  927374  927376
# 4  chr1  927387  927389
#
#    aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.941
# 1                                              0.909
# 2                                              0.952
# 3                                              0.878
# 4                                              0.962
#
#    aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.971
# 1                                              0.950
# 2                                              0.875
# 3                                              0.865
# 4                                              0.892
#
#    aS009W451.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                              0.909
# 1                                              0.944
# 2                                              0.952
# 3                                              0.784
# 4                                              0.943
#
#    bC00256A1bs.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# 0                                              0.829
# 1                                              0.828
# 2                                              0.931
# 3                                              0.800
# 4                                              0.969
#
#    bC003VO55.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# 0                                              0.889
# 1                                              0.957
# 2                                              0.926
# 3                                              0.727
# 4                                              0.773
#
#    bC0066P51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD8-T-cell.bw.bedgraph_rolled  \
# 0                                              0.882
# 1                                              0.833
# 2                                              0.882
# 3                                              0.952
# 4                                              0.952
#
#    cC0068L51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive_B_cell.bw.bedgraph_rolled  \
# 0                                              0.929
# 1                                              0.958
# 2                                              0.933
# 3                                              0.968
# 4                                              0.931
#
#    ...  ymel-960-T-CD8.bedgraph_rolled  zCD14-Tumor-1382.bedgraph_rolled  \
# 0  ...                           0.791                              0.44
# 1  ...                           0.950                              1.00
# 2  ...                           0.891                              1.00
# 3  ...                           0.936                              1.00
# 4  ...                           0.670                              1.00
#
#    zCD19-Tumor-1382.bedgraph_rolled  zCD4-Tumor-1382.bedgraph_rolled  \
# 0                             0.670                             0.43
# 1                             0.667                             1.00
# 2                             1.000                             1.00
# 3                             1.000                             1.00
# 4                             1.000                             0.00
#
#    zCD56-Tumor-1382.bedgraph_rolled  zCD8-Tumor-1382.bedgraph_rolled  \
# 0                             0.503                                1
# 1                             1.000                                1
# 2                             1.000                                1
# 3                             0.876                                1
# 4                             0.800                                0
#
#    zEpcam-Tumor-1313.bedgraph_rolled  zEpcam-Tumor-1382.bedgraph_rolled  \
# 0                              0.200                                  0
# 1                              0.797                                  1
# 2                              0.331                                  1
# 3                              0.750                                  0
# 4                              0.750                                  0
#
#    zEpcam-Tumor-1389.bedgraph_rolled  Minimum Value
# 0                              0.591          0.000
# 1                              0.646          0.077
# 2                              0.521          0.331
# 3                              0.125          0.000
# 4                              0.625          0.000
#
# [5 rows x 69 columns]

# %%
distdict = defaultdict(list)
for ddelta in distributiondelta:
    tempdf=outdf[outdf['Minimum Value']>=ddelta]
    distdict[ddelta].append(tempdf.shape[0])

# %%
distdictDF=pd.DataFrame.from_dict(distdict)
distdictDF.head()
# Out:
#    0.0  0.3  0.5  0.7  0.9
# 0    9    1    0    0    0

# %%
distdictDF.to_csv(infile+"_dist.txt",sep='\t',index=False)
outdf.to_csv(infile+"_withmincol.txt",sep='\t',index=False)
