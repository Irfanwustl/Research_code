# %%
import pandas as pd
import glob, os

infolder='/Users/irffanalahi/Research/Research_update/for_backgroundcalculation/try1/distribution_of_Hyper/allsmdistribution/sm.9'
out=infolder

# %%
files = glob.glob(infolder+'/*.txt')
filesdf=[]
for fp in files:
    tmpdf=pd.read_csv(fp,sep="\t",index_col=['chrom','start','end'])
    tmpdf['filename']=os.path.basename(fp)
    filesdf.append(tmpdf)

# %%
df_combined = pd.concat(filesdf, axis=0)
df_combined.head()
# Out:
#                            aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start     end
# chr4  169148249 169148251                                              1.000
# chr6  142760592 142760594                                              0.952
# chr12 123159397 123159399                                              1.000
#       121250441 121250443                                              0.966
# chr9  132286010 132286012                                              1.000
#
#                            aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start     end
# chr4  169148249 169148251                                              1.000
# chr6  142760592 142760594                                              0.977
# chr12 123159397 123159399                                              0.975
# ...

# %%
df_combined_onerow=df_combined.drop(['Minimum Value','EPCAM-others','FakeCell-others','filename'],axis=1)
df_combined_onerow.head()
# Out:
#                            aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start     end
# chr4  169148249 169148251                                              1.000
# chr6  142760592 142760594                                              0.952
# chr12 123159397 123159399                                              1.000
#       121250441 121250443                                              0.966
# chr9  132286010 132286012                                              1.000
#
#                            aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start     end
# chr4  169148249 169148251                                              1.000
# chr6  142760592 142760594                                              0.977
# chr12 123159397 123159399                                              0.975
# ...

# %%
df_combined_onerow.shape
# Out:
# (10000, 65)

# %%
outdf=df_combined_onerow.melt()
outdf.shape
# Out:
# (650000, 2)

# %%
outdf.head()
# Out:
#                                             variable  value
# 0  aS007DD51.CPG_methylation_calls.bs_call.GRCh38...  1.000
# 1  aS007DD51.CPG_methylation_calls.bs_call.GRCh38...  0.952
# 2  aS007DD51.CPG_methylation_calls.bs_call.GRCh38...  1.000
# 3  aS007DD51.CPG_methylation_calls.bs_call.GRCh38...  0.966
# 4  aS007DD51.CPG_methylation_calls.bs_call.GRCh38...  1.000

# %%
outdf.to_csv(out+"_stacked.txt",sep='\t')

# %%
df_combined.to_csv(out+"_combined.txt",sep='\t')
