# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import wilcoxon, mannwhitneyu
import matplotlib 
plt.rc('font', family='Arial')

# %%
cutoff = 2
#order = ['Memory B cell',  'CD8 effector','NK','Naive B cell','Naive CD8','CD8 central memory','Plasma','Mono', 'CD8 effector memory', 'Tregs','Naive CD4',
        #'CD4 effector memory','CD4 central memory']
file = '/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22_tiered/irAE/ALLctReference/forbarplot/allct_towardsSM_dummy_mean_SM.txt_unique_result_dupindex_binnedstats.pkl_maxscore_ctporportion_CSxOut.txtMergedResponseRC_pretx.txt_ctrename.txt'
data = pd.read_csv(file, sep='\t', index_col=0)
df = pd.DataFrame(data)

#order = ['Memory B',  'Naive B','NK','CD8 TCM','Mac (M2)','Mac (M1)','Mac (M0)','PC','PMN','Eos','Mono', 'CD8 TEMRA', 'CD8 TEM', 'Tregs','Naive CD8 T','Naive CD4 T',
 #       'CD4 TEM']
order=df.columns.tolist()
order.remove('Toxicity')

# %%
conditions = [(df['Toxicity'] <= cutoff), (df['Toxicity'] > cutoff)]
values = ['toxicity <= ' + str(cutoff), 'toxicity > ' + str(cutoff)]
df['Toxic'] = np.select(conditions, values)
df
# Out:
#                           Eosinophil  Erythrocyte  Mac (M0)  Mac (M1)  \
# Mixture
# Y-3688-cfDNA                0.051168     0.092592  0.062468  0.053787
# Y-3703-cfDNA                0.051390     0.104722  0.055247  0.045195
# Y-3715-cfDNA                0.058233     0.087549  0.049412  0.046058
# Y-3918-cfDNA                0.059931     0.049578  0.056697  0.050255
# Y-3920-cfDNA                0.054407     0.084027  0.053386  0.040411
# tot-YUTAUR_19-3926-cfDNA    0.043966     0.067899  0.049673  0.039322
# Y-3674-cfDNA                0.054292     0.074013  0.050619  0.040505
# Y-3707-cfDNA                0.043832     0.092332  0.046246  0.046816
# Y-3814-cfDNA                0.056277     0.088295  0.055202  0.046499
# Y-3879-cfDNA                0.052473     0.096972  0.052821  0.045761
# Y-3880-cfDNA                0.047150     0.079518  0.051820  0.035841
# tot-YUPRAF_19-3925-cfDNA    0.072593     0.063401  0.051357  0.046736
# tot-YUTHEA_20-4000-cfDNA    0.053453     0.102161  0.048054  0.043769
# y4-YUEVRY_19_3935-cfDNA     0.053352     0.080814  0.069344  0.051057
# y4-YUPARK_18_3832-cfDNA     0.046827     0.077330  0.058113  0.043609
#
#                           Mac (M2)  Megakaryocyte      Mono        NK  \
# Mixture
# Y-3688-cfDNA              0.033517       0.125528  0.041508  0.031229
# Y-3703-cfDNA              0.036792       0.112878  0.043369  0.033510
# Y-3715-cfDNA              0.033999       0.102446  0.050453  0.033438
# Y-3918-cfDNA              0.039778       0.078565  0.048568  0.029731
# Y-3920-cfDNA              0.032590       0.111758  0.062688  0.034095
# tot-YUTAUR_19-3926-cfDNA  0.032017       0.101124  0.044710  0.028970
# Y-3674-cfDNA              0.027499       0.095947  0.052893  0.034568
# Y-3707-cfDNA              0.032292       0.134247  0.046704  0.035554
# Y-3814-cfDNA              0.034204       0.106296  0.060408  0.028088
# Y-3879-cfDNA              0.033615       0.119732  0.045346  0.036784
# Y-3880-cfDNA              0.030208       0.105786  0.047567  0.033865
# tot-YUPRAF_19-3925-cfDNA  0.034159       0.083634  0.058106  0.032168
# tot-YUTHEA_20-4000-cfDNA  0.032852       0.126093  0.044448  0.029629
# y4-YUEVRY_19_3935-cfDNA   0.038894       0.111148  0.063997  0.036465
# tot-YUPRAF_19-3925-cfDNA  0.026723         0  toxicity <= 2
# tot-YUTHEA_20-4000-cfDNA  0.029403         0  toxicity <= 2
# y4-YUEVRY_19_3935-cfDNA   0.028809         0  toxicity <= 2
# y4-YUPARK_18_3832-cfDNA   0.027662         0  toxicity <= 2
#
# [15 rows x 23 columns]

# %%
p_vals = {}

REALpvals_irf={}
for cell in order:
    p_val_list = []
    if cell not in ['Toxicity', 'Toxic']:
        multi = 1
        for i, toxicity in enumerate(values):
            y = np.array(df[df['Toxic'] == toxicity][cell])
            p_val_list.append(y)
        if np.median(p_val_list[0]) >= np.median(p_val_list[1]):
            multi = -1
        p_vals[cell] = -np.log10(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1]) * multi
        REALpvals_irf[cell]=(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1])*multi
p_vals
# Out:
# {'Eosinophil': -0.1144814877985627,
#  'Erythrocyte': 0.020901906350527823,
#  'Mac (M0)': 0.22483893841886238,
#  'Mac (M1)': -0.020901906350527823,
#  'Mac (M2)': 0.4239362286819658,
#  'Megakaryocyte': 0.06566125951523769,
#  'Mono': -0.5802253778216345,
#  'NK': -0.4239362286819658,
#  'Naive CD4 T': 1.5340339458551522,
#  'Naive CD8 T': 1.5340339458551522,
#  'PMN': -0.49966499947934045,
#  'Tregs': 0.7561541271195982,
#  'CD4 TCM': 1.5340339458551522,
#  'CD8 TCM': 0.4239362286819658,
#  'CD8 TEMRA': 0.2866205651994099,
#  'CD4 TEM': 1.0580895678658395,
#  'CD8 TEM': 0.7561541271195982,
#  'iDC': -0.6656971945412119,
#  'Memory B': 0.49966499947934045,
#  'mDC': -0.49966499947934045,
#  'Naive B': 0.22483893841886238}

# %%
type(p_vals)
p_vals={k: v for k, v in sorted(p_vals.items(), key=lambda item: item[1])}
print(p_vals)
order=p_vals.keys()
print(order)
# Out:
# {'iDC': -0.6656971945412119, 'Mono': -0.5802253778216345, 'PMN': -0.49966499947934045, 'mDC': -0.49966499947934045, 'NK': -0.4239362286819658, 'Eosinophil': -0.1144814877985627, 'Mac (M1)': -0.020901906350527823, 'Erythrocyte': 0.020901906350527823, 'Megakaryocyte': 0.06566125951523769, 'Mac (M0)': 0.22483893841886238, 'Naive B': 0.22483893841886238, 'CD8 TEMRA': 0.2866205651994099, 'Mac (M2)': 0.4239362286819658, 'CD8 TCM': 0.4239362286819658, 'Memory B': 0.49966499947934045, 'Tregs': 0.7561541271195982, 'CD8 TEM': 0.7561541271195982, 'CD4 TEM': 1.0580895678658395, 'Naive CD4 T': 1.5340339458551522, 'Naive CD8 T': 1.5340339458551522, 'CD4 TCM': 1.5340339458551522}
# dict_keys(['iDC', 'Mono', 'PMN', 'mDC', 'NK', 'Eosinophil', 'Mac (M1)', 'Erythrocyte', 'Megakaryocyte', 'Mac (M0)', 'Naive B', 'CD8 TEMRA', 'Mac (M2)', 'CD8 TCM', 'Memory B', 'Tregs', 'CD8 TEM', 'CD4 TEM', 'Naive CD4 T', 'Naive CD8 T', 'CD4 TCM'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 10))
hfont = {'fontname':'Helvetica'}
#matplotlib.rc('xtick', labelsize=20) 
#matplotlib.rc('ytick', labelsize=60) 
for cell in order:
    y = p_vals[cell]
    if y <= 0:
        ax.barh(cell, y, color='lightgrey')
    else:
       # if cell=='CD4 TEM':
        #    ax.barh(cell, y, color='r')
        #else:
        ax.barh(cell, y, color='lightgrey')

# for label in ax.get_xticklabels():
#     label.set_fontproperties('Helvetica')
ax.tick_params(axis="y", labelsize=16)
ax.tick_params(axis="x", labelsize=13)
ax.axvline(linewidth=1, color='k')
ax.axvline(x=-np.log10(0.05), linewidth=1.5, color='k', ls='--')
ax.annotate('P < 0.05', (1.4, 8), fontsize=16,rotation=90)
#ax.annotate('P < 0.05', (1.4, 8), fontsize=16,rotation=90, **hfont)
ax.set_xlabel('-log10(P)',fontsize=20)
#ax.set_xlabel('-log10(P)',fontsize=20, **hfont)
ax.set_xlim([-1.75,1.75])
#ax.annotate('Severe\niRAE', xy=(0.7, -0.062), xycoords='axes fraction', xytext=(1.13, -0.089), fontsize=18, ha='center',
#            arrowprops=dict(arrowstyle="<-", color='r', lw=2), **hfont)

#ax.annotate('No Severe\niRAE', xy=(0.3, -0.062), xycoords='axes fraction', xytext=(-0.19, -0.089), fontsize=18, ha='center',
#            arrowprops=dict(arrowstyle="<-", color='b', lw=2), **hfont)

ax.annotate('Severe\nirAE', xy=(0.7, -0.062), xycoords='axes fraction', xytext=(1.13, -0.089), fontsize=18, ha='center',
            arrowprops=dict(arrowstyle="<-", color='r', lw=2))

ax.annotate('No severe\nirAE', xy=(0.3, -0.062), xycoords='axes fraction', xytext=(-0.19, -0.089), fontsize=18, ha='center',
            arrowprops=dict(arrowstyle="<-", color='b', lw=2))
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)
plt.savefig(file+'_cutoff_'+str(cutoff)+'_response_barplot.pdf', bbox_inches='tight')

# %%
REALpvals_irf
# Out:
# {'Eosinophil': -0.768278203545834,
#  'Erythrocyte': 0.953011395422729,
#  'Mac (M0)': 0.5958830905651777,
#  'Mac (M1)': -0.953011395422729,
#  'Mac (M2)': 0.376759117811582,
#  'Megakaryocyte': 0.8596837951986661,
#  'Mono': -0.2628903364198475,
#  'NK': -0.376759117811582,
#  'Naive CD4 T': 0.029239238256098945,
#  'Naive CD8 T': 0.029239238256098945,
#  'PMN': -0.31647178784797814,
#  'Tregs': 0.17532581762086596,
#  'CD4 TCM': 0.029239238256098945,
#  'CD8 TCM': 0.376759117811582,
#  'CD8 TEMRA': 0.5168677495508638,
#  'CD4 TEM': 0.08748033392519716,
#  'CD8 TEM': 0.17532581762086596,
#  'iDC': -0.2159249389401403,
#  'Memory B': 0.31647178784797814,
#  'mDC': -0.31647178784797814,
#  'Naive B': 0.5958830905651777}

# %%
REALpvals_irfdf=pd.DataFrame.from_dict(REALpvals_irf, orient='index',columns=['MWU_pvalue'])
REALpvals_irfdf.index.name = 'Celltype'

REALpvals_irfdf
# Out:
#                MWU_pvalue
# Celltype
# Eosinophil      -0.768278
# Erythrocyte      0.953011
# Mac (M0)         0.595883
# Mac (M1)        -0.953011
# Mac (M2)         0.376759
# Megakaryocyte    0.859684
# Mono            -0.262890
# NK              -0.376759
# Naive CD4 T      0.029239
# Naive CD8 T      0.029239
# PMN             -0.316472
# Tregs            0.175326
# CD4 TCM          0.029239
# CD8 TCM          0.376759
# CD8 TEMRA        0.516868
# CD4 TEM          0.087480
# CD8 TEM          0.175326
# iDC             -0.215925
# Memory B         0.316472
# mDC             -0.316472
# Naive B          0.595883

# %%
REALpvals_irfdf.to_csv(file+"_pvalue.txt",sep='\t')
