# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import wilcoxon, mannwhitneyu
import matplotlib 
#plt.rc('font', family='Helvetica')

# %%
cutoff = 2
#order = ['Memory B cell',  'CD8 effector','NK','Naive B cell','Naive CD8','CD8 central memory','Plasma','Mono', 'CD8 effector memory', 'Tregs','Naive CD4',
        #'CD4 effector memory','CD4 central memory']
file = '/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/irAE/benchmarkwithCSx/usingCSx/irAE/plot/melcfDNA_BL22_genepromSM_0.7.txt_TRAININGbestref_CSxSM.txtOnlyposition_intersected_cyberin_CSxOut.txt_irAEgt.txt_ctrename_changelabelled.txt'
data = pd.read_csv(file, sep='\t', index_col=0)
df = pd.DataFrame(data)

#order = ['Memory B',  'Naive B','NK','CD8 TCM','Mac (M2)','Mac (M1)','Mac (M0)','PC','PMN','Eos','Mono', 'CD8 TEMRA', 'CD8 TEM', 'Tregs','Naive CD8 T','Naive CD4 T',
#        'CD4 TEM']
order=df.columns.tolist()
order.remove('Toxicity')

# %%
conditions = [(df['Toxicity'] <= cutoff), (df['Toxicity'] > cutoff)]
values = ['toxicity <= ' + str(cutoff), 'toxicity > ' + str(cutoff)]
df['Toxic'] = np.select(conditions, values)
df
# Out:
#                           Naive CD4 T  Naive CD8 T   Naive B        NK  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA     0.013415     0.022924  0.045437  0.037809
# tot-YUTAUR_19-3926-cfDNA     0.012281     0.004340  0.000000  0.019761
# tot-YUTHEA_20-4000-cfDNA     0.000000     0.016870  0.000000  0.005477
# Y-3674-cfDNA                 0.002439     0.000000  0.016443  0.012891
# Y-3688-cfDNA                 0.022815     0.000000  0.002716  0.014497
# Y-3703-cfDNA                 0.000000     0.027670  0.000000  0.004566
# Y-3707-cfDNA                 0.024967     0.003321  0.030628  0.023092
# Y-3715-cfDNA                 0.001160     0.000000  0.000000  0.000000
# Y-3814-cfDNA                 0.000000     0.000000  0.000000  0.000000
# Y-3879-cfDNA                 0.000000     0.000000  0.000000  0.006498
# Y-3880-cfDNA                 0.000004     0.000000  0.000000  0.000000
# Y-3918-cfDNA                 0.075565     0.000000  0.083818  0.035038
# Y-3920-cfDNA                 0.000000     0.037942  0.000000  0.000259
# y4-YUEVRY_19_3935-cfDNA      0.000000     0.001179  0.000000  0.000000
# y4-YUPARK_18_3832-cfDNA      0.000000     0.012723  0.019564  0.004131
#
#                                 PC      Mono  Mac (M0)  Mac (M1)  Mac (M2)  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.010135  0.154051  0.063353  0.000000  0.000000
# tot-YUTAUR_19-3926-cfDNA  0.018080  0.082119  0.000000  0.050834  0.000000
# tot-YUTHEA_20-4000-cfDNA  0.009159  0.018043  0.000000  0.038273  0.000000
# Y-3674-cfDNA              0.014682  0.005506  0.000000  0.028221  0.000000
# Y-3688-cfDNA              0.007205  0.000000  0.102628  0.094217  0.000000
# Y-3703-cfDNA              0.000000  0.015457  0.000000  0.028705  0.000000
# Y-3707-cfDNA              0.000000  0.009600  0.000000  0.080878  0.064493
# Y-3715-cfDNA              0.000000  0.049654  0.000000  0.000000  0.000000
# Y-3814-cfDNA              0.000000  0.000000  0.007150  0.000000  0.023273
# Y-3879-cfDNA              0.000000  0.000000  0.000000  0.042709  0.000000
# Y-3880-cfDNA              0.000000  0.000000  0.000000  0.040931  0.000000
# Y-3918-cfDNA              0.065985  0.000000  0.000000  0.266268  0.056237
# Y-3920-cfDNA              0.001795  0.000000  0.149084  0.000000  0.000000
# y4-YUEVRY_19_3935-cfDNA   0.000000  0.212610  0.013574  0.000000  0.000000
# y4-YUPARK_18_3832-cfDNA   0.006812  0.017890  0.000000  0.029582  0.011806
#
#                                iDC  ...   CD8 TEM  Eosinophil     Tregs  \
# Mixture                             ...
# tot-YUPRAF_19-3925-cfDNA  0.000000  ...  0.000000    0.044258  0.008394
# tot-YUTAUR_19-3926-cfDNA  0.000000  ...  0.000000    0.005942  0.000000
# tot-YUTHEA_20-4000-cfDNA  0.000000  ...  0.000000    0.000838  0.010590
# Y-3674-cfDNA              0.061923  ...  0.000000    0.000000  0.031108
# Y-3688-cfDNA              0.000000  ...  0.000000    0.007792  0.015579
# Y-3703-cfDNA              0.067895  ...  0.000000    0.000000  0.000000
# Y-3707-cfDNA              0.000000  ...  0.000000    0.000000  0.000000
# Y-3715-cfDNA              0.000000  ...  0.017733    0.000000  0.000000
# Y-3814-cfDNA              0.109865  ...  0.037885    0.000000  0.060709
# Y-3879-cfDNA              0.066055  ...  0.000000    0.000000  0.025189
# Y-3880-cfDNA              0.059446  ...  0.000000    0.000000  0.000000
# Y-3918-cfDNA              0.091850  ...  0.000000    0.000000  0.048906
# Y-3920-cfDNA              0.052428  ...  0.036326    0.380318  0.000000
# y4-YUEVRY_19_3935-cfDNA   0.015468  ...  0.000000    0.000000  0.000000
# y4-YUPARK_18_3832-cfDNA   0.000000  ...  0.015744    0.000000  0.000000
#
#                           CD8 TEMRA  Megakaryocyte   CD4 TEM  Erythrocyte  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA   0.090705       0.056713  0.000000     0.042582
# tot-YUTAUR_19-3926-cfDNA   0.032207       0.221415  0.000000     0.057520
# tot-YUTHEA_20-4000-cfDNA   0.000000       0.246930  0.016942     0.171653
# Y-3674-cfDNA               0.018978       0.022391  0.000000     0.013495
# Y-3688-cfDNA               0.000000       0.218402  0.000000     0.128450
# Y-3703-cfDNA               0.118554       0.487232  0.000000     0.076413
# Y-3707-cfDNA               0.000000       0.333011  0.013376     0.014218
# Y-3715-cfDNA               0.000000       0.118582  0.038005     0.000000
# Y-3814-cfDNA               0.000000       0.000000  0.024939     0.413806
# Y-3879-cfDNA               0.050454       0.172110  0.000000     0.000000
# Y-3880-cfDNA               0.000000       0.021835  0.065868     0.013959
# Y-3918-cfDNA               0.016321       0.037659  0.000000     0.000000
# Y-3920-cfDNA               0.086470       0.195589  0.000000     0.000000
# y4-YUEVRY_19_3935-cfDNA    0.005526       0.222764  0.007735     0.005919
# y4-YUPARK_18_3832-cfDNA    0.000000       0.158773  0.030620     0.008475
#
#                           Memory B  Toxicity          Toxic
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.000000         1  toxicity <= 2
# tot-YUTAUR_19-3926-cfDNA  0.026241         3   toxicity > 2
# tot-YUTHEA_20-4000-cfDNA  0.008965         1  toxicity <= 2
# Y-3674-cfDNA              0.000000         0  toxicity <= 2
# Y-3688-cfDNA              0.013988         3   toxicity > 2
# Y-3703-cfDNA              0.018279         3   toxicity > 2
# Y-3707-cfDNA              0.000000         0  toxicity <= 2
# Y-3715-cfDNA              0.004933         3   toxicity > 2
# Y-3814-cfDNA              0.000000         2  toxicity <= 2
# Y-3879-cfDNA              0.021873         2  toxicity <= 2
# Y-3880-cfDNA              0.002440         2  toxicity <= 2
# Y-3918-cfDNA              0.000000         4   toxicity > 2
# Y-3920-cfDNA              0.019960         3   toxicity > 2
# y4-YUEVRY_19_3935-cfDNA   0.001625         1  toxicity <= 2
# y4-YUPARK_18_3832-cfDNA   0.000000         0  toxicity <= 2
#
# [15 rows x 23 columns]

# %%
p_vals = {}

REALpvals_irf={}
for cell in order:
    p_val_list = []
    if cell not in ['Toxicity', 'Toxic']:
        multi = 1
        for i, toxicity in enumerate(values):
            y = np.array(df[df['Toxic'] == toxicity][cell])
            p_val_list.append(y)
        if np.median(p_val_list[0]) >= np.median(p_val_list[1]):
            multi = -1
        p_vals[cell] = -np.log10(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1]) * multi
        REALpvals_irf[cell]=(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1])*multi
p_vals
# Out:
# {'Naive CD4 T': 0.45408186646753235,
#  'Naive CD8 T': 0.12140276065875873,
#  'Naive B': -0.1310039474829483,
#  'NK': 0.14189809754307509,
#  'PC': 0.3773753717883122,
#  'Mono': -0.1456935605383679,
#  'Mac (M0)': -0.13922339535387027,
#  'Mac (M1)': 0.29310698435114985,
#  'Mac (M2)': -0.22435218917875083,
#  'iDC': 0.02206028641790695,
#  'mDC': 0.5571395286179781,
#  'PMN': -1.0580895678658395,
#  'CD8 TCM': -0.12140276065875873,
#  'CD8 TEM': -0.1516000616395699,
#  'Eosinophil': 0.5823393138904848,
#  'Tregs': -0.24784396190814947,
#  'CD8 TEMRA': 0.45408186646753235,
#  'Megakaryocyte': 0.3529526070805657,
#  'CD4 TEM': -0.7967122269926376,
#  'Erythrocyte': 0.19769913363049535,
#  'Memory B': 1.1681995977349284}

# %%
type(p_vals)
p_vals={k: v for k, v in sorted(p_vals.items(), key=lambda item: item[1])}
print(p_vals)
order=p_vals.keys()
print(order)
# Out:
# {'PMN': -1.0580895678658395, 'CD4 TEM': -0.7967122269926376, 'Tregs': -0.24784396190814947, 'Mac (M2)': -0.22435218917875083, 'CD8 TEM': -0.1516000616395699, 'Mono': -0.1456935605383679, 'Mac (M0)': -0.13922339535387027, 'Naive B': -0.1310039474829483, 'CD8 TCM': -0.12140276065875873, 'iDC': 0.02206028641790695, 'Naive CD8 T': 0.12140276065875873, 'NK': 0.14189809754307509, 'Erythrocyte': 0.19769913363049535, 'Mac (M1)': 0.29310698435114985, 'Megakaryocyte': 0.3529526070805657, 'PC': 0.3773753717883122, 'Naive CD4 T': 0.45408186646753235, 'CD8 TEMRA': 0.45408186646753235, 'mDC': 0.5571395286179781, 'Eosinophil': 0.5823393138904848, 'Memory B': 1.1681995977349284}
# dict_keys(['PMN', 'CD4 TEM', 'Tregs', 'Mac (M2)', 'CD8 TEM', 'Mono', 'Mac (M0)', 'Naive B', 'CD8 TCM', 'iDC', 'Naive CD8 T', 'NK', 'Erythrocyte', 'Mac (M1)', 'Megakaryocyte', 'PC', 'Naive CD4 T', 'CD8 TEMRA', 'mDC', 'Eosinophil', 'Memory B'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 10))

#matplotlib.rc('xtick', labelsize=20) 
#matplotlib.rc('ytick', labelsize=60) 
for cell in order:
    y = p_vals[cell]
    if y <= 0:
        ax.barh(cell, y, color='lightgrey')
    else:
        #if cell=='CD4 TEM':
         #   ax.barh(cell, y, color='r')
        #else:
        ax.barh(cell, y, color='lightgrey')

ax.tick_params(axis="y", labelsize=16)
ax.tick_params(axis="x", labelsize=13)
ax.axvline(linewidth=1, color='k')
ax.axvline(x=-np.log10(0.05), linewidth=1.5, color='k', ls='--')
ax.annotate('P < 0.05', (1.4, 8), fontsize=16,rotation=90)
ax.set_xlabel('-log10(P)',fontsize=20)
ax.set_xlim([-1.75,1.75])
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)
plt.savefig(file+'_cutoff_'+str(cutoff)+'_response_barplot.pdf', bbox_inches='tight')

# %%
REALpvals_irf
# Out:
# {'Naive CD4 T': 0.35149417604628286,
#  'Naive CD8 T': 0.7561313405988775,
#  'Naive B': -0.739598552509219,
#  'NK': 0.7212766990291557,
#  'PC': 0.4193963323510689,
#  'Mono': -0.7150006546880892,
#  'Mac (M0)': -0.7257325541518737,
#  'Mac (M1)': 0.5092054176517762,
#  'Mac (M2)': -0.5965513197351586,
#  'iDC': 0.9504728449836777,
#  'mDC': 0.2772429245145195,
#  'PMN': -0.08748033392519716,
#  'CD8 TCM': -0.7561313405988775,
#  'CD8 TEM': -0.7053423141486048,
#  'Eosinophil': 0.26161382230735397,
#  'Tregs': -0.5651399880422409,
#  'CD8 TEMRA': 0.35149417604628286,
#  'Megakaryocyte': 0.4436570559117131,
#  'CD4 TEM': -0.15969369620356633,
#  'Erythrocyte': 0.6343089895833207,
#  'Memory B': 0.06788915486182899}

# %%
REALpvals_irfdf=pd.DataFrame.from_dict(REALpvals_irf, orient='index',columns=['MWU_pvalue'])
REALpvals_irfdf.index.name = 'Celltype'

REALpvals_irfdf
# Out:
#                MWU_pvalue
# Celltype
# Naive CD4 T      0.351494
# Naive CD8 T      0.756131
# Naive B         -0.739599
# NK               0.721277
# PC               0.419396
# Mono            -0.715001
# Mac (M0)        -0.725733
# Mac (M1)         0.509205
# Mac (M2)        -0.596551
# iDC              0.950473
# mDC              0.277243
# PMN             -0.087480
# CD8 TCM         -0.756131
# CD8 TEM         -0.705342
# Eosinophil       0.261614
# Tregs           -0.565140
# CD8 TEMRA        0.351494
# Megakaryocyte    0.443657
# CD4 TEM         -0.159694
# Erythrocyte      0.634309
# Memory B         0.067889

# %%
REALpvals_irfdf.to_csv(file+"_pvalue.txt",sep='\t')
