# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import wilcoxon, mannwhitneyu
import matplotlib 
#plt.rc('font', family='Helvetica')

# %%
cutoff = 2
#order = ['Memory B cell',  'CD8 effector','NK','Naive B cell','Naive CD8','CD8 central memory','Plasma','Mono', 'CD8 effector memory', 'Tregs','Naive CD4',
        #'CD4 effector memory','CD4 central memory']
file = 'task2_pretx_changelabelled_bettername_fewerct.txt'
data = pd.read_csv(file, sep='\t', index_col=0)
df = pd.DataFrame(data)

#order = ['Memory B',  'Naive B','NK','CD8 TCM','Mac (M2)','Mac (M1)','Mac (M0)','PC','PMN','Eos','Mono', 'CD8 TEMRA', 'CD8 TEM', 'Tregs','Naive CD8 T','Naive CD4 T',
 #       'CD4 TEM']
order=df.columns.tolist()
order.remove('Toxicity')

# %%
conditions = [(df['Toxicity'] <= cutoff), (df['Toxicity'] > cutoff)]
values = ['toxicity <= ' + str(cutoff), 'toxicity > ' + str(cutoff)]
df['Toxic'] = np.select(conditions, values)
df
# Out:
#                                Eos  Erythroblast  Mac (M0)  Mac (M1)  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.074498      0.066531  0.036577  0.044414
# tot-YUTAUR_19-3926-cfDNA  0.047686      0.074109  0.032133  0.028729
# tot-YUTHEA_20-4000-cfDNA  0.055521      0.115136  0.035011  0.039618
# Y-3674-cfDNA              0.046662      0.066936  0.032497  0.023546
# Y-3688-cfDNA              0.042208      0.114403  0.051025  0.064132
# Y-3703-cfDNA              0.055774      0.107653  0.035101  0.019269
# Y-3707-cfDNA              0.038123      0.123476  0.027200  0.033429
# Y-3715-cfDNA              0.042338      0.075726  0.031934  0.046949
# Y-3814-cfDNA              0.023978      0.132162  0.039438  0.045420
# Y-3879-cfDNA              0.061027      0.080752  0.032340  0.047467
# Y-3880-cfDNA              0.079995      0.091552  0.028107  0.029877
# Y-3918-cfDNA              0.055445      0.047991  0.039510  0.038096
# Y-3920-cfDNA              0.159858      0.077558  0.036184  0.059973
# y4-YUEVRY_19_3935-cfDNA   0.068452      0.101780  0.054087  0.033084
# y4-YUPARK_18_3832-cfDNA   0.023623      0.086033  0.035400  0.033419
#
#                           Mac (M2)        MK      Mono        NK  Naive CD4 T  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.032557  0.078836  0.056628  0.041966     0.022621
# tot-YUTAUR_19-3926-cfDNA  0.028973  0.091935  0.042271  0.038487     0.027399
# tot-YUTHEA_20-4000-cfDNA  0.031698  0.139834  0.034440  0.035204     0.020802
# Y-3674-cfDNA              0.025673  0.103018  0.022150  0.038874     0.018915
# Y-3688-cfDNA              0.040406  0.100405  0.032233  0.038541     0.029188
# Y-3703-cfDNA              0.037810  0.149276  0.048074  0.049030     0.029233
# Y-3707-cfDNA              0.039456  0.198160  0.030715  0.049326     0.032789
# Y-3715-cfDNA              0.031801  0.073712  0.047820  0.039112     0.021753
# Y-3814-cfDNA              0.029626  0.098891  0.080377  0.040567     0.023881
# Y-3879-cfDNA              0.029624  0.164350  0.036762  0.043843     0.023583
# tot-YUPRAF_19-3925-cfDNA         1  toxicity <= 2
# tot-YUTAUR_19-3926-cfDNA         3   toxicity > 2
# tot-YUTHEA_20-4000-cfDNA         1  toxicity <= 2
# Y-3674-cfDNA                     0  toxicity <= 2
# Y-3688-cfDNA                     3   toxicity > 2
# Y-3703-cfDNA                     3   toxicity > 2
# Y-3707-cfDNA                     0  toxicity <= 2
# Y-3715-cfDNA                     3   toxicity > 2
# Y-3814-cfDNA                     2  toxicity <= 2
# Y-3879-cfDNA                     2  toxicity <= 2
# Y-3880-cfDNA                     2  toxicity <= 2
# Y-3918-cfDNA                     4   toxicity > 2
# Y-3920-cfDNA                     3   toxicity > 2
# y4-YUEVRY_19_3935-cfDNA          1  toxicity <= 2
# y4-YUPARK_18_3832-cfDNA          0  toxicity <= 2
#
# [15 rows x 23 columns]

# %%
p_vals = {}

REALpvals_irf={}
for cell in order:
    p_val_list = []
    if cell not in ['Toxicity', 'Toxic']:
        multi = 1
        for i, toxicity in enumerate(values):
            y = np.array(df[df['Toxic'] == toxicity][cell])
            p_val_list.append(y)
        if np.median(p_val_list[0]) >= np.median(p_val_list[1]):
            multi = -1
        p_vals[cell] = -np.log10(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1]) * multi
        REALpvals_irf[cell]=(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1])*multi
p_vals
# Out:
# {'Memory B': -0.2878861471679597,
#  'Naive B': -0.2869355208157593,
#  'NK': -0.020901906350527823,
#  'CD8 TCM': -0.020901906350527823,
#  'Mac (M2)': 0.22483893841886238,
#  'Mac (M1)': 0.22483893841886238,
#  'Mac (M0)': 0.16749849448288415,
#  'PC': 0.1144814877985627,
#  'PMN': 0.06566125951523769,
#  'Eos': -0.020901906350527823,
#  'Mono': -0.4239362286819658,
#  'CD8 TEMRA': -0.0,
#  'CD8 TEM': 0.22507852703824652,
#  'Tregs': 0.020901906350527823,
#  'Naive CD8 T': 0.4239362286819658,
#  'Naive CD4 T': 0.4239362286819658,
#  'CD4 TEM': 1.6664264506240625}

# %%
type(p_vals)
p_vals={k: v for k, v in sorted(p_vals.items(), key=lambda item: item[1])}
print(p_vals)
order=p_vals.keys()
print(order)
# Out:
# {'Mono': -0.4239362286819658, 'Memory B': -0.2878861471679597, 'Naive B': -0.2869355208157593, 'NK': -0.020901906350527823, 'CD8 TCM': -0.020901906350527823, 'Eos': -0.020901906350527823, 'CD8 TEMRA': -0.0, 'Tregs': 0.020901906350527823, 'PMN': 0.06566125951523769, 'PC': 0.1144814877985627, 'Mac (M0)': 0.16749849448288415, 'Mac (M2)': 0.22483893841886238, 'Mac (M1)': 0.22483893841886238, 'CD8 TEM': 0.22507852703824652, 'Naive CD8 T': 0.4239362286819658, 'Naive CD4 T': 0.4239362286819658, 'CD4 TEM': 1.6664264506240625}
# dict_keys(['Mono', 'Memory B', 'Naive B', 'NK', 'CD8 TCM', 'Eos', 'CD8 TEMRA', 'Tregs', 'PMN', 'PC', 'Mac (M0)', 'Mac (M2)', 'Mac (M1)', 'CD8 TEM', 'Naive CD8 T', 'Naive CD4 T', 'CD4 TEM'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 10))
hfont = {'fontname':'Helvetica'}
#matplotlib.rc('xtick', labelsize=20) 
#matplotlib.rc('ytick', labelsize=60) 
for cell in order:
    y = p_vals[cell]
    if y <= 0:
        ax.barh(cell, y, color='lightgrey')
    else:
        if cell=='CD4 TEM':
            ax.barh(cell, y, color='r')
        else:
            ax.barh(cell, y, color='lightgrey')

# for label in ax.get_xticklabels():
#     label.set_fontproperties('Helvetica')
ax.tick_params(axis="y", labelsize=16)
ax.tick_params(axis="x", labelsize=13)
ax.axvline(linewidth=1, color='k')
ax.axvline(x=-np.log10(0.05), linewidth=1.5, color='k', ls='--')
ax.annotate('P < 0.05', (1.4, 8), fontsize=16,rotation=90)
#ax.annotate('P < 0.05', (1.4, 8), fontsize=16,rotation=90, **hfont)
ax.set_xlabel('-log10(P)',fontsize=20)
#ax.set_xlabel('-log10(P)',fontsize=20, **hfont)
ax.set_xlim([-1.75,1.75])
#ax.annotate('Severe\niRAE', xy=(0.7, -0.062), xycoords='axes fraction', xytext=(1.13, -0.089), fontsize=18, ha='center',
#            arrowprops=dict(arrowstyle="<-", color='r', lw=2), **hfont)

#ax.annotate('No Severe\niRAE', xy=(0.3, -0.062), xycoords='axes fraction', xytext=(-0.19, -0.089), fontsize=18, ha='center',
#            arrowprops=dict(arrowstyle="<-", color='b', lw=2), **hfont)

ax.annotate('Severe\niRAE', xy=(0.7, -0.062), xycoords='axes fraction', xytext=(1.13, -0.089), fontsize=18, ha='center',
            arrowprops=dict(arrowstyle="<-", color='r', lw=2))

ax.annotate('No severe\niRAE', xy=(0.3, -0.062), xycoords='axes fraction', xytext=(-0.19, -0.089), fontsize=18, ha='center',
            arrowprops=dict(arrowstyle="<-", color='b', lw=2))
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)
plt.savefig(file+'_cutoff_'+str(cutoff)+'_response_barplot.pdf', bbox_inches='tight')

# %%
REALpvals_irf
# Out:
# {'Memory B': -0.5153637324829679,
#  'Naive B': -0.5164930466870377,
#  'NK': -0.953011395422729,
#  'CD8 TCM': -0.953011395422729,
#  'Mac (M2)': 0.5958830905651777,
#  'Mac (M1)': 0.5958830905651777,
#  'Mac (M0)': 0.6799884022342944,
#  'PC': 0.768278203545834,
#  'PMN': 0.8596837951986661,
#  'Eos': -0.953011395422729,
#  'Mono': -0.376759117811582,
#  'CD8 TEMRA': 1.0,
#  'CD8 TEM': 0.5955544485034858,
#  'Tregs': 0.953011395422729,
#  'Naive CD8 T': 0.376759117811582,
#  'Naive CD4 T': 0.376759117811582,
#  'CD4 TEM': 0.0215562667600163}

# %%
REALpvals_irfdf=pd.DataFrame.from_dict(REALpvals_irf, orient='index',columns=['MWU_pvalue'])
REALpvals_irfdf.index.name = 'Celltype'

REALpvals_irfdf

# %%
REALpvals_irfdf.to_csv(file+"_pvalue.txt",sep='\t')
