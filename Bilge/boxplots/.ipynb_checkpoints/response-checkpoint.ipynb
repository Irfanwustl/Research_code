# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from statannot import add_stat_annotation
from scipy.stats import mannwhitneyu

# %%
cutoff = 0
file = '/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/response_prediction/boxplots/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkladjustedScore_minus_avgctporportion_CSxOut.txt_melanoma_noah_Response_encodedpretx_onlytot.txt'
data = pd.read_csv(file, sep='\t', index_col=0, encoding= 'unicode_escape')
df = pd.DataFrame(data)

df
# Out:
#                                   Eo        Er        M0        M1        M2  \
# Mixture
# tot-YUCLUE_20-3998-cfDNA    0.065300  0.110462  0.034082  0.035795  0.031368
# tot-YUMARS_15-3443-cfDNA    0.075086  0.108316  0.035720  0.042972  0.036181
# tot-YUMICRO_20-4006-cfDNA   0.049824  0.052968  0.053496  0.064282  0.048002
# tot-YUMOTE_17-3755-cfDNA    0.052617  0.090688  0.046706  0.065389  0.042338
# tot-YUPRAF_19-3925-cfDNA    0.074498  0.066531  0.036577  0.044414  0.032557
# tot-YUREIL_17-3713-cfDNA    0.042108  0.089605  0.030752  0.031161  0.029828
# tot-YUSTRAW_20-4002-cfDNA   0.074337  0.057766  0.034979  0.029497  0.032718
# tot-YUTAUR_19-3926-cfDNA    0.047686  0.074109  0.032133  0.028729  0.028973
# tot-YUTHEA_20-4000-cfDNA    0.055521  0.115136  0.035011  0.039618  0.031698
# tot-YUVIRTUE_20-4029-cfDNA  0.066972  0.136717  0.034340  0.039719  0.032995
#
#                                   Mg      Mono        NK  NaiveCD4  NaiveCD8  \
# Mixture
# tot-YUCLUE_20-3998-cfDNA    0.115972  0.035473  0.034014  0.021448  0.016680
# tot-YUMARS_15-3443-cfDNA    0.119551  0.058316  0.057135  0.026227  0.019147
# tot-YUMICRO_20-4006-cfDNA   0.099401  0.037090  0.044297  0.031814  0.047695
# tot-YUMOTE_17-3755-cfDNA    0.130518  0.046640  0.035351  0.024637  0.020434
# tot-YUPRAF_19-3925-cfDNA    0.078836  0.056628  0.041966  0.022621  0.020296
# tot-YUREIL_17-3713-cfDNA    0.096496  0.048726  0.038508  0.022024  0.012686
# tot-YUSTRAW_20-4002-cfDNA   0.085675  0.046591  0.055820  0.024367  0.021285
# tot-YUTAUR_19-3926-cfDNA    0.091935  0.042271  0.038487  0.027399  0.012229
# tot-YUTHEA_20-4000-cfDNA    0.139834  0.034440  0.035204  0.020802  0.015957
# tot-YUVIRTUE_20-4029-cfDNA  0.159350  0.046437  0.040478  0.024797  0.017493
#
#                             ...       cm4       cm8       ed8       em4  \
# Mixture                     ...
# tot-YUCLUE_20-3998-cfDNA    ...  0.025017  0.024237  0.025805  0.020473
# tot-YUMARS_15-3443-cfDNA    ...  0.013692  0.018555  0.026659  0.009123
# tot-YUMICRO_20-4006-cfDNA   ...  0.038990  0.038722  0.013818  0.014235
# tot-YUMOTE_17-3755-cfDNA    ...  0.025597  0.021424  0.012634  0.012359
# tot-YUPRAF_19-3925-cfDNA    ...  0.028840  0.023787  0.031863  0.024324
# tot-YUREIL_17-3713-cfDNA    ...  0.019442  0.016011  0.018903  0.011009
# tot-YUSTRAW_20-4002-cfDNA   ...  0.025600  0.017034  0.023818  0.011856
# tot-YUTAUR_19-3926-cfDNA    ...  0.020663  0.015800  0.032141  0.010035
# tot-YUTHEA_20-4000-cfDNA    ...  0.015984  0.033990  0.021989  0.021578
# tot-YUVIRTUE_20-4029-cfDNA  ...  0.027963  0.027453  0.019230  0.007001
#
#                                  em8       iDC        mB       mDC        nB  \
# Mixture
# tot-YUCLUE_20-3998-cfDNA    0.018596  0.038029  0.022266  0.022114  0.017984
# tot-YUMARS_15-3443-cfDNA    0.018918  0.034169  0.016106  0.021243  0.027125
# tot-YUMICRO_20-4006-cfDNA   0.020608  0.043023  0.022541  0.025652  0.020645
# tot-YUMOTE_17-3755-cfDNA    0.019189  0.037588  0.032799  0.032543  0.026918
# tot-YUPRAF_19-3925-cfDNA    0.031087  0.042787  0.020717  0.041132  0.032623
# tot-YUREIL_17-3713-cfDNA    0.009595  0.037312  0.023660  0.025897  0.024363
# tot-YUSTRAW_20-4002-cfDNA   0.010912  0.036441  0.020502  0.037597  0.019707
# tot-YUTAUR_19-3926-cfDNA    0.026756  0.033291  0.045697  0.019908  0.031558
# tot-YUTHEA_20-4000-cfDNA    0.011892  0.033884  0.018097  0.032866  0.026335
# tot-YUVIRTUE_20-4029-cfDNA  0.015824  0.042579  0.022019  0.027570  0.018260
#
#                             ResponseEncoded
# Mixture
# tot-YUCLUE_20-3998-cfDNA                  1
# tot-YUMARS_15-3443-cfDNA                  0
# tot-YUMICRO_20-4006-cfDNA                 1
# tot-YUMOTE_17-3755-cfDNA                  1
# tot-YUPRAF_19-3925-cfDNA                  0
# tot-YUREIL_17-3713-cfDNA                  0
# tot-YUSTRAW_20-4002-cfDNA                 0
# tot-YUTAUR_19-3926-cfDNA                  1
# tot-YUTHEA_20-4000-cfDNA                  0
# tot-YUVIRTUE_20-4029-cfDNA                1
#
# [10 rows x 23 columns]

# %%
fol = file+'_boxplots' + str(cutoff)
os.mkdir(fol)

# %%
conditions = [(df['ResponseEncoded'] <= cutoff), (df['ResponseEncoded'] > cutoff)]
values = ['Response <= ' + str(cutoff), 'Response > ' + str(cutoff)]
df['ResponseEncodedNew'] = np.select(conditions, values)
df
# Out:
#                                   Eo        Er        M0        M1        M2  \
# Mixture
# tot-YUCLUE_20-3998-cfDNA    0.065300  0.110462  0.034082  0.035795  0.031368
# tot-YUMARS_15-3443-cfDNA    0.075086  0.108316  0.035720  0.042972  0.036181
# tot-YUMICRO_20-4006-cfDNA   0.049824  0.052968  0.053496  0.064282  0.048002
# tot-YUMOTE_17-3755-cfDNA    0.052617  0.090688  0.046706  0.065389  0.042338
# tot-YUPRAF_19-3925-cfDNA    0.074498  0.066531  0.036577  0.044414  0.032557
# tot-YUREIL_17-3713-cfDNA    0.042108  0.089605  0.030752  0.031161  0.029828
# tot-YUTAUR_19-3926-cfDNA    0.033291  0.045697  0.019908  0.031558
# tot-YUTHEA_20-4000-cfDNA    0.033884  0.018097  0.032866  0.026335
# tot-YUVIRTUE_20-4029-cfDNA  0.042579  0.022019  0.027570  0.018260
#
#                             ResponseEncoded  ResponseEncodedNew
# Mixture
# tot-YUCLUE_20-3998-cfDNA                  1        Response > 0
# tot-YUMARS_15-3443-cfDNA                  0       Response <= 0
# tot-YUMICRO_20-4006-cfDNA                 1        Response > 0
# tot-YUMOTE_17-3755-cfDNA                  1        Response > 0
# tot-YUPRAF_19-3925-cfDNA                  0       Response <= 0
# tot-YUREIL_17-3713-cfDNA                  0       Response <= 0
# tot-YUSTRAW_20-4002-cfDNA                 0       Response <= 0
# tot-YUTAUR_19-3926-cfDNA                  1        Response > 0
# tot-YUTHEA_20-4000-cfDNA                  0       Response <= 0
# tot-YUVIRTUE_20-4029-cfDNA                1        Response > 0
#
# [10 rows x 24 columns]

# %%
#df=df.sort_values(by=['ResponseEncoded'])
#df.head()

# %%
p_vals = {}
for cell in df.columns:
    p_val_list = []
    if cell not in ['ResponseEncoded', 'ResponseEncodedNew']:
        fig, ax = plt.subplots(1, 1)
        sns.boxplot(x='ResponseEncodedNew', y=cell, data=df, ax=ax, palette=[(0.4, 0.4, 0.4), (0.8, 0.8, 0.8)])
        add_stat_annotation(ax, data=df, x='ResponseEncodedNew', y=cell,
                    box_pairs=[(values[0], values[1])],
                    test='Mann-Whitney', text_format='simple', loc='inside', verbose=2)
        for i, toxicity in enumerate(values):
            y = np.array(df[df['ResponseEncodedNew'] == toxicity][cell])
            p_val_list.append(y)
            x = np.random.normal(i, 0.04, size=len(y))
            #plt.scatter(x, y, c='k')
            
            #################################irf################
            sns.stripplot(x = 'ResponseEncodedNew',
              y = cell,color='black',
              data = df)
        p_vals[cell] = [mannwhitneyu(p_val_list[0], p_val_list[1])[1]]
        plt.savefig(fol + '/' + cell + '.pdf', bbox_inches='tight')
# Out:
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.963e-01 U_stat=7.000e+00
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.345e-01 U_stat=1.400e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.300e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.761e-01 U_stat=1.500e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.761e-01 U_stat=1.500e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.034e-01 U_stat=1.700e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.101e-01 U_stat=6.000e+00
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.963e-01 U_stat=7.000e+00
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.101e-01 U_stat=1.900e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.300e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.437e-01 U_stat=2.000e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.101e-01 U_stat=6.000e+00
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.200e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.963e-01 U_stat=1.800e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.309e-01 U_stat=1.600e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.309e-01 U_stat=9.000e+00
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.761e-01 U_stat=1.000e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.963e-01 U_stat=1.800e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.034e-01 U_stat=1.700e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.010e-02 U_stat=2.200e+01
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.101e-01 U_stat=6.000e+00
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# Response > 0 v.s. Response <= 0: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.034e-01 U_stat=8.000e+00

# %%
df_pvals = pd.DataFrame.from_dict(p_vals, orient='index', columns=['p-value (MWU)'])
df_pvals.to_csv(file + '_pvals.txt', sep='\t')
