# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import wilcoxon, mannwhitneyu
import matplotlib 
#plt.rc('font', family='Helvetica')

# %%
cutoff = 2
#order = ['Memory B cell',  'CD8 effector','NK','Naive B cell','Naive CD8','CD8 central memory','Plasma','Mono', 'CD8 effector memory', 'Tregs','Naive CD4',
        #'CD4 effector memory','CD4 central memory']
file = '/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/irAE/benchmarkwithCSx/usingCSx/irAE/plot/melcfDNA_BL22_genepromSM_0.7.txt_TRAININGbestref_CSxSM.txtOnlyposition_intersected_cyberin_CSxOut.txt_irAEgt.txt_ctrename_changelabelled.txt'
data = pd.read_csv(file, sep='\t', index_col=0)
df = pd.DataFrame(data)

#order = ['Memory B',  'Naive B','NK','CD8 TCM','Mac (M2)','Mac (M1)','Mac (M0)','PC','PMN','Eos','Mono', 'CD8 TEMRA', 'CD8 TEM', 'Tregs','Naive CD8 T','Naive CD4 T',
#        'CD4 TEM']
order=df.columns.tolist()
order.remove('Toxicity')

# %%
conditions = [(df['Toxicity'] <= cutoff), (df['Toxicity'] > cutoff)]
values = ['toxicity <= ' + str(cutoff), 'toxicity > ' + str(cutoff)]
df['Toxic'] = np.select(conditions, values)
df
# Out:
#                                 Eo        Er        M0        M1        M2  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.074498  0.066531  0.036577  0.044414  0.032557
# tot-YUTAUR_19-3926-cfDNA  0.047686  0.074109  0.032133  0.028729  0.028973
# tot-YUTHEA_20-4000-cfDNA  0.055521  0.115136  0.035011  0.039618  0.031698
# Y-3674-cfDNA              0.046662  0.066936  0.032497  0.023546  0.025673
# Y-3688-cfDNA              0.042208  0.114403  0.051025  0.064132  0.040406
# Y-3703-cfDNA              0.055774  0.107653  0.035101  0.019269  0.037810
# Y-3707-cfDNA              0.038123  0.123476  0.027200  0.033429  0.039456
# Y-3715-cfDNA              0.042338  0.075726  0.031934  0.046949  0.031801
# Y-3814-cfDNA              0.023978  0.132162  0.039438  0.045420  0.029626
# Y-3879-cfDNA              0.061027  0.080752  0.032340  0.047467  0.029624
# Y-3880-cfDNA              0.079995  0.091552  0.028107  0.029877  0.035800
# Y-3918-cfDNA              0.055445  0.047991  0.039510  0.038096  0.048937
# Y-3920-cfDNA              0.159858  0.077558  0.036184  0.059973  0.027303
# y4-YUEVRY_19_3935-cfDNA   0.068452  0.101780  0.054087  0.033084  0.034576
# y4-YUPARK_18_3832-cfDNA   0.023623  0.086033  0.035400  0.033419  0.037225
#
#                                 Mg      Mono        NK  NaiveCD4  NaiveCD8  \
# Mixture
# tot-YUPRAF_19-3925-cfDNA  0.078836  0.056628  0.041966  0.022621  0.020296
# tot-YUTAUR_19-3926-cfDNA  0.091935  0.042271  0.038487  0.027399  0.012229
# tot-YUTHEA_20-4000-cfDNA  0.139834  0.034440  0.035204  0.020802  0.015957
# Y-3674-cfDNA              0.103018  0.022150  0.038874  0.018915  0.007695
# Y-3920-cfDNA              0.030607  0.000000  0.042172  0.000000         3
# y4-YUEVRY_19_3935-cfDNA   0.046586  0.040936  0.020961  0.011023         1
# y4-YUPARK_18_3832-cfDNA   0.029075  0.028990  0.028035  0.039656         0
#
#                                   Toxic
# Mixture
# tot-YUPRAF_19-3925-cfDNA  toxicity <= 2
# tot-YUTAUR_19-3926-cfDNA   toxicity > 2
# tot-YUTHEA_20-4000-cfDNA  toxicity <= 2
# Y-3674-cfDNA              toxicity <= 2
# Y-3688-cfDNA               toxicity > 2
# Y-3703-cfDNA               toxicity > 2
# Y-3707-cfDNA              toxicity <= 2
# Y-3715-cfDNA               toxicity > 2
# Y-3814-cfDNA              toxicity <= 2
# Y-3879-cfDNA              toxicity <= 2
# Y-3880-cfDNA              toxicity <= 2
# Y-3918-cfDNA               toxicity > 2
# Y-3920-cfDNA               toxicity > 2
# y4-YUEVRY_19_3935-cfDNA   toxicity <= 2
# y4-YUPARK_18_3832-cfDNA   toxicity <= 2
#
# [15 rows x 24 columns]

# %%
p_vals = {}

REALpvals_irf={}
for cell in order:
    p_val_list = []
    if cell not in ['Toxicity', 'Toxic']:
        multi = 1
        for i, toxicity in enumerate(values):
            y = np.array(df[df['Toxic'] == toxicity][cell])
            p_val_list.append(y)
        if np.median(p_val_list[0]) >= np.median(p_val_list[1]):
            multi = -1
        p_vals[cell] = -np.log10(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1]) * multi
        REALpvals_irf[cell]=(mannwhitneyu(p_val_list[0], p_val_list[1], alternative='two-sided')[1])*multi
p_vals
# Out:
# {'Eo': -0.020901906350527823,
#  'Er': -0.49966499947934045,
#  'M0': 0.16749849448288415,
#  'M1': 0.22483893841886238,
#  'M2': 0.22483893841886238,
#  'Mg': -0.851664157813288,
#  'Mono': -0.4239362286819658,
#  'NK': -0.020901906350527823,
#  'NaiveCD4': 0.4239362286819658,
#  'NaiveCD8': 0.4239362286819658,
#  'PC': 0.1144814877985627,
#  'PMN': 0.06566125951523769,
#  'Tregs': 0.020901906350527823,
#  'cm4': 1.6664264506240625,
#  'cm8': -0.020901906350527823,
#  'ed8': 0.6656971945412119,
#  'em4': -0.0,
#  'em8': 0.22507852703824652,
#  'iDC': -1.4070445876108515,
#  'mB': -0.2878861471679597,
#  'mDC': 0.06566125951523769,
#  'nB': -0.2869355208157593}

# %%
type(p_vals)
p_vals={k: v for k, v in sorted(p_vals.items(), key=lambda item: item[1])}
print(p_vals)
order=p_vals.keys()
print(order)
# Out:
# {'iDC': -1.4070445876108515, 'Mg': -0.851664157813288, 'Er': -0.49966499947934045, 'Mono': -0.4239362286819658, 'mB': -0.2878861471679597, 'nB': -0.2869355208157593, 'Eo': -0.020901906350527823, 'NK': -0.020901906350527823, 'cm8': -0.020901906350527823, 'em4': -0.0, 'Tregs': 0.020901906350527823, 'PMN': 0.06566125951523769, 'mDC': 0.06566125951523769, 'PC': 0.1144814877985627, 'M0': 0.16749849448288415, 'M1': 0.22483893841886238, 'M2': 0.22483893841886238, 'em8': 0.22507852703824652, 'NaiveCD4': 0.4239362286819658, 'NaiveCD8': 0.4239362286819658, 'ed8': 0.6656971945412119, 'cm4': 1.6664264506240625}
# dict_keys(['iDC', 'Mg', 'Er', 'Mono', 'mB', 'nB', 'Eo', 'NK', 'cm8', 'em4', 'Tregs', 'PMN', 'mDC', 'PC', 'M0', 'M1', 'M2', 'em8', 'NaiveCD4', 'NaiveCD8', 'ed8', 'cm4'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 10))

#matplotlib.rc('xtick', labelsize=20) 
#matplotlib.rc('ytick', labelsize=60) 
for cell in order:
    y = p_vals[cell]
    if y <= 0:
        ax.barh(cell, y, color='lightgrey')
    else:
        #if cell=='CD4 TEM':
         #   ax.barh(cell, y, color='r')
        #else:
        ax.barh(cell, y, color='lightgrey')

ax.tick_params(axis="y", labelsize=16)
ax.tick_params(axis="x", labelsize=13)
ax.axvline(linewidth=1, color='k')
ax.axvline(x=-np.log10(0.05), linewidth=1.5, color='k', ls='--')
ax.annotate('P < 0.05', (1.4, 8), fontsize=16,rotation=90)
ax.set_xlabel('-log10(P)',fontsize=20)
ax.set_xlim([-1.75,1.75])
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)
plt.savefig(file+'_cutoff_'+str(cutoff)+'_response_barplot.pdf', bbox_inches='tight')

# %%
REALpvals_irf
# Out:
# {'Eo': -0.953011395422729,
#  'Er': -0.31647178784797814,
#  'M0': 0.6799884022342944,
#  'M1': 0.5958830905651777,
#  'M2': 0.5958830905651777,
#  'Mg': -0.14071352485269262,
#  'Mono': -0.376759117811582,
#  'NK': -0.953011395422729,
#  'NaiveCD4': 0.376759117811582,
#  'NaiveCD8': 0.376759117811582,
#  'PC': 0.768278203545834,
#  'PMN': 0.8596837951986661,
#  'Tregs': 0.953011395422729,
#  'cm4': 0.0215562667600163,
#  'cm8': -0.953011395422729,
#  'ed8': 0.2159249389401403,
#  'em4': 1.0,
#  'em8': 0.5955544485034858,
#  'iDC': -0.039170166029983945,
#  'mB': -0.5153637324829679,
#  'mDC': 0.8596837951986661,
#  'nB': -0.5164930466870377}

# %%
REALpvals_irfdf=pd.DataFrame.from_dict(REALpvals_irf, orient='index',columns=['MWU_pvalue'])
REALpvals_irfdf.index.name = 'Celltype'

REALpvals_irfdf
# Out:
#           MWU_pvalue
# Celltype
# Eo         -0.953011
# Er         -0.316472
# M0          0.679988
# M1          0.595883
# M2          0.595883
# Mg         -0.140714
# Mono       -0.376759
# NK         -0.953011
# NaiveCD4    0.376759
# NaiveCD8    0.376759
# PC          0.768278
# PMN         0.859684
# Tregs       0.953011
# cm4         0.021556
# cm8        -0.953011
# ed8         0.215925
# em4         1.000000
# em8         0.595554
# iDC        -0.039170
# mB         -0.515364
# mDC         0.859684
# nB         -0.516493

# %%
REALpvals_irfdf.to_csv(file+"_pvalue.txt",sep='\t')
