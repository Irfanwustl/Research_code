# %%
import pandas as pd
largeSMfile = '/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/Epcam_blue/UsingPdac/PDAC_epcam_rankedV1_SM_top1000_SM_unique'

infofile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/Epcam_blue/UsingPdac/PDAC_epcam_rankedV1_index.txt'

largesmdf=pd.read_csv(largeSMfile,sep='\t',index_col=['chrom','start'])
largesmdf.head()
# Out:
#                 NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr19 56104234              0.9              0.9        0.9        0.9
#       4054391               0.9              0.9        0.9        0.9
# chr14 73536470              0.9              0.9        0.9        0.9
#       73536615              0.9              0.9        0.9        0.9
# chr10 94404632              0.9              0.9        0.9        0.9
#
#                 PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr19 56104234        0.9          0.9        0.9        0.9        0.9
#       4054391         0.9          0.9        0.9        0.9        0.9
# chr14 73536470        0.9          0.9        0.9        0.9        0.9
#       73536615        0.9          0.9        0.9        0.9        0.9
# chr10 94404632        0.9          0.9        0.9        0.9        0.9
#
#                 iDC-others  ...  em8-others  Eo-others  Tregs-others  \
# chrom start                 ...
# chr19 56104234         0.9  ...         0.9        0.9           0.9
#       4054391          0.9  ...         0.9        0.9           0.9
# chr14 73536470         0.9  ...         0.9        0.9           0.9
#       73536615         0.9  ...         0.9        0.9           0.9
# chr10 94404632         0.9  ...         0.9        0.9           0.9
#
#                 em4-others  ed8-others  Mg-others  cm4-others  Er-others  \
# chrom start
# chr19 56104234         0.9         0.9        0.9         0.9        0.9
#       4054391          0.9         0.9        0.9         0.9        0.9
# chr14 73536470         0.9         0.9        0.9         0.9        0.9
#       73536615         0.9         0.9        0.9         0.9        0.9
# chr10 94404632         0.9         0.9        0.9         0.9        0.9
#
#                 mB-others  EPCAM-others
# chrom start
# chr19 56104234        0.9     -0.993903
#       4054391         0.9     -0.993395
# chr14 73536470        0.9     -0.991971
#       73536615        0.9     -0.990523
# chr10 94404632        0.9     -0.990420
#
# [5 rows x 23 columns]

# %%
largesmdf['mincolname']=largesmdf.idxmin(axis=1)
largesmdf.head()
# Out:
#                 NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr19 56104234              0.9              0.9        0.9        0.9
#       4054391               0.9              0.9        0.9        0.9
# chr14 73536470              0.9              0.9        0.9        0.9
#       73536615              0.9              0.9        0.9        0.9
# chr10 94404632              0.9              0.9        0.9        0.9
#
#                 PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr19 56104234        0.9          0.9        0.9        0.9        0.9
#       4054391         0.9          0.9        0.9        0.9        0.9
# chr14 73536470        0.9          0.9        0.9        0.9        0.9
#       73536615        0.9          0.9        0.9        0.9        0.9
# chr10 94404632        0.9          0.9        0.9        0.9        0.9
#
#                 iDC-others  ...  Eo-others  Tregs-others  em4-others  \
# chrom start                 ...
# chr19 56104234         0.9  ...        0.9           0.9         0.9
#       4054391          0.9  ...        0.9           0.9         0.9
# chr14 73536470         0.9  ...        0.9           0.9         0.9
#       73536615         0.9  ...        0.9           0.9         0.9
# chr10 94404632         0.9  ...        0.9           0.9         0.9
#
#                 ed8-others  Mg-others  cm4-others  Er-others  mB-others  \
# chrom start
# chr19 56104234         0.9        0.9         0.9        0.9        0.9
#       4054391          0.9        0.9         0.9        0.9        0.9
# chr14 73536470         0.9        0.9         0.9        0.9        0.9
#       73536615         0.9        0.9         0.9        0.9        0.9
# chr10 94404632         0.9        0.9         0.9        0.9        0.9
#
#                 EPCAM-others    mincolname
# chrom start
# chr19 56104234     -0.993903  EPCAM-others
#       4054391      -0.993395  EPCAM-others
# chr14 73536470     -0.991971  EPCAM-others
#       73536615     -0.990523  EPCAM-others
# chr10 94404632     -0.990420  EPCAM-others
#
# [5 rows x 24 columns]

# %%
infodf=pd.read_csv(infofile,sep='\t')
#infodf['Unnamed: 0']
infodf.head()
# Out:
#   Unnamed: 0  Index
# 0      EPCAM    248

# %%
grouped=largesmdf.groupby('mincolname')
outlist=[]
for name, group in grouped:
   
    tempct=name.replace('-others','')
    corresnumber=(infodf[infodf['Unnamed: 0']==tempct]['Index']).tolist()[0]
   
    tempdf=group.head(n=corresnumber+1)
    
    outlist.append(tempdf)

# %%
outdf=pd.concat(outlist)
outdf=outdf.drop(['mincolname'],axis=1)

# %%
outdf.to_csv(infofile+"_inflectionSM.txt",sep='\t')
