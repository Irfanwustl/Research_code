# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/rankspace_idea/GSEA_run/Bugfixed/othertest/NaiveCD4_CpGdelta_info_faster.txt_V1hypo_rankedtop5000.txt'

indf=pd.read_csv(infile,sep='\t')
indf.head()
# Out:
#    chrom      start        end  NaiveCD4-Bcell  NaiveCD4-Myloid  NaiveCD4-NK  \
# 0  chr16   27233119   27233121        0.530125         0.945750     0.961333
# 1   chr8    1792266    1792268        0.855250         0.952750     0.925000
# 2  chr19    1072193    1072195        0.939625         0.941063     0.845500
# 3   chr2  171081668  171081670        0.905625         0.911000     0.868333
# 4   chr5  134964628  134964630        0.939250         0.943312     0.431500
#
#    NaiveCD4-NaiveCD8  NaiveCD4-PMNlike  NaiveCD4-Tregs  NaiveCD4-cm4  ...  \
# 0           0.395000          0.886333          0.7605        0.5380  ...
# 1           0.547333          0.901375          0.4050        0.6285  ...
# 2           0.462167          0.915833          0.5700        0.6005  ...
# 3           0.438000          0.829667          0.5130        0.7755  ...
# 4           0.492167          0.910056          0.6730        0.5855  ...
#
# ...

# %%
indf.shape
# Out:
# (5000, 53)

# %%
indf.columns
# Out:
# Index(['chrom', 'start', 'end', 'NaiveCD4-Bcell', 'NaiveCD4-Myloid',
#        'NaiveCD4-NK', 'NaiveCD4-NaiveCD8', 'NaiveCD4-PMNlike',
#        'NaiveCD4-Tregs', 'NaiveCD4-cm4', 'NaiveCD4-cm8', 'NaiveCD4-ed8',
#        'NaiveCD4-em4', 'NaiveCD4-em8', 'Minimum delta', 'Maximum delta',
#        'Average delta', 'NaiveCD4', 'NaiveCD8', 'nB', 'NK', 'PC', 'Mono', 'M0',
#        'M1', 'M2', 'iDC', 'mDC', 'PMN', 'cm8', 'em8', 'Eo', 'Tregs', 'em4',
#        'ed8', 'Mg', 'cm4', 'Er', 'mB', '(Minimum delta+Average delta)/2',
#        'Minimum delta rank', 'Average delta rank',
#        '(Minimum delta rank+Average delta rank)/2', 'OwnGroup_avg_delta',
#        'OtherGroup_avg_delta', 'OwnGroup_avg_delta rank',
#        'OtherGroup_avg_delta rank',
#        '(OwnGroup_avg_delta rank+OtherGroup_avg_delta rank)/2',
#        '(OwnGroup_avg_delta rank+Average delta rank)/2', 'Methylation rank',
#        '(Methylation rank+OtherGroup_avg_delta rank+OwnGroup_avg_delta rank)/3',
# ...

# %%
boxplot = indf.boxplot(column=['OwnGroup_avg_delta','OtherGroup_avg_delta','Average delta','Minimum delta'],rot=90)
