# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rankfile = 'BL22_all_matrix_promdata_intwith_Tregs_CpGdelta_info_faster.txt_3000_forheatunderlyingdata_ranked_pos.txt_sorted.txt_cyberin'
genefile = 'BL22_all_matrix_promdata_intwith_SMTregs_51pos_cyberin.txt'
testfile = 'BL22_all_matrix_promdata_intwith_Tregs_CpGdelta_info_faster.txt_3000_forheatunderlyingdata_ranked_pos.txt_sorted_500.txt_cyberin_toy.txt'

df_rank = pd.read_csv(rankfile, sep='\t')
df_gene = pd.read_csv(genefile, sep='\t')
df_test = pd.read_csv(testfile, sep='\t')
display(df_rank)
display(df_gene)
display(df_test)
# Out:
#              position  \
# 0       chrX:49260635
# 1      chr5:180312123
# 2       chr18:3898036
# 3      chr2:235763067
# 4       chrX:49260622
# ...               ...
# 2995  chr11:102324812
# 2996   chr11:66701672
# 2997   chr16:69130985
# 2998    chr19:5975563
# 2999    chr3:71057490
#
#       aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# 0                                                 1.000
# 1                                                 0.886
# 2                                                 0.972
# 3                                                 0.941
# 4                                                 0.870
# ...                                                 ...
# 2995                                              0.931
# 2996                                              0.600
# 2997                                                NaN
# 2998                                              1.000
# ...

# %%
gene_lst = np.array(df_gene['position'])
gene_final = []
for gene in gene_lst:
    if gene in np.array(df_rank['position']):
        gene_final.append(gene)

# %%
ES = 0
max_ES = 0
ES_vals = []
N = len(df_rank['position'])
N_S = len(df_gene['position'])
for gene in df_rank['position']:
    if gene in gene_final:
        ES += np.sqrt((N - N_S) / N_S)
        ES_vals.append(ES)
    else:
        ES -= np.sqrt(N_S / (N - N_S))
        ES_vals.append(ES)
    if ES > max_ES:
        max_ES = ES
        
plt.plot(list(range(len(ES_vals))), ES_vals)
plt.xlabel('Gene List Rank')
plt.ylabel('Enrichment Score')
print('Maximum Enrichment Score =', max_ES)
# Out:
# Maximum Enrichment Score = 538.2702922847113

# %%
# for test
ES = 0
max_ES = 0
ES_vals = []
N = len(df_rank['position'])
N_S = len(df_test['position'])
for gene in df_rank['position']:
    if gene in np.array(df_test['position']):
        ES += np.sqrt((N - N_S) / N_S)
        ES_vals.append(ES)
    else:
        ES -= np.sqrt(N_S / (N - N_S))
        ES_vals.append(ES)
    if ES > max_ES:
        max_ES = ES
        
plt.plot(list(range(len(ES_vals))), ES_vals)
plt.xlabel('Gene List Rank')
plt.ylabel('Enrichment Score')
print('Maximum Enrichment Score =', max_ES)
# Out:
# Maximum Enrichment Score = 500.0
