# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/BL22_groupv2/All/Alllinked/towardsFinalRef/allct_towardsSM_dummy_min_SM.txt'

indf=pd.read_csv(infile,sep='\t',index_col=['chrom','start'])
indf.head()
# Out:
#                NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr1  6015263              0.9              0.9        0.9        0.9
#       6015308              0.9              0.9        0.9        0.9
#       6059969              0.9              0.9        0.9        0.9
#       6064054              0.9              0.9        0.9        0.9
#       8374071              0.9              0.9        0.9        0.9
#
#                PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr1  6015263        0.9          0.9        0.9        0.9  -0.787762
#       6015308        0.9          0.9        0.9        0.9  -0.846048
#       6059969        0.9          0.9        0.9        0.9  -0.782476
#       6064054        0.9          0.9        0.9        0.9  -0.792238
#       8374071        0.9          0.9        0.9        0.9  -0.947500
#
#                iDC-others  ...  cm8-others  em8-others  Eo-others  \
# chrom start                ...
# chr1  6015263         0.9  ...         0.9         0.9        0.9
#       6015308         0.9  ...         0.9         0.9        0.9
#       6059969         0.9  ...         0.9         0.9        0.9
#       6064054         0.9  ...         0.9         0.9        0.9
#       8374071         0.9  ...         0.9         0.9        0.9
#
#                Tregs-others  em4-others  ed8-others  Mg-others  cm4-others  \
# chrom start
# chr1  6015263           0.9         0.9         0.9        0.9         0.9
#       6015308           0.9         0.9         0.9        0.9         0.9
#       6059969           0.9         0.9         0.9        0.9         0.9
#       6064054           0.9         0.9         0.9        0.9         0.9
#       8374071           0.9         0.9         0.9        0.9         0.9
#
#                Er-others  mB-others
# chrom start
# chr1  6015263        0.9        0.9
#       6015308        0.9        0.9
#       6059969        0.9        0.9
#       6064054        0.9        0.9
#       8374071        0.9        0.9
#
# [5 rows x 22 columns]

# %%
indf.shape
# Out:
# (25407, 22)

# %%
indf = indf[~indf.index.duplicated(keep=False)]

# %%
indf.shape
# Out:
# (20758, 22)

# %%
indf.to_csv(infile+"_unique",sep='\t')
