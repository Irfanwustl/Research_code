# %%
import pandas as pd
import pandas as pd
from collections import defaultdict
from sklearn import metrics
import numpy as np
import sys
import time

start_time = time.time()

inbinfile='BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkl'

outfile=inbinfile


consideringALLheyper=True


inbindf=pd.read_pickle(inbinfile)
####BL22#####
scorecolumns=['NaiveCD4-others','NaiveCD8-others','nB-others','NK-others','PC-others','Mono-others','M0-others','M1-others','M2-others','iDC-others','mDC-others','PMN-others','cm8-others','em8-others','Eo-others','Tregs-others','em4-others','ed8-others','Mg-others','cm4-others','Er-others','mB-others']


#scorecolumns=['CD4-others','CD8-others','nB-others','NK-others','Mn-others','mNeu-others','m8-others','DC-others','Eo-others','Tr-others','m4-others','Mg-others','Er-others','mB-others']

inbindf=inbindf.reset_index()
inbindf.head()
# Out:
#                                            index  NaiveCD4-others  \
# 0   Eo.HWI-ST537:223:C4DVTACXX:7:1211:7435:87447        -0.181992
# 1  Eo.HWI-ST537:224:C4E15ACXX:4:2108:11851:51609        -0.078167
# 2  Eo.HWI-ST537:224:C4E15ACXX:5:2205:15200:28811        -0.238056
# 3  Eo.HWI-ST699:234:C48WNACXX:4:2307:17364:71298        -0.095000
# 4   Eo.HWI-ST731:122:C7CNDACXX:4:2202:4871:39568        -0.048310
#
#    NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  M0-others  \
# 0        -0.146024  -0.188627  -0.131008  -0.087008    -0.121579   0.035913
# 1        -0.018802  -0.051278  -0.062452  -0.053722    -0.026135  -0.065595
# 2        -0.233865  -0.196849  -0.222341  -0.203135     0.735881   0.502960
# 3        -0.117000   0.924333  -0.085222  -0.103381    -0.074397  -0.102333
# 4         0.812135  -0.089167   0.288325   0.107437    -0.092659  -0.130722
#
#    M1-others  M2-others  ...  LENhypoCpG  LENhyperCpG  total_cpg  \
# 0   0.019849   0.431214  ...         1.0          0.0        1.0
# 1  -0.078167  -0.053373  ...         1.0          0.0        1.0
# 2   0.526008   0.567563  ...         1.0          0.0        1.0
# 3  -0.084175  -0.066365  ...         1.0          0.0        1.0
# 4  -0.130722  -0.107675  ...         1.0          0.0        1.0
#
#    LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0                      1.0                   iDC-others
# 1                      1.0                   PMN-others
# 2                      1.0                  Mono-others
# 3                      1.0                    nB-others
# 4                      1.0              NaiveCD8-others
#
#    maxscore_beforeCpGweight      maxscoredCT  maxscore  \
# 0                  0.769421       iDC-others  0.769421
# 1                  0.969452       PMN-others  0.969452
# 2                  0.735881      Mono-others  0.735881
# 3                  0.924333        nB-others  0.924333
# 4                  0.812135  NaiveCD8-others  0.812135
#
#    deltabasedfragassignment                                           filename
# 0                iDC-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 1                PMN-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 2               Mono-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 3                 nB-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 4           NaiveCD8-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
#
# [5 rows x 33 columns]

# %%
if consideringALLheyper==True:
    allassigned=inbindf.copy()


elif consideringALLheyper==False:
    allassigned=inbindf[inbindf['deltabasedfragassignment']!='NotAssigned'].copy()
    
else:
    print("wrong input")
    sys.exit(1)
#
allassigned.head()
# Out:
#                                            index  NaiveCD4-others  \
# 0   Eo.HWI-ST537:223:C4DVTACXX:7:1211:7435:87447        -0.181992
# 1  Eo.HWI-ST537:224:C4E15ACXX:4:2108:11851:51609        -0.078167
# 2  Eo.HWI-ST537:224:C4E15ACXX:5:2205:15200:28811        -0.238056
# 3  Eo.HWI-ST699:234:C48WNACXX:4:2307:17364:71298        -0.095000
# 4   Eo.HWI-ST731:122:C7CNDACXX:4:2202:4871:39568        -0.048310
#
#    NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  M0-others  \
# 0        -0.146024  -0.188627  -0.131008  -0.087008    -0.121579   0.035913
# 1        -0.018802  -0.051278  -0.062452  -0.053722    -0.026135  -0.065595
# 2        -0.233865  -0.196849  -0.222341  -0.203135     0.735881   0.502960
# 3        -0.117000   0.924333  -0.085222  -0.103381    -0.074397  -0.102333
# 4         0.812135  -0.089167   0.288325   0.107437    -0.092659  -0.130722
#
#    M1-others  M2-others  ...  LENhypoCpG  LENhyperCpG  total_cpg  \
# 0   0.019849   0.431214  ...         1.0          0.0        1.0
# 1  -0.078167  -0.053373  ...         1.0          0.0        1.0
# 2   0.526008   0.567563  ...         1.0          0.0        1.0
# 3  -0.084175  -0.066365  ...         1.0          0.0        1.0
# 4  -0.130722  -0.107675  ...         1.0          0.0        1.0
#
#    LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0                      1.0                   iDC-others
# 1                      1.0                   PMN-others
# 2                      1.0                  Mono-others
# 3                      1.0                    nB-others
# 4                      1.0              NaiveCD8-others
#
#    maxscore_beforeCpGweight      maxscoredCT  maxscore  \
# 0                  0.769421       iDC-others  0.769421
# 1                  0.969452       PMN-others  0.969452
# 2                  0.735881      Mono-others  0.735881
# 3                  0.924333        nB-others  0.924333
# 4                  0.812135  NaiveCD8-others  0.812135
#
#    deltabasedfragassignment                                           filename
# 0                iDC-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 1                PMN-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 2               Mono-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 3                 nB-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
# 4           NaiveCD8-others  BL22test_NR_3215798_insilmix6_sorted_binnedsta...
#
# [5 rows x 33 columns]

# %%
allassigned.loc[inbindf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=allassigned.loc[inbindf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
allassigned['secondmaxScore']='Notassigned'
allassigned['secondmaxScoreCT']='Notassigned'
allassigned.head()
# Out:
#                                            index  NaiveCD4-others  \
# 0   Eo.HWI-ST537:223:C4DVTACXX:7:1211:7435:87447        -0.181992
# 1  Eo.HWI-ST537:224:C4E15ACXX:4:2108:11851:51609        -0.078167
# 2  Eo.HWI-ST537:224:C4E15ACXX:5:2205:15200:28811        -0.238056
# 3  Eo.HWI-ST699:234:C48WNACXX:4:2307:17364:71298        -0.095000
# 4   Eo.HWI-ST731:122:C7CNDACXX:4:2202:4871:39568        -0.048310
#
#    NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  M0-others  \
# 0        -0.146024  -0.188627  -0.131008  -0.087008    -0.121579   0.035913
# 1        -0.018802  -0.051278  -0.062452  -0.053722    -0.026135  -0.065595
# 2        -0.233865  -0.196849  -0.222341  -0.203135     0.735881   0.502960
# 3        -0.117000   0.924333  -0.085222  -0.103381    -0.074397  -0.102333
# 4         0.812135  -0.089167   0.288325   0.107437    -0.092659  -0.130722
#
#    M1-others  M2-others  ...  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0   0.019849   0.431214  ...        1.0                      1.0
# 1  -0.078167  -0.053373  ...        1.0                      1.0
# 2   0.526008   0.567563  ...        1.0                      1.0
# 3  -0.084175  -0.066365  ...        1.0                      1.0
# 4  -0.130722  -0.107675  ...        1.0                      1.0
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight      maxscoredCT  \
# 0                   iDC-others                  0.769421       iDC-others
# 1                   PMN-others                  0.969452       PMN-others
# 2                  Mono-others                  0.735881      Mono-others
# 3                    nB-others                  0.924333        nB-others
# 4              NaiveCD8-others                  0.812135  NaiveCD8-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.769421                iDC-others
# 1  0.969452                PMN-others
# 2  0.735881               Mono-others
# 3  0.924333                 nB-others
# 4  0.812135           NaiveCD8-others
#
#                                             filename  secondmaxScore  \
# 0  BL22test_NR_3215798_insilmix6_sorted_binnedsta...     Notassigned
# 1  BL22test_NR_3215798_insilmix6_sorted_binnedsta...     Notassigned
# 2  BL22test_NR_3215798_insilmix6_sorted_binnedsta...     Notassigned
# 3  BL22test_NR_3215798_insilmix6_sorted_binnedsta...     Notassigned
# 4  BL22test_NR_3215798_insilmix6_sorted_binnedsta...     Notassigned
#
#    secondmaxScoreCT
# 0       Notassigned
# 1       Notassigned
# 2       Notassigned
# 3       Notassigned
# 4       Notassigned
#
# [5 rows x 35 columns]

# %%
grouped=allassigned.groupby('maxscoredCT')

for name, group in grouped:
    
    
    tempscorecolumns=scorecolumns.copy()
    
    tempscorecolumns.remove(name)
    
    allassigned.loc[group.index,'secondmaxScore']=group[tempscorecolumns].max(axis=1)
    allassigned.loc[group.index,'secondmaxScoreCT']=(group[tempscorecolumns]).idxmax(axis=1)

# %%
allassigned['adjustedScore_minus']=allassigned['maxscore']-allassigned['secondmaxScore']
allassigned['adjustedScore_minus_avg']=(allassigned['maxscore']+(allassigned['maxscore']-allassigned['secondmaxScore']))/2
allassigned.head()
# Out:
#                                            index  NaiveCD4-others  \
# 0   Eo.HWI-ST537:223:C4DVTACXX:7:1211:7435:87447        -0.181992
# 1  Eo.HWI-ST537:224:C4E15ACXX:4:2108:11851:51609        -0.078167
# 2  Eo.HWI-ST537:224:C4E15ACXX:5:2205:15200:28811        -0.238056
# 3  Eo.HWI-ST699:234:C48WNACXX:4:2307:17364:71298        -0.095000
# 4   Eo.HWI-ST731:122:C7CNDACXX:4:2202:4871:39568        -0.048310
#
#    NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  M0-others  \
# 0        -0.146024  -0.188627  -0.131008  -0.087008    -0.121579   0.035913
# 1        -0.018802  -0.051278  -0.062452  -0.053722    -0.026135  -0.065595
# 2        -0.233865  -0.196849  -0.222341  -0.203135     0.735881   0.502960
# 3        -0.117000   0.924333  -0.085222  -0.103381    -0.074397  -0.102333
# 4         0.812135  -0.089167   0.288325   0.107437    -0.092659  -0.130722
#
#    M1-others  M2-others  ...  maxscoredCT_beforeCpGweight  \
# 0   0.019849   0.431214  ...                   iDC-others
# 1  -0.078167  -0.053373  ...                   PMN-others
# 2   0.526008   0.567563  ...                  Mono-others
# 3  -0.084175  -0.066365  ...                    nB-others
# 4  -0.130722  -0.107675  ...              NaiveCD8-others
#
#    maxscore_beforeCpGweight      maxscoredCT  maxscore  \
# 0                  0.769421       iDC-others  0.769421
# 1                  0.969452       PMN-others  0.969452
# 2                  0.735881      Mono-others  0.735881
# 3                  0.924333        nB-others  0.924333
# 4                  0.812135  NaiveCD8-others  0.812135
#
#    deltabasedfragassignment  \
# 0                iDC-others
# 1                PMN-others
# 2               Mono-others
# 3                 nB-others
# 4           NaiveCD8-others
#
#                                             filename  secondmaxScore  \
# 0  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.724373
# 1  BL22test_NR_3215798_insilmix6_sorted_binnedsta...       0.0360238
# 2  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.567563
# 3  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.842619
# 4  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.288325
#
#    secondmaxScoreCT  adjustedScore_minus  adjustedScore_minus_avg
# 0        mDC-others            0.0450476                 0.407234
# 1         Eo-others             0.933429                  0.95144
# 2         M2-others             0.168317                 0.452099
# 3         mB-others            0.0817143                 0.503024
# 4         NK-others              0.52381                 0.667972
#
# [5 rows x 37 columns]

# %%
allassigned.columns
# Out:
# Index(['index', 'NaiveCD4-others', 'NaiveCD8-others', 'nB-others', 'NK-others',
#        'PC-others', 'Mono-others', 'M0-others', 'M1-others', 'M2-others',
#        'iDC-others', 'mDC-others', 'PMN-others', 'cm8-others', 'em8-others',
#        'Eo-others', 'Tregs-others', 'em4-others', 'ed8-others', 'Mg-others',
#        'cm4-others', 'Er-others', 'mB-others', 'LENhypoCpG', 'LENhyperCpG',
#        'total_cpg', 'LENhypoCpG_BY_total_cpg', 'maxscoredCT_beforeCpGweight',
#        'maxscore_beforeCpGweight', 'maxscoredCT', 'maxscore',
#        'deltabasedfragassignment', 'filename', 'secondmaxScore',
#        'secondmaxScoreCT', 'adjustedScore_minus', 'adjustedScore_minus_avg'],
#       dtype='object')

# %%
adjustedScore_minus0val=list(set(allassigned[allassigned['LENhypoCpG_BY_total_cpg']==0]['adjustedScore_minus'].tolist()))
if len(adjustedScore_minus0val)==0:
    pass
elif len(adjustedScore_minus0val)!=1 or adjustedScore_minus0val[0]!=0:
    print(adjustedScore_minus0val)
    sys.exit(1)

# %%
adjustedScore_minus_avg0val=list(set(allassigned[allassigned['LENhypoCpG_BY_total_cpg']==0]['adjustedScore_minus_avg'].tolist()))


if len(adjustedScore_minus_avg0val)==0:
    pass

elif len(adjustedScore_minus_avg0val)!=1 or adjustedScore_minus_avg0val[0]!=0:
    print(adjustedScore_minus_avg0val)
    sys.exit(1)

# %%
allassigned['LENhypoCpG_0.8']=0
allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.8,'LENhypoCpG_0.8']=allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.8,'LENhypoCpG']

# %%
allassigned['LENhypoCpG_0.5']=0
allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.5,'LENhypoCpG_0.5']=allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.5,'LENhypoCpG']

# %%
allassigned.head()
# Out:
#                                            index  NaiveCD4-others  \
# 0   Eo.HWI-ST537:223:C4DVTACXX:7:1211:7435:87447        -0.181992
# 1  Eo.HWI-ST537:224:C4E15ACXX:4:2108:11851:51609        -0.078167
# 2  Eo.HWI-ST537:224:C4E15ACXX:5:2205:15200:28811        -0.238056
# 3  Eo.HWI-ST699:234:C48WNACXX:4:2307:17364:71298        -0.095000
# 4   Eo.HWI-ST731:122:C7CNDACXX:4:2202:4871:39568        -0.048310
#
#    NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  M0-others  \
# 0        -0.146024  -0.188627  -0.131008  -0.087008    -0.121579   0.035913
# 1        -0.018802  -0.051278  -0.062452  -0.053722    -0.026135  -0.065595
# 2        -0.233865  -0.196849  -0.222341  -0.203135     0.735881   0.502960
# 3        -0.117000   0.924333  -0.085222  -0.103381    -0.074397  -0.102333
# 4         0.812135  -0.089167   0.288325   0.107437    -0.092659  -0.130722
#
#    M1-others  M2-others  ...      maxscoredCT  maxscore  \
# 0   0.019849   0.431214  ...       iDC-others  0.769421
# 1  -0.078167  -0.053373  ...       PMN-others  0.969452
# 2   0.526008   0.567563  ...      Mono-others  0.735881
# 3  -0.084175  -0.066365  ...        nB-others  0.924333
# 4  -0.130722  -0.107675  ...  NaiveCD8-others  0.812135
#
#    deltabasedfragassignment  \
# 0                iDC-others
# 1                PMN-others
# 2               Mono-others
# 3                 nB-others
# 4           NaiveCD8-others
#
#                                             filename  secondmaxScore  \
# 0  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.724373
# 1  BL22test_NR_3215798_insilmix6_sorted_binnedsta...       0.0360238
# 2  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.567563
# 3  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.842619
# 4  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.288325
#
#    secondmaxScoreCT  adjustedScore_minus  adjustedScore_minus_avg  \
# 0        mDC-others            0.0450476                 0.407234
# 1         Eo-others             0.933429                  0.95144
# 2         M2-others             0.168317                 0.452099
# 3         mB-others            0.0817143                 0.503024
# 4         NK-others              0.52381                 0.667972
#
#    LENhypoCpG_0.8  LENhypoCpG_0.5
# 0             1.0             1.0
# 1             1.0             1.0
# 2             1.0             1.0
# 3             1.0             1.0
# 4             1.0             1.0
#
# [5 rows x 39 columns]

# %%
def calposscore(fgrouped,whichmethod,fname):
    ctposscoredict= defaultdict(list)
    totalcpgdict=defaultdict(list)
    hypocpgdict=defaultdict(list)
    hypercpgdict=defaultdict(list)
    
    TPposscoredict=defaultdict(list)
    FPposscoredict=defaultdict(list)
    
    for score in scorecolumns:
        ctname=score.replace('-others','')
        deltabasedfragassigned=fgrouped['deltabasedfragassignment'].tolist()
        if score in deltabasedfragassigned:
            
            runningDF=fgrouped[fgrouped['deltabasedfragassignment']==score]
            
            temp_posscore=runningDF[whichmethod].tolist()
            temptotal_posscore=sum(temp_posscore)
            temp_posfrag=len(temp_posscore)
            
            runningDF_TP=runningDF[runningDF['index'].str.contains(ctname)]
            
            tempTP_score=runningDF_TP[whichmethod].tolist()
            tempTP_totalposscore=sum(tempTP_score)
            
            runningDF_FP=runningDF[~runningDF['index'].str.contains(ctname)]
            
            tempFP_score=runningDF_FP[whichmethod].tolist()
            tempFP_totalposscore=sum(tempFP_score)
            
           
            
            #runningDF_FP=

        else:
            temptotal_posscore=0
            temp_posfrag=0

        

        ctposscoredict[ctname].append(temptotal_posscore)
        
        TPposscoredict[ctname].append(tempTP_totalposscore)
        FPposscoredict[ctname].append(tempFP_totalposscore)
        
 
        
        totalcpgdict[ctname].append(runningDF['total_cpg'].sum())
        hypocpgdict[ctname].append(runningDF['LENhypoCpG'].sum())
        hypercpgdict[ctname].append(runningDF['LENhyperCpG'].sum())
        
        
    ctposscoredf=pd.DataFrame.from_dict(ctposscoredict)
    ctposscoredf['Mixture']=fname

    totalcpgdf=pd.DataFrame.from_dict(totalcpgdict)
    totalcpgdf['Mixture']=fname
    
    hypocpgdf=pd.DataFrame.from_dict(hypocpgdict)
    hypocpgdf['Mixture']=fname
    
    hypercpgdf=pd.DataFrame.from_dict(hypercpgdict)
    hypercpgdf['Mixture']=fname
    
    TPposscoreDF=pd.DataFrame.from_dict(TPposscoredict)
    FPposscoreDF=pd.DataFrame.from_dict(FPposscoredict)
    
    TPposscoreDF['Mixture']=fname
    FPposscoreDF['Mixture']=fname
    
    
   
    return ctposscoredf,totalcpgdf,hypocpgdf,hypercpgdf,TPposscoreDF,FPposscoreDF

# %%
filegrouped=allassigned.groupby('filename')

maxscorelist=[]
adjustedScore_minuslist=[]
adjustedScore_minus_avglist=[]


alltotalcpg=[]
allhypocpg=[]
allhypercpg=[]


TPscorelist=[]
FPscorelist=[]

for name, group in filegrouped:
    #maxscorelist.append(calposscore(group,'maxscore',name))
    #adjustedScore_minuslist.append(calposscore(group,'adjustedScore_minus',name))
    
    r1,r2,r3,r4,r5,r6=calposscore(group,'adjustedScore_minus_avg',name)
    adjustedScore_minus_avglist.append(r1)
    
    alltotalcpg.append(r2)
    allhypocpg.append(r3)
    allhypercpg.append(r4)
    
    TPscorelist.append(r5)
    FPscorelist.append(r6)

# %%
'''
maxscorelistDF=pd.concat(maxscorelist)
maxscorelistDF.set_index('Mixture',inplace=True)
adjustedScore_minuslistDF=pd.concat(adjustedScore_minuslist)
adjustedScore_minuslistDF.set_index('Mixture',inplace=True)
'''

adjustedScore_minus_avglistDF=pd.concat(adjustedScore_minus_avglist)
adjustedScore_minus_avglistDF.set_index('Mixture',inplace=True)

# %%
alltotalcpgDF=pd.concat(alltotalcpg)
allhypocpgDF=pd.concat(allhypocpg)
allhypercpgDF=pd.concat(allhypercpg)

alltotalcpgDF.set_index('Mixture',inplace=True)
allhypocpgDF.set_index('Mixture',inplace=True)
allhypercpgDF.set_index('Mixture',inplace=True)

# %%
'''
maxscorelistDF.to_csv(outfile+'_maxscore_CSxOut.txt',sep="\t")
adjustedScore_minuslistDF.to_csv(outfile+'adjustedScore_minus_CSxOut.txt',sep="\t")
'''

adjustedScore_minus_avglistDF.to_csv(outfile+'adjustedScore_minus_avg_CSxOut.txt',sep="\t")

# %%
end_time = time.time()

time_elapsed = (end_time - start_time)

print(time_elapsed)
# Out:
# 1.2723782062530518

# %%
alltotalcpgDF
# Out:
#                                                     NaiveCD4  NaiveCD8     nB  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...     822.0     228.0  143.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...     777.0     212.0  127.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...     792.0     226.0  123.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...     758.0     184.0  133.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...     767.0     212.0  125.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...     810.0     226.0  137.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...     801.0     224.0  126.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...     782.0     230.0  133.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...     814.0     217.0  119.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...     775.0     241.0  136.0
#
#                                                        NK     PC   Mono  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  739.0  116.0  295.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  720.0  113.0  309.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  722.0  124.0  301.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  713.0  123.0  288.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  742.0  113.0  299.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  747.0  126.0  273.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  698.0  106.0  304.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  727.0  116.0  294.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  781.0  115.0  325.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  723.0  112.0  282.0
#
#                                                        M0     M1     M2  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  786.0  158.0  723.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  788.0  172.0  720.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  825.0  162.0  719.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  818.0  166.0  750.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  834.0  152.0  703.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  855.0  170.0  723.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  817.0  172.0  733.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  789.0  156.0  708.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  841.0  179.0  760.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  844.0  167.0  702.0
#
#                                                       iDC  ...    cm8   em8  \
# Mixture                                                    ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  342.0  ...  184.0  73.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  300.0  ...  206.0  86.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  322.0  ...  174.0  80.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  354.0  ...  182.0  80.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  320.0  ...  201.0  62.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  329.0  ...  184.0  70.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  329.0  ...  191.0  78.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  314.0  ...  200.0  80.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  342.0  ...  167.0  82.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  311.0  ...  223.0  91.0
#
#                                                        Eo  Tregs   em4   ed8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  163.0  146.0  76.0  70.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  168.0  154.0  77.0  70.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  171.0  148.0  90.0  74.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  169.0  153.0  91.0  75.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  151.0  149.0  88.0  89.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  158.0  142.0  94.0  72.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  162.0  155.0  71.0  71.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  167.0  157.0  90.0  62.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  167.0  137.0  92.0  80.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  149.0  168.0  56.0  74.0
#
#                                                        Mg    cm4     Er     mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  231.0   86.0  395.0   95.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  207.0   79.0  419.0   87.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  202.0   86.0  410.0  111.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  227.0   89.0  373.0   92.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  226.0   87.0  396.0   94.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  239.0   91.0  399.0   89.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  226.0   86.0  395.0   85.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  228.0   79.0  406.0   90.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  207.0  105.0  397.0  100.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  239.0   80.0  411.0   97.0
#
# [10 rows x 22 columns]

# %%
allhypocpgDF
# Out:
#                                                     NaiveCD4  NaiveCD8    nB  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...     157.0      39.0  11.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...      99.0      29.0  23.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...     136.0      30.0  20.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...     148.0      31.0  16.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...     170.0      35.0  14.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...     173.0      28.0  21.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...     121.0      31.0  25.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...     143.0      31.0  21.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...     139.0      36.0  16.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...     136.0      29.0  14.0
#
#                                                       NK    PC   Mono     M0  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  51.0   7.0   81.0  184.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  83.0   4.0  102.0  186.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  52.0  10.0   92.0  238.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  77.0   4.0   61.0  147.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  85.0   8.0   69.0  193.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  96.0   5.0   69.0  186.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  86.0   5.0   69.0  123.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  99.0   5.0   68.0  204.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  76.0   4.0   52.0  117.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  96.0   7.0   76.0  216.0
#
#                                                       M1     M2   iDC  ...  \
# Mixture                                                                ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  33.0  135.0  74.0  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  36.0  137.0  76.0  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  40.0  153.0  88.0  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  27.0  108.0  69.0  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  34.0  124.0  60.0  ...
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  34.0  128.0  72.0  ...
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  24.0  122.0  60.0  ...
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  27.0  140.0  68.0  ...
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  13.0  109.0  61.0  ...
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  33.0  154.0  67.0  ...
#
#                                                      cm8   em8    Eo  Tregs  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  30.0  21.0  18.0   21.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  43.0  34.0  18.0   15.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  26.0  25.0  29.0   15.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  51.0  29.0   9.0   29.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  49.0  24.0  14.0   21.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  46.0  23.0  11.0   26.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  41.0  29.0   7.0   34.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  46.0  25.0  19.0   27.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  54.0  29.0  18.0   18.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  45.0  26.0  12.0   29.0
#
#                                                      em4   ed8    Mg   cm4  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  12.0  14.0  17.0  23.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  10.0   9.0  11.0  12.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  11.0  10.0  15.0  13.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  20.0  13.0  14.0  22.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  21.0   9.0  15.0  24.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  22.0  15.0  14.0  25.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  11.0  10.0  20.0  21.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  17.0  10.0  12.0  21.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  17.0  24.0  17.0  25.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  14.0   9.0  14.0  22.0
#
#                                                       Er    mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  50.0   5.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  27.0   9.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  28.0  14.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  38.0  16.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  43.0   7.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  72.0   8.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  50.0  11.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  54.0   6.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  47.0  13.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  81.0   8.0
#
# [10 rows x 22 columns]

# %%
allhypercpgDF
# Out:
#                                                     NaiveCD4  NaiveCD8     nB  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...     665.0     189.0  132.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...     678.0     183.0  104.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...     656.0     196.0  103.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...     610.0     153.0  117.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...     597.0     177.0  111.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...     637.0     198.0  116.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...     680.0     193.0  101.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...     639.0     199.0  112.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...     675.0     181.0  103.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...     639.0     212.0  122.0
#
#                                                        NK     PC   Mono  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  688.0  109.0  214.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  637.0  109.0  207.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  670.0  114.0  209.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  636.0  119.0  227.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  657.0  105.0  230.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  651.0  121.0  204.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  612.0  101.0  235.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  628.0  111.0  226.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  705.0  111.0  273.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  627.0  105.0  206.0
#
#                                                        M0     M1     M2  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  602.0  125.0  588.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  602.0  136.0  583.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  587.0  122.0  566.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  671.0  139.0  642.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  641.0  118.0  579.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  669.0  136.0  595.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  694.0  148.0  611.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  585.0  129.0  568.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  724.0  166.0  651.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  628.0  134.0  548.0
#
#                                                       iDC  ...    cm8   em8  \
# Mixture                                                    ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  268.0  ...  154.0  52.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  224.0  ...  163.0  52.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  234.0  ...  148.0  55.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  285.0  ...  131.0  51.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  260.0  ...  152.0  38.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  257.0  ...  138.0  47.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  269.0  ...  150.0  49.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  246.0  ...  154.0  55.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  281.0  ...  113.0  53.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  244.0  ...  178.0  65.0
#
#                                                        Eo  Tregs   em4   ed8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  145.0  125.0  64.0  56.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  150.0  139.0  67.0  61.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  142.0  133.0  79.0  64.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  160.0  124.0  71.0  62.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  137.0  128.0  67.0  80.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  147.0  116.0  72.0  57.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  155.0  121.0  60.0  61.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  148.0  130.0  73.0  52.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  149.0  119.0  75.0  56.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  137.0  139.0  42.0  65.0
#
#                                                        Mg   cm4     Er    mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  214.0  63.0  345.0  90.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  196.0  67.0  392.0  78.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  187.0  73.0  382.0  97.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  213.0  67.0  335.0  76.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  211.0  63.0  353.0  87.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  225.0  66.0  327.0  81.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstat...  206.0  65.0  345.0  74.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstat...  216.0  58.0  352.0  84.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstat...  190.0  80.0  350.0  87.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstat...  225.0  58.0  330.0  89.0
#
# [10 rows x 22 columns]

# %%
smfile='BL22_genepromSM_0.7.txt_TRAININGbestref.txt'
smdf=pd.read_csv(smfile,sep="\t",index_col=['chrom','start'])
smdf.head()
# Out:
#                  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr3  48773066          0.023151         0.045151   0.054929   0.051786
#       138232377         0.017310         0.042103   0.071786   0.080865
# chr12 76769087          0.070095         0.011778   0.039714   0.058222
# chr8  23158892          0.073817         0.021087   0.082897   0.058103
# chr5  5463864           0.051214         0.011754   0.031659   0.062040
#
#                  PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr3  48773066    0.065754     0.032929   0.071690   0.030833   0.046897
#       138232377  -0.010627     0.080865   0.080865   0.002643   0.080865
# chr12 76769087    0.070095     0.046349   0.070095   0.028190   0.034825
# chr8  23158892    0.030865     0.056357   0.068929   0.011310   0.005373
# chr5  5463864     0.047024     0.031310   0.045627   0.019437   0.026770
#
#                  iDC-others  ...  cm8-others  em8-others  Eo-others  \
# chrom start                  ...
# chr3  48773066     0.025595  ...    0.071690    0.054929  -0.975929
#       138232377    0.035294  ...    0.080865    0.062008  -0.966754
# chr12 76769087     0.033952  ...    0.054905    0.059619  -0.964952
# chr8  23158892     0.082897  ...    0.062992    0.056706  -0.964722
# chr5  5463864      0.074611  ...    0.051040    0.059421  -0.964103
#
#                  Tregs-others  em4-others  ed8-others  Mg-others  cm4-others  \
# chrom start
# chr3  48773066       0.071690    0.036595    0.057548   0.071690    0.050214
#       138232377      0.080865    0.054675    0.080865   0.080865    0.080865
# chr12 76769087       0.019286    0.070095    0.037095   0.070095    0.058571
# chr8  23158892       0.070325    0.031563    0.040468   0.060373    0.068230
# chr5  5463864        0.058373    0.059421    0.057325   0.020659    0.042135
#
#                  Er-others  mB-others
# chrom start
# chr3  48773066    0.071690   0.034500
#       138232377   0.080865   0.060960
# chr12 76769087    0.070095   0.035524
# chr8  23158892    0.067706   0.042563
# chr5  5463864     0.048944   0.041611
#
# [5 rows x 22 columns]

# %%
smdf['mincolname']=smdf.idxmin(axis=1)
grouped=smdf.groupby('mincolname')
outlist=defaultdict(list)
for name, group in grouped:
    tempct=name.replace('-others','')
    outlist[tempct].append(group.shape[0])
outdf=pd.DataFrame.from_dict(outlist,orient='index',columns=['#CpG'])
outdf.index.name='Celltype'
outdf.head()
# Out:
#           #CpG
# Celltype
# Eo          50
# Er         100
# M0         200
# M1          50
# M2         200

# %%
smdfPMN=smdf[smdf['mincolname']=='PMN-others']
smdfPMN.shape
# Out:
# (25, 23)

# %%
alltotalcpgDF['PMN']
# Out:
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedstats.pkl    76.0
# BL22test_NR_3215798_insilmix1_sorted_binnedstats.pkl     83.0
# BL22test_NR_3215798_insilmix2_sorted_binnedstats.pkl     83.0
# BL22test_NR_3215798_insilmix3_sorted_binnedstats.pkl     81.0
# BL22test_NR_3215798_insilmix4_sorted_binnedstats.pkl     80.0
# BL22test_NR_3215798_insilmix5_sorted_binnedstats.pkl     83.0
# BL22test_NR_3215798_insilmix6_sorted_binnedstats.pkl     72.0
# BL22test_NR_3215798_insilmix7_sorted_binnedstats.pkl     68.0
# BL22test_NR_3215798_insilmix8_sorted_binnedstats.pkl     80.0
# BL22test_NR_3215798_insilmix9_sorted_binnedstats.pkl     77.0
# Name: PMN, dtype: float64

# %%
####just testing###

# %%
smdfPMNsampled=smdfPMN.sample(n=76,replace=True)
smdfPMNsampled['PMN-others'].sum()*.13
# Out:
# -9.511924603174606

# %%
smdfPMNsampled=smdfPMN.sample(n=76,replace=True)
smdfPMNsampled['PMN-others'].sum()
# Out:
# -73.19423015873016

# %%
smdfPMNsampled=smdfPMN.sample(n=80,replace=True)
smdfPMNsampled['PMN-others'].sum()*.08
# Out:
# -6.170781587301588

# %%
smdfPMNsampled=smdfPMN.sample(n=83,replace=True)
smdfPMNsampled['PMN-others'].sum()*.03
# Out:
# -2.401029761904762

# %%
####just testing###

# %%
###prepare maxpossible score###
def maxpossiblescore(fgroupedTotalCpG,fname,smwithmincol):
    ctposscoredict= defaultdict(list)
    
    
    for score in scorecolumns:
        ctname=score.replace('-others','')
        currenttotalCpG=fgroupedTotalCpG[ctname] ###############check. needs to be float, not series
       
        
        corressSM=smwithmincol[smwithmincol['mincolname']==score]
        corressampled=corressSM.sample(n=int(currenttotalCpG),replace=True)
        
        corressscore=-1*corressampled[score].sum()
        
        ctposscoredict[ctname].append(corressscore)
        
        
        
        
        
        
    ctposscoredf=pd.DataFrame.from_dict(ctposscoredict)
    ctposscoredf['Mixture']=fname
    
   

    
   
    return ctposscoredf

# %%
maxscorepossible=[]


    
for index, row in alltotalcpgDF.iterrows():
    maxscorepossible.append(maxpossiblescore(row,index,smdf))

maxscorepossibleDF=pd.concat(maxscorepossible)
maxscorepossibleDF.set_index('Mixture',inplace=True)


maxscorepossibleDF['PMN']
# Out:
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedstats.pkl    73.211516
# BL22test_NR_3215798_insilmix1_sorted_binnedstats.pkl     79.987651
# BL22test_NR_3215798_insilmix2_sorted_binnedstats.pkl     79.980667
# BL22test_NR_3215798_insilmix3_sorted_binnedstats.pkl     78.114873
# BL22test_NR_3215798_insilmix4_sorted_binnedstats.pkl     77.136000
# BL22test_NR_3215798_insilmix5_sorted_binnedstats.pkl     80.074317
# BL22test_NR_3215798_insilmix6_sorted_binnedstats.pkl     69.423429
# BL22test_NR_3215798_insilmix7_sorted_binnedstats.pkl     65.480611
# BL22test_NR_3215798_insilmix8_sorted_binnedstats.pkl     77.096056
# BL22test_NR_3215798_insilmix9_sorted_binnedstats.pkl     74.218897
# Name: PMN, dtype: float64

# %%
maxscorepossibleDF.head()
# Out:
#                                                       NaiveCD4    NaiveCD8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  653.836222  176.851952
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  619.150016  164.265222
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  630.672770  175.516810
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  603.801373  142.531048
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  610.307206  164.072056
#
#                                                             nB          NK  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  133.181190  667.130056
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  118.302175  648.735587
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  114.467262  651.414214
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  124.039563  643.439159
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  116.347778  669.364476
#
#                                                             PC        Mono  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  111.821714  217.000619
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  109.011667  227.864222
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  119.717706  221.809286
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  118.733722  211.546317
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  109.085706  219.945595
#
#                                                             M0          M1  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  608.886143  123.742754
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  609.043643  134.589421
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  638.115381  126.264627
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  631.544865  129.386960
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  644.038254  118.495246
#
#                                                             M2         iDC  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  581.347984  267.993643
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  578.860071  235.174778
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  579.012365  252.088000
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  605.007357  277.047262
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  566.743452  250.812254
#
#                                                     ...         cm8  \
# Mixture                                             ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  ...  142.559556
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  ...  158.665794
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  ...  134.230825
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  ...  140.357603
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  ...  155.180460
#
#                                                           em8          Eo  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  53.427571  155.132341
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  62.698714  160.091714
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  58.726389  162.708873
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  58.844302  160.897532
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  45.795913  143.641175
#
#                                                          Tregs        em4  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  118.464222  58.868944
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  125.261960  60.272063
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  120.775849  70.323794
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  124.336373  70.711159
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  121.127087  68.260270
#
#                                                           ed8          Mg  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  60.670087  211.956214
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  60.727714  189.287492
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  64.229889  185.713516
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  65.057817  207.783405
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  77.238127  207.576611
#
#                                                           cm4          Er  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  62.992921  353.585738
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  57.879484  375.432897
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  63.018794  367.453500
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  65.255024  334.106286
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  63.753397  354.421921
#
#                                                             mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   88.882635
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   81.401619
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  103.856310
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   86.010206
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   87.915214
#
# [5 rows x 22 columns]

# %%
gt='BL22Testmixture_outputgt_fract_namechanged.txt'
gtdf=pd.read_csv(gt,sep='\t',index_col=0)
gtdf.head()
# Out:
#                                                     NaiveCD4  NaiveCD8  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.001567  0.008916
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.019763  0.067135
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.016832  0.063332
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.025658  0.077149
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.075323  0.052262
#
#                                                           nB        NK  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.089903  0.061825
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.078821  0.008333
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.027583  0.030681
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.025406  0.039902
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.046414  0.054890
#
#                                                           PC      Mono  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.050337  0.098178
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.086130  0.032387
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.036016  0.021821
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.070235  0.057107
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.061212  0.003146
#
#                                                           M0        M1  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.096435  0.015229
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.090040  0.081458
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.000066  0.057864
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.062788  0.064365
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.014326  0.085246
#
#                                                           M2       iDC  ...  \
# Mixture                                                                 ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.020884  0.038765  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.030769  0.040650  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.008802  0.081407  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.044093  0.019512  ...
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.012295  0.103779  ...
#
#                                                          cm8       em8  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.034814  0.097541
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.025479  0.094256
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.002127  0.063747
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.058935  0.021134
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.018251  0.014336
#
#                                                           Eo     Tregs  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.051067  0.009634
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.098377  0.016312
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.016275  0.069077
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.031924  0.026297
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.029931  0.055539
#
#                                                          em4       ed8  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.081890  0.036467
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.006932  0.002470
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.061973  0.081773
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.066437  0.079915
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.031640  0.095913
#
#                                                           Mg       cm4  \
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.030411  0.012113
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.070859  0.007504
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.069628  0.080661
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.069884  0.085429
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.002125  0.075938
#
#                                                           Er        mB
# Mixture
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.001277  0.052114
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.001665  0.039045
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.017842  0.086525
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  0.022945  0.014311
# BL22test_NR_3215798_insilmix5_sorted_binnedstat...  0.092160  0.023713
#
# [5 rows x 22 columns]

# %%
scoreprediction_from_ref=maxscorepossibleDF*gtdf
scoreprediction_from_ref.head()
# Out:
#                                                      NaiveCD4   NaiveCD8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  29.997548   5.712392
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   0.970412   1.464669
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  12.463732  11.783291
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  10.163060   9.026794
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  15.659560  12.658055
#
#                                                            nB         NK  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   0.602086   4.226952
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  10.635769  40.108032
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.022466   5.428491
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   3.421378  19.741151
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   2.955953  26.709192
#
#                                                            PC       Mono  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   2.769383  13.951389
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   5.487307  22.371275
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  10.311259   7.183806
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   4.276292   4.616205
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   7.661647  12.560343
#
#                                                            M0         M1  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  45.356071   2.441521
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  58.732929   2.049627
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  57.456052  10.285290
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   0.041854   7.486905
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  40.437638   7.626901
#
#                                                            M2        iDC  ...  \
# Mixture                                                                   ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  34.069060  20.164375  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  12.088702   9.116583  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  17.815407  10.247394  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   5.325571  22.553567  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  24.989342   4.893858  ...
#
#                                                          cm8       em8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  6.493217  1.786353
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  5.523863  6.115693
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  3.420076  5.535329
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.298491  3.751141
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  9.145600  0.967842
#
#                                                            Eo     Tregs  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  11.264940  6.576296
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   8.175409  1.206798
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  16.006817  1.970065
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   2.618634  8.588749
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   4.585614  3.185301
#
#                                                          em4       ed8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  1.867756  2.322111
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  4.935701  2.214540
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.487477  0.158671
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  4.382209  5.319942
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  4.535041  6.172514
#
#                                                            Mg       cm4  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  12.202107  4.179356
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   5.756328  0.701115
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  13.159511  0.472921
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  14.467492  5.263503
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  14.506324  5.446372
#
#                                                            Er        mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  20.420628  2.818630
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   0.479338  4.242155
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   0.611832  4.055044
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   5.961147  7.442023
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   8.132119  1.258157
#
# [5 rows x 22 columns]

# %%
adjustedScore_minus_avglistDF.head()
# Out:
#                                                      NaiveCD4   NaiveCD8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  66.907110  16.941726
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  41.127440  11.596523
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  58.475985  12.747033
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  64.090155  14.476772
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  74.087497  15.708789
#
#                                                            nB         NK  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   6.718210  32.773638
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  15.498393  58.237918
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  13.915448  33.943132
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   9.569448  52.414684
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   8.854341  58.242374
#
#                                                           PC       Mono  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  6.589242  32.922021
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  3.847409  39.882976
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  9.606417  35.474724
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  3.785952  24.274788
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  7.586710  27.297488
#
#                                                            M0         M1  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  70.421696  13.174377
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  69.910589  13.891842
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  90.807778  15.819139
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  53.762378   9.931273
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  73.648828  12.702414
#
#                                                            M2        iDC  ...  \
# Mixture                                                                   ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  64.185649  28.183746  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  65.117079  30.113123  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  72.510540  34.279252  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  50.256091  26.938306  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  56.579191  22.422485  ...
#
#                                                           cm8        em8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  12.189979   7.960833
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  16.637637  12.438906
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.800841   9.013937
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  20.526967  10.537618
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  19.554550   8.912397
#
#                                                            Eo      Tregs  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  15.650774   8.566724
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  15.640941   7.000824
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  25.239905   6.231562
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   6.334271  14.264484
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  11.378925   8.770065
#
#                                                          em4       ed8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  5.312679  7.119315
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  4.372742  3.974370
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  4.418713  5.483417
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  7.905829  6.000849
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  8.555046  4.477853
#
#                                                            Mg       cm4  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  12.350144  9.219668
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   6.466247  4.763049
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.629836  5.187321
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  10.070286  8.486180
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   9.603140  9.287906
#
#                                                            Er         mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  37.414487   3.164370
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  14.840815   5.926992
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  15.501766   9.540278
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  27.740905  10.877816
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  31.357940   3.903967
#
# [5 rows x 22 columns]

# %%
scoreprediction_from_ref_VS_adjustedScore_minus_avglistDF=scoreprediction_from_ref.merge(adjustedScore_minus_avglistDF,left_index=True,right_index=True)
scoreprediction_from_ref_VS_adjustedScore_minus_avglistDF.head()
# Out:
#                                                     NaiveCD4_x  NaiveCD8_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   29.997548    5.712392
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...    0.970412    1.464669
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   12.463732   11.783291
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   10.163060    9.026794
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   15.659560   12.658055
#
#                                                          nB_x       NK_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   0.602086   4.226952
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  10.635769  40.108032
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.022466   5.428491
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   3.421378  19.741151
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   2.955953  26.709192
#
#                                                          PC_x     Mono_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   2.769383  13.951389
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   5.487307  22.371275
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  10.311259   7.183806
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   4.276292   4.616205
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   7.661647  12.560343
#
#                                                          M0_x       M1_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  45.356071   2.441521
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  58.732929   2.049627
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  57.456052  10.285290
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   0.041854   7.486905
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  40.437638   7.626901
#
#                                                          M2_x      iDC_x  ...  \
# Mixture                                                                   ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  34.069060  20.164375  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  12.088702   9.116583  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  17.815407  10.247394  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   5.325571  22.553567  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  24.989342   4.893858  ...
#
#                                                         cm8_y      em8_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  12.189979   7.960833
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  16.637637  12.438906
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.800841   9.013937
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  20.526967  10.537618
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  19.554550   8.912397
#
#                                                          Eo_y    Tregs_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  15.650774   8.566724
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  15.640941   7.000824
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  25.239905   6.231562
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   6.334271  14.264484
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  11.378925   8.770065
#
#                                                        em4_y     ed8_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  5.312679  7.119315
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  4.372742  3.974370
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  4.418713  5.483417
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  7.905829  6.000849
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  8.555046  4.477853
#
#                                                          Mg_y     cm4_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  12.350144  9.219668
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   6.466247  4.763049
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.629836  5.187321
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  10.070286  8.486180
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   9.603140  9.287906
#
#                                                          Er_y       mB_y
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  37.414487   3.164370
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  14.840815   5.926992
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  15.501766   9.540278
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  27.740905  10.877816
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  31.357940   3.903967
#
# [5 rows x 44 columns]

# %%
import matplotlib.pyplot as plt
cross_corr=scoreprediction_from_ref_VS_adjustedScore_minus_avglistDF.corr()
plt.matshow(cross_corr)
plt.show()

# %%
cross_corr.to_csv(smfile+"_Rresult_prediction_pearson_corresscorr.txt",sep='\t')

# %%
import seaborn as sns
from matplotlib.offsetbox import AnchoredText


celltypetoplot='Tregs'

ax=sns.scatterplot(scoreprediction_from_ref_VS_adjustedScore_minus_avglistDF[celltypetoplot+'_x'], scoreprediction_from_ref_VS_adjustedScore_minus_avglistDF[celltypetoplot+'_y'],edgecolor='none')
ax=sns.regplot(scoreprediction_from_ref_VS_adjustedScore_minus_avglistDF[celltypetoplot+'_x'], scoreprediction_from_ref_VS_adjustedScore_minus_avglistDF[celltypetoplot+'_y'],scatter=False,ci = None)

plt.title(celltypetoplot)
plt.xlabel('Expectated score from hash table', fontsize=18)
plt.ylabel('Soft RC score', fontsize=16)

text='r = %s' % (format(cross_corr[celltypetoplot+'_x'][celltypetoplot+'_y'], '.2f'))


anc = AnchoredText(text, loc="upper left", frameon=False,prop=dict(fontstyle="italic"))
ax.add_artist(anc)

# %%
def renamect(act):
    if act=='CD4':
        return 'Naive CD4 T'
    if act=='CD8':
        return 'Naive CD8 T'

    if act=='NaiveCD4':
        return 'Naive CD4 T'
    if act=='NaiveCD8':
        return 'Naive CD8 T'
    if act=='Tr':
        return 'Tregs'
    if act=='mB':
        return 'Memory B'
    if act=='nB':
        return 'Naive B'
    if act=='m4':
        return 'Memory CD4 T'
    if act=='m8':
        return 'Memory CD8 T'
    if act=='Mn':
        return 'Monocytes'


    if act=='em8':
        return 'CD8 TEM'
    if act=='cm8':
        return 'CD8 TCM'

    if act=='em4':
        return 'CD4 TEM'
    if act=='cm4':
        return 'CD4 TCM'


    if act=='ed8':
        return 'CD8 TEMRA'

    if act=='PC':
        return 'PC'

    if act=='M0':
        return 'Mac (M0)'

    if act=='M1':
        return 'Mac (M1)'

    if act=='M2':
        return 'Mac (M2)'
    if act=='Eo':
        return 'Eos'

    if act=='Mg':
        return 'Megakaryocyte'




    return act

# %%
def allcor_plots(celltypetoplot,dftouse,cross_corrtouse,wheretosave,WHICHRC):
    plt.figure()
    ax=sns.scatterplot(dftouse[celltypetoplot+'_x'], dftouse[celltypetoplot+'_y'],edgecolor='none')
    ax=sns.regplot(dftouse[celltypetoplot+'_x'], dftouse[celltypetoplot+'_y'],scatter=False,ci = None)

    renamedct=renamect(celltypetoplot)
    plt.title(renamedct)
    plt.xlabel('Expectated score from hash table', fontsize=18)
    plt.ylabel('Soft RC score'+' ('+WHICHRC+')', fontsize=16)

    text='r = %s' % (format(cross_corrtouse[celltypetoplot+'_x'][celltypetoplot+'_y'], '.2f'))


    anc = AnchoredText(text, loc="upper left", frameon=False,prop=dict(fontstyle="italic"))
    ax.add_artist(anc)
    
    savename=wheretosave+"/"+renamedct+"_"+WHICHRC+".pdf"
    plt.savefig(savename,dpi=300,bbox_inches="tight")
    
    plt.close()

# %%
for score in scorecolumns:
    ctname=score.replace('-others','')
    #allcor_plots(ctname)

# %%
#adjustedScore_minus_avglistDF=pd.concat(adjustedScore_minus_avglist)
#adjustedScore_minus_avglistDF.set_index('Mixture',inplace=True)

TPscorelistDF=pd.concat(TPscorelist)
FPscorelistDF=pd.concat(FPscorelist)

TPscorelistDF.set_index('Mixture',inplace=True)
FPscorelistDF.set_index('Mixture',inplace=True)
TPscorelistDF.head()
# Out:
#                                                      NaiveCD4  NaiveCD8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  13.839739  3.899313
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   0.000000  0.465635
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   6.498774  4.460583
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   6.498774  4.460583
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   8.858119  4.460583
#
#                                                            nB         NK  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   0.749202   3.471456
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  10.586810  28.533548
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.284817   4.362230
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   2.058730  14.498325
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   2.058730  17.501865
#
#                                                           PC       Mono  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  0.954476   7.155697
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  1.902810  11.843038
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  6.707341   3.652328
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  1.902810   1.810697
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  3.810151   6.707269
#
#                                                            M0        M1  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  17.397893  0.412000
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  21.881865  0.412000
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  21.498508  4.824155
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   0.000000  3.211425
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  15.674325  3.629373
#
#                                                            M2       iDC  ...  \
# Mixture                                                                  ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  16.445675  7.672857  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   7.719187  3.339242  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  10.052984  3.339242  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   2.895210  9.421024  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  13.560310  2.912405  ...
#
#                                                          cm8       em8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  0.467996  1.470964
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.467996  5.805579
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.000000  5.805579
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.000000  3.023841
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  1.017206  1.103425
#
#                                                            Eo     Tregs  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  10.257567  1.339905
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   9.327841  0.000000
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  20.238421  0.000000
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   0.933972  5.007345
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   4.567440  0.835131
#
#                                                         em4       ed8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  1.75956  1.622810
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  1.75956  1.622810
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  1.75956  0.000000
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  1.75956  3.586187
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  1.75956  3.586187
#
#                                                           Mg       cm4  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  4.837377  3.654306
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  2.634984  0.000000
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  4.837377  0.000000
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  4.837377  3.654306
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  4.837377  3.654306
#
#                                                            Er        mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  27.668429  0.881095
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   0.000000  3.026016
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   0.000000  3.026016
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  18.674770  6.437948
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  18.674770  0.000000
#
# [5 rows x 22 columns]

# %%
FPscorelistDF.head()
# Out:
#                                                      NaiveCD4   NaiveCD8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  53.067371  13.042412
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  41.127440  11.130888
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  51.977212   8.286449
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  57.591381  10.016188
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  65.229378  11.248206
#
#                                                           nB         NK  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  5.969008  29.302182
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  4.911583  29.704370
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  4.630631  29.580902
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  7.510718  37.916359
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  6.795611  40.740509
#
#                                                           PC       Mono  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  5.634766  25.766324
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  1.944599  28.039937
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  2.899075  31.822396
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  1.883143  22.464091
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  3.776560  20.590220
#
#                                                            M0         M1  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  53.023803  12.762377
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  48.028724  13.479842
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  69.309270  10.994984
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  53.762378   6.719848
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  57.974502   9.073041
#
#                                                            M2        iDC  ...  \
# Mixture                                                                   ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  47.739974  20.510889  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  57.397893  26.773880  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  62.457555  30.940009  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  47.360880  17.517282  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  43.018882  19.510080  ...
#
#                                                           cm8       em8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  11.721983  6.489869
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  16.169641  6.633327
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.800841  3.208357
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  20.526967  7.513777
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  18.537344  7.808972
#
#                                                           Eo     Tregs  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  5.393207  7.226819
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  6.313100  7.000824
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  5.001485  6.231562
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  5.400298  9.257138
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  6.811485  7.934934
#
#                                                          em4       ed8  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  3.553119  5.496506
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  2.613183  2.351561
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  2.659154  5.483417
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  6.146270  2.414662
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  6.795486  0.891667
#
#                                                           Mg       cm4  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  7.512767  5.565362
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  3.831263  4.763049
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  4.792459  5.187321
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  5.232909  4.831874
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  4.765763  5.633601
#
#                                                            Er        mB
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   9.746059  2.283274
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  14.840815  2.900976
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  15.501766  6.514263
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   9.066136  4.439868
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  12.683170  3.903967
#
# [5 rows x 22 columns]

# %%
scoreprediction_from_ref_VS_TPscorelistDF=scoreprediction_from_ref.merge(TPscorelistDF,left_index=True,right_index=True)
scoreprediction_from_ref_VS_TPscorelistDF.head()
# Out:
#                                                     NaiveCD4_x  NaiveCD8_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   29.997548    5.712392
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...    0.970412    1.464669
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   12.463732   11.783291
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   10.163060    9.026794
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   15.659560   12.658055
#
#                                                          nB_x       NK_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   0.602086   4.226952
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  10.635769  40.108032
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.022466   5.428491
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   3.421378  19.741151
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   2.955953  26.709192
#
#                                                          PC_x     Mono_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   2.769383  13.951389
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   5.487307  22.371275
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  10.311259   7.183806
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   4.276292   4.616205
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   7.661647  12.560343
#
#                                                          M0_x       M1_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  45.356071   2.441521
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  58.732929   2.049627
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  57.456052  10.285290
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   0.041854   7.486905
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  40.437638   7.626901
#
#                                                          M2_x      iDC_x  ...  \
# Mixture                                                                   ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  34.069060  20.164375  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  12.088702   9.116583  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  17.815407  10.247394  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   5.325571  22.553567  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  24.989342   4.893858  ...
#
#                                                        cm8_y     em8_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  0.467996  1.470964
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  0.467996  5.805579
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  0.000000  5.805579
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  0.000000  3.023841
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  1.017206  1.103425
#
#                                                          Eo_y   Tregs_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  10.257567  1.339905
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   9.327841  0.000000
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  20.238421  0.000000
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   0.933972  5.007345
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   4.567440  0.835131
#
#                                                       em4_y     ed8_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  1.75956  1.622810
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  1.75956  1.622810
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  1.75956  0.000000
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  1.75956  3.586187
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  1.75956  3.586187
#
#                                                         Mg_y     cm4_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  4.837377  3.654306
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  2.634984  0.000000
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  4.837377  0.000000
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  4.837377  3.654306
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  4.837377  3.654306
#
#                                                          Er_y      mB_y
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  27.668429  0.881095
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   0.000000  3.026016
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   0.000000  3.026016
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  18.674770  6.437948
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  18.674770  0.000000
#
# [5 rows x 44 columns]

# %%
scoreprediction_from_ref_VS_FPscorelistDF=scoreprediction_from_ref.merge(FPscorelistDF,left_index=True,right_index=True)
scoreprediction_from_ref_VS_FPscorelistDF.head()
# Out:
#                                                     NaiveCD4_x  NaiveCD8_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   29.997548    5.712392
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...    0.970412    1.464669
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   12.463732   11.783291
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   10.163060    9.026794
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   15.659560   12.658055
#
#                                                          nB_x       NK_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   0.602086   4.226952
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  10.635769  40.108032
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.022466   5.428491
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   3.421378  19.741151
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   2.955953  26.709192
#
#                                                          PC_x     Mono_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   2.769383  13.951389
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...   5.487307  22.371275
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  10.311259   7.183806
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   4.276292   4.616205
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...   7.661647  12.560343
#
#                                                          M0_x       M1_x  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  45.356071   2.441521
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  58.732929   2.049627
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  57.456052  10.285290
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   0.041854   7.486905
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  40.437638   7.626901
#
#                                                          M2_x      iDC_x  ...  \
# Mixture                                                                   ...
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  34.069060  20.164375  ...
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  12.088702   9.116583  ...
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  17.815407  10.247394  ...
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   5.325571  22.553567  ...
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  24.989342   4.893858  ...
#
#                                                         cm8_y     em8_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  11.721983  6.489869
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  16.169641  6.633327
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...   9.800841  3.208357
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  20.526967  7.513777
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  18.537344  7.808972
#
#                                                         Eo_y   Tregs_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  5.393207  7.226819
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  6.313100  7.000824
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  5.001485  6.231562
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  5.400298  9.257138
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  6.811485  7.934934
#
#                                                        em4_y     ed8_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  3.553119  5.496506
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  2.613183  2.351561
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  2.659154  5.483417
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  6.146270  2.414662
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  6.795486  0.891667
#
#                                                         Mg_y     cm4_y  \
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...  7.512767  5.565362
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  3.831263  4.763049
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  4.792459  5.187321
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...  5.232909  4.831874
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  4.765763  5.633601
#
#                                                          Er_y      mB_y
# Mixture
# BL22test_NR_3215798_insilmix10_sorted_binnedsta...   9.746059  2.283274
# BL22test_NR_3215798_insilmix1_sorted_binnedstat...  14.840815  2.900976
# BL22test_NR_3215798_insilmix2_sorted_binnedstat...  15.501766  6.514263
# BL22test_NR_3215798_insilmix3_sorted_binnedstat...   9.066136  4.439868
# BL22test_NR_3215798_insilmix4_sorted_binnedstat...  12.683170  3.903967
#
# [5 rows x 44 columns]

# %%
cross_corrwithTP=scoreprediction_from_ref_VS_TPscorelistDF.corr()
cross_corrwithFP=scoreprediction_from_ref_VS_FPscorelistDF.corr()

# %%
for score in scorecolumns:
    ctname=score.replace('-others','')
    allcor_plots(ctname,scoreprediction_from_ref_VS_TPscorelistDF,cross_corrwithTP,'TP_corr','TP')
    allcor_plots(ctname,scoreprediction_from_ref_VS_FPscorelistDF,cross_corrwithFP,'FP_corr','FP')

# %%
forTP_FPfragdf=allassigned.copy()
forTP_FPfragdf.shape
# Out:
# (42711, 39)

# %%
forTP_FPfragdf=forTP_FPfragdf.loc[forTP_FPfragdf['adjustedScore_minus_avg'] > 0]
forTP_FPfragdf.shape
# Out:
# (8276, 39)

# %%
forTP_FPfragdf[['deltabasedfragassignment_no_other', 'fsltu']] = forTP_FPfragdf['deltabasedfragassignment'].str.split('-', expand=True)
forTP_FPfragdf.head()
# Out:
#                                            index  NaiveCD4-others  \
# 0   Eo.HWI-ST537:223:C4DVTACXX:7:1211:7435:87447        -0.181992
# 1  Eo.HWI-ST537:224:C4E15ACXX:4:2108:11851:51609        -0.078167
# 2  Eo.HWI-ST537:224:C4E15ACXX:5:2205:15200:28811        -0.238056
# 3  Eo.HWI-ST699:234:C48WNACXX:4:2307:17364:71298        -0.095000
# 4   Eo.HWI-ST731:122:C7CNDACXX:4:2202:4871:39568        -0.048310
#
#    NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  M0-others  \
# 0        -0.146024  -0.188627  -0.131008  -0.087008    -0.121579   0.035913
# 1        -0.018802  -0.051278  -0.062452  -0.053722    -0.026135  -0.065595
# 2        -0.233865  -0.196849  -0.222341  -0.203135     0.735881   0.502960
# 3        -0.117000   0.924333  -0.085222  -0.103381    -0.074397  -0.102333
# 4         0.812135  -0.089167   0.288325   0.107437    -0.092659  -0.130722
#
#    M1-others  M2-others  ...  deltabasedfragassignment  \
# 0   0.019849   0.431214  ...                iDC-others
# 1  -0.078167  -0.053373  ...                PMN-others
# 2   0.526008   0.567563  ...               Mono-others
# 3  -0.084175  -0.066365  ...                 nB-others
# 4  -0.130722  -0.107675  ...           NaiveCD8-others
#
#                                             filename  secondmaxScore  \
# 0  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.724373
# 1  BL22test_NR_3215798_insilmix6_sorted_binnedsta...       0.0360238
# 2  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.567563
# 3  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.842619
# 4  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.288325
#
#    secondmaxScoreCT  adjustedScore_minus  adjustedScore_minus_avg  \
# 0        mDC-others            0.0450476                 0.407234
# 1         Eo-others             0.933429                  0.95144
# 2         M2-others             0.168317                 0.452099
# 3         mB-others            0.0817143                 0.503024
# 4         NK-others              0.52381                 0.667972
#
#    LENhypoCpG_0.8  LENhypoCpG_0.5  deltabasedfragassignment_no_other   fsltu
# 0             1.0             1.0                                iDC  others
# 1             1.0             1.0                                PMN  others
# 2             1.0             1.0                               Mono  others
# 3             1.0             1.0                                 nB  others
# 4             1.0             1.0                           NaiveCD8  others
#
# [5 rows x 41 columns]

# %%
TPdflist=[]
FPdflist=[]

for score in scorecolumns:
    ctname=score.replace('-others','')
    currentdfforTPFP=forTP_FPfragdf[forTP_FPfragdf['deltabasedfragassignment']==score]
    currentTPdf=currentdfforTPFP[currentdfforTPFP['index'].str.contains(ctname)]
    currentFPdf=currentdfforTPFP[~currentdfforTPFP['index'].str.contains(ctname)]
    TPdflist.append(currentTPdf)
    FPdflist.append(currentFPdf)

# %%
outTPdf=pd.concat(TPdflist)
outFPdf=pd.concat(FPdflist)
outTPdf.head()
# Out:
#                                               index  NaiveCD4-others  \
# 253  NaiveCD4.HWI-7001432L_73:1:2314:10590:47890#12         0.812643
# 254    NaiveCD4.HWI-ST1450_140:8:2312:2080:62501#12         1.553413
# 257    NaiveCD4.HWI-ST539_167:5:2204:8934:33784#BC4         1.627921
# 258   NaiveCD4.HWI-ST539_167:7:2312:15177:56033#BC2         0.780952
# 259    NaiveCD4.HWI-ST699_224:3:1205:16947:73462#12         4.703095
#
#      NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  M0-others  \
# 253         0.709976  -0.160246  -0.099135  -0.152913    -0.130563  -0.162690
# 254         1.336206  -0.264206  -0.109857  -0.232429    -0.142333  -0.104619
# 257         0.901921  -0.314365  -0.225667  -0.218683    -0.300048  -0.262333
# 258         0.694000  -0.179714  -0.114762  -0.028159    -0.177270  -0.204508
# 259         4.366111  -0.738238  -0.430937  -0.638540    -0.901667  -0.662460
#
#      M1-others  M2-others  ...  deltabasedfragassignment  \
# 253  -0.079929  -0.077833  ...           NaiveCD4-others
# 254  -0.167127  -0.199254  ...           NaiveCD4-others
# 257  -0.194937  -0.223571  ...           NaiveCD4-others
# 258  -0.154921  -0.192635  ...           NaiveCD4-others
# 259  -0.759889  -0.749063  ...           NaiveCD4-others
#
#                                               filename  secondmaxScore  \
# 253  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.709976
# 254  BL22test_NR_3215798_insilmix6_sorted_binnedsta...         1.33621
# 257  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.901921
# 258  BL22test_NR_3215798_insilmix6_sorted_binnedsta...           0.694
# 259  BL22test_NR_3215798_insilmix6_sorted_binnedsta...         4.36611
#
#      secondmaxScoreCT  adjustedScore_minus  adjustedScore_minus_avg  \
# 253   NaiveCD8-others             0.102667                 0.457655
# 254   NaiveCD8-others             0.217206                  0.88531
# 257   NaiveCD8-others                0.726                  1.17696
# 258   NaiveCD8-others            0.0869524                 0.433952
# 259   NaiveCD8-others             0.336984                  2.52004
#
#      LENhypoCpG_0.8  LENhypoCpG_0.5  deltabasedfragassignment_no_other   fsltu
# 253             1.0             1.0                           NaiveCD4  others
# 254             2.0             2.0                           NaiveCD4  others
# 257             2.0             2.0                           NaiveCD4  others
# 258             1.0             1.0                           NaiveCD4  others
# 259             6.0             6.0                           NaiveCD4  others
#
# [5 rows x 41 columns]

# %%
outFPdf.head()
# Out:
#                                       index  NaiveCD4-others  NaiveCD8-others  \
# 11    Er.HWI-ST1450_141:3:2214:9441:21665#9         0.792738         0.077563
# 12   Er.HWI-ST1450_141:8:2105:12460:23755#9         1.796923         1.400530
# 16    Er.HWI-ST537_174:7:2312:17772:54361#8         0.783286         0.655825
# 27    Er.HWI-ST539_177:2:2109:17842:45321#8         0.818532         0.302929
# 81  M2.HWI-ST1450_140:1:1205:15689:16558#18         0.785135         0.647897
#
#     nB-others  NK-others  PC-others  Mono-others  M0-others  M1-others  \
# 11  -0.151167  -0.093897  -0.070500    -0.119389  -0.113103  -0.040468
# 12  -0.312589  -0.197875  -0.192637    -0.367851  -0.313899  -0.354756
# 16  -0.191000  -0.042238  -0.076460    -0.197984  -0.177730  -0.189603
# 27  -0.166405   0.366484  -0.157675    -0.185262  -0.162913  -0.170246
# 81  -0.195437  -0.080548   0.525675    -0.211500  -0.182516  -0.209754
#
#     M2-others  ...  deltabasedfragassignment  \
# 11  -0.075040  ...           NaiveCD4-others
# 12  -0.240042  ...           NaiveCD4-others
# 16  -0.188556  ...           NaiveCD4-others
# 27  -0.148944  ...           NaiveCD4-others
# 81  -0.167500  ...           NaiveCD4-others
#
#                                              filename  secondmaxScore  \
# 11  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.466754
# 12  BL22test_NR_3215798_insilmix6_sorted_binnedsta...         1.40053
# 16  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.655825
# 27  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.366484
# 81  BL22test_NR_3215798_insilmix6_sorted_binnedsta...        0.647897
#
#     secondmaxScoreCT  adjustedScore_minus  adjustedScore_minus_avg  \
# 11        cm4-others             0.325984                 0.559361
# 12   NaiveCD8-others             0.396393                  1.09666
# 16   NaiveCD8-others              0.12746                 0.455373
# 27         NK-others             0.452048                  0.63529
# 81   NaiveCD8-others             0.137238                 0.461187
#
#     LENhypoCpG_0.8  LENhypoCpG_0.5  deltabasedfragassignment_no_other   fsltu
# 11             1.0             1.0                           NaiveCD4  others
# 12             0.0             3.0                           NaiveCD4  others
# 16             1.0             1.0                           NaiveCD4  others
# 27             1.0             1.0                           NaiveCD4  others
# 81             1.0             1.0                           NaiveCD4  others
#
# [5 rows x 41 columns]

# %%
sns.kdeplot(outTPdf['total_cpg'],label='TP_fragment', shade=True,color='green')
sns.kdeplot(outFPdf['total_cpg'],label='FP_fragment', shade=True,color='red')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
#sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']=='PMN']['total_cpg'],label='TP_fragment', shade=True,color='green')

# %%
sns.barplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']=='PMN']['total_cpg'],label='TP_fragment', color='green')

# %%
outTPdf[outTPdf['deltabasedfragassignment_no_other']=='PMN']['LENhypoCpG'].max()
# Out:
# 1.0

# %%
outTPdf[outTPdf['deltabasedfragassignment_no_other']=='NK']['total_cpg'].plot.bar()

# %%
outFPdf[outFPdf['deltabasedfragassignment_no_other']=='NK']['total_cpg'].plot.bar()

# %%
outFPdf.columns
# Out:
# Index(['index', 'NaiveCD4-others', 'NaiveCD8-others', 'nB-others', 'NK-others',
#        'PC-others', 'Mono-others', 'M0-others', 'M1-others', 'M2-others',
#        'iDC-others', 'mDC-others', 'PMN-others', 'cm8-others', 'em8-others',
#        'Eo-others', 'Tregs-others', 'em4-others', 'ed8-others', 'Mg-others',
#        'cm4-others', 'Er-others', 'mB-others', 'LENhypoCpG', 'LENhyperCpG',
#        'total_cpg', 'LENhypoCpG_BY_total_cpg', 'maxscoredCT_beforeCpGweight',
#        'maxscore_beforeCpGweight', 'maxscoredCT', 'maxscore',
#        'deltabasedfragassignment', 'filename', 'secondmaxScore',
#        'secondmaxScoreCT', 'adjustedScore_minus', 'adjustedScore_minus_avg',
#        'LENhypoCpG_0.8', 'LENhypoCpG_0.5', 'deltabasedfragassignment_no_other',
#        'fsltu'],
#       dtype='object')

# %%
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']=='NK']['total_cpg'],label='TP_fragment', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']=='NK']['total_cpg'],label='FP_fragment', shade=True,color='red')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']=='NaiveCD8']['total_cpg'],label='TP_fragment', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']=='NaiveCD8']['total_cpg'],label='FP_fragment', shade=True,color='red')

# %%
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']=='PC']['total_cpg'],label='TP_fragment', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']=='PC']['total_cpg'],label='FP_fragment', shade=True,color='red')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']=='NK']['adjustedScore_minus_avg'],label='TP_fragment', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']=='NK']['adjustedScore_minus_avg'],label='FP_fragment', shade=True,color='red')

# %%
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']=='PMN']['adjustedScore_minus_avg'],label='TP_fragment', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']=='PMN']['adjustedScore_minus_avg'],label='FP_fragment', shade=True,color='red')

# %%
density_celltype='PC'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['adjustedScore_minus_avg'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['adjustedScore_minus_avg'],label='FP', shade=True,color='red')
plt.legend(loc='upper left',title='Fragment')
plt.xlabel('Soft RC score')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_softrc.pdf', bbox_inches='tight')

# %%
density_celltype='NK'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['adjustedScore_minus_avg'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['adjustedScore_minus_avg'],label='FP', shade=True,color='red')
plt.legend(loc='upper left',title='Fragment')
plt.xlabel('Soft RC score')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_softrc.pdf', bbox_inches='tight')

# %%
density_celltype='PMN'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['adjustedScore_minus_avg'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['adjustedScore_minus_avg'],label='FP', shade=True,color='red')
plt.legend(loc='upper left',title='Fragment')
plt.xlabel('Soft RC score')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_softrc.pdf', bbox_inches='tight')

# %%
density_celltype='PC'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['total_cpg'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['total_cpg'],label='FP', shade=True,color='red')
plt.legend(loc='upper left',title='Fragment')
plt.xlabel('total_cpg')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_total_cpg.pdf', bbox_inches='tight')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
density_celltype='PMN'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['total_cpg'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['total_cpg'],label='FP', shade=True,color='red')
plt.legend(loc='upper left',title='Fragment')
plt.xlabel('total_cpg')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_total_cpg.pdf', bbox_inches='tight')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
density_celltype='NK'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['total_cpg'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['total_cpg'],label='FP', shade=True,color='red')
plt.legend(loc='upper right',title='Fragment')
plt.xlabel('total_cpg')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_total_cpg.pdf', bbox_inches='tight')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
outTPdf['Fragment']='TP'
outFPdf['Fragment']='FP'
outTPdf.shape
# Out:
# (1580, 42)

# %%
combinedTPFP=pd.concat([outTPdf,outFPdf])
combinedTPFP.shape
# Out:
# (8276, 42)

# %%
combinedTPFP['Cell type']='Undefined'
for index, row in combinedTPFP.iterrows():
    combinedTPFP.loc[index,'Cell type']=renamect(row['deltabasedfragassignment_no_other'])

# %%
#combinedTPFP['Cell type']

# %%
from matplotlib.pyplot import figure
figure(figsize=(15, 6))
ax=sns.boxplot(x='Cell type', y='total_cpg', hue='Fragment',data=combinedTPFP)
#ax=sns.stripplot(x='Cell type', y='total_cpg',hue='Fragment',data=combinedTPFP)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.legend(loc='upper left',title='Fragment')
plt.savefig(inbinfile+'_totalCpG.pdf', bbox_inches='tight')

# %%
import seaborn as sns
from matplotlib.pyplot import figure
display(combinedTPFP)
len_lst = np.zeros(len(combinedTPFP))
cell_lst = []
for i in range(len(combinedTPFP['LENhypoCpG'])):
    cell = list(combinedTPFP['Cell type'])[i]
    hypo = list(combinedTPFP['LENhypoCpG'])[i]
    frag = list(combinedTPFP['Fragment'])[i]
    if frag == 'TP':
        cell_lst.append(cell + ' TP')
    elif frag == 'FP':
        cell_lst.append(cell + ' FP')
    combinedTPFP_cell = len(combinedTPFP[(combinedTPFP['Cell type'] == cell) & (combinedTPFP['LENhypoCpG'] == hypo)])
    len_lst[i] = combinedTPFP_cell

combinedTPFP_hypocounts = combinedTPFP.copy()
combinedTPFP_hypocounts['Hypo Counts'] = len_lst
combinedTPFP_hypocounts['Cell Types'] = cell_lst
combinedTPFP_hypocounts
# Out:
#                                                 index  NaiveCD4-others  \
# 253    NaiveCD4.HWI-7001432L_73:1:2314:10590:47890#12         0.812643
# 254      NaiveCD4.HWI-ST1450_140:8:2312:2080:62501#12         1.553413
# 257      NaiveCD4.HWI-ST539_167:5:2204:8934:33784#BC4         1.627921
# 258     NaiveCD4.HWI-ST539_167:7:2312:15177:56033#BC2         0.780952
# 259      NaiveCD4.HWI-ST699_224:3:1205:16947:73462#12         4.703095
# ...                                               ...              ...
# 38808    NaiveCD8.HWI-ST1450_140:8:1106:9408:48520#19        -0.017123
# 38993   em4.HWI-ST731:93:C490KACXX:2:1316:12635:64123        -0.036036
# 39046  em8.HWI-ST537:241:C73HGACXX:3:2210:16779:62264        -0.029135
# 39074  iDC.HWI-ST537:256:C8F79ACXX:4:1116:10924:33317        -0.089651
# 39267           nB.HWI-ST459_148:5:1201:11552:17347#7        -0.072262
#
#        NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  \
# 253           0.709976  -0.160246  -0.099135  -0.152913    -0.130563
# 254           1.336206  -0.264206  -0.109857  -0.232429    -0.142333
# 257           0.901921  -0.314365  -0.225667  -0.218683    -0.300048
# 258           0.694000  -0.179714  -0.114762  -0.028159    -0.177270
# 259           4.366111  -0.738238  -0.430937  -0.638540    -0.901667
# ...                ...        ...        ...        ...          ...
# 38808        -0.050472   0.240591  -0.031266  -0.038250    -0.045583
# 38993        -0.045115  -0.013163  -0.042321   0.112202    -0.031147
# 39046        -0.025992  -0.007659  -0.026865   0.001944    -0.036992
# 39074        -0.045651   0.111492  -0.089651   0.050381    -0.057873
# 39267        -0.068071   0.305929  -0.055500   0.013992    -0.064230
#
#        M0-others  M1-others  M2-others  ...  secondmaxScore  secondmaxScoreCT  \
# 253    -0.162690  -0.079929  -0.077833  ...        0.709976   NaiveCD8-others
# 254    -0.104619  -0.167127  -0.199254  ...         1.33621   NaiveCD8-others
# 257    -0.262333  -0.194937  -0.223571  ...        0.901921   NaiveCD8-others
# 258    -0.204508  -0.154921  -0.192635  ...           0.694   NaiveCD8-others
# 259    -0.662460  -0.759889  -0.749063  ...         4.36611   NaiveCD8-others
# ...          ...        ...        ...  ...             ...               ...
# 38808  -0.033536  -0.032663  -0.034409  ...        0.240591         nB-others
# 38993  -0.034115  -0.028528  -0.014560  ...        0.112202         PC-others
# 39046  -0.035944  -0.013944  -0.027738  ...      0.00194444         PC-others
# 39074  -0.045302  -0.035873  -0.037968  ...        0.111492         nB-others
# 39267  -0.069468  -0.070516  -0.055151  ...        0.305929         nB-others
#
#        adjustedScore_minus  adjustedScore_minus_avg  LENhypoCpG_0.8  \
# 253               0.102667                 0.457655             1.0
# 254               0.217206                  0.88531             2.0
# 257                  0.726                  1.17696             2.0
# 258              0.0869524                 0.433952             1.0
# 259               0.336984                  2.52004             6.0
# ...                    ...                      ...             ...
# 38808             0.225675                  0.34597             0.0
# 38993             0.356802                 0.412903             0.0
# 39046             0.470119                 0.471091             0.0
# 39074                0.836                 0.891746             1.0
# 39267             0.626302                 0.779266             1.0
#
#        LENhypoCpG_0.5  deltabasedfragassignment_no_other   fsltu  Fragment  \
# 253               1.0                           NaiveCD4  others        TP
# 254               2.0                           NaiveCD4  others        TP
# 257               2.0                           NaiveCD4  others        TP
# 258               1.0                           NaiveCD4  others        TP
# 259               6.0                           NaiveCD4  others        TP
# ...               ...                                ...     ...       ...
# 38808             1.0                                 mB  others        FP
# 38993             1.0                                 mB  others        FP
# 39046             1.0                                 mB  others        FP
# 39074             1.0                                 mB  others        FP
# 39267             1.0                                 mB  others        FP
#
#          Cell type
# 253    Naive CD4 T
# 254    Naive CD4 T
# 257    Naive CD4 T
# 258    Naive CD4 T
# 259    Naive CD4 T
# ...            ...
# 38808     Memory B
# 38993     Memory B
# 39046     Memory B
# 39074     Memory B
# 39267     Memory B
#
# [8276 rows x 43 columns]
#                                                 index  NaiveCD4-others  \
# 253    NaiveCD4.HWI-7001432L_73:1:2314:10590:47890#12         0.812643
# 254      NaiveCD4.HWI-ST1450_140:8:2312:2080:62501#12         1.553413
# 257      NaiveCD4.HWI-ST539_167:5:2204:8934:33784#BC4         1.627921
# 258     NaiveCD4.HWI-ST539_167:7:2312:15177:56033#BC2         0.780952
# 259      NaiveCD4.HWI-ST699_224:3:1205:16947:73462#12         4.703095
# ...                                               ...              ...
# 38808    NaiveCD8.HWI-ST1450_140:8:1106:9408:48520#19        -0.017123
# 38993   em4.HWI-ST731:93:C490KACXX:2:1316:12635:64123        -0.036036
# 39046  em8.HWI-ST537:241:C73HGACXX:3:2210:16779:62264        -0.029135
# 39074  iDC.HWI-ST537:256:C8F79ACXX:4:1116:10924:33317        -0.089651
# 39267           nB.HWI-ST459_148:5:1201:11552:17347#7        -0.072262
#
#        NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  \
# 253           0.709976  -0.160246  -0.099135  -0.152913    -0.130563
# 254           1.336206  -0.264206  -0.109857  -0.232429    -0.142333
# 257           0.901921  -0.314365  -0.225667  -0.218683    -0.300048
# 258           0.694000  -0.179714  -0.114762  -0.028159    -0.177270
# 259           4.366111  -0.738238  -0.430937  -0.638540    -0.901667
# ...                ...        ...        ...        ...          ...
# 38808        -0.050472   0.240591  -0.031266  -0.038250    -0.045583
# 38993        -0.045115  -0.013163  -0.042321   0.112202    -0.031147
# 39046        -0.025992  -0.007659  -0.026865   0.001944    -0.036992
# 39074        -0.045651   0.111492  -0.089651   0.050381    -0.057873
# 39267        -0.068071   0.305929  -0.055500   0.013992    -0.064230
#
#        M0-others  M1-others  M2-others  ...  adjustedScore_minus  \
# 253    -0.162690  -0.079929  -0.077833  ...             0.102667
# 254    -0.104619  -0.167127  -0.199254  ...             0.217206
# 257    -0.262333  -0.194937  -0.223571  ...                0.726
# 258    -0.204508  -0.154921  -0.192635  ...            0.0869524
# 259    -0.662460  -0.759889  -0.749063  ...             0.336984
# ...          ...        ...        ...  ...                  ...
# 38808  -0.033536  -0.032663  -0.034409  ...             0.225675
# 38993  -0.034115  -0.028528  -0.014560  ...             0.356802
# 39046  -0.035944  -0.013944  -0.027738  ...             0.470119
# 39074  -0.045302  -0.035873  -0.037968  ...                0.836
# 39267  -0.069468  -0.070516  -0.055151  ...             0.626302
#
#        adjustedScore_minus_avg  LENhypoCpG_0.8  LENhypoCpG_0.5  \
# 253                   0.457655             1.0             1.0
# 254                    0.88531             2.0             2.0
# 257                    1.17696             2.0             2.0
# 258                   0.433952             1.0             1.0
# 259                    2.52004             6.0             6.0
# ...                        ...             ...             ...
# 38808                  0.34597             0.0             1.0
# 38993                 0.412903             0.0             1.0
# 39046                 0.471091             0.0             1.0
# 39074                 0.891746             1.0             1.0
# 39267                 0.779266             1.0             1.0
#
#        deltabasedfragassignment_no_other   fsltu  Fragment    Cell type  \
# 253                             NaiveCD4  others        TP  Naive CD4 T
# 254                             NaiveCD4  others        TP  Naive CD4 T
# 257                             NaiveCD4  others        TP  Naive CD4 T
# 258                             NaiveCD4  others        TP  Naive CD4 T
# 259                             NaiveCD4  others        TP  Naive CD4 T
# ...                                  ...     ...       ...          ...
# 38808                                 mB  others        FP     Memory B
# 38993                                 mB  others        FP     Memory B
# 39046                                 mB  others        FP     Memory B
# 39074                                 mB  others        FP     Memory B
# 39267                                 mB  others        FP     Memory B
#
#        Hypo Counts      Cell Types
# 253          966.0  Naive CD4 T TP
# 254          109.0  Naive CD4 T TP
# 257          109.0  Naive CD4 T TP
# 258          966.0  Naive CD4 T TP
# 259            9.0  Naive CD4 T TP
# ...            ...             ...
# 38808         74.0     Memory B FP
# 38993         74.0     Memory B FP
# 39046         74.0     Memory B FP
# 39074         74.0     Memory B FP
# 39267         74.0     Memory B FP
#
# [8276 rows x 45 columns]

# %%
combinedTPFP_hypocounts[combinedTPFP_hypocounts['Fragment'] == 'FP'].drop_duplicates(subset = ['Cell type', 'LENhypoCpG'])
# Out:
#                                                 index  NaiveCD4-others  \
# 11              Er.HWI-ST1450_141:3:2214:9441:21665#9         0.792738
# 12             Er.HWI-ST1450_141:8:2105:12460:23755#9         1.796923
# 317   Tregs.D6L3XBQ1:317:C6CGAACXX:4:2110:17630:92090         1.546635
# 4659    NaiveCD8.HWI-ST1450_140:6:2315:19884:72206#19         3.182278
# 4        Eo.HWI-ST731:122:C7CNDACXX:4:2202:4871:39568        -0.048310
# ...                                               ...              ...
# 456    ed8.HWI-ST537:222:C48Y0ACXX:5:1112:17017:62679         0.665138
# 126        Mg.D6L3XBQ1:315:C68E6ACXX:1:1101:2929:2310        -0.105706
# 4486           M2.HWI-ST699_224:1:1209:20570:42814#18        -0.193349
# 262      NaiveCD8.HWI-ST1450_140:8:1106:9408:48520#19        -0.017123
# 8634             Er.HWI-ST699_225:7:2201:7479:30026#9        -0.153921
#
#       NaiveCD8-others  nB-others  NK-others  PC-others  Mono-others  \
# 11           0.077563  -0.151167  -0.093897  -0.070500    -0.119389
# 12           1.400530  -0.312589  -0.197875  -0.192637    -0.367851
# 317          1.445365  -0.324413  -0.206032  -0.260857    -0.292984
# 4659         2.614119  -0.772484  -0.611500   0.070151    -0.701944
# 4            0.812135  -0.089167   0.288325   0.107437    -0.092659
# ...               ...        ...        ...        ...          ...
# 456          0.364820  -0.215794  -0.240704  -0.159688    -0.280746
# 126         -0.108500  -0.095579  -0.039008  -0.097675    -0.093833
# 4486        -0.248873  -0.215349  -0.172746  -0.047381    -0.247825
# 262         -0.050472   0.240591  -0.031266  -0.038250    -0.045583
# 8634        -0.102587   0.104492  -0.084429  -0.020524    -0.141000
#
#       M0-others  M1-others  M2-others  ...  secondmaxScoreCT  \
# 11    -0.113103  -0.040468  -0.075040  ...        cm4-others
# 12    -0.313899  -0.354756  -0.240042  ...   NaiveCD8-others
# 317   -0.264000  -0.284952  -0.261556  ...   NaiveCD8-others
# 4659  -0.775627  -0.711024  -0.549341  ...   NaiveCD8-others
# 4     -0.130722  -0.130722  -0.107675  ...         NK-others
# ...         ...        ...        ...  ...               ...
# 456   -0.262354  -0.225106  -0.207180  ...      Tregs-others
# 126   -0.107802  -0.095929  -0.052278  ...         Mg-others
# 4486  -0.175540  -0.131889  -0.187063  ...         Mg-others
# 262   -0.033536  -0.032663  -0.034409  ...         nB-others
# 8634  -0.100492  -0.090714  -0.091413  ...         nB-others
#
#       adjustedScore_minus  adjustedScore_minus_avg  LENhypoCpG_0.8  \
# 11               0.325984                 0.559361             1.0
# 12               0.396393                  1.09666             0.0
# 317               0.10127                 0.823952             2.0
# 4659             0.568159                  1.87522             4.0
# 4                 0.52381                 0.667972             1.0
# ...                   ...                      ...             ...
# 456              0.219302                 0.599886             0.0
# 126               0.43319                 0.661623             1.0
# 4486              3.65986                  3.64935             4.0
# 262              0.225675                  0.34597             0.0
# 8634               1.7689                  1.82115             2.0
#
#       LENhypoCpG_0.5  deltabasedfragassignment_no_other   fsltu  Fragment  \
# 11               1.0                           NaiveCD4  others        FP
# 12               3.0                           NaiveCD4  others        FP
# 317              2.0                           NaiveCD4  others        FP
# 4659             4.0                           NaiveCD4  others        FP
# 4                1.0                           NaiveCD8  others        FP
# ...              ...                                ...     ...       ...
# 456              2.0                                cm4  others        FP
# 126              1.0                                 Er  others        FP
# 4486             4.0                                 Er  others        FP
# 262              1.0                                 mB  others        FP
# 8634             2.0                                 mB  others        FP
#
#         Cell type  Hypo Counts
# 11    Naive CD4 T        966.0
# 12    Naive CD4 T         44.0
# 317   Naive CD4 T        109.0
# 4659  Naive CD4 T         13.0
# 4     Naive CD8 T        201.0
# ...           ...          ...
# 456       CD4 TCM         24.0
# 126            Er        278.0
# 4486           Er         12.0
# 262      Memory B         74.0
# 8634     Memory B          4.0
#
# [65 rows x 44 columns]

# %%
lim = 1
figure(figsize=(20, 6))
newdf = combinedTPFP_hypocounts.drop_duplicates(subset = ['Cell type', 'LENhypoCpG', 'Fragment']).copy()

for idx in newdf.index:
    if newdf.at[idx, 'LENhypoCpG'] <= lim:
        newdf.at[idx, 'Hypo Counts'] = 0

# newdf = newdf[newdf['LENhypoCpG'] > lim]
# negdf = combinedTPFP_hypocounts[combinedTPFP_hypocounts['Fragment'] == 'FP'].drop_duplicates(subset = ['Cell type', 'LENhypoCpG'])
sorted_df = newdf.sort_values(by=['Cell Types'])

cols = np.unique(sorted_df['Cell Types'])
col_vals = []
for col in cols:
    if 'FP' in col:
        col_vals.append(col[:-3])


ax=sns.scatterplot(x='Cell Types', y='LENhypoCpG', hue='Fragment', size='Hypo Counts', sizes=(20, 200), data=sorted_df)
# sns.scatterplot(x='Cell type', y='LENhypoCpG', color='blue', size='Hypo Counts', style='Fragment', sizes=(20, 200), data=negdf, ax=ax)
# ax.set_xticks(range(0, len(sorted_df['Cell Types'])+1, 2))
# sns.stripplot(x='Cell type', y='total_cpg',hue='Fragment',data=sorted_df, alpha=0, ax=ax)
for i in range(min(ax.get_xticks()) + 1, max(ax.get_xticks()),  2):
    x_pos = i + 0.5
    ax.plot([x_pos, x_pos], [0, 9], c='k', lw=1)
ax.set_xlim(min(ax.get_xticks()) - 0.6, max(ax.get_xticks()) + 0.6)
ax.set_xticks(np.array(range(min(ax.get_xticks()), max(ax.get_xticks()),2)) + 0.5)
ax.set_xticklabels(col_vals,rotation=90)
ax.tick_params(labelsize=11.5)
ax.set_ylabel('#Hypo CpG')
ax.set_ylim(lim + 0.5, max(np.unique(newdf['LENhypoCpG'])) + 0.5)
ax.set_xlabel('Cell Types', labelpad=15)
plt.legend(loc='upper left')
plt.savefig(inbinfile+'_LENhypoCpG_diffsizes.pdf', bbox_inches='tight')

# %%
figure(figsize=(35, 10))
newdf = combinedTPFP_hypocounts.copy()
newdf = newdf.sort_values(by=['Cell Types'])
# newdf = newdf[newdf['LENhypoCpG'] > lim]
new_lenhypo = np.zeros(len(newdf['LENhypoCpG']))
for i, hypo in enumerate(list(newdf['LENhypoCpG'])):
    new_lenhypo[i] = hypo + float(np.random.randint(-20, 20)) / 100
    
newdf['LENhypoCpG_jitter'] = new_lenhypo
# negdf = combinedTPFP_hypocounts[combinedTPFP_hypocounts['Fragment'] == 'FP'].drop_duplicates(subset = ['Cell type', 'LENhypoCpG'])

cols = np.unique(sorted_df['Cell Types'])
col_vals = []
for col in cols:
    if 'FP' in col:
        col_vals.append(col[:-3])

ax=sns.stripplot(x='Cell Types', y='LENhypoCpG_jitter', hue='Fragment', data=newdf, jitter=0.2, size=5)
for i in range(min(ax.get_xticks()) + 1, max(ax.get_xticks()),  2):
    x_pos = i + 0.5
    ax.plot([x_pos, x_pos], [0, 9], c='k', lw=1)
ax.set_xlim(min(ax.get_xticks()) - 0.6, max(ax.get_xticks()) + 0.6)
ax.set_xticks(np.array(range(min(ax.get_xticks()), max(ax.get_xticks()),2)) + 0.5)
ax.set_xticklabels(col_vals,rotation=90)
ax.tick_params(labelsize=20)
ax.set_ylabel('#Hypo CpG', fontsize=18)
ax.set_xlabel('Cell Types', fontsize=18, labelpad=15)
ax.set_ylim(lim + 0.5, max(np.unique(newdf['LENhypoCpG'])) + 0.5)
plt.legend(loc='upper left', fontsize=18)
plt.savefig(inbinfile+'_LENhypoCpG_samesize.pdf', bbox_inches='tight')

# %%
density_celltype='NaiveCD8'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='FP', shade=True,color='red')
plt.legend(loc='upper right',title='Fragment')
plt.xlabel('#Hypo CpG')
plt.title(renamect(density_celltype))
plt.savefig(inbinfile+density_celltype+'_density_LENhypoCpG.pdf', bbox_inches='tight')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
density_celltype='NaiveCD4'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='FP', shade=True,color='red')
plt.legend(loc='upper right',title='Fragment')
plt.xlabel('#Hypo CpG')
plt.title(renamect(density_celltype))
plt.savefig(inbinfile+density_celltype+'_density_LENhypoCpG.pdf', bbox_inches='tight')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
density_celltype='NK'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='FP', shade=True,color='red')
plt.legend(loc='upper right',title='Fragment')
plt.xlabel('#Hypo CpG')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_LENhypoCpG.pdf', bbox_inches='tight')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
density_celltype='M0'
sns.kdeplot(outTPdf[outTPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='TP', shade=True,color='green')
sns.kdeplot(outFPdf[outFPdf['deltabasedfragassignment_no_other']==density_celltype]['LENhypoCpG'],label='FP', shade=True,color='red')
plt.legend(loc='upper right',title='Fragment')
plt.xlabel('#Hypo CpG')
plt.title(density_celltype)
plt.savefig(inbinfile+density_celltype+'_density_LENhypoCpG.pdf', bbox_inches='tight')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
figure(figsize=(15, 6))
ax=sns.boxplot(x='Cell type', y='adjustedScore_minus_avg', hue='Fragment',data=combinedTPFP)
#ax=sns.stripplot(x='Cell type', y='total_cpg',hue='Fragment',data=combinedTPFP)
ax.set_ylabel('Soft RC score')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.legend(loc='upper left',title='Fragment')
plt.savefig(inbinfile+'_totalSoftRCscore.pdf', bbox_inches='tight')
