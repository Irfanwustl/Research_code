# %%
import pandas as pd
import pandas as pd
from collections import defaultdict
from sklearn import metrics
import numpy as np
import sys
import time

start_time = time.time()

###should be the final one###
inbinfile='/Users/irffanalahi/Research/Research_update/for_backgroundcalculation/Allaboutcpginfo/allcandidate_towardsSM_dummy_mean_SM_top1000.txt_result_dupindex_binnedstats.pkl_FINAL_binnedstats.pkl'

outfile=inbinfile


consideringALLheyper=True


inbindf=pd.read_pickle(inbinfile)
####BL22#####
#scorecolumns=['NaiveCD4-others','NaiveCD8-others','nB-others','NK-others','Mono-others','M0-others','M1-others','M2-others','iDC-others','mDC-others','PMN-others','cm8-others','em8-others','Eo-others','Tregs-others','em4-others','ed8-others','Mg-others','cm4-others','Er-others','mB-others','EPCAM-others']


scorecolumns=['EPCAM-others']

#BL14
#scorecolumns=['CD4-others','CD8-others','nB-others','NK-others','Mn-others','mNeu-others','m8-others','DC-others','Eo-others','Tr-others','m4-others','Mg-others','Er-others','mB-others']


allassigned=inbindf.copy()
allassigned.head()
# Out:
#                                      index  EPCAM-others  FakeCell-others  \
# 0   A00354:698:HG3L3DSX3:2:1101:19298:2942      0.979725             -0.9
# 1  A00354:698:HG3L3DSX3:2:1101:25907:33677      0.983030             -0.9
# 2  A00354:698:HG3L3DSX3:2:1101:27977:26209      0.979283             -0.9
# 3  A00354:698:HG3L3DSX3:2:1102:10438:13244      0.979528             -0.9
# 4   A00354:698:HG3L3DSX3:2:1102:10872:1908      0.982500             -0.9
#
#    LENhypoCpG  LENhyperCpG  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0         1.0          0.0        1.0                      1.0
# 1         1.0          0.0        1.0                      1.0
# 2         1.0          0.0        1.0                      1.0
# 3         1.0          0.0        1.0                      1.0
# 4         1.0          0.0        1.0                      1.0
#
#   maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight   maxscoredCT  \
# 0                EPCAM-others                  0.979725  EPCAM-others
# 1                EPCAM-others                  0.983030  EPCAM-others
# 2                EPCAM-others                  0.979283  EPCAM-others
# 3                EPCAM-others                  0.979528  EPCAM-others
# 4                EPCAM-others                  0.982500  EPCAM-others
#
#    maxscore deltabasedfragassignment                                filename  \
# 0  0.979725             EPCAM-others  BS-Seq_01-spike_sorted_binnedstats.pkl
# 1  0.983030             EPCAM-others  BS-Seq_01-spike_sorted_binnedstats.pkl
# 2  0.979283             EPCAM-others  BS-Seq_01-spike_sorted_binnedstats.pkl
# 3  0.979528             EPCAM-others  BS-Seq_01-spike_sorted_binnedstats.pkl
# 4  0.982500             EPCAM-others  BS-Seq_01-spike_sorted_binnedstats.pkl
#
#    secondmaxScore secondmaxScoreCT  adjustedScore_minus  \
# 0            -0.9  FakeCell-others             1.879725
# 1            -0.9  FakeCell-others             1.883030
# 2            -0.9  FakeCell-others             1.879283
# 3            -0.9  FakeCell-others             1.879528
# 4            -0.9  FakeCell-others             1.882500
#
#    adjustedScore_minus_avg  LENhypoCpG_0.8  LENhypoCpG_0.65  LENhypoCpG_0.5
# 0                 1.429725             1.0              1.0             1.0
# 1                 1.433030             1.0              1.0             1.0
# 2                 1.429283             1.0              1.0             1.0
# 3                 1.429528             1.0              1.0             1.0
# 4                 1.432500             1.0              1.0             1.0

# %%
####considering only positive fragment#########

#allassigned=allassigned[allassigned['maxscore']>0]

# %%
allassigned.loc[allassigned['LENhypoCpG']==0,'maxscore_beforeCpGweight']=0

# %%
allassigned[allassigned['LENhypoCpG']==0].head()
# Out:
#                                         index  EPCAM-others  FakeCell-others  \
# 2305  A00354:698:HG3L3DSX3:2:1101:10737:20181           0.0             -0.0
# 2306  A00354:698:HG3L3DSX3:2:1101:10899:19805           0.0             -0.0
# 2307   A00354:698:HG3L3DSX3:2:1101:10908:3129           0.0             -0.0
# 2308   A00354:698:HG3L3DSX3:2:1101:11849:6104           0.0             -0.0
# 2309   A00354:698:HG3L3DSX3:2:1101:11849:7545           0.0             -0.0
#
#       LENhypoCpG  LENhyperCpG  total_cpg  LENhypoCpG_BY_total_cpg  \
# 2305         0.0          2.0        2.0                      0.0
# 2306         0.0          1.0        1.0                      0.0
# 2307         0.0          1.0        1.0                      0.0
# 2308         0.0          1.0        1.0                      0.0
# 2309         0.0          1.0        1.0                      0.0
#
#      maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight   maxscoredCT  \
# 2305                EPCAM-others                       0.0  EPCAM-others
# 2306                EPCAM-others                       0.0  EPCAM-others
# 2307                EPCAM-others                       0.0  EPCAM-others
# 2308                EPCAM-others                       0.0  EPCAM-others
# 2309                EPCAM-others                       0.0  EPCAM-others
#
#       maxscore deltabasedfragassignment  \
# 2305      -0.0             EPCAM-others
# 2306      -0.0             EPCAM-others
# 2307      -0.0             EPCAM-others
# 2308      -0.0             EPCAM-others
# 2309      -0.0             EPCAM-others
#
#                                     filename  secondmaxScore secondmaxScoreCT  \
# 2305  BS-Seq_01-spike_sorted_binnedstats.pkl            -0.0  FakeCell-others
# 2306  BS-Seq_01-spike_sorted_binnedstats.pkl            -0.0  FakeCell-others
# 2307  BS-Seq_01-spike_sorted_binnedstats.pkl            -0.0  FakeCell-others
# 2308  BS-Seq_01-spike_sorted_binnedstats.pkl            -0.0  FakeCell-others
# 2309  BS-Seq_01-spike_sorted_binnedstats.pkl            -0.0  FakeCell-others
#
#       adjustedScore_minus  adjustedScore_minus_avg  LENhypoCpG_0.8  \
# 2305                  0.0                      0.0             0.0
# 2306                  0.0                      0.0             0.0
# 2307                  0.0                      0.0             0.0
# 2308                  0.0                      0.0             0.0
# 2309                  0.0                      0.0             0.0
#
#       LENhypoCpG_0.65  LENhypoCpG_0.5
# 2305              0.0             0.0
# 2306              0.0             0.0
# 2307              0.0             0.0
# 2308              0.0             0.0
# 2309              0.0             0.0

# %%
allassigned[allassigned['maxscore_beforeCpGweight']<allassigned['maxscore']]
# Out:
# Empty DataFrame
# Columns: [index, EPCAM-others, FakeCell-others, LENhypoCpG, LENhyperCpG, total_cpg, LENhypoCpG_BY_total_cpg, maxscoredCT_beforeCpGweight, maxscore_beforeCpGweight, maxscoredCT, maxscore, deltabasedfragassignment, filename, secondmaxScore, secondmaxScoreCT, adjustedScore_minus, adjustedScore_minus_avg, LENhypoCpG_0.8, LENhypoCpG_0.65, LENhypoCpG_0.5]
# Index: []

# %%
def calposscore(fgrouped,whichmethod,fname):
    ctposscoredict= defaultdict(list)
    totalcpgdict=defaultdict(list)
    hypocpgdict=defaultdict(list)
    hypercpgdict=defaultdict(list)
    
    TPposscoredict=defaultdict(list)
    FPposscoredict=defaultdict(list)
    
    for score in scorecolumns:
        ctname=score.replace('-others','')
        deltabasedfragassigned=fgrouped['deltabasedfragassignment'].tolist()
        if score in deltabasedfragassigned:
            
            runningDF=fgrouped[fgrouped['deltabasedfragassignment']==score]
            
            temp_posscore=runningDF[whichmethod].tolist()
            temptotal_posscore=sum(temp_posscore)
            temp_posfrag=len(temp_posscore)
            
            runningDF_TP=runningDF[runningDF['index'].str.contains(ctname)]
            
            tempTP_score=runningDF_TP[whichmethod].tolist()
            tempTP_totalposscore=sum(tempTP_score)
            
            runningDF_FP=runningDF[~runningDF['index'].str.contains(ctname)]
            
            tempFP_score=runningDF_FP[whichmethod].tolist()
            tempFP_totalposscore=sum(tempFP_score)
            
           
            
            #runningDF_FP=

        else:
            temptotal_posscore=0
            temp_posfrag=0

        

        ctposscoredict[ctname].append(temptotal_posscore)
        
        TPposscoredict[ctname].append(tempTP_totalposscore)
        FPposscoredict[ctname].append(tempFP_totalposscore)
        
 
        
        totalcpgdict[ctname].append(runningDF['total_cpg'].sum())
        hypocpgdict[ctname].append(runningDF['LENhypoCpG'].sum())
        hypercpgdict[ctname].append(runningDF['LENhyperCpG'].sum())
        
        
    ctposscoredf=pd.DataFrame.from_dict(ctposscoredict)
    ctposscoredf['Mixture']=fname

    totalcpgdf=pd.DataFrame.from_dict(totalcpgdict)
    totalcpgdf['Mixture']=fname
    
    hypocpgdf=pd.DataFrame.from_dict(hypocpgdict)
    hypocpgdf['Mixture']=fname
    
    hypercpgdf=pd.DataFrame.from_dict(hypercpgdict)
    hypercpgdf['Mixture']=fname
    
    TPposscoreDF=pd.DataFrame.from_dict(TPposscoredict)
    FPposscoreDF=pd.DataFrame.from_dict(FPposscoredict)
    
    TPposscoreDF['Mixture']=fname
    FPposscoreDF['Mixture']=fname
    
    
   
    return ctposscoredf,totalcpgdf,hypocpgdf,hypercpgdf,TPposscoreDF,FPposscoreDF

# %%
filegrouped=allassigned.groupby('filename')

maxscorelist=[]



alltotalcpg=[]
allhypocpg=[]
allhypercpg=[]


TPscorelist=[]
FPscorelist=[]

for name, group in filegrouped:
    #maxscorelist.append(calposscore(group,'maxscore',name))
    #adjustedScore_minuslist.append(calposscore(group,'adjustedScore_minus',name))
    
    r1,r2,r3,r4,r5,r6=calposscore(group,'maxscore',name)
    maxscorelist.append(r1)
    
    alltotalcpg.append(r2)
    allhypocpg.append(r3)
    allhypercpg.append(r4)
    
    TPscorelist.append(r5)
    FPscorelist.append(r6)

# %%
###without weighting by CpG score
maxscoreBeefoeCpGwiightlist=[]
for name, group in filegrouped:
    #maxscorelist.append(calposscore(group,'maxscore',name))
    #adjustedScore_minuslist.append(calposscore(group,'adjustedScore_minus',name))
    
    rbefore1,_,_,_,_,_=calposscore(group,'maxscore_beforeCpGweight',name)
    maxscoreBeefoeCpGwiightlist.append(rbefore1)

# %%
maxscoreBeefoeCpGwightlistDF=pd.concat(maxscoreBeefoeCpGwiightlist)
maxscoreBeefoeCpGwightlistDF.set_index('Mixture',inplace=True)
maxscoreBeefoeCpGwightlistDF.head()
# Out:
#                                               EPCAM
# Mixture
# BS-Seq_01-spike_sorted_binnedstats.pkl  2328.401599
# BS-Seq_03-spike_sorted_binnedstats.pkl  1507.239976
# BS-Seq_04-spike_sorted_binnedstats.pkl  1168.195355
# BS-Seq_05-spike_sorted_binnedstats.pkl  1142.654317
# BS-Seq_06-spike_sorted_binnedstats.pkl  1025.735346

# %%
maxscorelistDF=pd.concat(maxscorelist)
maxscorelistDF.set_index('Mixture',inplace=True)

# %%
maxscorelistDF.head()
# Out:
#                                               EPCAM
# Mixture
# BS-Seq_01-spike_sorted_binnedstats.pkl  2296.122215
# BS-Seq_03-spike_sorted_binnedstats.pkl  1473.268744
# BS-Seq_04-spike_sorted_binnedstats.pkl  1140.252797
# BS-Seq_05-spike_sorted_binnedstats.pkl  1117.936785
# BS-Seq_06-spike_sorted_binnedstats.pkl   993.658524

# %%
alltotalcpgDF=pd.concat(alltotalcpg)
allhypocpgDF=pd.concat(allhypocpg)
allhypercpgDF=pd.concat(allhypercpg)

alltotalcpgDF.set_index('Mixture',inplace=True)
allhypocpgDF.set_index('Mixture',inplace=True)
allhypercpgDF.set_index('Mixture',inplace=True)

# %%
alltotalcpgDF.to_csv(outfile+"_totalcpg.txt",sep='\t')

# %%
allhypocpgDF.to_csv(outfile+"_hypocpg.txt",sep='\t')

# %%
allhypercpgDF.to_csv(outfile+"_hypercpg.txt",sep='\t')
