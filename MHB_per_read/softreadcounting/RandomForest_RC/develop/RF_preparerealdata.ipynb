# 0  -0.189423  -0.222449    -0.201987  -0.013346  -0.180090  -0.220654  ...
# 1  -0.334795  -0.643872    -0.605462   2.053641  -0.574949  -0.595051  ...
# 2  -0.069385   0.009590     0.962667  -0.094872  -0.009077  -0.041026  ...
# 3  -0.267462  -0.363308    -0.408897   0.086487  -0.371923  -0.307128  ...
# 4   0.009910  -0.378141    -0.445628  -0.322679  -0.387115  -0.244603  ...
#
#    LENhypoCpG  LENhyperCpG  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0         1.0          0.0        1.0                      1.0
# 1         3.0          0.0        3.0                      1.0
# 2         1.0          0.0        1.0                      1.0
# 3         2.0          0.0        2.0                      1.0
# 4         2.0          0.0        2.0                      1.0
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  maxscoredCT  \
# 0                   CD4-others                  0.770654   CD4-others
# 1                    m4-others                  2.251256    m4-others
# 2                  mNeu-others                  0.962667  mNeu-others
# 3                   CD4-others                  1.475179   CD4-others
# 4                   CD4-others                  1.460526   CD4-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.770654                CD4-others
# 1  2.251256                 m4-others
# 2  0.962667               mNeu-others
# 3  1.475179                CD4-others
# 4  1.460526                CD4-others
#
#                                             filename
# 0  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 1  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 2  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 3  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 4  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
#
# [5 rows x 25 columns]

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'CD4-others',
#  'CD8-others',
#  'DC-others',
#  'Eo-others',
#  'Er-others',
#  'Mg-others',
#  'Mn-others',
#  'NK-others',
#  'NotAssigned',
#  'Tr-others',
#  'm4-others',
#  'm8-others',
#  'mB-others',
#  'mNeu-others',
#  'nB-others'}

# %%
indf.loc[indf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=indf.loc[indf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'CD4-others',
#  'CD8-others',
#  'DC-others',
#  'Eo-others',
#  'Er-others',
#  'Mg-others',
#  'Mn-others',
#  'NK-others',
#  'Tr-others',
#  'm4-others',
#  'm8-others',
#  'mB-others',
#  'mNeu-others',
#  'nB-others'}

# %%
finalallcolumns=indf.columns
finalallcolumns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename'],
#       dtype='object')

# %%
scorecolumns=['CD4-others', 'CD8-others', 'nB-others', 'NK-others','Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others','Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others']

# %%
for scolumn in scorecolumns:
    indf[scolumn]=indf[scolumn]/indf['LENhypoCpG_BY_total_cpg']
    indf.loc[:,scolumn].fillna(0,inplace=True)

# %%
indf.head()
# Out:
#                                      index  CD4-others  CD8-others  nB-others  \
# 0  A00354:526:H7N2TDSX2:3:1101:16224:35665    0.770654    0.667090  -0.174346
# 1  A00354:526:H7N2TDSX2:3:1101:18249:16532   -0.412692   -0.460795  -0.570282
# 2   A00354:526:H7N2TDSX2:3:1101:2889:19304   -0.114256   -0.066513  -0.058256
# 3  A00354:526:H7N2TDSX2:3:1101:31882:30123    1.475179    1.424385  -0.371923
# 4   A00354:526:H7N2TDSX2:3:1101:5204:35462    1.460526    1.082167  -0.411167
#
#    NK-others  Mn-others  mNeu-others  m8-others  DC-others  Eo-others  ...  \
# 0  -0.189423  -0.222449    -0.201987  -0.013346  -0.180090  -0.220654  ...
# 1  -0.334795  -0.643872    -0.605462   2.053641  -0.574949  -0.595051  ...
# 2  -0.069385   0.009590     0.962667  -0.094872  -0.009077  -0.041026  ...
# 3  -0.267462  -0.363308    -0.408897   0.086487  -0.371923  -0.307128  ...
# 4   0.009910  -0.378141    -0.445628  -0.322679  -0.387115  -0.244603  ...
#
#    LENhypoCpG  LENhyperCpG  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0         1.0          0.0        1.0                      1.0
# 1         3.0          0.0        3.0                      1.0
# 2         1.0          0.0        1.0                      1.0
# 3         2.0          0.0        2.0                      1.0
# 4         2.0          0.0        2.0                      1.0
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  maxscoredCT  \
# 0                   CD4-others                  0.770654   CD4-others
# 1                    m4-others                  2.251256    m4-others
# 2                  mNeu-others                  0.962667  mNeu-others
# 3                   CD4-others                  1.475179   CD4-others
# 4                   CD4-others                  1.460526   CD4-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.770654                CD4-others
# 1  2.251256                 m4-others
# 2  0.962667               mNeu-others
# 3  1.475179                CD4-others
# 4  1.460526                CD4-others
#
#                                             filename
# 0  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 1  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 2  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 3  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
# 4  healthy_normal-NU-35-Bulk-WB_sorted_binnedstat...
#
# [5 rows x 25 columns]

# %%
indf['deltaMedian']=indf[scorecolumns].median(axis=1)

# %%
indf['deltaMean']=indf[scorecolumns].mean(axis=1)

# %%
indf.columns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename',
#        'deltaMedian', 'deltaMean'],
#       dtype='object')

# %%
indf.to_pickle(infile+"_totalformatteddata.pkl")
