# 3  A00118:116:HJ7VFDSXX:3:1106:14154:33802   -0.126368   -0.054573  -0.141923
# 4   A00118:116:HJ7VFDSXX:3:1116:22724:8563   -0.084538   -0.094231  -0.097462
#
#    NK-others  Mn-others  mNeu-others  m8-others  DC-others  Eo-others  ...  \
# 0  -0.095423  -0.053423     0.956731  -0.107808  -0.050551  -0.063654  ...
# 1  -0.036808  -0.145577    -0.172859  -0.046141  -0.157782  -0.167295  ...
# 2  -0.197038  -0.226474    -0.191295  -0.095628  -0.194885  -0.190397  ...
# 3  -0.113923  -0.032077     1.278179  -0.110692  -0.157718  -0.055769  ...
# 4  -0.089923  -0.009513     0.963667  -0.081308  -0.034641  -0.035000  ...
#
#    LENhypoCpG  LENhyperCpG  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0         1.0          0.0        1.0                 1.000000
# 1         1.0          0.0        1.0                 1.000000
# 2         1.0          0.0        1.0                 1.000000
# 3         2.0          1.0        3.0                 0.666667
# 4         1.0          0.0        1.0                 1.000000
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  maxscoredCT  \
# 0                  mNeu-others                  0.956731  mNeu-others
# 1                   CD4-others                  0.739654   CD4-others
# 2                   CD4-others                  0.760705   CD4-others
# 3                  mNeu-others                  1.917269  mNeu-others
# 4                  mNeu-others                  0.963667  mNeu-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.956731               mNeu-others
# 1  0.739654                CD4-others
# 2  0.760705                CD4-others
# 3  1.278179               mNeu-others
# 4  0.963667               mNeu-others
#
#                                             filename
# 0  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 1  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 2  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 3  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 4  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
#
# [5 rows x 25 columns]

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'CD4-others',
#  'CD8-others',
#  'DC-others',
#  'Eo-others',
#  'Er-others',
#  'Mg-others',
#  'Mn-others',
#  'NK-others',
#  'NotAssigned',
#  'Tr-others',
#  'm4-others',
#  'm8-others',
#  'mB-others',
#  'mNeu-others',
#  'nB-others'}

# %%
indf.loc[indf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=indf.loc[indf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'CD4-others',
#  'CD8-others',
#  'DC-others',
#  'Eo-others',
#  'Er-others',
#  'Mg-others',
#  'Mn-others',
#  'NK-others',
#  'Tr-others',
#  'm4-others',
#  'm8-others',
#  'mB-others',
#  'mNeu-others',
#  'nB-others'}

# %%
finalallcolumns=indf.columns
finalallcolumns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename'],
#       dtype='object')

# %%
scorecolumns=['CD4-others', 'CD8-others', 'nB-others', 'NK-others','Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others','Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others']

# %%
for scolumn in scorecolumns:
    indf[scolumn]=indf[scolumn]/indf['LENhypoCpG_BY_total_cpg']
    indf.loc[:,scolumn].fillna(0,inplace=True)

# %%
indf.head()
# Out:
#                                      index  CD4-others  CD8-others  nB-others  \
# 0  A00118:116:HJ7VFDSXX:3:1102:19949:17722   -0.061679   -0.066346  -0.026500
# 1   A00118:116:HJ7VFDSXX:3:1103:12717:2597    0.739654    0.554423  -0.180038
# 2   A00118:116:HJ7VFDSXX:3:1103:4670:35446    0.760705    0.612808  -0.191295
# 3  A00118:116:HJ7VFDSXX:3:1106:14154:33802   -0.189551   -0.081859  -0.212885
# 4   A00118:116:HJ7VFDSXX:3:1116:22724:8563   -0.084538   -0.094231  -0.097462
#
#    NK-others  Mn-others  mNeu-others  m8-others  DC-others  Eo-others  ...  \
# 0  -0.095423  -0.053423     0.956731  -0.107808  -0.050551  -0.063654  ...
# 1  -0.036808  -0.145577    -0.172859  -0.046141  -0.157782  -0.167295  ...
# 2  -0.197038  -0.226474    -0.191295  -0.095628  -0.194885  -0.190397  ...
# 3  -0.170885  -0.048115     1.917269  -0.166038  -0.236577  -0.083654  ...
# 4  -0.089923  -0.009513     0.963667  -0.081308  -0.034641  -0.035000  ...
#
#    LENhypoCpG  LENhyperCpG  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0         1.0          0.0        1.0                 1.000000
# 1         1.0          0.0        1.0                 1.000000
# 2         1.0          0.0        1.0                 1.000000
# 3         2.0          1.0        3.0                 0.666667
# 4         1.0          0.0        1.0                 1.000000
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  maxscoredCT  \
# 0                  mNeu-others                  0.956731  mNeu-others
# 1                   CD4-others                  0.739654   CD4-others
# 2                   CD4-others                  0.760705   CD4-others
# 3                  mNeu-others                  1.917269  mNeu-others
# 4                  mNeu-others                  0.963667  mNeu-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.956731               mNeu-others
# 1  0.739654                CD4-others
# 2  0.760705                CD4-others
# 3  1.278179               mNeu-others
# 4  0.963667               mNeu-others
#
#                                             filename
# 0  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 1  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 2  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 3  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
# 4  TWCY-1382-1382-BULK-PBMC_sorted_onlyregionIN_B...
#
# [5 rows x 25 columns]

# %%
indf['deltaMedian']=indf[scorecolumns].median(axis=1)

# %%
indf['deltaMean']=indf[scorecolumns].mean(axis=1)

# %%
indf.columns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename',
#        'deltaMedian', 'deltaMean'],
#       dtype='object')

# %%
indf.to_pickle(infile+"_totalformatteddata.pkl")
