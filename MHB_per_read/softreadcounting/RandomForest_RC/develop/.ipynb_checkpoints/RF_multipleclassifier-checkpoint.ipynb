# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import metrics
from collections import defaultdict

import sys

import time
start_time = time.time()



infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/genepromdelta.7/Randomforest/developing/BL14_genepromSM_0.7.txt_bestref.txt_result_dupindex_binnedstats.pkl'


gtcol='label2'

n_trees=100

testratio=0.4

indf=pd.read_pickle(infile)

indf.head()
# Out:
#                                            CD4-others  CD8-others  nB-others  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12    0.740282    0.736333  -0.280282
# CD4.HWI-7001432L_73:1:2103:15384:27344#12    1.470244    1.029782  -0.478269
# CD4.HWI-7001432L_74:1:1215:11529:42195#12    0.794564    0.657436  -0.185795
# CD4.HWI-ST1450_140:1:1307:21239:47394#12     0.378667    0.192897  -0.140051
# CD4.HWI-ST1450_140:1:2215:5251:69917#12      0.738205   -0.133744  -0.264769
#
#                                            NK-others  Mn-others  mNeu-others  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12  -0.116949  -0.260179    -0.260538
# CD4.HWI-7001432L_73:1:2103:15384:27344#12  -0.078731  -0.474679    -0.252833
# CD4.HWI-7001432L_74:1:1215:11529:42195#12  -0.150615  -0.164256    -0.154564
# CD4.HWI-ST1450_140:1:1307:21239:47394#12   -0.102718  -0.117615    -0.105949
# CD4.HWI-ST1450_140:1:2215:5251:69917#12    -0.271949  -0.237487    -0.201590
#
#                                            m8-others  DC-others  Eo-others  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12   0.168795  -0.280282  -0.268436
# CD4.HWI-7001432L_73:1:2103:15384:27344#12  -0.105295  -0.336474  -0.349756
# CD4.HWI-7001432L_74:1:1215:11529:42195#12  -0.022462  -0.185436  -0.093000
# CD4.HWI-ST1450_140:1:1307:21239:47394#12    0.048410  -0.122641  -0.140051
# CD4.HWI-ST1450_140:1:2215:5251:69917#12     0.289128  -0.217744  -0.234795
#
#                                            Tr-others  ...  LENhypoCpG  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12   0.164487  ...         1.0
# CD4.HWI-7001432L_73:1:2103:15384:27344#12   0.294782  ...         2.0
# CD4.HWI-7001432L_74:1:1215:11529:42195#12   0.089538  ...         1.0
# CD4.HWI-ST1450_140:1:1307:21239:47394#12    0.055410  ...         1.0
# CD4.HWI-ST1450_140:1:2215:5251:69917#12     0.719359  ...         1.0
#
#                                            LENhyperCpG  total_cpg  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12          0.0        1.0
# CD4.HWI-7001432L_73:1:2103:15384:27344#12          0.0        2.0
# CD4.HWI-7001432L_74:1:1215:11529:42195#12          0.0        1.0
# CD4.HWI-ST1450_140:1:1307:21239:47394#12           1.0        2.0
# CD4.HWI-ST1450_140:1:2215:5251:69917#12            0.0        1.0
#
#                                            LENhypoCpG_BY_total_cpg  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12                      1.0
# CD4.HWI-7001432L_73:1:2103:15384:27344#12                      1.0
# CD4.HWI-7001432L_74:1:1215:11529:42195#12                      1.0
# CD4.HWI-ST1450_140:1:1307:21239:47394#12                       0.5
# CD4.HWI-ST1450_140:1:2215:5251:69917#12                        1.0
#
#                                            maxscoredCT_beforeCpGweight  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12                   CD4-others
# CD4.HWI-7001432L_73:1:2103:15384:27344#12                   CD4-others
# CD4.HWI-7001432L_74:1:1215:11529:42195#12                   CD4-others
# CD4.HWI-ST1450_140:1:1307:21239:47394#12                    CD4-others
# CD4.HWI-ST1450_140:1:2215:5251:69917#12                     CD4-others
#
#                                            maxscore_beforeCpGweight  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12                  0.740282
# CD4.HWI-7001432L_73:1:2103:15384:27344#12                  1.470244
# CD4.HWI-7001432L_74:1:1215:11529:42195#12                  0.794564
# CD4.HWI-ST1450_140:1:1307:21239:47394#12                   0.757333
# CD4.HWI-ST1450_140:1:2215:5251:69917#12                    0.738205
#
#                                            maxscoredCT  maxscore  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12   CD4-others  0.740282
# CD4.HWI-7001432L_73:1:2103:15384:27344#12   CD4-others  1.470244
# CD4.HWI-7001432L_74:1:1215:11529:42195#12   CD4-others  0.794564
# CD4.HWI-ST1450_140:1:1307:21239:47394#12    CD4-others  0.378667
# CD4.HWI-ST1450_140:1:2215:5251:69917#12     CD4-others  0.738205
#
#                                           deltabasedfragassignment  \
# CD4.HWI-7001432L_73:1:1301:17083:62471#12               CD4-others
# CD4.HWI-7001432L_73:1:2103:15384:27344#12               CD4-others
# CD4.HWI-7001432L_74:1:1215:11529:42195#12               CD4-others
# CD4.HWI-ST1450_140:1:1307:21239:47394#12                CD4-others
# CD4.HWI-ST1450_140:1:2215:5251:69917#12                 CD4-others
#
#                                                                                     filename
# CD4.HWI-7001432L_73:1:1301:17083:62471#12  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# CD4.HWI-7001432L_73:1:2103:15384:27344#12  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# CD4.HWI-7001432L_74:1:1215:11529:42195#12  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# CD4.HWI-ST1450_140:1:1307:21239:47394#12   CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# CD4.HWI-ST1450_140:1:2215:5251:69917#12    CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
#
# [5 rows x 24 columns]

# %%
allcolumns=indf.columns
allcolumns
# Out:
# Index(['CD4-others', 'CD8-others', 'nB-others', 'NK-others', 'Mn-others',
#        'mNeu-others', 'm8-others', 'DC-others', 'Eo-others', 'Tr-others',
#        'm4-others', 'Mg-others', 'Er-others', 'mB-others', 'LENhypoCpG',
#        'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename'],
#       dtype='object')

# %%
indf=indf.reset_index()
indf.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1301:17083:62471#12    0.740282    0.736333
# 1  CD4.HWI-7001432L_73:1:2103:15384:27344#12    1.470244    1.029782
# 2  CD4.HWI-7001432L_74:1:1215:11529:42195#12    0.794564    0.657436
# 3   CD4.HWI-ST1450_140:1:1307:21239:47394#12    0.378667    0.192897
# 4    CD4.HWI-ST1450_140:1:2215:5251:69917#12    0.738205   -0.133744
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.280282  -0.116949  -0.260179    -0.260538   0.168795  -0.280282
# 1  -0.478269  -0.078731  -0.474679    -0.252833  -0.105295  -0.336474
# 2  -0.185795  -0.150615  -0.164256    -0.154564  -0.022462  -0.185436
# 3  -0.140051  -0.102718  -0.117615    -0.105949   0.048410  -0.122641
# 4  -0.264769  -0.271949  -0.237487    -0.201590   0.289128  -0.217744
#
#    Eo-others  ...  LENhypoCpG  LENhyperCpG  total_cpg  \
# 0  -0.268436  ...         1.0          0.0        1.0
# 1  -0.349756  ...         2.0          0.0        2.0
# 2  -0.093000  ...         1.0          0.0        1.0
# 3  -0.140051  ...         1.0          1.0        2.0
# 4  -0.234795  ...         1.0          0.0        1.0
#
#    LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0                      1.0                   CD4-others
# 1                      1.0                   CD4-others
# 2                      1.0                   CD4-others
# 3                      0.5                   CD4-others
# 4                      1.0                   CD4-others
#
#    maxscore_beforeCpGweight  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0                  0.740282   CD4-others  0.740282                CD4-others
# 1                  1.470244   CD4-others  1.470244                CD4-others
# 2                  0.794564   CD4-others  0.794564                CD4-others
# 3                  0.757333   CD4-others  0.378667                CD4-others
# 4                  0.738205   CD4-others  0.738205                CD4-others
#
#                                             filename
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
#
# [5 rows x 25 columns]

# %%
indf[['label','Last']] =indf['index'].str.split('.',expand=True)
indf.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1301:17083:62471#12    0.740282    0.736333
# 1  CD4.HWI-7001432L_73:1:2103:15384:27344#12    1.470244    1.029782
# 2  CD4.HWI-7001432L_74:1:1215:11529:42195#12    0.794564    0.657436
# 3   CD4.HWI-ST1450_140:1:1307:21239:47394#12    0.378667    0.192897
# 4    CD4.HWI-ST1450_140:1:2215:5251:69917#12    0.738205   -0.133744
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.280282  -0.116949  -0.260179    -0.260538   0.168795  -0.280282
# 1  -0.478269  -0.078731  -0.474679    -0.252833  -0.105295  -0.336474
# 2  -0.185795  -0.150615  -0.164256    -0.154564  -0.022462  -0.185436
# 3  -0.140051  -0.102718  -0.117615    -0.105949   0.048410  -0.122641
# 4  -0.264769  -0.271949  -0.237487    -0.201590   0.289128  -0.217744
#
#    Eo-others  ...  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0  -0.268436  ...        1.0                      1.0
# 1  -0.349756  ...        2.0                      1.0
# 2  -0.093000  ...        1.0                      1.0
# 3  -0.140051  ...        2.0                      0.5
# 4  -0.234795  ...        1.0                      1.0
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  maxscoredCT  \
# 0                   CD4-others                  0.740282   CD4-others
# 1                   CD4-others                  1.470244   CD4-others
# 2                   CD4-others                  0.794564   CD4-others
# 3                   CD4-others                  0.757333   CD4-others
# 4                   CD4-others                  0.738205   CD4-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.740282                CD4-others
# 1  1.470244                CD4-others
# 2  0.794564                CD4-others
# 3  0.378667                CD4-others
# 4  0.738205                CD4-others
#
#                                             filename  label  \
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
#
#                                     Last
# 0  HWI-7001432L_73:1:1301:17083:62471#12
# 1  HWI-7001432L_73:1:2103:15384:27344#12
# 2  HWI-7001432L_74:1:1215:11529:42195#12
# 3   HWI-ST1450_140:1:1307:21239:47394#12
# 4    HWI-ST1450_140:1:2215:5251:69917#12
#
# [5 rows x 27 columns]

# %%
set(indf['label'].tolist())
# Out:
# {'CD4',
#  'CD8',
#  'DC',
#  'Eo',
#  'Er',
#  'Mg',
#  'Mn',
#  'NK',
#  'Tr',
#  'm4',
#  'm8',
#  'mB',
#  'mNeu',
#  'nB'}

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'CD4-others',
#  'CD8-others',
#  'DC-others',
#  'Eo-others',
#  'Er-others',
#  'Mg-others',
#  'Mn-others',
#  'NK-others',
#  'NotAssigned',
#  'Tr-others',
#  'm4-others',
#  'm8-others',
#  'mB-others',
#  'mNeu-others',
#  'nB-others'}

# %%
indf.loc[indf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=indf.loc[indf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'CD4-others',
#  'CD8-others',
#  'DC-others',
#  'Eo-others',
#  'Er-others',
#  'Mg-others',
#  'Mn-others',
#  'NK-others',
#  'Tr-others',
#  'm4-others',
#  'm8-others',
#  'mB-others',
#  'mNeu-others',
#  'nB-others'}

# %%
indf['label2']="Notyet"
indf.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1301:17083:62471#12    0.740282    0.736333
# 1  CD4.HWI-7001432L_73:1:2103:15384:27344#12    1.470244    1.029782
# 2  CD4.HWI-7001432L_74:1:1215:11529:42195#12    0.794564    0.657436
# 3   CD4.HWI-ST1450_140:1:1307:21239:47394#12    0.378667    0.192897
# 4    CD4.HWI-ST1450_140:1:2215:5251:69917#12    0.738205   -0.133744
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.280282  -0.116949  -0.260179    -0.260538   0.168795  -0.280282
# 1  -0.478269  -0.078731  -0.474679    -0.252833  -0.105295  -0.336474
# 2  -0.185795  -0.150615  -0.164256    -0.154564  -0.022462  -0.185436
# 3  -0.140051  -0.102718  -0.117615    -0.105949   0.048410  -0.122641
# 4  -0.264769  -0.271949  -0.237487    -0.201590   0.289128  -0.217744
#
#    Eo-others  ...  LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0  -0.268436  ...                      1.0                   CD4-others
# 1  -0.349756  ...                      1.0                   CD4-others
# 2  -0.093000  ...                      1.0                   CD4-others
# 3  -0.140051  ...                      0.5                   CD4-others
# 4  -0.234795  ...                      1.0                   CD4-others
#
#    maxscore_beforeCpGweight  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0                  0.740282   CD4-others  0.740282                CD4-others
# 1                  1.470244   CD4-others  1.470244                CD4-others
# 2                  0.794564   CD4-others  0.794564                CD4-others
# 3                  0.757333   CD4-others  0.378667                CD4-others
# 4                  0.738205   CD4-others  0.738205                CD4-others
#
#                                             filename  label  \
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
#
#                                     Last  label2
# 0  HWI-7001432L_73:1:1301:17083:62471#12  Notyet
# 1  HWI-7001432L_73:1:2103:15384:27344#12  Notyet
# 2  HWI-7001432L_74:1:1215:11529:42195#12  Notyet
# 3   HWI-ST1450_140:1:1307:21239:47394#12  Notyet
# 4    HWI-ST1450_140:1:2215:5251:69917#12  Notyet
#
# [5 rows x 28 columns]

# %%
def common_member(a, b):
    a_set = set(a)
    b_set = set(b)
    if len(a_set.intersection(b_set)) > 0:
        return(True) 
    return(False)

# %%
grouped=indf.groupby('deltabasedfragassignment')

for name, group in grouped:
    
    celltype=name.replace('-others','')
 
    
  
    notctindex=group.index[group['label']!=celltype].tolist()
    ctindex=group.index[group['label']==celltype].tolist()
    
    if common_member(notctindex,ctindex)==True:
        print("something wrong")
        sys.exit(1)
    

    indf.loc[notctindex,'label2']="NOT"+celltype
    indf.loc[ctindex,'label2']=celltype

# %%
len(set(indf['label2'].tolist()))
# Out:
# 28

# %%
finalallcolumns=indf.columns
finalallcolumns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename',
#        'label', 'Last', 'label2'],
#       dtype='object')

# %%
scorecolumns=['CD4-others', 'CD8-others', 'nB-others', 'NK-others','Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others','Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others']

# %%
for scolumn in scorecolumns:
    indf[scolumn]=indf[scolumn]/indf['LENhypoCpG_BY_total_cpg']
    indf.loc[:,scolumn].fillna(0,inplace=True)

# %%
indf.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1301:17083:62471#12    0.740282    0.736333
# 1  CD4.HWI-7001432L_73:1:2103:15384:27344#12    1.470244    1.029782
# 2  CD4.HWI-7001432L_74:1:1215:11529:42195#12    0.794564    0.657436
# 3   CD4.HWI-ST1450_140:1:1307:21239:47394#12    0.757333    0.385795
# 4    CD4.HWI-ST1450_140:1:2215:5251:69917#12    0.738205   -0.133744
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.280282  -0.116949  -0.260179    -0.260538   0.168795  -0.280282
# 1  -0.478269  -0.078731  -0.474679    -0.252833  -0.105295  -0.336474
# 2  -0.185795  -0.150615  -0.164256    -0.154564  -0.022462  -0.185436
# 3  -0.280103  -0.205436  -0.235231    -0.211897   0.096821  -0.245282
# 4  -0.264769  -0.271949  -0.237487    -0.201590   0.289128  -0.217744
#
#    Eo-others  ...  LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0  -0.268436  ...                      1.0                   CD4-others
# 1  -0.349756  ...                      1.0                   CD4-others
# 2  -0.093000  ...                      1.0                   CD4-others
# 3  -0.280103  ...                      0.5                   CD4-others
# 4  -0.234795  ...                      1.0                   CD4-others
#
#    maxscore_beforeCpGweight  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0                  0.740282   CD4-others  0.740282                CD4-others
# 1                  1.470244   CD4-others  1.470244                CD4-others
# 2                  0.794564   CD4-others  0.794564                CD4-others
# 3                  0.757333   CD4-others  0.378667                CD4-others
# 4                  0.738205   CD4-others  0.738205                CD4-others
#
#                                             filename  label  \
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...    CD4
#
#                                     Last label2
# 0  HWI-7001432L_73:1:1301:17083:62471#12    CD4
# 1  HWI-7001432L_73:1:2103:15384:27344#12    CD4
# 2  HWI-7001432L_74:1:1215:11529:42195#12    CD4
# 3   HWI-ST1450_140:1:1307:21239:47394#12    CD4
# 4    HWI-ST1450_140:1:2215:5251:69917#12    CD4
#
# [5 rows x 28 columns]

# %%
indf['deltaMedian']=indf[scorecolumns].median(axis=1)

# %%
indf['deltaMean']=indf[scorecolumns].mean(axis=1)

# %%
indf.columns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename',
#        'label', 'Last', 'label2', 'deltaMedian', 'deltaMean'],
#       dtype='object')

# %%
features=['CD4-others', 'CD8-others', 'nB-others', 'NK-others','Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others','Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others','LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg','deltaMedian', 'deltaMean']

# %%
indf.to_pickle(infile+"_totalformatteddata.pkl")

# %%
#######needto be flexible below

# %%
from sklearn.metrics import RocCurveDisplay

celltypeAUC=defaultdict(list)

alltrainindex=[]
alltestindex=[]

for score in scorecolumns:
    
    tempct=score.replace('-others','')
    
 
  
    indfsingleCT=(indf[indf['deltabasedfragassignment']==score]).copy()
    indfsingleCT.loc[indfsingleCT['label2']==tempct,'label2']=1
    indfsingleCT.loc[indfsingleCT['label2']=='NOT'+tempct,'label2']=0
    

    
    indfsingleCT['label2']=indfsingleCT['label2'].astype(int)
    
   
    
    
    
    Y=indfsingleCT[gtcol]
    X=indfsingleCT[features]
    trainX,testX,trainY,testY =  train_test_split(X,Y,test_size=testratio, random_state=0)
    

    traindf=pd.concat([trainX,trainY],axis=1)
    testdf=pd.concat([testX,testY],axis=1)
    
    traindf.loc[traindf['label2']==1,'label2']=tempct
    traindf.loc[traindf['label2']==0,'label2']='NOT'+tempct
    
    testdf.loc[testdf['label2']==1,'label2']=tempct
    testdf.loc[testdf['label2']==0,'label2']='NOT'+tempct
    
    
    
    
    alltrainindex=alltrainindex+traindf.index.tolist()
    alltestindex=alltestindex+testdf.index.tolist()
    
    
   
    
    RDF_classifier = RandomForestClassifier(oob_score=True,n_estimators=n_trees)
    
    RDF_classifier.fit(trainX, trainY)
    
    
    
    predict_test=RDF_classifier.predict_proba(testX)
    
    
    fpr, tpr, thresholds=metrics.roc_curve(testY,predict_test[:,1],pos_label=1)
    
    


    tempAUC=metrics.auc(fpr, tpr)
    
    
   
    
   


    
    
    celltypeAUC[score]=celltypeAUC[score]+[tempAUC]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
alltraindflistDF=indf.loc[alltrainindex]
alltestdflistDF=indf.loc[alltestindex]

# %%
alltraindflistDF.to_pickle(infile+"_train.pkl")
alltestdflistDF.to_pickle(infile+"_test.pkl")

# %%
celltypeAUCdf=pd.DataFrame.from_dict(celltypeAUC, orient='index',columns=['AUC'])
celltypeAUCdf.index.name = 'Celltype'
celltypeAUCdf.to_csv(infile+"_RFAUC.txt",sep="\t")

# %%
end_time = time.time()

time_elapsed = (end_time - start_time)

print(time_elapsed)
# Out:
# 3.7190358638763428
