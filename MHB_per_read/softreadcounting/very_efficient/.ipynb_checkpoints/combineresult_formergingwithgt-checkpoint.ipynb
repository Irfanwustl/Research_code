# %%
import pandas as pd
import glob
import os

infol='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/allct_nohyper'

suffix='posscore.txt'

posscorefiles=glob.glob(infol+"/*"+suffix)

posscorefiles
# Out:
# ['/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/allct_nohyper/CD4allrange_NR_1000000_insilmix52_sorted_scored_nohyper.txt_posscore.txt',
#  '/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/allct_nohyper/CD4allrange_NR_1000000_insilmix41_sorted_scored_nohyper.txt_posscore.txt',
#  '/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/allct_nohyper/CD4allrange_NR_1000000_insilmix50_sorted_scored_nohyper.txt_posscore.txt',
#  '/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/allct_nohyper/CD4allrange_NR_1000000_insilmix45_sorted_scored_nohyper.txt_posscore.txt',
#  '/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/allct_nohyper/CD4allrange_NR_1000000_insilmix60_sorted_scored_nohyper.txt_posscore.txt']

# %%
outdflist=[]
for posscorefile in posscorefiles:
    currentdf=pd.read_csv(posscorefile,sep="\t")
    
    currentdf['Mixture']=os.path.basename(posscorefile)
    
   

    outdflist.append(currentdf)

# %%
outdf=pd.concat(outdflist)
outdf=outdf.set_index('Mixture')
outdf.to_csv(infol+"")
# Out:
#                                                             CD4          CD8  \
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...  4927.692872  7661.060987
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  4210.566577  7242.923448
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  3971.335910  7895.444423
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  3729.318885  9642.691435
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  6043.829654  5744.445615
#
#                                                               nB  \
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...  19462.896819
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  18072.943012
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  13170.831973
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  14522.379461
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  14275.904845
#
#                                                               NK           Mn  \
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...  31241.738679  2080.034974
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  21287.164487  2603.710539
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  38827.270923  2558.137731
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  27995.503987  2372.112654
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  21243.315474  2280.987244
#
#                                                             mNeu           m8  \
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...  12833.261013  5361.791320
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  20676.071872  5649.385679
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  15793.575872  5461.130167
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  12313.331128  5744.897923
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  14374.677628  4833.583090
#
#                                                               DC  \
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...  11033.939705
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  12439.618436
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  15427.416051
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  15473.357718
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  14722.881064
#
#                                                               Eo           Tr  \
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...  16489.270205  6651.871795
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  12156.004808  7207.602013
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  12407.287769  4548.392859
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  21937.514872  5024.676308
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  12709.635551  6206.977333
#
#                                                              m4           Mg  \
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...  1881.731064  4489.044218
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  2055.591115  4659.351833
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  1522.777282  5640.924397
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  1226.131923  5904.335820
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  1708.462436  3844.078897
#
#                                                               Er            mB
# Mixture
# CD4allrange_NR_1000000_insilmix52_sorted_scored...   9989.491820  50815.573578
# CD4allrange_NR_1000000_insilmix41_sorted_scored...  13343.119167  52331.655360
# CD4allrange_NR_1000000_insilmix50_sorted_scored...  16908.678385  56746.409668
# CD4allrange_NR_1000000_insilmix45_sorted_scored...  16957.332641  55110.088514
# CD4allrange_NR_1000000_insilmix60_sorted_scored...  12271.056372  39632.738757
