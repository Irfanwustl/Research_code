# %%
import pandas as pd

softRDfile='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/CD4allrange_NR_1000000_insilmix41_sorted_scored_nohyper.txt'
cpginfofile='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/CD4allrange_NR_1000000_insilmix41_sorted_scored_nohyper_cpgoinfomerged.txt'

softRDdf=pd.read_csv(softRDfile,sep="\t",index_col=0)
softRDdf.head()
# Out:
#                                                CD4-others  CD8-others  \
# mNeu.HWI-ST700660_187:6:2113:13379:61927#14     -0.107538    0.014513
# DC.HWI-ST537:222:C48Y0ACXX:5:1303:3330:45149    -0.107538    0.014513
# DC.HWI-ST731:132:C8F1WACXX:4:2310:8951:31721    -0.107538    0.014513
# m4.HWI-ST537:240:C6B3NACXX:3:2310:15483:54518   -0.107538    0.014513
# mNeu.D6L3XBQ1:311:C5TN1ACXX:4:1104:9877:12295   -0.215077    0.029026
#
#                                                nB-others  NK-others  \
# mNeu.HWI-ST700660_187:6:2113:13379:61927#14    -0.115436   0.782718
# DC.HWI-ST537:222:C48Y0ACXX:5:1303:3330:45149   -0.115436   0.782718
# DC.HWI-ST731:132:C8F1WACXX:4:2310:8951:31721   -0.115436   0.782718
# m4.HWI-ST537:240:C6B3NACXX:3:2310:15483:54518  -0.115436   0.782718
# mNeu.D6L3XBQ1:311:C5TN1ACXX:4:1104:9877:12295  -0.230872   1.565436
#
#                                                Mn-others  mNeu-others  \
# ...

# %%
cpginfodf=pd.read_csv(cpginfofile,sep="\t",index_col=0)
cpginfodf.head()
# Out:
#                                                                         hypoCpG  \
# mNeu.HWI-ST700660_187:6:2113:13379:61927#14                    ['chr1:1221863']
# DC.HWI-ST537:222:C48Y0ACXX:5:1303:3330:45149                   ['chr1:1221863']
# DC.HWI-ST731:132:C8F1WACXX:4:2310:8951:31721                   ['chr1:1221863']
# m4.HWI-ST537:240:C6B3NACXX:3:2310:15483:54518                  ['chr1:1221863']
# mNeu.D6L3XBQ1:311:C5TN1ACXX:4:1104:9877:12295  ['chr1:1221863', 'chr1:1221863']
#
#                                                hyperCpG  LENhypoCpG  \
# mNeu.HWI-ST700660_187:6:2113:13379:61927#14    NotFound         1.0
# DC.HWI-ST537:222:C48Y0ACXX:5:1303:3330:45149   NotFound         1.0
# DC.HWI-ST731:132:C8F1WACXX:4:2310:8951:31721   NotFound         1.0
# m4.HWI-ST537:240:C6B3NACXX:3:2310:15483:54518  NotFound         1.0
# mNeu.D6L3XBQ1:311:C5TN1ACXX:4:1104:9877:12295  NotFound         2.0
#
#                                                LENhyperCpG
# ...

# %%
print(softRDdf.shape)
print(cpginfodf.shape)
# Out:
# (122699, 16)
# (527965, 4)

# %%
mergeddf=softRDdf.merge(cpginfodf,left_index=True,right_index=True,how='inner')
mergeddf.shape
# Out:
# (208363, 20)

# %%
cpginfodf[cpginfodf.index.duplicated()]
# Out:
#                                                   hypoCpG  \
# m8.HWI-ST537_195:4:1201:20481:93285#14           NotFound
# m8.HWI-ST459_146:6:1114:5608:81443#5             NotFound
# m8.HWI-ST459_146:3:2212:7141:76607#5             NotFound
# Mg.HWI-ST700660:289:C6N9FACXX:1:2305:5576:21220  NotFound
# Mn.HWI-ST731:132:C8F1WACXX:3:1110:11252:18381    NotFound
# ...                                                   ...
# m4.D6L3XBQ1:297:C48VVACXX:1:1314:3499:69731      NotFound
# Er.HWI-ST699_225:2:1312:14355:55671#9            NotFound
# m8.HWI-ST537_195:1:2202:13405:15005#14           NotFound
# m4.HWI-ST731:96:C48UKACXX:3:2306:12170:91043     NotFound
# m4.HWI-ST731:96:C48UKACXX:3:2316:5481:95064      NotFound
#
#                                                                              hyperCpG  \
# m8.HWI-ST537_195:4:1201:20481:93285#14               ['chr1:1221863', 'chr1:1221863']
# m8.HWI-ST459_146:6:1114:5608:81443#5                 ['chr1:1221863', 'chr1:1221863']
# ...

# %%
mergeddf.head()
# Out:
#                                            CD4-others  CD8-others  nB-others  \
# CD4.HWI-7001432L_73:1:1101:15458:40711#12   -0.032167   -0.148115  -0.203397
# CD4.HWI-7001432L_73:1:1101:15458:40711#12   -0.032167   -0.148115  -0.203397
# CD4.HWI-7001432L_73:1:1103:17455:40816#12   -0.051538   -0.089231  -0.088513
# CD4.HWI-7001432L_73:1:1103:17455:40816#12   -0.051538   -0.089231  -0.088513
# CD4.HWI-7001432L_73:1:1107:12469:51878#12   -0.258128   -0.101256  -0.229769
#
#                                            NK-others  Mn-others  mNeu-others  \
# CD4.HWI-7001432L_73:1:1101:15458:40711#12  -0.101090  -0.029295    -0.059808
# CD4.HWI-7001432L_73:1:1101:15458:40711#12  -0.101090  -0.029295    -0.059808
# CD4.HWI-7001432L_73:1:1103:17455:40816#12  -0.073795  -0.076667    -0.064821
# CD4.HWI-7001432L_73:1:1103:17455:40816#12  -0.073795  -0.076667    -0.064821
# CD4.HWI-7001432L_73:1:1107:12469:51878#12   0.753462  -0.195308    -0.252026
#
# ...
