# %%
import pandas as pd


posscorefile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/RF/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkl_totalformatteddata.pkl_RFprob_CSxOut.txt'
ct_cpgfile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/BL22/moreSM/Thebestref/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_info.txt'

posscoredf=pd.read_csv(posscorefile,sep="\t",index_col='Mixture')

posscoredf.head()
# Out:
#                                                       NaiveCD4   NaiveCD8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  102.172063  10.215020
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  124.726145  21.275964
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  152.388251  17.348256
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  138.944771  13.424970
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  133.063707  13.062992
#
#                                                            nB          NK  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  22.421574  125.938597
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  19.624541  166.773432
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  14.081741  119.301160
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  20.205947  203.983005
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  22.167788  113.859414
#
#                                                            PC       Mono  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  14.165585  49.789880
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  19.041905  45.462459
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  14.620008  65.293347
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  21.306207  47.841365
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  20.869028  38.573792
#
#                                                            M0         M1  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  58.179512   9.968362
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  54.860703  10.914817
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  56.698396  11.205863
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  56.102924   8.802912
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  46.046212   8.779504
#
#                                                            M2        iDC  ...  \
# Mixture                                                                   ...
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  39.486363  22.485962  ...
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  50.212498  19.558016  ...
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  46.880419  21.976011  ...
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  46.623141  20.700574  ...
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  37.330986  24.163167  ...
#
#                                                          cm8        em8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  5.047592  37.477772
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  3.625549  23.819135
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  6.164918  28.319956
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  6.381745  19.262800
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  8.184519  29.872261
#
#                                                            Eo      Tregs  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  17.899494  11.972074
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  15.154905  14.473422
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  14.728868  15.782666
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  16.578868   8.057603
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  18.220532   9.915312
#
#                                                        em4      ed8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  4.8293  34.7671
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  4.3198  25.4777
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  3.9189  23.5751
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  2.2130  37.3074
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  5.7939  25.6214
#
#                                                            Mg        cm4  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  11.682874  34.672390
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...   9.352567  36.458574
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  11.814673  37.618082
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  17.979462  30.305401
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...   9.186886  40.106620
#
#                                                            Er         mB
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  22.113010  12.438417
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  27.491248  19.833368
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  21.980824  17.012725
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  30.853321  13.361720
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  25.806934  17.873633
#
# [5 rows x 22 columns]

# %%
ct_cpgdf=pd.read_csv(ct_cpgfile,sep="\t")
ct_cpgdf.head()
# Out:
#   Celltype  #CpG
# 0       Eo    50
# 1       Er   100
# 2       M0   200
# 3       M1    50
# 4       M2   200

# %%
allct=ct_cpgdf['Celltype'].tolist()
len(allct)
# Out:
# 22

# %%
for ct in allct:
    posscoredf[ct]=posscoredf[ct]/int(ct_cpgdf.loc[ct_cpgdf['Celltype']==ct,'#CpG'])

# %%
posscoredf
# Out:
#                                                     NaiveCD4  NaiveCD8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.510860  0.204300
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.623631  0.425519
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.761941  0.346965
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.694724  0.268499
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.665319  0.261260
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.452268  0.137037
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.573979  0.213291
#
#                                                           nB        NK  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.640616  0.629693
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.560701  0.833867
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.402335  0.596506
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.577313  1.019915
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.633365  0.569297
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.662003  0.797453
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.447567  0.978203
#
#                                                           PC      Mono  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.404731  0.497899
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.544054  0.454625
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.417715  0.652933
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.608749  0.478414
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.596258  0.385738
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.521307  0.797176
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.474266  0.720696
#
#                                                           M0        M1  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.290898  0.199367
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.274304  0.218296
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.283492  0.224117
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.280515  0.176058
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.230231  0.175590
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.320483  0.154841
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.334273  0.205108
#
#                                                           M2       iDC  ...  \
# Mixture                                                                 ...
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.197432  0.224860  ...
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.251062  0.195580  ...
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.234402  0.219760  ...
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.233116  0.207006  ...
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.186655  0.241632  ...
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.207967  0.265784  ...
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.181584  0.207848  ...
#
#                                                          cm8       em8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.100952  1.873889
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.072511  1.190957
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.123298  1.415998
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.127635  0.963140
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.163690  1.493613
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.050021  1.255186
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.062902  1.192798
#
#                                                           Eo     Tregs  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.357990  0.299302
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.303098  0.361836
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.294577  0.394567
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.331577  0.201440
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.364411  0.247883
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.469239  0.316838
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.330872  0.197085
#
#                                                          em4       ed8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.193172  1.390684
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.172792  1.019108
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.156756  0.943004
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.088520  1.492296
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.231756  1.024856
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.122432  0.973600
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.069172  1.209604
#
#                                                           Mg       cm4  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.233657  1.155746
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.187051  1.215286
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.236293  1.253936
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.359589  1.010180
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.183738  1.336887
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.251212  0.816270
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.192065  1.070543
#
#                                                           Er        mB
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.221130  0.355383
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.274912  0.566668
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.219808  0.486078
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.308533  0.381763
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.258069  0.510675
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.216908  0.527213
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.220024  0.580651
#
# [7 rows x 22 columns]

# %%
sumofnormalizedctscore=posscoredf[allct].sum(axis=1)

# %%
sumofnormalizedctscore
# Out:
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL22_geneprom_sorted_binnedstats.pkl    10.452376
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL22_geneprom_sorted_binnedstats.pkl    10.393583
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL22_geneprom_sorted_binnedstats.pkl    10.314053
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL22_geneprom_sorted_binnedstats.pkl    10.434136
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL22_geneprom_sorted_binnedstats.pkl    10.473294
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL22_geneprom_sorted_binnedstats.pkl    10.430100
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL22_geneprom_sorted_binnedstats.pkl    10.238386
# dtype: float64

# %%
for ct in allct:
    posscoredf[ct]=posscoredf[ct]/sumofnormalizedctscore

# %%
posscoredf
# Out:
#                                                     NaiveCD4  NaiveCD8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.048875  0.019546
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.060002  0.040941
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.073874  0.033640
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.066582  0.025733
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.063525  0.024945
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.043362  0.013139
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.056062  0.020833
#
#                                                           nB        NK  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.061289  0.060244
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.053947  0.080229
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.039008  0.057834
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.055329  0.097748
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.060474  0.054357
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.063470  0.076457
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.043715  0.095543
#
#                                                           PC      Mono  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.038721  0.047635
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.052345  0.043741
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.040500  0.063305
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.058342  0.045851
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.056931  0.036831
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.049981  0.076430
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.046322  0.070392
#
#                                                           M0        M1  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.027831  0.019074
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.026392  0.021003
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.027486  0.021729
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.026884  0.016873
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.021983  0.016766
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.030727  0.014846
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.032649  0.020033
#
#                                                           M2       iDC  ...  \
# Mixture                                                                 ...
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.018889  0.021513  ...
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.024156  0.018817  ...
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.022726  0.021307  ...
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.022342  0.019839  ...
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.017822  0.023071  ...
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.019939  0.025482  ...
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.017736  0.020301  ...
#
#                                                          cm8       em8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.009658  0.179279
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.006977  0.114586
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.011954  0.137288
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.012232  0.092307
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.015629  0.142612
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.004796  0.120343
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.006144  0.116503
#
#                                                           Eo     Tregs  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.034250  0.028635
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.029162  0.034813
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.028561  0.038255
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.031778  0.019306
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.034794  0.023668
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.044989  0.030377
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.032317  0.019250
#
#                                                          em4       ed8  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.018481  0.133050
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.016625  0.098052
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.015198  0.091429
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.008484  0.143021
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.022128  0.097854
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.011738  0.093345
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.006756  0.118144
#
#                                                           Mg       cm4  \
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.022354  0.110573
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.017997  0.116927
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.022910  0.121575
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.034463  0.096815
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.017543  0.127647
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.024085  0.078261
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.018759  0.104562
#
#                                                           Er        mB
# Mixture
# healthy_NU-03-bulk-PBMC_sorted_onlyregionIN_BL2...  0.021156  0.034000
# healthy_NU-14-bulk-PBMC_sorted_onlyregionIN_BL2...  0.026450  0.054521
# healthy_NU-24-bulk-PBMC_sorted_onlyregionIN_BL2...  0.021312  0.047128
# healthy_NU-31-bulk-PBMC_sorted_onlyregionIN_BL2...  0.029570  0.036588
# healthy_NU-49-bulk-PBMC_sorted_onlyregionIN_BL2...  0.024641  0.048760
# healthy_NU-50-bulk-PBMC_sorted_onlyregionIN_BL2...  0.020796  0.050547
# healthy_NU-51-bulk-PBMC_sorted_onlyregionIN_BL2...  0.021490  0.056713
#
# [7 rows x 22 columns]

# %%
posscoredf[allct].to_csv(posscorefile+"_ctporportion_CSxOut.txt",sep='\t')
posscoredf.to_csv(posscorefile+"_ctporportion_readyforplt.txt",sep='\t')
