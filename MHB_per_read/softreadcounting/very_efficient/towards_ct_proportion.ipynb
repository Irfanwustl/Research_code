# %%
import pandas as pd


posscorefile='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/corr/allctcorr_weightedbycpg/towards_celltype_proportion/bined_cpginfo_allct_posscore.txt_CSxOut.txt_CD4mixture_output_1000000_highestCD430percent_allrealadded.txt'
ct_cpgfile='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/fulltest/corr/allctcorr_weightedbycpg/towards_celltype_proportion/ct_cpg.txt'

posscoredf=pd.read_csv(posscorefile,sep="\t",index_col='Mixture')

posscoredf.head()
# Out:
#                                            CD4          CD8            nB  \
# Mixture
# CD4allrange_NR_1000000_insilmix41  2737.363514  4437.547877  12678.495018
# CD4allrange_NR_1000000_insilmix45  2421.288906  6829.619840   9000.357233
# CD4allrange_NR_1000000_insilmix50  2641.707411  5091.146157   7721.144813
# CD4allrange_NR_1000000_insilmix52  3510.603098  5006.665564  14132.375270
# CD4allrange_NR_1000000_insilmix60  4683.345522  3147.246036   9480.970981
#
#                                              NK           Mn          mNeu  \
# Mixture
# CD4allrange_NR_1000000_insilmix41  11122.569382  1557.958238  16730.664454
# CD4allrange_NR_1000000_insilmix45  17837.867124  1309.977008   8051.770178
# CD4allrange_NR_1000000_insilmix50  29005.508488  1482.883252  11806.457503
# CD4allrange_NR_1000000_insilmix52  21721.462737  1116.155853   9002.444703
# CD4allrange_NR_1000000_insilmix60  12236.323520  1302.468706  10724.441071
#
# ...

# %%
ct_cpgdf=pd.read_csv(ct_cpgfile,sep="\t")
ct_cpgdf.head()
# Out:
#   Celltype  #CpG
# 0      CD4   166
# 1       m4    76
# 2       Tr   523
# 3      CD8   262
# 4       m8   149

# %%
allct=ct_cpgdf['Celltype'].tolist()
len(allct)
# Out:
# 14

# %%
int(ct_cpgdf.loc[ct_cpgdf['Celltype']=='CD4','#CpG'])
# Out:
# 166

# %%
for ct in allct:
    posscoredf[ct]=posscoredf[ct]/int(ct_cpgdf.loc[ct_cpgdf['Celltype']==ct,'#CpG'])

# %%
posscoredf
# Out:
#                                          CD4        CD8         nB         NK  \
# Mixture
# CD4allrange_NR_1000000_insilmix41  16.490142  16.937206  23.565976   9.331015
# CD4allrange_NR_1000000_insilmix45  14.586078  26.067251  16.729289  14.964654
# CD4allrange_NR_1000000_insilmix50  15.913900  19.431856  14.351570  24.333480
# CD4allrange_NR_1000000_insilmix52  21.148211  19.109411  26.268356  18.222704
# CD4allrange_NR_1000000_insilmix60  28.212925  12.012389  17.622623  10.265372
#
#                                           Mn       mNeu         m8         DC  \
# Mixture
# CD4allrange_NR_1000000_insilmix41  10.182734  32.805224  27.550793  14.285334
# CD4allrange_NR_1000000_insilmix45   8.561941  15.787785  28.743934  20.653502
# CD4allrange_NR_1000000_insilmix50   9.692047  23.149917  26.696275  20.369753
# CD4allrange_NR_1000000_insilmix52   7.295136  17.651852  25.917194  12.320554
# CD4allrange_NR_1000000_insilmix60   8.512867  21.028316  23.684613  19.993354
#
# ...

# %%
sumofnormalizedctscore=posscoredf[allct].sum(axis=1)

# %%
sumofnormalizedctscore
# Out:
# Mixture
# CD4allrange_NR_1000000_insilmix41    245.262703
# CD4allrange_NR_1000000_insilmix45    257.125721
# CD4allrange_NR_1000000_insilmix50    249.997754
# CD4allrange_NR_1000000_insilmix52    241.790522
# CD4allrange_NR_1000000_insilmix60    221.294124
# dtype: float64

# %%
for ct in allct:
    posscoredf[ct]=posscoredf[ct]/sumofnormalizedctscore

# %%
posscoredf
# Out:
#                                         CD4       CD8        nB        NK  \
# Mixture
# CD4allrange_NR_1000000_insilmix41  0.067235  0.069057  0.096085  0.038045
# CD4allrange_NR_1000000_insilmix45  0.056727  0.101379  0.065063  0.058200
# CD4allrange_NR_1000000_insilmix50  0.063656  0.077728  0.057407  0.097335
# CD4allrange_NR_1000000_insilmix52  0.087465  0.079033  0.108641  0.075366
# CD4allrange_NR_1000000_insilmix60  0.127491  0.054282  0.079634  0.046388
#
#                                          Mn      mNeu        m8        DC  \
# Mixture
# CD4allrange_NR_1000000_insilmix41  0.041518  0.133755  0.112332  0.058245
# CD4allrange_NR_1000000_insilmix45  0.033299  0.061401  0.111789  0.080325
# CD4allrange_NR_1000000_insilmix50  0.038769  0.092600  0.106786  0.081480
# CD4allrange_NR_1000000_insilmix52  0.030171  0.073005  0.107189  0.050955
# CD4allrange_NR_1000000_insilmix60  0.038469  0.095024  0.107028  0.090347
#
# ...

# %%
posscoredf[allct].to_csv(posscorefile+"_ctporportion_CSxOut.txt",sep='\t')
posscoredf.to_csv(posscorefile+"_ctporportion_readyforplt.txt",sep='\t')
