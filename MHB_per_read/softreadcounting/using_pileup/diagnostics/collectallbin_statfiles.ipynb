# %%
import pandas as pd
import glob
import os

infol='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/softRD_pileup/cd4bams_softRDpileup'

suffix='binnedstats.txt'

allstatfiles=glob.glob(infol+"/*"+suffix)

# %%
filesdf=[]
for fp in allstatfiles:
    tmpdf=pd.read_csv(fp,sep="\t",index_col=0,low_memory=False)
    tmpdf['filename']=os.path.basename(fp)
    filesdf.append(tmpdf)

# %%
df_combined = pd.concat(filesdf, axis=0)
df_combined.head()
# Out:
#                                                CD4-others  CD8-others  \
# CD4.HWI-ST1450_140:7:1113:21311:32158#12        -0.107538    0.014513
# DC.HWI-ST537:222:C48Y0ACXX:5:1303:3330:45149    -0.107538    0.014513
# DC.HWI-ST731:132:C8F1WACXX:4:2310:8951:31721    -0.107538    0.014513
# m4.HWI-ST537:240:C6B3NACXX:3:2310:15483:54518   -0.107538    0.014513
# mNeu.HWI-ST731_20:3:2106:7915:23475#0           -0.107538    0.014513
#
#                                                nB-others  NK-others  \
# CD4.HWI-ST1450_140:7:1113:21311:32158#12       -0.115436   0.782718
# DC.HWI-ST537:222:C48Y0ACXX:5:1303:3330:45149   -0.115436   0.782718
# DC.HWI-ST731:132:C8F1WACXX:4:2310:8951:31721   -0.115436   0.782718
# m4.HWI-ST537:240:C6B3NACXX:3:2310:15483:54518  -0.115436   0.782718
# mNeu.HWI-ST731_20:3:2106:7915:23475#0          -0.115436   0.782718
#
#                                                Mn-others  mNeu-others  \
# ...

# %%
df_combined.shape
# Out:
# (2211776, 26)

# %%
nodupindex = df_combined[~df_combined.index.duplicated(keep='first')]

# %%
nodupindex.shape
# Out:
# (796997, 26)

# %%
df_combined.to_csv(infol+"_"+suffix,sep='\t')
nodupindex.to_csv(infol+"_nodupindex_"+suffix,sep='\t')
