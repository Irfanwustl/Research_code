# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

infile='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_intesectedwith_CD4DMRofBL14atleast.2SM_g1_CD4_3_g2_others_33_withheader.txt_othermean.txt'
celltype='CD4-others'
indf=pd.read_csv(infile,sep="\t",index_col=['chrom','start'])

indf.head()
# Out:
#                 CD4-others  CD8-others  nB-others  NK-others  Mn-others  \
# chrom start
# chr1  32387132   -0.707256   -0.392077   0.130231   0.104744   0.105103
#       32387376   -0.716974   -0.172051   0.165744   0.095385   0.223179
#       32387403   -0.783192    0.005833   0.101679   0.091269   0.146551
#       32387409   -0.764192    0.083705   0.105244   0.106321   0.097346
#       32387417   -0.295179    0.017846   0.042615   0.016769   0.063795
#
#                 mNeu-others  m8-others  DC-others  Eo-others  Tr-others  \
# chrom start
# chr1  32387132     0.101872   0.076385   0.118385   0.094154  -0.001692
#       32387376     0.072410   0.040103   0.145641  -0.019128  -0.107436
#       32387403     0.096654  -0.000449   0.146551   0.113167  -0.093603
#       32387409     0.070423   0.105603   0.116372   0.116372  -0.145321
#       32387417    -0.030256   0.063795   0.043692   0.027718  -0.011590
#
#                 m4-others  Mg-others  Er-others  mB-others
# chrom start
# chr1  32387132   0.052692   0.138846   0.054846   0.123769
#       32387376  -0.061128   0.113872   0.109564   0.110821
#       32387403  -0.164141   0.077090   0.132551   0.130038
#       32387409  -0.155013   0.093218   0.103449   0.066474
#       32387417  -0.032590   0.023949   0.040103   0.029333

# %%
ax = sns.heatmap(indf)

# %%
indfneg=-1*indf

# %%
ax = sns.heatmap(indfneg,vmin=-1, vmax=1,cmap='viridis')

# %%
indfnegSorted=indfneg.sort_values(by=[celltype],ascending=False)
indfnegSorted.head()
# Out:
#                 CD4-others  CD8-others  nB-others  NK-others  Mn-others  \
# chrom start
# chr17 42306094    0.831077    0.448590  -0.187154  -0.167051  -0.172436
# chr14 98229432    0.822103   -0.057385  -0.200974  -0.085744  -0.142821
# chr16 50550305    0.818667    0.520000  -0.165282  -0.122205  -0.162410
#       50550294    0.800474    0.445090  -0.168038  -0.144346  -0.154038
# chr6  33630083    0.799744    0.064564  -0.170564  -0.111692  -0.137897
#
#                 mNeu-others  m8-others  DC-others  Eo-others  Tr-others  \
# chrom start
# chr17 42306094    -0.193615  -0.056846  -0.193615  -0.157538   0.150462
# chr14 98229432    -0.089333   0.014410  -0.200974  -0.039974   0.030026
# chr16 50550305    -0.140154  -0.117359  -0.177487  -0.139436  -0.045744
#       50550294    -0.137885  -0.038987  -0.161218  -0.101449  -0.041679
# chr6  33630083    -0.132872  -0.146513  -0.140051  -0.155128   0.102795
#
#                 m4-others  Mg-others  Er-others  mB-others
# chrom start
# chr17 42306094   0.195692  -0.150538  -0.193615  -0.153410
# chr14 98229432   0.175949  -0.111051  -0.123974   0.009744
# chr16 50550305   0.098026  -0.137821  -0.103359  -0.125436
#       50550294   0.107474  -0.133756  -0.131603  -0.140038
# chr6  33630083   0.311718  -0.103974  -0.040436  -0.139692

# %%
allcolumns=indfnegSorted.columns
ax =indfnegSorted.plot( y='CD4-others',  label='celltype')
for ct in allcolumns:
    if ct=="CD4-others":
        continue
    indfnegSorted.plot( y=ct,  label=ct,ax=ax)
ax.set_ylim([-1,1])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
subneg=indfneg.loc[('chr11',64490607):('chr11',64490796)]
print(subneg.shape)
ax = sns.heatmap(subneg,vmin=-1, vmax=1,cmap='viridis',annot=True,fmt='.2f')
# Out:
# (10, 14)

# %%
subnegsum=subneg.sum().to_frame()
ax = sns.heatmap(subnegsum,cmap='viridis',annot=True,fmt='.2f')

# %%
subneg=indfneg.loc[('chr14',77029561):('chr14',77029731)]
print(subneg.shape)
ax = sns.heatmap(subneg,vmin=-1, vmax=1,cmap='viridis',annot=True,fmt='.2f')
# Out:
# (10, 14)

# %%
subnegsum=subneg.sum().to_frame()
ax = sns.heatmap(subnegsum,cmap='viridis',annot=True,fmt='.2f')
