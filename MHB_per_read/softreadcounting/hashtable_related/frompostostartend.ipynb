# %%
import pandas as pd
infile="/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_othermean_backup.txt"

outfile=infile

scorecolumns=['CD4-others','CD8-others','nB-others','NK-others','Mn-others','mNeu-others','m8-others','DC-others','Eo-others','Tr-others','m4-others','Mg-others','Er-others','mB-others']

indf=pd.read_csv(infile,sep="\t")
indf.head()
# Out:
#      position       CD4       CD8        nB        NK        Mn      mNeu  \
# 0  chr1:16138  0.879333  0.870667  0.954667  0.935667  0.918667  0.785000
# 1  chr1:16242  0.654000  0.641667  0.765667  0.697667  0.743333  0.569667
# 2  chr1:16633  0.948667  1.000000  0.875000  0.884333  1.000000  0.741000
# 3  chr1:16645  0.980333  0.972333  0.966667  0.946333  1.000000  0.958333
# 4  chr1:16664  0.984000  0.963000  1.000000  0.942000  1.000000  1.000000
#
#        m8        DC      Eo  ...  Mn-others  mNeu-others  m8-others  \
# 0  0.8690  0.948000  0.9200  ...   0.014423    -0.129526  -0.039064
# 1  0.6395  0.660333  0.6400  ...   0.109038    -0.077987  -0.002782
# 2  0.8750  0.889000  0.7335  ...   0.102013    -0.176910  -0.032603
# 3  1.0000  0.958333  1.0000  ...   0.024756    -0.020115   0.024756
# 4  1.0000  0.889000  0.9720  ...   0.035603     0.035603   0.035603
#
#    DC-others  Eo-others  Tr-others  m4-others  Mg-others  Er-others  mB-others
# ...

# %%
indf[['chrom','start']] = indf.position.str.split(':',expand=True)
indf['start'] = indf['start'].astype(int)

# %%
indf.head()
# Out:
#      position       CD4       CD8        nB        NK        Mn      mNeu  \
# 0  chr1:16138  0.879333  0.870667  0.954667  0.935667  0.918667  0.785000
# 1  chr1:16242  0.654000  0.641667  0.765667  0.697667  0.743333  0.569667
# 2  chr1:16633  0.948667  1.000000  0.875000  0.884333  1.000000  0.741000
# 3  chr1:16645  0.980333  0.972333  0.966667  0.946333  1.000000  0.958333
# 4  chr1:16664  0.984000  0.963000  1.000000  0.942000  1.000000  1.000000
#
#        m8        DC      Eo  ...  m8-others  DC-others  Eo-others  Tr-others  \
# 0  0.8690  0.948000  0.9200  ...  -0.039064   0.046013   0.015859  -0.024526
# 1  0.6395  0.660333  0.6400  ...  -0.002782   0.019654  -0.002244   0.083910
# 2  0.8750  0.889000  0.7335  ...  -0.032603  -0.017526  -0.184987   0.102013
# 3  1.0000  0.958333  1.0000  ...   0.024756  -0.020115   0.024756   0.024756
# 4  1.0000  0.889000  0.9720  ...   0.035603  -0.083936   0.005449   0.035603
#
# ...

# %%
indf['end']=indf['start']+2
indf.head()
# Out:
#      position       CD4       CD8        nB        NK        Mn      mNeu  \
# 0  chr1:16138  0.879333  0.870667  0.954667  0.935667  0.918667  0.785000
# 1  chr1:16242  0.654000  0.641667  0.765667  0.697667  0.743333  0.569667
# 2  chr1:16633  0.948667  1.000000  0.875000  0.884333  1.000000  0.741000
# 3  chr1:16645  0.980333  0.972333  0.966667  0.946333  1.000000  0.958333
# 4  chr1:16664  0.984000  0.963000  1.000000  0.942000  1.000000  1.000000
#
#        m8        DC      Eo  ...  DC-others  Eo-others  Tr-others  m4-others  \
# 0  0.8690  0.948000  0.9200  ...   0.046013   0.015859  -0.024526   0.056244
# 1  0.6395  0.660333  0.6400  ...   0.019654  -0.002244   0.083910  -0.038321
# 2  0.8750  0.889000  0.7335  ...  -0.017526  -0.184987   0.102013   0.102013
# 3  1.0000  0.958333  1.0000  ...  -0.020115   0.024756   0.024756   0.024756
# 4  1.0000  0.889000  0.9720  ...  -0.083936   0.005449   0.035603  -0.018244
#
#    Mg-others  Er-others  mB-others  chrom  start    end
# ...

# %%
indf=indf.drop(['position'],axis=1)

# %%
indf.head()
# Out:
#         CD4       CD8        nB        NK        Mn      mNeu      m8  \
# 0  0.879333  0.870667  0.954667  0.935667  0.918667  0.785000  0.8690
# 1  0.654000  0.641667  0.765667  0.697667  0.743333  0.569667  0.6395
# 2  0.948667  1.000000  0.875000  0.884333  1.000000  0.741000  0.8750
# 3  0.980333  0.972333  0.966667  0.946333  1.000000  0.958333  1.0000
# 4  0.984000  0.963000  1.000000  0.942000  1.000000  1.000000  1.0000
#
#          DC      Eo      Tr  ...  DC-others  Eo-others  Tr-others  m4-others  \
# 0  0.948000  0.9200  0.8825  ...   0.046013   0.015859  -0.024526   0.056244
# 1  0.660333  0.6400  0.7200  ...   0.019654  -0.002244   0.083910  -0.038321
# 2  0.889000  0.7335  1.0000  ...  -0.017526  -0.184987   0.102013   0.102013
# 3  0.958333  1.0000  1.0000  ...  -0.020115   0.024756   0.024756   0.024756
# 4  0.889000  0.9720  1.0000  ...  -0.083936   0.005449   0.035603  -0.018244
#
#    Mg-others  Er-others  mB-others  chrom  start    end
# ...

# %%
indf=indf.set_index(['chrom','start','end'])

# %%
indf.head()
# Out:
#                         CD4       CD8        nB        NK        Mn      mNeu  \
# chrom start end
# chr1  16138 16140  0.879333  0.870667  0.954667  0.935667  0.918667  0.785000
#       16242 16244  0.654000  0.641667  0.765667  0.697667  0.743333  0.569667
#       16633 16635  0.948667  1.000000  0.875000  0.884333  1.000000  0.741000
#       16645 16647  0.980333  0.972333  0.966667  0.946333  1.000000  0.958333
#       16664 16666  0.984000  0.963000  1.000000  0.942000  1.000000  1.000000
#
#                        m8        DC      Eo      Tr  ...  Mn-others  \
# chrom start end                                      ...
# chr1  16138 16140  0.8690  0.948000  0.9200  0.8825  ...   0.014423
#       16242 16244  0.6395  0.660333  0.6400  0.7200  ...   0.109038
#       16633 16635  0.8750  0.889000  0.7335  1.0000  ...   0.102013
#       16645 16647  1.0000  0.958333  1.0000  1.0000  ...   0.024756
#       16664 16666  1.0000  0.889000  0.9720  1.0000  ...   0.035603
#
# ...

# %%
indf=indf[scorecolumns]
indf.head()
# Out:
#                    CD4-others  CD8-others  nB-others  NK-others  Mn-others  \
# chrom start end
# chr1  16138 16140   -0.027936   -0.037269   0.053192   0.032731   0.014423
#       16242 16244    0.012833   -0.000449   0.133090   0.059859   0.109038
#       16633 16635    0.046731    0.102013  -0.032603  -0.022551   0.102013
#       16645 16647    0.003577   -0.005038  -0.011141  -0.033038   0.024756
#       16664 16666    0.018372   -0.004244   0.035603  -0.026859   0.035603
#
#                    mNeu-others  m8-others  DC-others  Eo-others  Tr-others  \
# chrom start end
# chr1  16138 16140    -0.129526  -0.039064   0.046013   0.015859  -0.024526
#       16242 16244    -0.077987  -0.002782   0.019654  -0.002244   0.083910
#       16633 16635    -0.176910  -0.032603  -0.017526  -0.184987   0.102013
#       16645 16647    -0.020115   0.024756  -0.020115   0.024756   0.024756
#       16664 16666     0.035603   0.035603  -0.083936   0.005449   0.035603
#
# ...

# %%
indf.to_csv(outfile+"_likebg.txt.gz",sep="\t", chunksize = 1000000, compression = 'gzip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-4e39baf94721> in <module>
# ----> 1 indf.to_csv(outfile+"_likebg.txt.gz",sep="\t", chunksize = 1000000, compression = 'gzip')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ...

# %%
indf=indf.reset_index()

# %%
indf.head()

# %%
indf=indf.drop(['end'],axis=1)

# %%
indf.head()

# %%
indf=indf.set_index(['chrom','start'])

# %%
indf.to_csv(outfile+"_noend.txt.gz",sep="\t", chunksize = 100000, compression = 'gzip')
