# %%
import os
import glob
import pybedtools


infolder='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/deltafolder_withend_allout'

outfolder='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/allcombination'

# %%
def listdir_nohidden(path):
    return glob.glob(os.path.join(path, '*'))

# %%
allfolders=listdir_nohidden(infolder)

# %%
def runbedinter(filelist1,filelist2):
    for  f1 in filelist1:
        for f2 in filelist2:
            f1bed=pybedtools.BedTool(f1)
            f2bed=pybedtools.BedTool(f2)
            f1intf2=f1bed.intersect(f2bed)
            
            f1base=os.path.basename(f1)
            f2base=os.path.basename(f2)
            
            outname=outfolder+'/'+f1base+'_int_'+f2base
            
            
           
            
            f1intf2.moveto(outname)

# %%
totalfolders=len(allfolders)

i=0

while i<totalfolders:
    tempfilelist1=listdir_nohidden(allfolders[i])
    
   
    
    j=i+1
    while j<totalfolders:
        tempfilelist2=listdir_nohidden(allfolders[j])
        
        
        
        runbedinter(tempfilelist1,tempfilelist2)
        
        j=j+1
    
    i=i+1
    
    break  ##############################
# Out:
# ['/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/deltafolder_withend_allout/CD8TL_mel_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txt_thresholdpos/CD8TL_mel_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txtCD8TIL_-0.5_onlypos', '/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/deltafolder_withend_allout/CD8TL_mel_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txt_thresholdpos/CD8TL_mel_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txtCD8TIL_-0.1_onlypos']
# now tempfilelist2
# ['/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/deltafolder_withend_allout/activated_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txt_thresholdpos/activated_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txtCD8TIL_-0.5_onlypos', '/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/deltafolder_withend_allout/activated_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txt_thresholdpos/activated_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txtCD8TIL_-0.1_onlypos']
# ............
# chr1	6202818	6202820
#  chr1	7827186	7827188
#  chr1	7939056	7939058
#  chr1	7939089	7939091
#  chr1	7939179	7939181
#  chr1	7939511	7939513
#  chr1	7939539	7939541
#  chr1	7939541	7939543
#  chr1	7939549	7939551
#  chr1	7940210	7940212
#  None
# chr1	965991	965993
#  chr1	973625	973627
#  chr1	998770	998772
#  chr1	1009418	1009420
#  chr1	1009507	1009509
#  chr1	1012884	1012886
#  chr1	1012918	1012920
#  chr1	1012942	1012944
#  chr1	1012959	1012961
#  chr1	1041163	1041165
#  None
# chr1	1993777	1993779
#  chr1	2507542	2507544
#  chr1	3384758	3384760
#  chr1	6007579	6007580
#  chr1	6202818	6202820
#  chr1	6339736	6339738
#  chr1	6648184	6648186
#  chr1	7827186	7827188
#  chr1	7829880	7829882
#  chr1	7927341	7927343
#  None
# chr1	926156	926158
#  chr1	931519	931521
#  chr1	931556	931558
#  chr1	933922	933924
#  chr1	934911	934913
#  chr1	934930	934932
#  chr1	934939	934941
#  chr1	934962	934964
#  chr1	935044	935046
#  chr1	935927	935929
#  None
# ['/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/deltafolder_withend_allout/naive_myloid_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txt_thresholdpos/naive_myloid_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txtCD8TIL_-0.1_onlypos', '/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/automate_v3_3steps/deltafolder_withend_allout/naive_myloid_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txt_thresholdpos/naive_myloid_CD8TIL_all_matrixCin_nr0.5_imputed_rowmean_bg_othermean.txt_withend.txtCD8TIL_-0.5_onlypos']
# ............
# chr1	973625	973627
#  chr1	981868	981870
#  chr1	1002703	1002705
#  chr1	1007636	1007638
#  chr1	1009169	1009171
#  chr1	1009418	1009420
#  chr1	1009462	1009464
#  chr1	1009476	1009478
#  chr1	1009496	1009498
#  chr1	1009507	1009509
#  None
# chr1	973625	973627
#  chr1	1012884	1012886
#  chr1	1012959	1012961
#  chr1	1037278	1037280
#  chr1	1050809	1050811
#  chr1	1050816	1050818
#  chr1	1053242	1053244
#  chr1	1053272	1053274
#  chr1	1056327	1056329
#  chr1	1099040	1099042
#  None
# chr1	926156	926158
#  chr1	931519	931521
#  chr1	931556	931558
#  chr1	931569	931571
#  chr1	931966	931968
#  chr1	933922	933924
#  chr1	934911	934913
#  chr1	934930	934932
#  chr1	934939	934941
#  chr1	934962	934964
#  None
# chr1	931519	931521
#  chr1	931556	931558
#  chr1	939220	939222
#  chr1	973576	973578
#  chr1	973607	973609
#  chr1	973625	973627
#  chr1	973708	973710
#  chr1	1012884	1012886
#  chr1	1012959	1012961
#  chr1	1037278	1037280
#  None
