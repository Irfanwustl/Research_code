# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/B22withLTME/towarsbestREF/helpfromBL22/diagnosis/forheatmap/why_wrongTIL85/BL22LTMEtraining_all_matrix_interwith_NewSMTIL85.txt'

indf=pd.read_csv(infile,sep="\t",index_col=['chrom','start','end'])

indf.head()
# Out:
#                          aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167222 24167223                                              0.920
#       24167223 24167224                                              0.920
#       47356985 47356986                                              0.967
#       47356986 47356987                                              0.967
# chr10 7561912  7561913                                               0.965
#
#                          aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167222 24167223                                              0.974
#       24167223 24167224                                              0.974
#       47356985 47356986                                              0.968
#       47356986 47356987                                              0.968
# ...

# %%
forheat1=indf.dropna(subset=['ymel-1254-T-CD14.bedgraph_rolled','ymel-1254-T-CD8.bedgraph_rolled','ymel-1457-T-CD4.bedgraph_rolled','ymel-1457-T-CD8.bedgraph_rolled','ymel-960-T-CD14.bedgraph_rolled','ymel-960-T-CD4.bedgraph_rolled','zmel-1254-T-CD45-Negative.bedgraph_rolled','zmel-1457-T-CD45-Negative.bedgraph_rolled'], how='all')

forheat1.head()
# Out:
#                          aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167223 24167224                                              0.920
#       47356986 47356987                                              0.967
# chr10 7561913  7561914                                               0.965
# chr11 40871595 40871596                                              1.000
#       47589763 47589764                                              0.792
#
#                          aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167223 24167224                                              0.974
#       47356986 47356987                                              0.968
# chr10 7561913  7561914                                               0.963
# chr11 40871595 40871596                                              0.961
# ...

# %%
forheat2onlyOurs=forheat1[['ymel-1254-T-CD14.bedgraph_rolled','ymel-1254-T-CD8.bedgraph_rolled','ymel-1457-T-CD4.bedgraph_rolled','ymel-1457-T-CD8.bedgraph_rolled','ymel-960-T-CD14.bedgraph_rolled','ymel-960-T-CD4.bedgraph_rolled','zmel-1254-T-CD45-Negative.bedgraph_rolled','zmel-1457-T-CD45-Negative.bedgraph_rolled']]

forheat2onlyOurs.head()
# Out:
#                          ymel-1254-T-CD14.bedgraph_rolled  \
# chrom start    end
# chr1  24167223 24167224                               0.0
#       47356986 47356987                               0.0
# chr10 7561913  7561914                                0.1
# chr11 40871595 40871596                               0.0
#       47589763 47589764                               0.0
#
#                          ymel-1254-T-CD8.bedgraph_rolled  \
# chrom start    end
# chr1  24167223 24167224                            0.000
#       47356986 47356987                            0.167
# chr10 7561913  7561914                             0.100
# chr11 40871595 40871596                            0.000
#       47589763 47589764                            0.000
#
#                          ymel-1457-T-CD4.bedgraph_rolled  \
# chrom start    end
# chr1  24167223 24167224                             0.09
#       47356986 47356987                             0.00
# ...

# %%
forheat2onlyBlue=indf[~indf.index.isin(forheat2onlyOurs.index)]
forheat2onlyBlue.shape
# Out:
# (36, 62)

# %%
forheat2onlyBlue=forheat2onlyBlue.drop(['ymel-1254-T-CD14.bedgraph_rolled','ymel-1254-T-CD8.bedgraph_rolled','ymel-1457-T-CD4.bedgraph_rolled','ymel-1457-T-CD8.bedgraph_rolled','ymel-960-T-CD14.bedgraph_rolled','ymel-960-T-CD4.bedgraph_rolled','zmel-1254-T-CD45-Negative.bedgraph_rolled','zmel-1457-T-CD45-Negative.bedgraph_rolled'], axis=1)
forheat2onlyBlue.head()
# Out:
#                          aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167222 24167223                                              0.920
#       47356985 47356986                                              0.967
# chr10 7561912  7561913                                               0.965
# chr11 40871594 40871595                                              1.000
#       47589762 47589763                                              0.792
#
#                          aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167222 24167223                                              0.974
#       47356985 47356986                                              0.968
# chr10 7561912  7561913                                               0.963
# chr11 40871594 40871595                                              0.961
# ...

# %%
forheat2=forheat2onlyBlue.merge(forheat2onlyOurs,how='outer',left_index=True, right_index=True)
forheat2.head()
# Out:
#                          aS007DD51.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167222 24167223                                              0.920
#       24167223 24167224                                                NaN
#       47356985 47356986                                              0.967
#       47356986 47356987                                                NaN
# chr10 7561912  7561913                                               0.965
#
#                          aS007G756.CPG_methylation_calls.bs_call.GRCh38.20160531-P-naive-CD4-T-cell.bw.bedgraph_rolled  \
# chrom start    end
# chr1  24167222 24167223                                              0.974
#       24167223 24167224                                                NaN
#       47356985 47356986                                              0.968
#       47356986 47356987                                                NaN
# ...

# %%
forheat1.to_csv(infile+"_heat1.txt",sep="\t")
forheat2.to_csv(infile+"_heat2.txt",sep="\t")
