# %%
import pandas as pd
import os

infile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/tieredApproach/BL22_groupv2/All/Alllinked/towardsFinalRef/allct_towardsSM_dummy_mean_SM.txt_unique_withmincol.txt'


outdir=infile+"_ctpos"
os.mkdir(outdir)
indf=pd.read_csv(infile,sep='\t')

indf.head()
# Out:
#   chrom     start  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# 0  chr1   6012593              0.9              0.9        0.9        0.9
# 1  chr1  10525350              0.9              0.9        0.9        0.9
# 2  chr1  10525356              0.9              0.9        0.9        0.9
# 3  chr1  10525449              0.9              0.9        0.9        0.9
# 4  chr1  13765075              0.9              0.9        0.9        0.9
#
#    PC-others  Mono-others  M0-others  M1-others  ...  em8-others  Eo-others  \
# 0        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 1        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 2        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 3        0.9          0.9        0.9        0.9  ...         0.9        0.9
# 4        0.9          0.9        0.9        0.9  ...         0.9        0.9
#
# ...

# %%
indf['end']=indf['start']+2
indf.head()
# Out:
#   chrom     start  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# 0  chr1   6012593              0.9              0.9        0.9        0.9
# 1  chr1  10525350              0.9              0.9        0.9        0.9
# 2  chr1  10525356              0.9              0.9        0.9        0.9
# 3  chr1  10525449              0.9              0.9        0.9        0.9
# 4  chr1  13765075              0.9              0.9        0.9        0.9
#
#    PC-others  Mono-others  M0-others  M1-others  ...  Eo-others  Tregs-others  \
# 0        0.9          0.9        0.9        0.9  ...        0.9           0.9
# 1        0.9          0.9        0.9        0.9  ...        0.9           0.9
# 2        0.9          0.9        0.9        0.9  ...        0.9           0.9
# 3        0.9          0.9        0.9        0.9  ...        0.9           0.9
# 4        0.9          0.9        0.9        0.9  ...        0.9           0.9
#
# ...

# %%
grouped=indf.groupby('mincolname')
for name, group in grouped:
    tempdf=group[['chrom','start','end']]
    ctname=name.replace('-others','')
    
    outname=outdir+"/"+ctname
    tempdf.to_csv(outname,sep='\t',index=False, header=False)
