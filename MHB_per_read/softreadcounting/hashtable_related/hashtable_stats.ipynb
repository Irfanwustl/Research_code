# %%
import pandas as pd
infile="/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_othermean_head.txt"

indf=pd.read_csv(infile,sep="\t",index_col=['position'])

alldelta=[.05,.1,.5]

indf.head()
# Out:
#             CD4-others  CD8-others  nB-others  NK-others  Mn-others  \
# position
# chr1:16138   -0.027936   -0.037269   0.053192   0.032731   0.014423
# chr1:16242    0.012833   -0.000449   0.133090   0.059859   0.109038
# chr1:16633    0.046731    0.102013  -0.032603  -0.022551   0.102013
# chr1:16645    0.003577   -0.005038  -0.011141  -0.033038   0.024756
# chr1:16664    0.018372   -0.004244   0.035603  -0.026859   0.035603
#
#             mNeu-others  m8-others  DC-others  Eo-others  Tr-others  \
# position
# chr1:16138    -0.129526  -0.039064   0.046013   0.015859  -0.024526
# chr1:16242    -0.077987  -0.002782   0.019654  -0.002244   0.083910
# chr1:16633    -0.176910  -0.032603  -0.017526  -0.184987   0.102013
# chr1:16645    -0.020115   0.024756  -0.020115   0.024756   0.024756
# chr1:16664     0.035603   0.035603  -0.083936   0.005449   0.035603
#
#             m4-others  Mg-others  Er-others  mB-others
# position
# chr1:16138   0.056244   0.034167  -0.032064   0.037756
# ...

# %%
negindf=-1*indf
negindf.head()
# Out:
#             CD4-others  CD8-others  nB-others  NK-others  Mn-others  \
# position
# chr1:16138    0.027936    0.037269  -0.053192  -0.032731  -0.014423
# chr1:16242   -0.012833    0.000449  -0.133090  -0.059859  -0.109038
# chr1:16633   -0.046731   -0.102013   0.032603   0.022551  -0.102013
# chr1:16645   -0.003577    0.005038   0.011141   0.033038  -0.024756
# chr1:16664   -0.018372    0.004244  -0.035603   0.026859  -0.035603
#
#             mNeu-others  m8-others  DC-others  Eo-others  Tr-others  \
# position
# chr1:16138     0.129526   0.039064  -0.046013  -0.015859   0.024526
# chr1:16242     0.077987   0.002782  -0.019654   0.002244  -0.083910
# chr1:16633     0.176910   0.032603   0.017526   0.184987  -0.102013
# chr1:16645     0.020115  -0.024756   0.020115  -0.024756  -0.024756
# chr1:16664    -0.035603  -0.035603   0.083936  -0.005449  -0.035603
#
#             m4-others  Mg-others  Er-others  mB-others
# position
# chr1:16138  -0.056244  -0.034167   0.032064  -0.037756
# ...

# %%
scorecolumns=negindf.columns

# %%
ct

for score in scorecolumns:
    for delta in alldelta:
        temp
