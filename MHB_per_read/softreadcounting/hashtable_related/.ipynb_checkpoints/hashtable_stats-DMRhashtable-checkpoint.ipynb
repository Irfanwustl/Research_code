# %%
import pandas as pd
from collections import defaultdict
import sys
import time
start_time = time.time()

infile="/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/uisnglinux/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_othermean_backup_nohead_interwithgeneprom1000_1000.txt"


outfile=infile

indf=pd.read_csv(infile,sep="\t",header=None)



indf.head()
# Out:
#      0       1       2         3         4         5         6         7   \
# 0  chr1  687193  687195  0.790333  0.874000  0.844500  0.672667  0.936333
# 1  chr1  687328  687330  1.000000  0.976333  0.958333  0.909000  0.955667
# 2  chr1  922981  922983  0.958333  0.945667  0.943000  0.955000  0.987667
# 3  chr1  922991  922993  0.967000  0.956000  0.933000  0.943667  0.959333
# 4  chr1  923025  923027  0.852000  0.828000  0.790000  0.796667  0.658333
#
#          8       9   ...        21        22        23        24        25  \
# 0  0.968333  0.4645  ...  0.191782  0.226244 -0.316346  0.187833  0.123577
# 1  0.977667  0.6560  ...  0.087718  0.111410 -0.235000  0.080179  0.075692
# 2  0.964667  0.9245  ...  0.045474  0.020705 -0.022551 -0.010167  0.020526
# 3  0.945000  0.9305  ...  0.012885 -0.002551 -0.018167  0.037654  0.011449
# 4  0.649333  0.7040  ... -0.084628 -0.094321 -0.035449  0.074756 -0.041910
#
#          26        27        28        29        30
# 0 -0.131115 -0.231808  0.016423 -0.078346 -0.148167
# 1 -0.238231 -0.095538 -0.043846 -0.043846 -0.072026
# 2 -0.011782 -0.019321  0.009218 -0.005321 -0.048577
# 3 -0.039167 -0.021397  0.027603  0.000141 -0.019423
# 4 -0.010679 -0.049987  0.062551  0.017321 -0.181192
#
# [5 rows x 31 columns]

# %%
allcomuns=['chrom','start','end','CD4','CD8','nB','NK','Mn','mNeu','m8','DC','Eo','Tr','m4','Mg','Er','mB','CD4-others','CD8-others','nB-others','NK-others','Mn-others','mNeu-others','m8-others','DC-others','Eo-others','Tr-others','m4-others','Mg-others','Er-others','mB-others']

# %%
len(allcomuns)
# Out:
# 31

# %%
indf.shape
# Out:
# (10676194, 31)

# %%
indf.columns =allcomuns
indf.set_index(['chrom','start','end'],inplace=True)
indf.head()
# Out:
#                           CD4       CD8        nB        NK        Mn  \
# chrom start  end
# chr1  687193 687195  0.790333  0.874000  0.844500  0.672667  0.936333
#       687328 687330  1.000000  0.976333  0.958333  0.909000  0.955667
#       922981 922983  0.958333  0.945667  0.943000  0.955000  0.987667
#       922991 922993  0.967000  0.956000  0.933000  0.943667  0.959333
#       923025 923027  0.852000  0.828000  0.790000  0.796667  0.658333
#
#                          mNeu      m8        DC      Eo      Tr  ...  \
# chrom start  end                                                 ...
# chr1  687193 687195  0.968333  0.4645  0.932667  0.8730  0.6365  ...
#       687328 687330  0.977667  0.6560  0.948667  0.9445  0.6530  ...
#       922981 922983  0.964667  0.9245  0.936000  0.9645  0.9345  ...
#       922991 922993  0.945000  0.9305  0.982333  0.9580  0.9110  ...
#       923025 923027  0.649333  0.7040  0.806333  0.6980  0.7270  ...
#
#                      Mn-others  mNeu-others  m8-others  DC-others  Eo-others  \
# chrom start  end
# chr1  687193 687195   0.191782     0.226244  -0.316346   0.187833   0.123577
#       687328 687330   0.087718     0.111410  -0.235000   0.080179   0.075692
#       922981 922983   0.045474     0.020705  -0.022551  -0.010167   0.020526
#       922981 922983   0.019321  -0.009218   0.005321   0.048577
#       922991 922993   0.021397  -0.027603  -0.000141   0.019423
#       923025 923027   0.049987  -0.062551  -0.017321   0.181192

# %%
alldelta=[.05,.1,.5,.6,.7,.8,0.9]

# %%
scorecolumns=negindf.columns

# %%
celltypeStats=defaultdict(list)

allindex=defaultdict(list)
for score in scorecolumns:

    for delta in alldelta:
        tmpdf=negindf[negindf[score]>=delta]
        allindex[delta]=allindex[delta]+tmpdf.index.tolist()
        
        celltypeStats[score]=celltypeStats[score]+[tmpdf.shape[0]]

# %%
celltypeStatsdf=pd.DataFrame.from_dict(celltypeStats, orient='index',columns=alldelta)
celltypeStatsdf.index.name = 'Celltype'
celltypeStatsdf.head()
# Out:
#               0.05    0.10   0.50   0.60   0.70  0.80  0.90
# Celltype
# CD4-others  236208  108499  10048   3699    654    31     0
# CD8-others  317332  128500   9646   2618    374    12     0
# nB-others   368908  193609  33230  22611  13657  5997   141
# NK-others   720622  360157  38658  23567  12588  4811   276
# Mn-others   585110  343957  55428  32918  14135  2030     5

# %%
celltypeStatsdf.to_csv(outfile+"_stats.txt",sep="\t")

# %%
alluniqueindexlen=defaultdict(list)
for key in allindex:
    alluniqueindexlen[key].append(len(set(allindex[key])))

# %%
alluniqueindexlen
# Out:
# defaultdict(list,
#             {0.05: [7750321],
#              0.1: [4878540],
#              0.5: [384322],
#              0.6: [226711],
#              0.7: [120285],
#              0.8: [42653],
#              0.9: [3200]})

# %%
alluniqueindexlendf=pd.DataFrame.from_dict(alluniqueindexlen)
alluniqueindexlendf.head()
# Out:
#       0.05     0.10    0.50    0.60    0.70   0.80  0.90
# 0  7750321  4878540  384322  226711  120285  42653  3200

# %%
alluniqueindexlendf.to_csv(outfile+"_uniquecpgs.txt",sep="\t")

# %%
end_time = time.time()

time_elapsed = (end_time - start_time)

print(time_elapsed)
# Out:
# 205.10886001586914

# %%
currentsm='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/softRD_pileup/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_intesectedwith_BL14ateast.2DMRs.txt_othermean.txt'

currentsmdf=pd.read_csv(currentsm,sep="\t")

# %%
currentsmdf.head()
# Out:
#   chrom    start  CD4-others  CD8-others  nB-others  NK-others  Mn-others  \
# 0  chr1  1221863    0.107538   -0.014513   0.115436  -0.782718   0.084564
# 1  chr1  1221897    0.099756    0.010731   0.105500  -0.790141   0.085397
# 2  chr1  1222070    0.110564    0.038410   0.103026  -0.860103   0.114154
# 3  chr1  1222077    0.090962    0.007321   0.157013  -0.859962   0.146244
# 4  chr1  1222089    0.107667    0.025103   0.093667  -0.853667   0.101205
#
#    mNeu-others  m8-others  DC-others  Eo-others  Tr-others  m4-others  \
# 0     0.119026   0.114359   0.028205   0.031974   0.102513   0.045974
# 1     0.092218   0.069423   0.037295  -0.010269   0.078577   0.028500
# 2     0.078256   0.063179   0.066051  -0.020821   0.089564  -0.000897
# 3     0.069423   0.105859   0.041423  -0.007218   0.085936  -0.022295
# 4     0.030846   0.085410   0.010385   0.000872   0.131179   0.080564
#
#    Mg-others  Er-others  mB-others
# 0   0.000205   0.041128   0.006308
# 1   0.090423   0.066731   0.035859
# 2   0.083103   0.058333   0.077179
# 3   0.075705   0.047705   0.061885
# 4   0.080026   0.049333   0.057410

# %%
currentsmdf['position']=currentsmdf[['chrom','start']].apply(lambda row: ':'.join(row.values.astype(str)), axis=1)

# %%
currentsmdf=currentsmdf.set_index('position')

# %%
currentsmdf=currentsmdf.drop(['chrom','start'],axis=1)

# %%
currentsmdf.head()
# Out:
#               CD4-others  CD8-others  nB-others  NK-others  Mn-others  \
# position
# chr1:1221863    0.107538   -0.014513   0.115436  -0.782718   0.084564
# chr1:1221897    0.099756    0.010731   0.105500  -0.790141   0.085397
# chr1:1222070    0.110564    0.038410   0.103026  -0.860103   0.114154
# chr1:1222077    0.090962    0.007321   0.157013  -0.859962   0.146244
# chr1:1222089    0.107667    0.025103   0.093667  -0.853667   0.101205
#
#               mNeu-others  m8-others  DC-others  Eo-others  Tr-others  \
# position
# chr1:1221863     0.119026   0.114359   0.028205   0.031974   0.102513
# chr1:1221897     0.092218   0.069423   0.037295  -0.010269   0.078577
# chr1:1222070     0.078256   0.063179   0.066051  -0.020821   0.089564
# chr1:1222077     0.069423   0.105859   0.041423  -0.007218   0.085936
# chr1:1222089     0.030846   0.085410   0.010385   0.000872   0.131179
#
#               m4-others  Mg-others  Er-others  mB-others
# position
# chr1:1221863   0.045974   0.000205   0.041128   0.006308
# chr1:1221897   0.028500   0.090423   0.066731   0.035859
# chr1:1222070  -0.000897   0.083103   0.058333   0.077179
# chr1:1222077  -0.022295   0.075705   0.047705   0.061885
# chr1:1222089   0.080564   0.080026   0.049333   0.057410

# %%
negindf_subsetted=negindf[negindf.index.isin(currentsmdf.index.tolist())]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-658a2280ce2f> in <module>
# ----> 1 negindf_subsetted=negindf[negindf.index.isin(currentsmdf.index.tolist())]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/multi.py in isin(self, values, level)
#    3418     def isin(self, values, level=None):
#    3419         if level is None:
# -> 3420             values = MultiIndex.from_tuples(values, names=self.names).values
#    3421             return algos.isin(self.values, values)
#    3422         else:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/multi.py in from_tuples(cls, tuples, sortorder, names)
#     493             arrays = zip(*tuples)
#     494
# --> 495         return MultiIndex.from_arrays(arrays, sortorder=sortorder, names=names)
#     496
#     497     @classmethod
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/multi.py in from_arrays(cls, arrays, sortorder, names)
#     434             sortorder=sortorder,
#     435             names=names,
# --> 436             verify_integrity=False,
#     437         )
#     438
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/multi.py in __new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity, _set_identity)
#     270         if names is not None:
#     271             # handles name validation
# --> 272             result._set_names(names)
#     273
#     274         if sortorder is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/multi.py in _set_names(self, names, level, validate)
#    1215             if level is None and len(names) != self.nlevels:
#    1216                 raise ValueError(
# -> 1217                     "Length of names must match number of levels in MultiIndex."
#    1218                 )
#    1219
#
# ValueError: Length of names must match number of levels in MultiIndex.

# %%
negindf_subsetted.shape

# %%
currentsmdf.shape

# %%
import seaborn as sns
ax = sns.heatmap(negindf_subsetted,vmin=-1, vmax=1,cmap='viridis')

# %%
ax = sns.heatmap(-1*currentsmdf,vmin=-1, vmax=1,cmap='viridis')

# %%
negindf_subsetted.to_csv(outfile+"_subsetted.txt",sep="\t")

# %%
(-1*currentsmdf).to_csv(outfile+"_currentsm.txt",sep="\t")
