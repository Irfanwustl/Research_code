# %%
import pandas as pd
import glob, os
import sys



infolder="/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/try2"
outname=infolder

celltype="CD4"
files = glob.glob(infolder+'/*softRD_result.txt')
df = pd.concat([pd.read_csv(fp,sep="\t").assign(Mixture=os.path.basename(fp)) for fp in files])
df=df.set_index('Mixture')
df.head()
# Out:
#                                                     deltabasedresult  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_howsm_...          0.093876
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...          0.193164
# CD4allrange_NR_1000000_insilmix50_sorted_howsm_...          0.091903
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...          1.000000
# CD4allrange_NR_1000000_insilmix52_sorted_howsm_...          0.132505
#
#                                                     deltaweightedbycpgResult  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_howsm_...                  0.053697
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...                  0.110331
# CD4allrange_NR_1000000_insilmix50_sorted_howsm_...                  0.052385
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...                  0.497437
# CD4allrange_NR_1000000_insilmix52_sorted_howsm_...                  0.075587
#
#                                                     fragresult  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_howsm_...    0.136195
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...    0.217817
# CD4allrange_NR_1000000_insilmix50_sorted_howsm_...    0.130710
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...    1.000000
# CD4allrange_NR_1000000_insilmix52_sorted_howsm_...    0.169454
#
#                                                     cpgweightedFRAGresult
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_howsm_...               0.093025
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...               0.188498
# CD4allrange_NR_1000000_insilmix50_sorted_howsm_...               0.090884
# CD4allrange_NR_1000000_insilmix60_sorted_howsm_...               1.000000
# CD4allrange_NR_1000000_insilmix52_sorted_howsm_...               0.129311

# %%
colnames=df.columns.tolist()
for cname in colnames:
    
    tempdf=(df[cname]).to_frame(name=celltype)
    tempdf.to_csv(outname+"/"+'result_'+cname+"_CSxOut.txt",sep="\t")
