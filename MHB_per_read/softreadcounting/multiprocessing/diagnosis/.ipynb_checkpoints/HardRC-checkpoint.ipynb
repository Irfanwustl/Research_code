# %%
import pandas as pd
import pandas as pd
from collections import defaultdict
from sklearn import metrics
import numpy as np
import sys
import time

start_time = time.time()

inbinfile='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/softRD_pileup/HardRDdevelop/cd4bams_softMultiprocessing_dupindex_binnedstats.pkl'




#######outfile=inbinfile


mincpgLIST=[1,3,5]

consideringALLheyper=True


inbindf=pd.read_pickle(inbinfile)
scorecolumns=['CD4-others','CD8-others','nB-others','NK-others','Mn-others','mNeu-others','m8-others','DC-others','Eo-others','Tr-others','m4-others','Mg-others','Er-others','mB-others']

inbindf=inbindf.reset_index()
inbindf.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:15458:40711#12   -0.016083   -0.074058
# 1   CD4.HWI-7001432L_73:1:1101:5520:53472#12   -0.013074   -0.012715
# 2  CD4.HWI-7001432L_73:1:1102:14628:95915#12   -0.043212   -0.040878
# 3   CD4.HWI-7001432L_73:1:1102:19489:7478#12   -0.153423   -0.143731
# 4  CD4.HWI-7001432L_73:1:1103:17455:40816#12   -0.006442   -0.011154
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.101699  -0.050545  -0.014647    -0.029904   0.005545  -0.091468
# 1  -0.012715  -0.010562  -0.016233    -0.008838  -0.003741  -0.012787
# 2  -0.004801  -0.000853  -0.061160    -0.054699  -0.062417  -0.028314
# 3  -0.043577  -0.075526  -0.171013    -0.113577  -0.046987  -0.187167
# 4  -0.011064  -0.009224  -0.009583    -0.008103   0.003631  -0.011737
#
#    Eo-others  ...  LENhypoCpG  LENhyperCpG  total_cpg  \
# 0   0.102199  ...         1.0          1.0        2.0
# 1  -0.010203  ...         1.0          4.0        5.0
# 2  -0.024455  ...         1.0          1.0        2.0
# 3  -0.180526  ...         1.0          0.0        1.0
# 4  -0.010099  ...         1.0          7.0        8.0
#
#    LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0                    0.500                    Mg-others
# 1                    0.200                    Er-others
# 2                    0.500                    mB-others
# 3                    1.000                    mB-others
# 4                    0.125                    Tr-others
#
#    maxscore_beforeCpGweight  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0                  0.619013    Mg-others  0.309506                 Mg-others
# 1                  0.629603    Er-others  0.125921                 Er-others
# 2                  0.819987    mB-others  0.409994                 mB-others
# 3                  0.825321    mB-others  0.825321                 mB-others
# 4                  0.663897    Tr-others  0.082987                 Tr-others
#
#                                             filename
# 0  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 1  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 2  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 3  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 4  CD4allrange_NR_1000000_insilmix50_sorted_binne...
#
# [5 rows x 25 columns]

# %%
if consideringALLheyper==True:
    allassigned=inbindf.copy()


elif consideringALLheyper==False:
    allassigned=inbindf[inbindf['deltabasedfragassignment']!='NotAssigned'].copy()
    
else:
    print("wrong input")
    sys.exit(1)
#
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:15458:40711#12   -0.016083   -0.074058
# 1   CD4.HWI-7001432L_73:1:1101:5520:53472#12   -0.013074   -0.012715
# 2  CD4.HWI-7001432L_73:1:1102:14628:95915#12   -0.043212   -0.040878
# 3   CD4.HWI-7001432L_73:1:1102:19489:7478#12   -0.153423   -0.143731
# 4  CD4.HWI-7001432L_73:1:1103:17455:40816#12   -0.006442   -0.011154
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.101699  -0.050545  -0.014647    -0.029904   0.005545  -0.091468
# 1  -0.012715  -0.010562  -0.016233    -0.008838  -0.003741  -0.012787
# 2  -0.004801  -0.000853  -0.061160    -0.054699  -0.062417  -0.028314
# 3  -0.043577  -0.075526  -0.171013    -0.113577  -0.046987  -0.187167
# 4  -0.011064  -0.009224  -0.009583    -0.008103   0.003631  -0.011737
#
#    Eo-others  ...  LENhypoCpG  LENhyperCpG  total_cpg  \
# 0   0.102199  ...         1.0          1.0        2.0
# 1  -0.010203  ...         1.0          4.0        5.0
# 2  -0.024455  ...         1.0          1.0        2.0
# 3  -0.180526  ...         1.0          0.0        1.0
# 4  -0.010099  ...         1.0          7.0        8.0
#
#    LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0                    0.500                    Mg-others
# 1                    0.200                    Er-others
# 2                    0.500                    mB-others
# 3                    1.000                    mB-others
# 4                    0.125                    Tr-others
#
#    maxscore_beforeCpGweight  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0                  0.619013    Mg-others  0.309506                 Mg-others
# 1                  0.629603    Er-others  0.125921                 Er-others
# 2                  0.819987    mB-others  0.409994                 mB-others
# 3                  0.825321    mB-others  0.825321                 mB-others
# 4                  0.663897    Tr-others  0.082987                 Tr-others
#
#                                             filename
# 0  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 1  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 2  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 3  CD4allrange_NR_1000000_insilmix50_sorted_binne...
# 4  CD4allrange_NR_1000000_insilmix50_sorted_binne...
#
# [5 rows x 25 columns]

# %%
allassigned.loc[inbindf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=allassigned.loc[inbindf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
allassigned['secondmaxScore']='Notassigned'
allassigned['secondmaxScoreCT']='Notassigned'
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:15458:40711#12   -0.016083   -0.074058
# 1   CD4.HWI-7001432L_73:1:1101:5520:53472#12   -0.013074   -0.012715
# 2  CD4.HWI-7001432L_73:1:1102:14628:95915#12   -0.043212   -0.040878
# 3   CD4.HWI-7001432L_73:1:1102:19489:7478#12   -0.153423   -0.143731
# 4  CD4.HWI-7001432L_73:1:1103:17455:40816#12   -0.006442   -0.011154
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.101699  -0.050545  -0.014647    -0.029904   0.005545  -0.091468
# 1  -0.012715  -0.010562  -0.016233    -0.008838  -0.003741  -0.012787
# 2  -0.004801  -0.000853  -0.061160    -0.054699  -0.062417  -0.028314
# 3  -0.043577  -0.075526  -0.171013    -0.113577  -0.046987  -0.187167
# 4  -0.011064  -0.009224  -0.009583    -0.008103   0.003631  -0.011737
#
#    Eo-others  ...  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0   0.102199  ...        2.0                    0.500
# 1  -0.010203  ...        5.0                    0.200
# 2  -0.024455  ...        2.0                    0.500
# 3  -0.180526  ...        1.0                    1.000
# 4  -0.010099  ...        8.0                    0.125
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  maxscoredCT  \
# 0                    Mg-others                  0.619013    Mg-others
# 1                    Er-others                  0.629603    Er-others
# 2                    mB-others                  0.819987    mB-others
# 3                    mB-others                  0.825321    mB-others
# 4                    Tr-others                  0.663897    Tr-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.309506                 Mg-others
# 1  0.125921                 Er-others
# 2  0.409994                 mB-others
# 3  0.825321                 mB-others
# 4  0.082987                 Tr-others
#
#                                             filename  secondmaxScore  \
# 0  CD4allrange_NR_1000000_insilmix50_sorted_binne...     Notassigned
# 1  CD4allrange_NR_1000000_insilmix50_sorted_binne...     Notassigned
# 2  CD4allrange_NR_1000000_insilmix50_sorted_binne...     Notassigned
# 3  CD4allrange_NR_1000000_insilmix50_sorted_binne...     Notassigned
# 4  CD4allrange_NR_1000000_insilmix50_sorted_binne...     Notassigned
#
#   secondmaxScoreCT
# 0      Notassigned
# 1      Notassigned
# 2      Notassigned
# 3      Notassigned
# 4      Notassigned
#
# [5 rows x 27 columns]

# %%
grouped=allassigned.groupby('maxscoredCT')

for name, group in grouped:
    
    
    tempscorecolumns=scorecolumns.copy()
    
    tempscorecolumns.remove(name)
    
    allassigned.loc[group.index,'secondmaxScore']=group[tempscorecolumns].max(axis=1)
    allassigned.loc[group.index,'secondmaxScoreCT']=(group[tempscorecolumns]).idxmax(axis=1)

# %%
allassigned['adjustedScore_minus']=allassigned['maxscore']-allassigned['secondmaxScore']
allassigned['adjustedScore_minus_avg']=(allassigned['maxscore']+(allassigned['maxscore']-allassigned['secondmaxScore']))/2
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:15458:40711#12   -0.016083   -0.074058
# 1   CD4.HWI-7001432L_73:1:1101:5520:53472#12   -0.013074   -0.012715
# 2  CD4.HWI-7001432L_73:1:1102:14628:95915#12   -0.043212   -0.040878
# 3   CD4.HWI-7001432L_73:1:1102:19489:7478#12   -0.153423   -0.143731
# 4  CD4.HWI-7001432L_73:1:1103:17455:40816#12   -0.006442   -0.011154
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.101699  -0.050545  -0.014647    -0.029904   0.005545  -0.091468
# 1  -0.012715  -0.010562  -0.016233    -0.008838  -0.003741  -0.012787
# 2  -0.004801  -0.000853  -0.061160    -0.054699  -0.062417  -0.028314
# 3  -0.043577  -0.075526  -0.171013    -0.113577  -0.046987  -0.187167
# 4  -0.011064  -0.009224  -0.009583    -0.008103   0.003631  -0.011737
#
#    Eo-others  ...  maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  \
# 0   0.102199  ...                    Mg-others                  0.619013
# 1  -0.010203  ...                    Er-others                  0.629603
# 2  -0.024455  ...                    mB-others                  0.819987
# 3  -0.180526  ...                    mB-others                  0.825321
# 4  -0.010099  ...                    Tr-others                  0.663897
#
#    maxscoredCT  maxscore  deltabasedfragassignment  \
# 0    Mg-others  0.309506                 Mg-others
# 1    Er-others  0.125921                 Er-others
# 2    mB-others  0.409994                 mB-others
# 3    mB-others  0.825321                 mB-others
# 4    Tr-others  0.082987                 Tr-others
#
#                                             filename  secondmaxScore  \
# 0  CD4allrange_NR_1000000_insilmix50_sorted_binne...        0.102199
# 1  CD4allrange_NR_1000000_insilmix50_sorted_binne...      0.00911026
# 2  CD4allrange_NR_1000000_insilmix50_sorted_binne...    -0.000852564
# 3  CD4allrange_NR_1000000_insilmix50_sorted_binne...        0.242705
# 4  CD4allrange_NR_1000000_insilmix50_sorted_binne...      0.00746795
#
#    secondmaxScoreCT  adjustedScore_minus adjustedScore_minus_avg
# 0         Eo-others             0.207308                0.258407
# 1         mB-others              0.11681                0.121365
# 2         NK-others             0.410846                 0.41042
# 3         Tr-others             0.582615                0.703968
# 4         m4-others            0.0755192               0.0792532
#
# [5 rows x 29 columns]

# %%
allassigned.columns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename',
#        'secondmaxScore', 'secondmaxScoreCT', 'adjustedScore_minus',
#        'adjustedScore_minus_avg'],
#       dtype='object')

# %%
adjustedScore_minus0val=list(set(allassigned[allassigned['LENhypoCpG_BY_total_cpg']==0]['adjustedScore_minus'].tolist()))
if len(adjustedScore_minus0val)==0:
    pass
elif len(adjustedScore_minus0val)!=1 or adjustedScore_minus0val[0]!=0:
    print(adjustedScore_minus0val)
    sys.exit(1)

# %%
adjustedScore_minus_avg0val=list(set(allassigned[allassigned['LENhypoCpG_BY_total_cpg']==0]['adjustedScore_minus_avg'].tolist()))


if len(adjustedScore_minus_avg0val)==0:
    pass

elif len(adjustedScore_minus_avg0val)!=1 or adjustedScore_minus_avg0val[0]!=0:
    print(adjustedScore_minus_avg0val)
    sys.exit(1)

# %%
allassigned['LENhypoCpG_0.8']=0
allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.8,'LENhypoCpG_0.8']=allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.8,'LENhypoCpG']

# %%
allassigned['LENhypoCpG_0.65']=0
allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.65,'LENhypoCpG_0.65']=allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.65,'LENhypoCpG']

# %%
allassigned['LENhypoCpG_0.5']=0
allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.5,'LENhypoCpG_0.5']=allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.5,'LENhypoCpG']

# %%
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:15458:40711#12   -0.016083   -0.074058
# 1   CD4.HWI-7001432L_73:1:1101:5520:53472#12   -0.013074   -0.012715
# 2  CD4.HWI-7001432L_73:1:1102:14628:95915#12   -0.043212   -0.040878
# 3   CD4.HWI-7001432L_73:1:1102:19489:7478#12   -0.153423   -0.143731
# 4  CD4.HWI-7001432L_73:1:1103:17455:40816#12   -0.006442   -0.011154
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.101699  -0.050545  -0.014647    -0.029904   0.005545  -0.091468
# 1  -0.012715  -0.010562  -0.016233    -0.008838  -0.003741  -0.012787
# 2  -0.004801  -0.000853  -0.061160    -0.054699  -0.062417  -0.028314
# 3  -0.043577  -0.075526  -0.171013    -0.113577  -0.046987  -0.187167
# 4  -0.011064  -0.009224  -0.009583    -0.008103   0.003631  -0.011737
#
#    Eo-others  ...  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0   0.102199  ...    Mg-others  0.309506                 Mg-others
# 1  -0.010203  ...    Er-others  0.125921                 Er-others
# 2  -0.024455  ...    mB-others  0.409994                 mB-others
# 3  -0.180526  ...    mB-others  0.825321                 mB-others
# 4  -0.010099  ...    Tr-others  0.082987                 Tr-others
#
#                                             filename  secondmaxScore  \
# 0  CD4allrange_NR_1000000_insilmix50_sorted_binne...        0.102199
# 1  CD4allrange_NR_1000000_insilmix50_sorted_binne...      0.00911026
# 2  CD4allrange_NR_1000000_insilmix50_sorted_binne...    -0.000852564
# 3  CD4allrange_NR_1000000_insilmix50_sorted_binne...        0.242705
# 4  CD4allrange_NR_1000000_insilmix50_sorted_binne...      0.00746795
#
#    secondmaxScoreCT  adjustedScore_minus  adjustedScore_minus_avg  \
# 0         Eo-others             0.207308                 0.258407
# 1         mB-others              0.11681                 0.121365
# 2         NK-others             0.410846                  0.41042
# 3         Tr-others             0.582615                 0.703968
# 4         m4-others            0.0755192                0.0792532
#
#    LENhypoCpG_0.8 LENhypoCpG_0.5
# 0             0.0            1.0
# 1             0.0            0.0
# 2             0.0            1.0
# 3             1.0            1.0
# 4             0.0            0.0
#
# [5 rows x 31 columns]

# %%
def hardRC(fgrouped,targetmincpg,cpgpatternratecolumn,fname):
    ctproportiondict=defaultdict(list)
    for score in scorecolumns:
        
     
        
        totalfragments=fgrouped[(fgrouped['deltabasedfragassignment']==score) & (fgrouped['total_cpg']>=targetmincpg)].shape[0]
        positivefragments=fgrouped[(fgrouped['deltabasedfragassignment']==score) & (fgrouped[cpgpatternratecolumn]>=targetmincpg)].shape[0]
        

        

        
        if totalfragments==0:
            tempctproportion=0
        
        else:
            tempctproportion=1.0*positivefragments/totalfragments
        
        ctname=score.replace('-others','')
        
        ctproportiondict[ctname].append(tempctproportion)
        
    ctproportionDF=pd.DataFrame.from_dict(ctproportiondict)
    
    ctproportionDF['Mixture']=fname
        
    return  ctproportionDF

# %%
filegrouped=allassigned.groupby('filename')

for mincpg in mincpgLIST:
    allfileresultfiftypercent=[]
    allfileresultsixtyfivepercent=[]
    allfileresulteightypercent=[]
    for name, group in filegrouped:
        allfileresultfiftypercent.append(hardRC(group,mincpg,'LENhypoCpG_0.5',name))
        allfileresultsixtyfivepercent.append(hardRC(group,mincpg,'LENhypoCpG_0.65',name))
        allfileresulteightypercent.append(hardRC(group,mincpg,'LENhypoCpG_0.8',name))
        
        
        
     

    allfileresultfiftypercentDF=pd.concat(allfileresultfiftypercent)
    allfileresultfiftypercentDF.set_index('Mixture',inplace=True) 
    
    allfileresultsixtyfivepercentDF=pd.concat(allfileresultsixtyfivepercent)
    allfileresultsixtyfivepercentDF.set_index('Mixture',inplace=True) 
    
    
    allfileresulteightypercentDF=pd.concat(allfileresulteightypercent)
    allfileresulteightypercentDF.set_index('Mixture',inplace=True)
    
    
    
    allfileresultfiftypercentDF.to_csv(outfile+"_pattern"+".5_mincpg"+str(mincpg),sep="\t")
    
    allfileresultsixtyfivepercentDF.to_csv(outfile+"_pattern"+".65_mincpg"+str(mincpg),sep="\t")
    
    allfileresulteightypercentDF.to_csv(outfile+"_pattern"+".8_mincpg"+str(mincpg),sep="\t")
# Out:
#                                                          CD4       CD8  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_binned...  0.056399  0.051080
# CD4allrange_NR_1000000_insilmix45_sorted_binned...  0.051319  0.091913
# CD4allrange_NR_1000000_insilmix50_sorted_binned...  0.059716  0.061014
# CD4allrange_NR_1000000_insilmix52_sorted_binned...  0.091280  0.064862
# CD4allrange_NR_1000000_insilmix60_sorted_binned...  0.143442  0.027412
#
#                                                           nB        NK  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_binned...  0.074568  0.019409
# CD4allrange_NR_1000000_insilmix45_sorted_binned...  0.040108  0.046629
# CD4allrange_NR_1000000_insilmix50_sorted_binned...  0.029000  0.094518
# CD4allrange_NR_1000000_insilmix52_sorted_binned...  0.089820  0.065295
# CD4allrange_NR_1000000_insilmix60_sorted_binned...  0.053362  0.027735
#
#                                                           Mn      mNeu  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_binned...  0.029941  0.118595
# CD4allrange_NR_1000000_insilmix45_sorted_binned...  0.016226  0.038327
# CD4allrange_NR_1000000_insilmix50_sorted_binned...  0.024274  0.074175
# CD4allrange_NR_1000000_insilmix52_sorted_binned...  0.012317  0.050432
# CD4allrange_NR_1000000_insilmix60_sorted_binned...  0.017560  0.068200
#
#                                                           m8        DC  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_binned...  0.113801  0.032362
# CD4allrange_NR_1000000_insilmix45_sorted_binned...  0.122413  0.068726
# CD4allrange_NR_1000000_insilmix50_sorted_binned...  0.110271  0.066199
# CD4allrange_NR_1000000_insilmix52_sorted_binned...  0.106912  0.026712
# CD4allrange_NR_1000000_insilmix60_sorted_binned...  0.104770  0.070523
#
#                                                           Eo        Tr  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_binned...  0.020864  0.099801
# CD4allrange_NR_1000000_insilmix45_sorted_binned...  0.100535  0.048656
# CD4allrange_NR_1000000_insilmix50_sorted_binned...  0.024363  0.036375
# CD4allrange_NR_1000000_insilmix52_sorted_binned...  0.060225  0.090017
# CD4allrange_NR_1000000_insilmix60_sorted_binned...  0.036746  0.086507
#
#                                                           m4        Mg  \
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_binned...  0.123554  0.042176
# CD4allrange_NR_1000000_insilmix45_sorted_binned...  0.037247  0.067426
# CD4allrange_NR_1000000_insilmix50_sorted_binned...  0.068089  0.062048
# CD4allrange_NR_1000000_insilmix52_sorted_binned...  0.108775  0.042658
# CD4allrange_NR_1000000_insilmix60_sorted_binned...  0.088660  0.031067
#
#                                                           Er        mB
# Mixture
# CD4allrange_NR_1000000_insilmix41_sorted_binned...  0.037606  0.084429
# CD4allrange_NR_1000000_insilmix45_sorted_binned...  0.059962  0.097091
# CD4allrange_NR_1000000_insilmix50_sorted_binned...  0.061905  0.102466
# CD4allrange_NR_1000000_insilmix52_sorted_binned...  0.014924  0.084674
# CD4allrange_NR_1000000_insilmix60_sorted_binned...  0.041440  0.055746

# %%
sys.exit(1)

###reemove everything after this cell

# %%
end_time = time.time()

time_elapsed = (end_time - start_time)

print(time_elapsed)
