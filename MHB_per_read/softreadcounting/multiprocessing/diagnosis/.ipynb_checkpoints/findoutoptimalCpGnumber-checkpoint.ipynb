# %%
import pandas as pd
import glob
import os
import time
import sys
import re

###no need to  beordered, but default SM should have a g_ hard coded if  default sm  is included###
orderedsoftRC='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/insilico/training/SM_BL22Trainmixture_output_mdadded_sorted_globalout_binnedstats.pkl__dupindex_binnedstats.pkl_AllhyperTrue_AUC.txtadjustedScore_minus_avg.txt'

orderedsoftRCDF=pd.read_csv(orderedsoftRC,sep="\t",index_col=0)

orderedsoftRCDF.head()
# Out:
#           BL22_genepromSM_0.7.txt_g_45.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.982502
# Er                                                 0.966473
# M0                                                 0.843803
# M1                                                 0.918283
# M2                                                 0.865532
#
#           BL22_genepromSM_0.7.txt_g_30.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.978002
# Er                                                 0.961239
# M0                                                 0.857775
# M1                                                 0.913439
# M2                                                 0.846919
#
#           BL22_genepromSM_0.7.txt_g_100.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.973385
# Er                                                 0.978754
# M0                                                 0.884850
# M1                                                 0.904952
# M2                                                 0.871924
#
#           BL22_genepromSM_0.7.txt_g_35.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.976824
# Er                                                 0.963646
# M0                                                 0.865006
# M1                                                 0.916664
# M2                                                 0.855859
#
#           BL22_genepromSM_0.7.txt_g_200.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.960786
# Er                                                 0.971481
# M0                                                 0.925177
# M1                                                 0.896595
# M2                                                 0.903224
#
#           BL22_genepromSM_0.7.txt_g_25.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.981315
# Er                                                 0.957266
# M0                                                 0.849094
# M1                                                 0.910889
# M2                                                 0.846088
#
#           BL22_genepromSM_0.7.txt_g_400.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.961511
# Er                                                 0.943385
# M0                                                 0.915353
# M1                                                 0.889640
# M2                                                 0.893071
#
#           BL22_genepromSM_0.7.txt_g_50.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.983070
# Er                                                 0.968963
# M0                                                 0.851472
# M1                                                 0.918329
# M2                                                 0.863410
#
#           BL22_genepromSM_0.7.txt_g_40.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# Eo                                                 0.976221
# Er                                                 0.964654
# M0                                                 0.850021
# M1                                                 0.910324
# M2                                                 0.862623
#
#           BL22_genepromSM_0.7.txt_g_300.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt
# Celltype
# Eo                                                 0.964798
# Er                                                 0.963955
# M0                                                 0.911464
# M1                                                 0.895245
# M2                                                 0.902543

# %%
allcolumns=orderedsoftRCDF.columns
allcolumns
# Out:
# Index(['BL22_genepromSM_0.7.txt_g_45.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_30.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_100.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_35.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_200.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_25.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_400.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_50.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_40.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL22_genepromSM_0.7.txt_g_300.txt_result_dupindex_binnedstats.pkl_AllhyperTrue_AUC.txt'],
#       dtype='object')

# %%
###create dict  for rename###


dictforrename={}

for acol in allcolumns:
    m = re.search('g_(.+?)\.', acol)
    if m:
        found = m.group(1)

    else:
        print("CpG num", biggerfile)
        print("exiting")

        sys.exit(1)
    
    cpgnum = found
    
    dictforrename[acol]=cpgnum

# %%
orderedsoftRCDFrenamed=orderedsoftRCDF.rename(columns=dictforrename)

# %%
orderedsoftRCDFrenamed.head()
# Out:
#                 45        30       100        35       200        25  \
# Celltype
# Eo        0.982502  0.978002  0.973385  0.976824  0.960786  0.981315
# Er        0.966473  0.961239  0.978754  0.963646  0.971481  0.957266
# M0        0.843803  0.857775  0.884850  0.865006  0.925177  0.849094
# M1        0.918283  0.913439  0.904952  0.916664  0.896595  0.910889
# M2        0.865532  0.846919  0.871924  0.855859  0.903224  0.846088
#
#                400        50        40       300
# Celltype
# Eo        0.961511  0.983070  0.976221  0.964798
# Er        0.943385  0.968963  0.964654  0.963955
# M0        0.915353  0.851472  0.850021  0.911464
# M1        0.889640  0.918329  0.910324  0.895245
# M2        0.893071  0.863410  0.862623  0.902543

# %%
allcpgnum=orderedsoftRCDFrenamed.columns
allcpgnum
# Out:
# Index(['45', '30', '100', '35', '200', '25', '400', '50', '40', '300'], dtype='object')

# %%
orderedsoftRCDFrenamed['MaxAUC']=orderedsoftRCDFrenamed.max(axis=1)
orderedsoftRCDFrenamed.head()
# Out:
#                 45        30       100        35       200        25  \
# Celltype
# Eo        0.982502  0.978002  0.973385  0.976824  0.960786  0.981315
# Er        0.966473  0.961239  0.978754  0.963646  0.971481  0.957266
# M0        0.843803  0.857775  0.884850  0.865006  0.925177  0.849094
# M1        0.918283  0.913439  0.904952  0.916664  0.896595  0.910889
# M2        0.865532  0.846919  0.871924  0.855859  0.903224  0.846088
#
#                400        50        40       300    MaxAUC
# Celltype
# Eo        0.961511  0.983070  0.976221  0.964798  0.983070
# Er        0.943385  0.968963  0.964654  0.963955  0.978754
# M0        0.915353  0.851472  0.850021  0.911464  0.925177
# M1        0.889640  0.918329  0.910324  0.895245  0.918329
# M2        0.893071  0.863410  0.862623  0.902543  0.903224

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(orderedsoftRCDFrenamed, annot=True,cmap='viridis')

# %%
orderedsoftRCDFrenamed['MaxAUCCpG']=orderedsoftRCDFrenamed[allcpgnum].idxmax(axis=1)
orderedsoftRCDFrenamed.to_csv(orderedsoftRC+"_bestREF.txt",sep="\t")

# %%
orderedsoftRCDFrenamed.head()
# Out:
#                 45        30       100        35       200        25  \
# Celltype
# Eo        0.982502  0.978002  0.973385  0.976824  0.960786  0.981315
# Er        0.966473  0.961239  0.978754  0.963646  0.971481  0.957266
# M0        0.843803  0.857775  0.884850  0.865006  0.925177  0.849094
# M1        0.918283  0.913439  0.904952  0.916664  0.896595  0.910889
# M2        0.865532  0.846919  0.871924  0.855859  0.903224  0.846088
#
#                400        50        40       300    MaxAUC MaxAUCCpG
# Celltype
# Eo        0.961511  0.983070  0.976221  0.964798  0.983070        50
# Er        0.943385  0.968963  0.964654  0.963955  0.978754       100
# M0        0.915353  0.851472  0.850021  0.911464  0.925177       200
# M1        0.889640  0.918329  0.910324  0.895245  0.918329        50
# M2        0.893071  0.863410  0.862623  0.902543  0.903224       200

# %%
orderedsoftRCDFrenamed.index += '-others'
orderedsoftRCDFrenamed.head()
# Out:
#                  45        30       100        35       200        25  \
# Celltype
# Eo-others  0.982502  0.978002  0.973385  0.976824  0.960786  0.981315
# Er-others  0.966473  0.961239  0.978754  0.963646  0.971481  0.957266
# M0-others  0.843803  0.857775  0.884850  0.865006  0.925177  0.849094
# M1-others  0.918283  0.913439  0.904952  0.916664  0.896595  0.910889
# M2-others  0.865532  0.846919  0.871924  0.855859  0.903224  0.846088
#
#                 400        50        40       300    MaxAUC MaxAUCCpG
# Celltype
# Eo-others  0.961511  0.983070  0.976221  0.964798  0.983070        50
# Er-others  0.943385  0.968963  0.964654  0.963955  0.978754       100
# M0-others  0.915353  0.851472  0.850021  0.911464  0.925177       200
# M1-others  0.889640  0.918329  0.910324  0.895245  0.918329        50
# M2-others  0.893071  0.863410  0.862623  0.902543  0.903224       200

# %%
toselectBestref=orderedsoftRCDFrenamed[['MaxAUCCpG']]
toselectBestref.head()
# Out:
#           MaxAUCCpG
# Celltype
# Eo-others        50
# Er-others       100
# M0-others       200
# M1-others        50
# M2-others       200

# %%
toselectBestref.to_csv(orderedsoftRC+"_TOselectbestREF.txt",sep="\t")
