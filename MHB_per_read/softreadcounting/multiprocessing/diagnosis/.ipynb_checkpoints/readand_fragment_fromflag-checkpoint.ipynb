# %%
import pandas as pd

infile='/Users/irffanalahi/rest_summer_2019/support/Healthy-PBMC-WGBS/Healthy-PBMC-WGBS_bam_flag_merged.txt'

indf=pd.read_csv(infile,sep="\t")
indf.head()
# Out:
#                                    sample      total  secondary  \
# 0  healthy_NU-51-bulk-PBMC.final.bam_flag  669472755    5276527
# 1  healthy_NU-50-bulk-PBMC.final.bam_flag  666531356    5072627
# 2  healthy_NU-24-bulk-PBMC.final.bam_flag  670365373    5657129
# 3  healthy_NU-03-bulk-PBMC.final.bam_flag  669688566    5290646
# 4  healthy_NU-49-bulk-PBMC.final.bam_flag  668919338    4980201
#
#    supplementary  duplicates     mapped  mapped_percent  paired_in_sequencing  \
# 0        8914802   106586214  665938776       99.472125             655281426
# 1        8160611   105267304  664003968       99.620815             653298118
# 2        9160154    99252471  666416954       99.411005             655548090
# 3        8273990   106458023  666449109       99.516274             656123930
# 4        7534815   110358016  663899976       99.249631             656404322
#
#        read1      read2  properly_paired  properly_paired_percentage  \
# ...

# %%
indf['Total_fragment']=indf['properly_paired']/2

# %%
indf.head()
# Out:
#                                    sample      total  secondary  \
# 0  healthy_NU-51-bulk-PBMC.final.bam_flag  669472755    5276527
# 1  healthy_NU-50-bulk-PBMC.final.bam_flag  666531356    5072627
# 2  healthy_NU-24-bulk-PBMC.final.bam_flag  670365373    5657129
# 3  healthy_NU-03-bulk-PBMC.final.bam_flag  669688566    5290646
# 4  healthy_NU-49-bulk-PBMC.final.bam_flag  668919338    4980201
#
#    supplementary  duplicates     mapped  mapped_percent  paired_in_sequencing  \
# 0        8914802   106586214  665938776       99.472125             655281426
# 1        8160611   105267304  664003968       99.620815             653298118
# 2        9160154    99252471  666416954       99.411005             655548090
# 3        8273990   106458023  666449109       99.516274             656123930
# 4        7534815   110358016  663899976       99.249631             656404322
#
#        read1      read2  properly_paired  properly_paired_percentage  \
# ...

# %%
indf.rename(columns={"sample": "Mixture"})

# %%
outdf=
