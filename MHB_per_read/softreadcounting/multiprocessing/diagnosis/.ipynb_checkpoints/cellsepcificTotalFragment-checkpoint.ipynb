#
# [5 rows x 34 columns]

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'NotAssigned', 'PC-others', 'TIL-others'}

# %%
len(set(indf['deltabasedfragassignment'].tolist()))
# Out:
# 3

# %%
allassigned=indf.copy()

# %%
allassigned.loc[indf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=allassigned.loc[indf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
set(allassigned['deltabasedfragassignment'].tolist())
# Out:
# {'PC-others', 'TIL-others'}

# %%
len(set(allassigned['deltabasedfragassignment'].tolist()))
# Out:
# 2

# %%
def calctfrag(fgrouped,fname):
    ctfragdict= defaultdict(list)
    for score in scorecolumns:
        tmpdf=fgrouped[fgrouped['deltabasedfragassignment']==score]
        
        ctname=score.replace('-others','')
        ctfragdict[ctname].append(tmpdf.shape[0])
    
    ctfragdf=pd.DataFrame.from_dict(ctfragdict) 
    ctfragdf['Mixture']=fname
    
    return ctfragdf

# %%
filegrouped=allassigned.groupby('filename')

totalfragdictlist=[]

for name, group in filegrouped:
    totalfragdictlist.append(calctfrag(group,name))

# %%
totalfragdictlistDF=pd.concat(totalfragdictlist)
totalfragdictlistDF.set_index('Mixture',inplace=True)

# %%
totalfragdictlistDF.head()
# Out:
#                                                     NaiveCD4  NaiveCD8  nB  \
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0         0   0
# Y-3685-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0         0   0
# Y-3688-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0         0   0
# Y-3694-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0         0   0
# Y-3703-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0         0   0
#
#                                                     NK  PC  Mono  M0  M1  M2  \
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...   0   1     0   0   0   0
# Y-3685-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...   0   2     0   0   0   0
# Y-3688-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...   0  12     0   0   0   0
# Y-3694-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...   0   1     0   0   0   0
# Y-3703-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...   0   1     0   0   0   0
#
#                                                     iDC  ...  Eo  Tregs  em4  \
# Mixture                                                  ...
# Y-3674-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0  ...   0      0    0
# Y-3685-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0  ...   0      0    0
# Y-3688-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0  ...   0      0    0
# Y-3694-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0  ...   0      0    0
# Y-3703-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0  ...   0      0    0
#
#                                                     ed8  Mg  cm4  Er  mB  TIL  \
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0   0    0   0   0    9
# Y-3685-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0   0    0   0   0    4
# Y-3688-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0   0    0   0   0   13
# Y-3694-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0   0    0   0   0    6
# Y-3703-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...    0   0    0   0   0    6
#
#                                                     MelTumor
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0
# Y-3685-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0
# Y-3688-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0
# Y-3694-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0
# Y-3703-cfDNA_sorted_onlyregionIN_PBLtilMel_meld...         0
#
# [5 rows x 24 columns]

# %%
totalfragdictlistDF.to_csv(infile+"_ctTotalFrag.txt",sep="\t")

# %%
print('done')
# Out:
# done
