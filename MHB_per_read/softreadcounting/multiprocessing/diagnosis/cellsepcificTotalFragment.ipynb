# %%
import pandas as pd
from collections import defaultdict

infile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/irAE/forcorr/deconprepare/CSxout/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkl'


####BL22#####
scorecolumns=['NaiveCD4-others','NaiveCD8-others','nB-others','NK-others','PC-others','Mono-others','M0-others','M1-others','M2-others','iDC-others','mDC-others','PMN-others','cm8-others','em8-others','Eo-others','Tregs-others','em4-others','ed8-others','Mg-others','cm4-others','Er-others','mB-others']



indf=pd.read_pickle(infile)

indf.head()
# Out:
#                                          NaiveCD4-others  NaiveCD8-others  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179         -0.105421        -0.018119
# A00354:161:HVKCVDSXX:1:1113:25816:23688        -0.071511        -0.046368
# A00354:161:HVKCVDSXX:1:1127:10926:22232        -0.273468        -0.279754
# A00354:161:HVKCVDSXX:1:1129:7075:28651          0.771730        -0.022365
# A00354:161:HVKCVDSXX:1:1131:13593:3176         -0.075905        -0.021079
#
#                                          nB-others  NK-others  PC-others  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179   -0.067008   0.894357  -0.094944
# A00354:161:HVKCVDSXX:1:1113:25816:23688  -0.052421  -0.064643   0.204944
# A00354:161:HVKCVDSXX:1:1127:10926:22232  -0.246579  -0.258452   0.191675
# A00354:161:HVKCVDSXX:1:1129:7075:28651   -0.167286  -0.167984  -0.043317
# A00354:161:HVKCVDSXX:1:1131:13593:3176   -0.054952   0.889302   0.043524
#
#                                          Mono-others  M0-others  M1-others  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179     -0.039071  -0.034881  -0.085865
# A00354:161:HVKCVDSXX:1:1113:25816:23688    -0.044156   0.068172   0.041516
# A00354:161:HVKCVDSXX:1:1127:10926:22232     0.162690   0.748659   0.748310
# A00354:161:HVKCVDSXX:1:1129:7075:28651     -0.176365  -0.194524  -0.167286
# A00354:161:HVKCVDSXX:1:1131:13593:3176     -0.073111  -0.043429  -0.075556
#
#                                          M2-others  iDC-others  ...  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179    0.016802   -0.088135  ...
# A00354:161:HVKCVDSXX:1:1113:25816:23688   0.266056    0.132251  ...
# A00354:161:HVKCVDSXX:1:1127:10926:22232   0.485881    0.698024  ...
# A00354:161:HVKCVDSXX:1:1129:7075:28651   -0.162048   -0.099016  ...
# A00354:161:HVKCVDSXX:1:1131:13593:3176   -0.059841   -0.072063  ...
#
#                                          LENhypoCpG  LENhyperCpG  total_cpg  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179          1.0          0.0        1.0
# A00354:161:HVKCVDSXX:1:1113:25816:23688         1.0          2.0        3.0
# A00354:161:HVKCVDSXX:1:1127:10926:22232         1.0          0.0        1.0
# A00354:161:HVKCVDSXX:1:1129:7075:28651          1.0          0.0        1.0
# A00354:161:HVKCVDSXX:1:1131:13593:3176          1.0          0.0        1.0
#
#                                          LENhypoCpG_BY_total_cpg  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179                  1.000000
# A00354:161:HVKCVDSXX:1:1113:25816:23688                 0.333333
# A00354:161:HVKCVDSXX:1:1127:10926:22232                 1.000000
# A00354:161:HVKCVDSXX:1:1129:7075:28651                  1.000000
# A00354:161:HVKCVDSXX:1:1131:13593:3176                  1.000000
#
#                                          maxscoredCT_beforeCpGweight  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179                     NK-others
# A00354:161:HVKCVDSXX:1:1113:25816:23688                    M2-others
# A00354:161:HVKCVDSXX:1:1127:10926:22232                    M0-others
# A00354:161:HVKCVDSXX:1:1129:7075:28651               NaiveCD4-others
# A00354:161:HVKCVDSXX:1:1131:13593:3176                     NK-others
#
#                                          maxscore_beforeCpGweight  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179                   0.894357
# A00354:161:HVKCVDSXX:1:1113:25816:23688                  0.798167
# A00354:161:HVKCVDSXX:1:1127:10926:22232                  0.748659
# A00354:161:HVKCVDSXX:1:1129:7075:28651                   0.771730
# A00354:161:HVKCVDSXX:1:1131:13593:3176                   0.889302
#
#                                              maxscoredCT  maxscore  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179         NK-others  0.894357
# A00354:161:HVKCVDSXX:1:1113:25816:23688        M2-others  0.266056
# A00354:161:HVKCVDSXX:1:1127:10926:22232        M0-others  0.748659
# A00354:161:HVKCVDSXX:1:1129:7075:28651   NaiveCD4-others  0.771730
# A00354:161:HVKCVDSXX:1:1131:13593:3176         NK-others  0.889302
#
#                                          deltabasedfragassignment  \
# A00354:161:HVKCVDSXX:1:1104:2085:27179                  NK-others
# A00354:161:HVKCVDSXX:1:1113:25816:23688                 M2-others
# A00354:161:HVKCVDSXX:1:1127:10926:22232                 M0-others
# A00354:161:HVKCVDSXX:1:1129:7075:28651            NaiveCD4-others
# A00354:161:HVKCVDSXX:1:1131:13593:3176                  NK-others
#
#                                                                                   filename
# A00354:161:HVKCVDSXX:1:1104:2085:27179   Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom...
# A00354:161:HVKCVDSXX:1:1113:25816:23688  Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom...
# A00354:161:HVKCVDSXX:1:1127:10926:22232  Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom...
# A00354:161:HVKCVDSXX:1:1129:7075:28651   Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom...
# A00354:161:HVKCVDSXX:1:1131:13593:3176   Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom...
#
# [5 rows x 32 columns]

# %%
set(indf['deltabasedfragassignment'].tolist())
# Out:
# {'Eo-others',
#  'Er-others',
#  'M0-others',
#  'M1-others',
#  'M2-others',
#  'Mg-others',
#  'Mono-others',
#  'NK-others',
#  'NaiveCD4-others',
#  'NaiveCD8-others',
#  'NotAssigned',
#  'PC-others',
#  'PMN-others',
#  'Tregs-others',
#  'cm4-others',
#  'cm8-others',
#  'ed8-others',
#  'em4-others',
#  'em8-others',
#  'iDC-others',
#  'mB-others',
#  'mDC-others',
#  'nB-others'}

# %%
len(set(indf['deltabasedfragassignment'].tolist()))
# Out:
# 23

# %%
allassigned=indf.copy()

# %%
allassigned.loc[indf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=allassigned.loc[indf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
set(allassigned['deltabasedfragassignment'].tolist())
# Out:
# {'Eo-others',
#  'Er-others',
#  'M0-others',
#  'M1-others',
#  'M2-others',
#  'Mg-others',
#  'Mono-others',
#  'NK-others',
#  'NaiveCD4-others',
#  'NaiveCD8-others',
#  'PC-others',
#  'PMN-others',
#  'Tregs-others',
#  'cm4-others',
#  'cm8-others',
#  'ed8-others',
#  'em4-others',
#  'em8-others',
#  'iDC-others',
#  'mB-others',
#  'mDC-others',
#  'nB-others'}

# %%
len(set(allassigned['deltabasedfragassignment'].tolist()))
# Out:
# 22

# %%
def calctfrag(fgrouped,fname):
    ctfragdict= defaultdict(list)
    for score in scorecolumns:
        tmpdf=fgrouped[fgrouped['deltabasedfragassignment']==score]
        
        ctname=score.replace('-others','')
        ctfragdict[ctname].append(tmpdf.shape[0])
    
    ctfragdf=pd.DataFrame.from_dict(ctfragdict) 
    ctfragdf['Mixture']=fname
    
    return ctfragdf

# %%
filegrouped=allassigned.groupby('filename')

totalfragdictlist=[]

for name, group in filegrouped:
    totalfragdictlist.append(calctfrag(group,name))

# %%
totalfragdictlistDF=pd.concat(totalfragdictlist)
totalfragdictlistDF.set_index('Mixture',inplace=True)

# %%
totalfragdictlistDF.head()
# Out:
#                                                     NaiveCD4  NaiveCD8   nB  \
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_BL22_geneprom_...       321        58   75
# Y-3685-cfDNA_sorted_onlyregionIN_BL22_geneprom_...       552       125  127
# Y-3688-cfDNA_sorted_onlyregionIN_BL22_geneprom_...       594        97  132
# Y-3694-cfDNA_sorted_onlyregionIN_BL22_geneprom_...       641       126  123
# Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom_...       432        72   91
#
#                                                      NK   PC  Mono   M0   M1  \
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  337   50   156  367  107
# Y-3685-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  529  116   264  618  149
# Y-3688-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  561  119   324  645  178
# Y-3694-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  659  103   316  669  185
# Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  386   76   216  458  120
#
#                                                      M2  iDC  ...  cm8  em8  \
# Mixture                                                       ...
# Y-3674-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  334  192  ...   68   30
# Y-3685-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  539  274  ...  112   65
# Y-3688-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  548  305  ...  154   67
# Y-3694-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  662  358  ...  119   60
# Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  402  201  ...  115   35
#
#                                                      Eo  Tregs  em4  ed8   Mg  \
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_BL22_geneprom_...   87     71   31   31   78
# Y-3685-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  143     97   41   44  133
# Y-3688-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  185     89   51   71  131
# Y-3694-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  158     89   51   65  156
# Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom_...  121     54   45   49  100
#
#                                                     cm4   Er   mB
# Mixture
# Y-3674-cfDNA_sorted_onlyregionIN_BL22_geneprom_...   50  160   60
# Y-3685-cfDNA_sorted_onlyregionIN_BL22_geneprom_...   80  263   93
# Y-3688-cfDNA_sorted_onlyregionIN_BL22_geneprom_...   84  260   90
# Y-3694-cfDNA_sorted_onlyregionIN_BL22_geneprom_...   94  316  109
# Y-3703-cfDNA_sorted_onlyregionIN_BL22_geneprom_...   50  190   68
#
# [5 rows x 22 columns]

# %%
totalfragdictlistDF.to_csv(infile+"_ctTotalFrag.txt",sep="\t")

# %%
print('done')
# Out:
# done
