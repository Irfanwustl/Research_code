# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import sys

infile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/BL22/moreSM/Thebestref/BL22_genepromSM_0.7.txt'



bestreffile='/Users/irffanalahi/Research/Research_update/SoftRD/hashtable_stats/BL22/moreSM/Thebestref/SM_BL22Testmixture_output_mdadded_sorted_globalout_binnedstats.pkl__dupindex_binnedstats.pkl_AllhyperTrue_AUC.txtadjustedScore_minus_avg.txt_TOselectbestREF.txt'

bestreffileDF=pd.read_csv(bestreffile,sep="\t",index_col=0)


outfile=infile
indf=pd.read_csv(infile,sep="\t",index_col=['chrom','start'])


indf.head()
# Out:
#                  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr6  37356861          0.146444         0.008159   0.145048  -0.834825
# chr3  53572908          0.091024         0.062040   0.103595   0.032706
# chr2  11600694          0.115452         0.113008   0.091008   0.116151
# chr11 2310163           0.086937         0.090778   0.082746   0.024429
# chr2  141239094         0.178730         0.144857   0.211206   0.117270
#
#                  PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr6  37356861   -0.045270     0.190095   0.143651   0.159365   0.190095
# chr3  53572908   -0.870690     0.104294   0.111976   0.050865   0.086135
# chr2  11600694   -0.708675     0.106024   0.049103   0.165389   0.104627
# chr11 2310163    -0.848238     0.091825   0.042587   0.092175   0.048524
# chr2  141239094  -0.725016     0.060000   0.141714   0.088635   0.056508
#
# ...

# %%
bestreffileDF.head()
# Out:
#            MaxAUCCpG
# Celltype
# Eo-others         50
# Er-others        100
# M0-others         35
# M1-others        100
# M2-others         30

# %%
bestref=bestreffileDF.to_dict()
bestref=bestref['MaxAUCCpG']
bestref
# Out:
# {'Eo-others': 50,
#  'Er-others': 100,
#  'M0-others': 35,
#  'M1-others': 100,
#  'M2-others': 30,
#  'Mg-others': 50,
#  'Mono-others': 25,
#  'NK-others': 35,
#  'NaiveCD4-others': 35,
#  'NaiveCD8-others': 50,
#  'PC-others': 100,
#  'PMN-others': 35,
#  'Tregs-others': 40,
#  'cm4-others': 100,
#  'cm8-others': 50,
#  'ed8-others': 25,
#  'em4-others': 25,
#  'em8-others': 45,
#  'iDC-others': 30,
#  'mB-others': 50,
#  'mDC-others': 45,
#  'nB-others': 200}

# %%
sum(bestref.values())
# Out:
# 1255

# %%
len(bestref)
# Out:
# 22

# %%
allctscorename=indf.columns

# %%
indf['minscore']=indf[allctscorename].min(axis=1)
indf.head()
# Out:
#                  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr6  37356861          0.146444         0.008159   0.145048  -0.834825
# chr3  53572908          0.091024         0.062040   0.103595   0.032706
# chr2  11600694          0.115452         0.113008   0.091008   0.116151
# chr11 2310163           0.086937         0.090778   0.082746   0.024429
# chr2  141239094         0.178730         0.144857   0.211206   0.117270
#
#                  PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr6  37356861   -0.045270     0.190095   0.143651   0.159365   0.190095
# chr3  53572908   -0.870690     0.104294   0.111976   0.050865   0.086135
# chr2  11600694   -0.708675     0.106024   0.049103   0.165389   0.104627
# chr11 2310163    -0.848238     0.091825   0.042587   0.092175   0.048524
# chr2  141239094  -0.725016     0.060000   0.141714   0.088635   0.056508
#
# ...

# %%
indf['minscoredCT']=(indf[allctscorename]).idxmin(axis=1)
indf.head()
# Out:
#                  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr6  37356861          0.146444         0.008159   0.145048  -0.834825
# chr3  53572908          0.091024         0.062040   0.103595   0.032706
# chr2  11600694          0.115452         0.113008   0.091008   0.116151
# chr11 2310163           0.086937         0.090778   0.082746   0.024429
# chr2  141239094         0.178730         0.144857   0.211206   0.117270
#
#                  PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr6  37356861   -0.045270     0.190095   0.143651   0.159365   0.190095
# chr3  53572908   -0.870690     0.104294   0.111976   0.050865   0.086135
# chr2  11600694   -0.708675     0.106024   0.049103   0.165389   0.104627
# chr11 2310163    -0.848238     0.091825   0.042587   0.092175   0.048524
# chr2  141239094  -0.725016     0.060000   0.141714   0.088635   0.056508
#
# ...

# %%
sorteddf=indf.sort_values(by=['minscore'])
sorteddf.head()
# Out:
#                  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr16 6767869           0.067921        -0.001921   0.067921   0.067921
# chr12 30645811          0.071008         0.051452   0.037833   0.050056
# chr3  48773066          0.023151         0.045151   0.054929   0.051786
# chr6  158122238         0.002214         0.025611   0.062976   0.052500
# chr18 6987775           0.075294         0.075294   0.054690   0.046310
#
#                  PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr16 6767869    -0.979698    -0.001921   0.067921  -0.009603   0.067921
# chr12 30645811   -0.976611     0.055643   0.071008   0.058437   0.041325
# chr3  48773066    0.065754     0.032929   0.071690   0.030833   0.046897
# chr6  158122238   0.058087     0.023167   0.072056   0.072056   0.048659
# chr18 6987775    -0.972325     0.057833   0.075294   0.026056   0.004056
#
# ...

# %%
groupedct=sorteddf.groupby('minscoredCT')


tempsmlist=[]
for name, group in groupedct:
   
    tempdf=group.head(n=bestref[name])
    
    
    tempout=tempdf.drop(['minscoredCT','minscore'],axis=1)
    
    tempsmlist.append(tempout)

# %%
outdf=pd.concat(tempsmlist)

outdf.head()
# Out:
#                  NaiveCD4-others  NaiveCD8-others  nB-others  NK-others  \
# chrom start
# chr3  48773066          0.023151         0.045151   0.054929   0.051786
#       138232377         0.017310         0.042103   0.071786   0.080865
# chr12 76769087          0.070095         0.011778   0.039714   0.058222
# chr8  23158892          0.073817         0.021087   0.082897   0.058103
# chr5  5463864           0.051214         0.011754   0.031659   0.062040
#
#                  PC-others  Mono-others  M0-others  M1-others  M2-others  \
# chrom start
# chr3  48773066    0.065754     0.032929   0.071690   0.030833   0.046897
#       138232377  -0.010627     0.080865   0.080865   0.002643   0.080865
# chr12 76769087    0.070095     0.046349   0.070095   0.028190   0.034825
# chr8  23158892    0.030865     0.056357   0.068929   0.011310   0.005373
# chr5  5463864     0.047024     0.031310   0.045627   0.019437   0.026770
#
# ...

# %%
outdf.shape
# Out:
# (1193, 22)

# %%
outdf.to_csv(outfile+"_bestref.txt",sep="\t")
