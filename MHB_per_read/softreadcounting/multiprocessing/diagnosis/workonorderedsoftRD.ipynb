# %%
import pandas as pd
import glob
import os
import time
import sys

orderedsoftRC='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/genepromdelta.7/combine_all_refperformance/SM2_CD4geneprom.7mixture_output_mdadded_sorted_globalout_binnedstats.pkl_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txtadjustedScore_minus_avg_ordered.txt'

orderedsoftRCDF=pd.read_csv(orderedsoftRC,sep="\t",index_col=0)

orderedsoftRCDF.head()
# Out:
#           BL14_genepromSM_0.7.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# CD4                                                0.792599
# CD8                                                0.810298
# DC                                                 0.875529
# Eo                                                 0.915749
# Er                                                 0.912750
#
#           BL14_genepromSM_0.7.txt_g_25.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# CD4                                                0.743998
# CD8                                                0.982507
# DC                                                 0.930944
# Eo                                                 0.986450
# Er                                                 0.919310
#
#           BL14_genepromSM_0.7.txt_g_30.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt  \
# Celltype
# ...

# %%
allcolumns=orderedsoftRCDF.columns
allcolumns
# Out:
# Index(['BL14_genepromSM_0.7.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_25.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_30.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_35.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_40.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_45.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_50.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_100.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_200.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt',
#        'BL14_genepromSM_0.7.txt_g_300.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt'],
# ...

# %%
orderedsoftRCDFrenamed=orderedsoftRCDF.rename(columns={'BL14_genepromSM_0.7.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'Delta>=0.7','BL14_genepromSM_0.7.txt_g_25.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top25CpG','BL14_genepromSM_0.7.txt_g_30.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top30CpG','BL14_genepromSM_0.7.txt_g_35.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top35CpG','BL14_genepromSM_0.7.txt_g_40.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top40CpG','BL14_genepromSM_0.7.txt_g_45.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top45CpG','BL14_genepromSM_0.7.txt_g_50.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top50CpG','BL14_genepromSM_0.7.txt_g_100.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top100CpG','BL14_genepromSM_0.7.txt_g_200.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top200CpG','BL14_genepromSM_0.7.txt_g_300.txt_result_nodupindex_binnedstats.pkl_AllhyperTrue_AUC.txt':'top300CpG'})

# %%
orderedsoftRCDFrenamed.head()
# Out:
#           Delta>=0.7  top25CpG  top30CpG  top35CpG  top40CpG  top45CpG  \
# Celltype
# CD4         0.792599  0.743998  0.758274  0.755619  0.769206  0.755749
# CD8         0.810298  0.982507  0.978982  0.981203  0.966667  0.967311
# DC          0.875529  0.930944  0.939874  0.907625  0.905143  0.905872
# Eo          0.915749  0.986450  0.983100  0.976174  0.977941  0.984689
# Er          0.912750  0.919310  0.925810  0.929087  0.931057  0.939938
#
#           top50CpG  top100CpG  top200CpG  top300CpG
# Celltype
# CD4       0.748607   0.763747   0.769244   0.779656
# CD8       0.976219   0.831490   0.782200   0.802693
# DC        0.914530   0.925582   0.916607   0.926480
# Eo        0.985545   0.982965   0.969877   0.965265
# Er        0.941865   0.960716   0.946019   0.947610

# %%
orderedsoftRCDFrenamed=orderedsoftRCDFrenamed[['top25CpG','top30CpG','top35CpG','top40CpG','top45CpG','top50CpG','top100CpG','top200CpG','top300CpG','Delta>=0.7']]

# %%
orderedsoftRCDFrenamed['MaxAUC']=orderedsoftRCDFrenamed.max(axis=1)
orderedsoftRCDFrenamed.head()
# Out:
#           top25CpG  top30CpG  top35CpG  top40CpG  top45CpG  top50CpG  \
# Celltype
# CD4       0.743998  0.758274  0.755619  0.769206  0.755749  0.748607
# CD8       0.982507  0.978982  0.981203  0.966667  0.967311  0.976219
# DC        0.930944  0.939874  0.907625  0.905143  0.905872  0.914530
# Eo        0.986450  0.983100  0.976174  0.977941  0.984689  0.985545
# Er        0.919310  0.925810  0.929087  0.931057  0.939938  0.941865
#
#           top100CpG  top200CpG  top300CpG  Delta>=0.7    MaxAUC
# Celltype
# CD4        0.763747   0.769244   0.779656    0.792599  0.792599
# CD8        0.831490   0.782200   0.802693    0.810298  0.982507
# DC         0.925582   0.916607   0.926480    0.875529  0.939874
# Eo         0.982965   0.969877   0.965265    0.915749  0.986450
# Er         0.960716   0.946019   0.947610    0.912750  0.960716

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.heatmap(orderedsoftRCDFrenamed, annot=True,cmap='viridis')

# %%
orderedsoftRCDFrenamed['MaxAUCCpG']=orderedsoftRCDFrenamed.idxmax(axis=1)
orderedsoftRCDFrenamed.to_csv(orderedsoftRC+"_bestREF.txt",sep="\t")
