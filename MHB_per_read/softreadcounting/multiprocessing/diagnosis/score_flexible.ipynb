# %%
import pandas as pd
import pandas as pd
from collections import defaultdict
from sklearn import metrics
import numpy as np
import sys
import time

start_time = time.time()

inbinfile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/genepromdelta.7/defaultsm/CD4geneprom.7mixture_output_mdadded_sorted_softMultiprocessing_binnedstats.pkl'

outfile=inbinfile


consideringALLheyper=True


inbindf=pd.read_pickle(inbinfile)
scorecolumns=['CD4-others','CD8-others','nB-others','NK-others','Mn-others','mNeu-others','m8-others','DC-others','Eo-others','Tr-others','m4-others','Mg-others','Er-others','mB-others']

inbindf=inbindf.reset_index()
inbindf.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:12586:47155#12   -0.023748   -0.048996
# 1   CD4.HWI-7001432L_73:1:1101:7312:57779#12   -0.040654   -0.263936
# 2  CD4.HWI-7001432L_73:1:1103:11709:12437#12   -0.029073   -0.030628
# 3   CD4.HWI-7001432L_73:1:1103:4514:10093#12   -0.228564   -0.164667
# 4  CD4.HWI-7001432L_73:1:1104:11479:62999#12   -0.055462   -0.054564
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.048996  -0.027338  -0.042415    -0.013697  -0.031226  -0.038705
# 1  -0.677833  -0.111372  -0.679628    -0.544654   0.212603  -0.562244
# 2  -0.009927  -0.045226  -0.063534    -0.047261   0.017774  -0.060303
# 3  -0.265897  -0.125897  -0.160718    -0.004923  -0.097359  -0.186923
# 4  -0.053308  -0.042359   0.013103     0.360051  -0.067577  -0.013103
#
#    Eo-others  ...  LENhypoCpG  LENhyperCpG  total_cpg  \
# 0   0.235850  ...         1.0          2.0        3.0
# 1   4.233295  ...         5.0          0.0        5.0
# 2  -0.017406  ...         1.0          2.0        3.0
# 3   0.721103  ...         1.0          0.0        1.0
# 4   0.148885  ...         1.0          1.0        2.0
#
#    LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0                 0.333333                    Eo-others
# 1                 1.000000                    Eo-others
# 2                 0.333333                    mB-others
# 3                 1.000000                    Eo-others
# 4                 0.500000                  mNeu-others
#
#    maxscore_beforeCpGweight  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0                  0.707551    Eo-others  0.235850                 Eo-others
# 1                  4.233295    Eo-others  4.233295                 Eo-others
# 2                  0.837859    mB-others  0.279286                 mB-others
# 3                  0.721103    Eo-others  0.721103                 Eo-others
# 4                  0.720103  mNeu-others  0.360051               mNeu-others
#
#                                             filename
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
#
# [5 rows x 25 columns]

# %%
if consideringALLheyper==True:
    allassigned=inbindf.copy()


elif consideringALLheyper==False:
    allassigned=inbindf[inbindf['deltabasedfragassignment']!='NotAssigned'].copy()
    
else:
    print("wrong input")
    sys.exit(1)
#
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:12586:47155#12   -0.023748   -0.048996
# 1   CD4.HWI-7001432L_73:1:1101:7312:57779#12   -0.040654   -0.263936
# 2  CD4.HWI-7001432L_73:1:1103:11709:12437#12   -0.029073   -0.030628
# 3   CD4.HWI-7001432L_73:1:1103:4514:10093#12   -0.228564   -0.164667
# 4  CD4.HWI-7001432L_73:1:1104:11479:62999#12   -0.055462   -0.054564
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.048996  -0.027338  -0.042415    -0.013697  -0.031226  -0.038705
# 1  -0.677833  -0.111372  -0.679628    -0.544654   0.212603  -0.562244
# 2  -0.009927  -0.045226  -0.063534    -0.047261   0.017774  -0.060303
# 3  -0.265897  -0.125897  -0.160718    -0.004923  -0.097359  -0.186923
# 4  -0.053308  -0.042359   0.013103     0.360051  -0.067577  -0.013103
#
#    Eo-others  ...  LENhypoCpG  LENhyperCpG  total_cpg  \
# 0   0.235850  ...         1.0          2.0        3.0
# 1   4.233295  ...         5.0          0.0        5.0
# 2  -0.017406  ...         1.0          2.0        3.0
# 3   0.721103  ...         1.0          0.0        1.0
# 4   0.148885  ...         1.0          1.0        2.0
#
#    LENhypoCpG_BY_total_cpg  maxscoredCT_beforeCpGweight  \
# 0                 0.333333                    Eo-others
# 1                 1.000000                    Eo-others
# 2                 0.333333                    mB-others
# 3                 1.000000                    Eo-others
# 4                 0.500000                  mNeu-others
#
#    maxscore_beforeCpGweight  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0                  0.707551    Eo-others  0.235850                 Eo-others
# 1                  4.233295    Eo-others  4.233295                 Eo-others
# 2                  0.837859    mB-others  0.279286                 mB-others
# 3                  0.721103    Eo-others  0.721103                 Eo-others
# 4                  0.720103  mNeu-others  0.360051               mNeu-others
#
#                                             filename
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...
#
# [5 rows x 25 columns]

# %%
allassigned.loc[inbindf['deltabasedfragassignment']=='NotAssigned','deltabasedfragassignment']=allassigned.loc[inbindf['deltabasedfragassignment']=='NotAssigned','maxscoredCT_beforeCpGweight']

# %%
allassigned['secondmaxScore']='Notassigned'
allassigned['secondmaxScoreCT']='Notassigned'
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:12586:47155#12   -0.023748   -0.048996
# 1   CD4.HWI-7001432L_73:1:1101:7312:57779#12   -0.040654   -0.263936
# 2  CD4.HWI-7001432L_73:1:1103:11709:12437#12   -0.029073   -0.030628
# 3   CD4.HWI-7001432L_73:1:1103:4514:10093#12   -0.228564   -0.164667
# 4  CD4.HWI-7001432L_73:1:1104:11479:62999#12   -0.055462   -0.054564
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.048996  -0.027338  -0.042415    -0.013697  -0.031226  -0.038705
# 1  -0.677833  -0.111372  -0.679628    -0.544654   0.212603  -0.562244
# 2  -0.009927  -0.045226  -0.063534    -0.047261   0.017774  -0.060303
# 3  -0.265897  -0.125897  -0.160718    -0.004923  -0.097359  -0.186923
# 4  -0.053308  -0.042359   0.013103     0.360051  -0.067577  -0.013103
#
#    Eo-others  ...  total_cpg  LENhypoCpG_BY_total_cpg  \
# 0   0.235850  ...        3.0                 0.333333
# 1   4.233295  ...        5.0                 1.000000
# 2  -0.017406  ...        3.0                 0.333333
# 3   0.721103  ...        1.0                 1.000000
# 4   0.148885  ...        2.0                 0.500000
#
#    maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  maxscoredCT  \
# 0                    Eo-others                  0.707551    Eo-others
# 1                    Eo-others                  4.233295    Eo-others
# 2                    mB-others                  0.837859    mB-others
# 3                    Eo-others                  0.721103    Eo-others
# 4                  mNeu-others                  0.720103  mNeu-others
#
#    maxscore  deltabasedfragassignment  \
# 0  0.235850                 Eo-others
# 1  4.233295                 Eo-others
# 2  0.279286                 mB-others
# 3  0.721103                 Eo-others
# 4  0.360051               mNeu-others
#
#                                             filename  secondmaxScore  \
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...     Notassigned
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...     Notassigned
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...     Notassigned
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...     Notassigned
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...     Notassigned
#
#   secondmaxScoreCT
# 0      Notassigned
# 1      Notassigned
# 2      Notassigned
# 3      Notassigned
# 4      Notassigned
#
# [5 rows x 27 columns]

# %%
grouped=allassigned.groupby('maxscoredCT')

for name, group in grouped:
    
    
    tempscorecolumns=scorecolumns.copy()
    
    tempscorecolumns.remove(name)
    
    allassigned.loc[group.index,'secondmaxScore']=group[tempscorecolumns].max(axis=1)
    allassigned.loc[group.index,'secondmaxScoreCT']=(group[tempscorecolumns]).idxmax(axis=1)

# %%
allassigned['adjustedScore_minus']=allassigned['maxscore']-allassigned['secondmaxScore']
allassigned['adjustedScore_minus_avg']=(allassigned['maxscore']+(allassigned['maxscore']-allassigned['secondmaxScore']))/2
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:12586:47155#12   -0.023748   -0.048996
# 1   CD4.HWI-7001432L_73:1:1101:7312:57779#12   -0.040654   -0.263936
# 2  CD4.HWI-7001432L_73:1:1103:11709:12437#12   -0.029073   -0.030628
# 3   CD4.HWI-7001432L_73:1:1103:4514:10093#12   -0.228564   -0.164667
# 4  CD4.HWI-7001432L_73:1:1104:11479:62999#12   -0.055462   -0.054564
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.048996  -0.027338  -0.042415    -0.013697  -0.031226  -0.038705
# 1  -0.677833  -0.111372  -0.679628    -0.544654   0.212603  -0.562244
# 2  -0.009927  -0.045226  -0.063534    -0.047261   0.017774  -0.060303
# 3  -0.265897  -0.125897  -0.160718    -0.004923  -0.097359  -0.186923
# 4  -0.053308  -0.042359   0.013103     0.360051  -0.067577  -0.013103
#
#    Eo-others  ...  maxscoredCT_beforeCpGweight  maxscore_beforeCpGweight  \
# 0   0.235850  ...                    Eo-others                  0.707551
# 1   4.233295  ...                    Eo-others                  4.233295
# 2  -0.017406  ...                    mB-others                  0.837859
# 3   0.721103  ...                    Eo-others                  0.721103
# 4   0.148885  ...                  mNeu-others                  0.720103
#
#    maxscoredCT  maxscore  deltabasedfragassignment  \
# 0    Eo-others  0.235850                 Eo-others
# 1    Eo-others  4.233295                 Eo-others
# 2    mB-others  0.279286                 mB-others
# 3    Eo-others  0.721103                 Eo-others
# 4  mNeu-others  0.360051               mNeu-others
#
#                                             filename  secondmaxScore  \
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...       0.0771838
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...        0.212603
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...       0.0658761
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...        0.695795
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...        0.148885
#
#    secondmaxScoreCT  adjustedScore_minus adjustedScore_minus_avg
# 0         Er-others             0.158667                0.197259
# 1         m8-others              4.02069                 4.12699
# 2         Tr-others              0.21341                0.246348
# 3         Er-others            0.0253077                0.373205
# 4         Eo-others             0.211167                0.285609
#
# [5 rows x 29 columns]

# %%
allassigned.columns
# Out:
# Index(['index', 'CD4-others', 'CD8-others', 'nB-others', 'NK-others',
#        'Mn-others', 'mNeu-others', 'm8-others', 'DC-others', 'Eo-others',
#        'Tr-others', 'm4-others', 'Mg-others', 'Er-others', 'mB-others',
#        'LENhypoCpG', 'LENhyperCpG', 'total_cpg', 'LENhypoCpG_BY_total_cpg',
#        'maxscoredCT_beforeCpGweight', 'maxscore_beforeCpGweight',
#        'maxscoredCT', 'maxscore', 'deltabasedfragassignment', 'filename',
#        'secondmaxScore', 'secondmaxScoreCT', 'adjustedScore_minus',
#        'adjustedScore_minus_avg'],
#       dtype='object')

# %%
adjustedScore_minus0val=list(set(allassigned[allassigned['LENhypoCpG_BY_total_cpg']==0]['adjustedScore_minus'].tolist()))
if len(adjustedScore_minus0val)==0:
    pass
elif len(adjustedScore_minus0val)!=1 or adjustedScore_minus0val[0]!=0:
    print(adjustedScore_minus0val)
    sys.exit(1)

# %%
adjustedScore_minus_avg0val=list(set(allassigned[allassigned['LENhypoCpG_BY_total_cpg']==0]['adjustedScore_minus_avg'].tolist()))


if len(adjustedScore_minus_avg0val)==0:
    pass

elif len(adjustedScore_minus_avg0val)!=1 or adjustedScore_minus_avg0val[0]!=0:
    print(adjustedScore_minus_avg0val)
    sys.exit(1)

# %%
allassigned['LENhypoCpG_0.8']=0
allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.8,'LENhypoCpG_0.8']=allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.8,'LENhypoCpG']

# %%
allassigned['LENhypoCpG_0.5']=0
allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.5,'LENhypoCpG_0.5']=allassigned.loc[allassigned['LENhypoCpG_BY_total_cpg']>=0.5,'LENhypoCpG']

# %%
allassigned.head()
# Out:
#                                        index  CD4-others  CD8-others  \
# 0  CD4.HWI-7001432L_73:1:1101:12586:47155#12   -0.023748   -0.048996
# 1   CD4.HWI-7001432L_73:1:1101:7312:57779#12   -0.040654   -0.263936
# 2  CD4.HWI-7001432L_73:1:1103:11709:12437#12   -0.029073   -0.030628
# 3   CD4.HWI-7001432L_73:1:1103:4514:10093#12   -0.228564   -0.164667
# 4  CD4.HWI-7001432L_73:1:1104:11479:62999#12   -0.055462   -0.054564
#
#    nB-others  NK-others  Mn-others  mNeu-others  m8-others  DC-others  \
# 0  -0.048996  -0.027338  -0.042415    -0.013697  -0.031226  -0.038705
# 1  -0.677833  -0.111372  -0.679628    -0.544654   0.212603  -0.562244
# 2  -0.009927  -0.045226  -0.063534    -0.047261   0.017774  -0.060303
# 3  -0.265897  -0.125897  -0.160718    -0.004923  -0.097359  -0.186923
# 4  -0.053308  -0.042359   0.013103     0.360051  -0.067577  -0.013103
#
#    Eo-others  ...  maxscoredCT  maxscore  deltabasedfragassignment  \
# 0   0.235850  ...    Eo-others  0.235850                 Eo-others
# 1   4.233295  ...    Eo-others  4.233295                 Eo-others
# 2  -0.017406  ...    mB-others  0.279286                 mB-others
# 3   0.721103  ...    Eo-others  0.721103                 Eo-others
# 4   0.148885  ...  mNeu-others  0.360051               mNeu-others
#
#                                             filename  secondmaxScore  \
# 0  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...       0.0771838
# 1  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...        0.212603
# 2  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...       0.0658761
# 3  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...        0.695795
# 4  CD4_fivemixgeneproNotpicard_NR_767146_insilmix...        0.148885
#
#    secondmaxScoreCT  adjustedScore_minus  adjustedScore_minus_avg  \
# 0         Er-others             0.158667                 0.197259
# 1         m8-others              4.02069                  4.12699
# 2         Tr-others              0.21341                 0.246348
# 3         Er-others            0.0253077                 0.373205
# 4         Eo-others             0.211167                 0.285609
#
#    LENhypoCpG_0.8 LENhypoCpG_0.5
# 0             0.0            0.0
# 1             5.0            5.0
# 2             0.0            0.0
# 3             1.0            1.0
# 4             0.0            1.0
#
# [5 rows x 31 columns]

# %%
def calposscore(fgrouped,whichmethod,fname):
    ctposscoredict= defaultdict(list)
    for score in scorecolumns:
        deltabasedfragassigned=fgrouped['deltabasedfragassignment'].tolist()
        if score in deltabasedfragassigned:
            temp_posscore=fgrouped.loc[fgrouped['deltabasedfragassignment']==score,whichmethod].tolist()
            temptotal_posscore=sum(temp_posscore)
            temp_posfrag=len(temp_posscore)

        else:
            temptotal_posscore=0
            temp_posfrag=0

        ctname=score.replace('-others','')

        ctposscoredict[ctname].append(temptotal_posscore)
    ctposscoredf=pd.DataFrame.from_dict(ctposscoredict)
    ctposscoredf['Mixture']=fname

   
    return ctposscoredf

# %%
filegrouped=allassigned.groupby('filename')

maxscorelist=[]
adjustedScore_minuslist=[]
adjustedScore_minus_avglist=[]

for name, group in filegrouped:
    maxscorelist.append(calposscore(group,'maxscore',name))
    adjustedScore_minuslist.append(calposscore(group,'adjustedScore_minus',name))
    adjustedScore_minus_avglist.append(calposscore(group,'adjustedScore_minus_avg',name))

# %%
maxscorelistDF=pd.concat(maxscorelist)
maxscorelistDF.set_index('Mixture',inplace=True)
adjustedScore_minuslistDF=pd.concat(adjustedScore_minuslist)
adjustedScore_minuslistDF.set_index('Mixture',inplace=True)
adjustedScore_minus_avglistDF=pd.concat(adjustedScore_minus_avglist)
adjustedScore_minus_avglistDF.set_index('Mixture',inplace=True)

# %%
maxscorelistDF.to_csv(outfile+'_maxscore_CSxOut.txt',sep="\t")
adjustedScore_minuslistDF.to_csv(outfile+'adjustedScore_minus_CSxOut.txt',sep="\t")
adjustedScore_minus_avglistDF.to_csv(outfile+'adjustedScore_minus_avg_CSxOut.txt',sep="\t")

# %%
end_time = time.time()

time_elapsed = (end_time - start_time)

print(time_elapsed)
# Out:
# 11.774690866470337
