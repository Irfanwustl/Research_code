# %%
import pandas as pd
import sys

totalctfragfile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/irAE/forcorr/deconprepare/CSxout/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkl_ctTotalFrag.txt'
deconfile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/BL22genepromdelta.7/Realdata/irAE/forcorr/deconprepare/CSxout/BL22_genepromSM_0.7.txt_TRAININGbestref.txt_result_dupindex_binnedstats.pkladjustedScore_minus_avg_CSxOut.txt'

totalctfragDF=pd.read_csv(totalctfragfile,sep="\t",index_col=0)

deconDF=pd.read_csv(deconfile,sep="\t",index_col=0)




totalctfragDF.head()
# Out:
#               NaiveCD4  NaiveCD8   nB   NK   PC  Mono   M0   M1   M2  iDC  \
# Mixture
# Y-3674-cfDNA       321        58   75  337   50   156  367  107  334  192
# Y-3685-cfDNA       552       125  127  529  116   264  618  149  539  274
# Y-3688-cfDNA       594        97  132  561  119   324  645  178  548  305
# Y-3694-cfDNA       641       126  123  659  103   316  669  185  662  358
# Y-3703-cfDNA       432        72   91  386   76   216  458  120  402  201
#
#               ...  cm8  em8   Eo  Tregs  em4  ed8   Mg  cm4   Er   mB
# Mixture       ...
# Y-3674-cfDNA  ...   68   30   87     71   31   31   78   50  160   60
# Y-3685-cfDNA  ...  112   65  143     97   41   44  133   80  263   93
# Y-3688-cfDNA  ...  154   67  185     89   51   71  131   84  260   90
# Y-3694-cfDNA  ...  119   60  158     89   51   65  156   94  316  109
# Y-3703-cfDNA  ...  115   35  121     54   45   49  100   50  190   68
#
# [5 rows x 22 columns]

# %%
deconDF.head()
# Out:
#                NaiveCD4  NaiveCD8        nB         NK         PC       Mono  \
# Mixture
# Y-3674-cfDNA  14.046855  1.428569  4.906048  28.868948   3.766972   8.224742
# Y-3685-cfDNA  25.256009  9.060086  2.958694  51.265135   5.195387  19.038555
# Y-3688-cfDNA  34.073107  4.525518  5.823139  44.991313   8.374567  18.814032
# Y-3694-cfDNA  27.675850  4.825263  3.801933  66.045949  13.359790  41.427655
# Y-3703-cfDNA  22.921827  3.080593  0.000000  38.445605   4.653028  18.847891
#
#                      M0         M1         M2        iDC  ...       cm8  \
# Mixture                                                   ...
# Y-3674-cfDNA  24.133302   4.371530  19.065400  12.423505  ...  2.262774
# Y-3685-cfDNA  36.640516   7.743638  33.367572  13.898431  ...  4.038438
# Y-3688-cfDNA  59.565152  18.716358  47.168294  24.267055  ...  8.375773
# Y-3694-cfDNA  55.720521  10.190548  56.407075  30.575203  ...  4.905306
# Y-3703-cfDNA  27.523441   3.777343  29.647725  10.169044  ...  4.924890
# ...

# %%
##must be same
if totalctfragDF.shape!=deconDF.shape:
    print("ERRORRR. Exitinig")
    sys.exit(1)

# %%
outdf=deconDF/totalctfragDF
outdf.head()
# Out:
#               NaiveCD4  NaiveCD8        nB        NK        PC      Mono  \
# Mixture
# Y-3674-cfDNA  0.043760  0.024630  0.065414  0.085665  0.075339  0.052723
# Y-3685-cfDNA  0.045754  0.072481  0.023297  0.096910  0.044788  0.072116
# Y-3688-cfDNA  0.057362  0.046655  0.044115  0.080198  0.070375  0.058068
# Y-3694-cfDNA  0.043176  0.038296  0.030910  0.100221  0.129707  0.131100
# Y-3703-cfDNA  0.053060  0.042786  0.000000  0.099600  0.061224  0.087259
#
#                     M0        M1        M2       iDC  ...       cm8       em8  \
# Mixture                                               ...
# Y-3674-cfDNA  0.065758  0.040855  0.057082  0.064706  ...  0.033276  0.002568
# Y-3685-cfDNA  0.059289  0.051971  0.061906  0.050724  ...  0.036057  0.033398
# Y-3688-cfDNA  0.092349  0.105148  0.086074  0.079564  ...  0.054388  0.030585
# Y-3694-cfDNA  0.083289  0.055084  0.085207  0.085406  ...  0.041221  0.038273
# ...

# %%
outdf.to_csv(deconfile+"_divbyCTFRAGNEEDtoRENAME.txt",sep="\t")

# %%
print('done')
# Out:
# done
