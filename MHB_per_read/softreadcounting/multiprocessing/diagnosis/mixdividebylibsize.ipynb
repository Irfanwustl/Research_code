# %%
import pandas as pd
libsizefile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/genepromdelta.7/REAL_samples/library_size_corrected/WG/Healthy-PBMC-WGBS_bam_flag_merged.txt_fragment.txt'
CSxfile='/Users/irffanalahi/Research/Research_update/SoftRD/largerEXP/genepromdelta.7/REAL_samples/library_size_corrected/WG/BL14_genepromSM_0.7.txtPBMC_bestref.txt_result_dupindex_binnedstats.pkl_totalformatteddata.pkl_7samplesRFprob10000trees_CSxOut.txt'

libsizeDF=pd.read_csv(libsizefile,sep="\t",index_col=0)
libsizeDF.head()
# Out:
#                          Total_fragment
# Mixture
# healthy_NU-51-bulk-PBMC     320846543.0
# healthy_NU-50-bulk-PBMC     320261082.0
# healthy_NU-24-bulk-PBMC     320066364.0
# healthy_NU-03-bulk-PBMC     320965983.0
# healthy_NU-49-bulk-PBMC     320214483.0

# %%
CSxDF=pd.read_csv(CSxfile,sep="\t",index_col=0)
CSxDF.head()
# Out:
#                                 CD4      CD8         nB       NK         Mn  \
# Mixture
# healthy_NU-03-bulk-PBMC  392.866594  22.9665  20.797162  19.3251  31.756029
# healthy_NU-14-bulk-PBMC  437.372309  26.1890  16.719135  24.1651  21.553827
# healthy_NU-24-bulk-PBMC  574.941194   8.4483  13.204540  15.2230  36.521884
# healthy_NU-31-bulk-PBMC  423.311841  17.1588  20.832980  23.0407  25.183634
# healthy_NU-49-bulk-PBMC  476.037024  19.6927  17.565661  18.3016  29.232320
#
#                               mNeu       m8         DC         Eo      Tr  \
# Mixture
# healthy_NU-03-bulk-PBMC  23.273406  49.1067  13.736219  11.131618  4.4531
# healthy_NU-14-bulk-PBMC  23.149435  24.6759  13.788762  12.820949  3.0371
# healthy_NU-24-bulk-PBMC  28.335423  40.8629  17.346775  11.846627  6.3279
# healthy_NU-31-bulk-PBMC  20.347255  26.7737  18.658341  10.542009  3.0836
# healthy_NU-49-bulk-PBMC  31.219645  33.3759  18.085062   6.562226  3.1436
#
# ...

# %%
CSxDFadjusted=CSxDF.div(libsizeDF['Total_fragment'], axis='index')
CSxDFadjusted.head()
# Out:
#                               CD4           CD8            nB            NK  \
# Mixture
# healthy_NU-03-bulk-PBMC  0.000001  7.155431e-08  6.479553e-08  6.020918e-08
# healthy_NU-14-bulk-PBMC  0.000001  8.223787e-08  5.250090e-08  7.588248e-08
# healthy_NU-24-bulk-PBMC  0.000002  2.639546e-08  4.125563e-08  4.756201e-08
# healthy_NU-31-bulk-PBMC  0.000001  5.331944e-08  6.473663e-08  7.159692e-08
# healthy_NU-49-bulk-PBMC  0.000001  6.149847e-08  5.485592e-08  5.715419e-08
#
#                                    Mn          mNeu            m8  \
# Mixture
# healthy_NU-03-bulk-PBMC  9.893893e-08  7.251051e-08  1.529966e-07
# healthy_NU-14-bulk-PBMC  6.768265e-08  7.269312e-08  7.748648e-08
# healthy_NU-24-bulk-PBMC  1.141072e-07  8.852984e-08  1.276701e-07
# healthy_NU-31-bulk-PBMC  7.825590e-08  6.322728e-08  8.319689e-08
# healthy_NU-49-bulk-PBMC  9.128981e-08  9.749604e-08  1.042298e-07
#
#                                    DC            Eo            Tr  \
# Mixture
# ...

# %%
CSxDFadjusted.to_csv(CSxfile+"_adjNEEDtoRENAME.txt",sep="\t")
