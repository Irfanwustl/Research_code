# %%
import pandas as pd
import glob
import os
import time
start_time = time.time()

infol='/Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/softRD_pileup/CD4mixture_output_81205_sorted_softMultiprocessing'

suffix='binnedstats.pkl'

allstatfiles=glob.glob(infol+"/*"+suffix)

# %%
filesdf=[]
for fp in allstatfiles:
    tmpdf=pd.read_pickle(fp)
    tmpdf['filename']=os.path.basename(fp)
    filesdf.append(tmpdf)

# %%
df_combined = pd.concat(filesdf, axis=0)
df_combined.head()
# Out:
#                                            CD4-others  CD8-others  nB-others  \
# CD4.HWI-7001432L_73:1:1107:12469:51878#12   -0.036875   -0.014465  -0.032824
# CD4.HWI-7001432L_73:1:1115:16112:84772#12    0.323955    0.114314  -0.104840
# CD4.HWI-7001432L_73:1:1302:20130:90923#12    3.927474    2.277269  -0.868064
# CD4.HWI-7001432L_73:1:1314:16857:93901#12   -0.059953   -0.039132  -0.039132
# CD4.HWI-7001432L_73:1:1316:18336:69206#12   -0.110487   -0.147821   0.234846
#
#                                            NK-others  Mn-others  mNeu-others  \
# CD4.HWI-7001432L_73:1:1107:12469:51878#12   0.107637  -0.027901    -0.036004
# CD4.HWI-7001432L_73:1:1115:16112:84772#12  -0.069122  -0.105558    -0.095865
# CD4.HWI-7001432L_73:1:1302:20130:90923#12  -0.677449  -0.849756    -0.788372
# CD4.HWI-7001432L_73:1:1314:16857:93901#12  -0.033748  -0.028363     0.016987
# CD4.HWI-7001432L_73:1:1316:18336:69206#12  -0.082846  -0.123051    -0.140641
#
# ...

# %%
df_combined.shape
# Out:
# (179150, 24)

# %%
nodupindex = df_combined[~df_combined.index.duplicated(keep='first')]

# %%
nodupindex.shape
# Out:
# (64631, 24)

# %%
df_combined.to_pickle(infol+"_"+suffix)
nodupindex.to_pickle(infol+"_nodupindex_"+suffix)

# %%
end_time = time.time()

time_elapsed = (end_time - start_time)

print(time_elapsed)
# Out:
# 0.5238819122314453
