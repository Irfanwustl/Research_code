# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/in-silico/background_pattern/readnumber_1000000/mincpg3/somefinalfiles/mNeuallrange_NR_1000000_insilmix44_sorted_howsm_single_mode_pp_masterdf.txt_rej-99999.0_mincpg3_rejmode_nov_final.txt'



indf=pd.read_csv(infile,sep='\t')
indf['acceptedCpG']=indf.acceptedCpG.apply(lambda x: x[1:-1].split(','))
indf['notacceptedCpG']=indf.notacceptedCpG.apply(lambda x: x[1:-1].split(','))

indf.head()
# Out:
#                                         ReadName allcelltype ucelltype  \
# 0         CD8.HWI-ST699_224:4:1108:8636:83001#19          []      ['']
# 1       m8.HWI-ST700660_250:3:1314:3514:18665#14          []      ['']
# 2    nB.HWI-ST539_192:2:1113:13739:98748#24nfmet          []      ['']
# 3  Eo.HWI-ST699:234:C48WNACXX:4:2107:17698:65552          []      ['']
# 4    m4.D6L3XBQ1:317:C6CGAACXX:1:1310:15611:9676          []      ['']
#
#   assignedcelltype CheckedCpG mismatchCpG notacceptedCpG acceptedCpG  \
# 0      NotAssigned         []        ['']           ['']        ['']
# 1      NotAssigned         []        ['']           ['']        ['']
# 2      NotAssigned         []        ['']           ['']        ['']
# 3      NotAssigned         []        ['']           ['']        ['']
# 4      NotAssigned         []        ['']           ['']        ['']
#
#   finalacceptedfor finalrejectedfor MateCIGARok hypolist  len_hypolist  \
# 0    notdetermined    notdetermined           Y       []             0
# 1    notdetermined    notdetermined           Y       []             0
# 2    notdetermined    notdetermined           Y       []             0
# 3    notdetermined    notdetermined           Y       []             0
# 4    notdetermined    notdetermined           Y       []             0
#
#                                            hyperlist  len_hyperlist  \
# 0  ['chr1:1221777', 'chr1:1221697', 'chr1:1221819...              7
# 1  ['chr1:1221777', 'chr1:1221819', 'chr1:1221791...              6
# 2  ['chr1:1221777', 'chr1:1221819', 'chr1:1221791...              5
# 3  ['chr1:1221777', 'chr1:1221819', 'chr1:1221791...              5
# 4  ['chr1:1221777', 'chr1:1221819', 'chr1:1221791...              6
#
#   allnotmatched  len_allnotmatched  fraglength intersection_ofhypohyper  \
# 0            []                  0         0.0                       []
# 1            []                  0         0.0                       []
# 2            []                  0         0.0                       []
# 3            []                  0         0.0                       []
# 4            []                  0         0.0                       []
#
#    len_intersection_ofhypohyper
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0

# %%
indf=indf[(indf['finalacceptedfor']=='mNeu') |  (indf['finalrejectedfor'].str.contains('mNeu'))] 
indf.head()
# Out:
#                                             ReadName  \
# 10677  Eo.HWI-ST731:122:C7CNDACXX:5:2203:10328:85141
# 10678    m4.HWI-ST731:96:C48UKACXX:2:2210:3115:24916
# 10679         CD4.HWI-ST699_224:2:2202:1612:41390#12
# 10681  mB.HWI-ST537:245:C7LMEACXX:7:2115:19162:71031
# 10682  m4.HWI-ST537:240:C6B3NACXX:3:2113:20579:44155
#
#                             allcelltype ucelltype assignedcelltype  \
# 10677          ['mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10678          ['mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10679  ['mNeu', 'mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10681          ['mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10682          ['mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
#
#                                               CheckedCpG mismatchCpG  \
# 10677  ['chr1:13711400', 'chr1:13711460', 'chr1:13711...        ['']
# 10678  ['chr1:13711400', 'chr1:13711460', 'chr1:13711...        ['']
# 10679  ['chr1:13711400', 'chr1:13711460', 'chr1:13711...        ['']
# 10681  ['chr1:13711400', 'chr1:13711460', 'chr1:13711...        ['']
# 10682  ['chr1:13711400', 'chr1:13711460', 'chr1:13711...        ['']
#
#                                           notacceptedCpG acceptedCpG  \
# 10677  ['chr1:13711400',  'chr1:13711460',  'chr1:137...        ['']
# 10678  ['chr1:13711400',  'chr1:13711460',  'chr1:137...        ['']
# 10679  ['chr1:13711400',  'chr1:13711460',  'chr1:137...        ['']
# 10681  ['chr1:13711400',  'chr1:13711460',  'chr1:137...        ['']
# 10682  ['chr1:13711400',  'chr1:13711460',  'chr1:137...        ['']
#
#       finalacceptedfor finalrejectedfor MateCIGARok hypolist  len_hypolist  \
# 10677    notdetermined         ['mNeu']           Y       []             0
# 10678    notdetermined         ['mNeu']           Y       []             0
# 10679    notdetermined         ['mNeu']           Y       []             0
# 10681    notdetermined         ['mNeu']           Y       []             0
# 10682    notdetermined         ['mNeu']           Y       []             0
#
#                                                hyperlist  len_hyperlist  \
# 10677  ['chr1:13711468', 'chr1:13711400', 'chr1:13711...              4
# 10678  ['chr1:13711468', 'chr1:13711400', 'chr1:13711...              4
# 10679  ['chr1:13711468', 'chr1:13711400', 'chr1:13711...              4
# 10681  ['chr1:13711400', 'chr1:13711310', 'chr1:13711...              4
# 10682  ['chr1:13711468', 'chr1:13711400', 'chr1:13711...              4
#
#       allnotmatched  len_allnotmatched  fraglength intersection_ofhypohyper  \
# 10677            []                  0         0.0                       []
# 10678            []                  0         0.0                       []
# 10679            []                  0         0.0                       []
# 10681            []                  0         0.0                       []
# 10682            []                  0         0.0                       []
#
#        len_intersection_ofhypohyper
# 10677                             0
# 10678                             0
# 10679                             0
# 10681                             0
# 10682                             0

# %%
def CountFrequency(my_list):
 
    # Creating an empty dictionary
    freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
    return freq

def fullcount(cpglist):
    cpglist_flat=[item for sublist in cpglist for item in sublist]
    cpglist_flat=list(map(eval,cpglist_flat))
    cpglist_flat=[i for i in cpglist_flat if i]
    cpglist_flat_freq=CountFrequency(cpglist_flat)
    return cpglist_flat_freq

# %%
pos_cpg=indf['acceptedCpG'].tolist()
pos_cpg_freq=fullcount(pos_cpg)
len(pos_cpg_freq)
# Out:
# 422
