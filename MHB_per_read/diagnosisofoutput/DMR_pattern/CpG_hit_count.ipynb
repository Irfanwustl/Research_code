# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/in-silico/background_pattern/readnumber_1000000/mincpg3/somefinalfiles/mNeuallrange_NR_1000000_insilmix40_sorted_howsm_single_mode_pp_masterdf.txt_rej-99999.0_mincpg3_rejmode_nov_final.txt'



indf=pd.read_csv(infile,sep='\t')
indf['acceptedCpG']=indf.acceptedCpG.apply(lambda x: x[1:-1].split(','))
indf['notacceptedCpG']=indf.notacceptedCpG.apply(lambda x: x[1:-1].split(','))

indf.head()
# Out:
#                                         ReadName allcelltype ucelltype  \
# 0         CD8.HWI-ST699_224:4:1108:8636:83001#19          []      ['']
# 1        CD4.HWI-ST699_224:6:1302:18271:98252#12          []      ['']
# 2    nB.HWI-ST539_192:2:1113:13739:98748#24nfmet          []      ['']
# 3   Tr.D6L3XBQ1:317:C6CGAACXX:3:1309:15852:96711          []      ['']
# 4  DC.HWI-ST537:256:C8F79ACXX:3:2116:18362:58604          []      ['']
#
#   assignedcelltype CheckedCpG mismatchCpG notacceptedCpG acceptedCpG  \
# 0      NotAssigned         []        ['']           ['']        ['']
# 1      NotAssigned         []        ['']           ['']        ['']
# 2      NotAssigned         []        ['']           ['']        ['']
# 3      NotAssigned         []        ['']           ['']        ['']
# 4      NotAssigned         []        ['']           ['']        ['']
#
#   finalacceptedfor finalrejectedfor MateCIGARok hypolist  len_hypolist  \
# 0    notdetermined    notdetermined           Y       []             0
# 1    notdetermined    notdetermined           Y       []             0
# 2    notdetermined    notdetermined           Y       []             0
# 3    notdetermined    notdetermined           Y       []             0
# 4    notdetermined    notdetermined           Y       []             0
#
#                                            hyperlist  len_hyperlist  \
# 0  ['chr1:1221819', 'chr1:1221821', 'chr1:1221768...              7
# 1  ['chr1:1221819', 'chr1:1221821', 'chr1:1221768...              6
# 2  ['chr1:1221819', 'chr1:1221821', 'chr1:1221768...              5
# 3  ['chr1:1221819', 'chr1:1221821', 'chr1:1221768...              8
# 4  ['chr1:1221819', 'chr1:1221821', 'chr1:1221768...              5
#
#   allnotmatched  len_allnotmatched  fraglength intersection_ofhypohyper  \
# 0            []                  0         0.0                       []
# 1            []                  0         0.0                       []
# 2            []                  0         0.0                       []
# 3            []                  0         0.0                       []
# 4            []                  0         0.0                       []
#
#    len_intersection_ofhypohyper
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0

# %%
indf=indf[(indf['finalacceptedfor']=='mNeu') |  (indf['finalrejectedfor'].str.contains('mNeu'))] 
indf.head()
# Out:
#                                               ReadName  \
# 10779      Tr.D6L3XBQ1:317:C6CGAACXX:3:2207:9167:57949
# 10780    Tr.HWI-ST537:222:C48Y0ACXX:6:2315:14505:83242
# 10781           CD4.HWI-ST699_224:2:2202:1612:41390#12
# 10782         NK.HWI-ST700660_252:2:1308:5968:68711#18
# 10783  Mn.HWI-ST700660:317:C8F1VACXX:2:1113:2900:52832
#
#                             allcelltype ucelltype assignedcelltype  \
# 10779          ['mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10780  ['mNeu', 'mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10781  ['mNeu', 'mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10782          ['mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
# 10783          ['mNeu', 'mNeu', 'mNeu']  ['mNeu']      NotAssigned
#
#                                               CheckedCpG mismatchCpG  \
# 10779  ['chr1:13711468', 'chr1:13711460', 'chr1:13711...        ['']
# 10780  ['chr1:13711468', 'chr1:13711460', 'chr1:13711...        ['']
# 10781  ['chr1:13711468', 'chr1:13711460', 'chr1:13711...        ['']
# 10782  ['chr1:13711468', 'chr1:13711460', 'chr1:13711...        ['']
# 10783  ['chr1:13711468', 'chr1:13711460', 'chr1:13711...        ['']
#
#                                           notacceptedCpG acceptedCpG  \
# 10779  ['chr1:13711468',  'chr1:13711460',  'chr1:137...        ['']
# 10780  ['chr1:13711468',  'chr1:13711460',  'chr1:137...        ['']
# 10781  ['chr1:13711468',  'chr1:13711460',  'chr1:137...        ['']
# 10782  ['chr1:13711468',  'chr1:13711460',  'chr1:137...        ['']
# 10783  ['chr1:13711468',  'chr1:13711460',  'chr1:137...        ['']
#
#       finalacceptedfor finalrejectedfor MateCIGARok hypolist  len_hypolist  \
# 10779    notdetermined         ['mNeu']           Y       []             0
# 10780    notdetermined         ['mNeu']           Y       []             0
# 10781    notdetermined         ['mNeu']           Y       []             0
# 10782    notdetermined         ['mNeu']           Y       []             0
# 10783    notdetermined         ['mNeu']           Y       []             0
#
#                                                hyperlist  len_hyperlist  \
# 10779  ['chr1:13711468', 'chr1:13711310', 'chr1:13711...              4
# 10780  ['chr1:13711468', 'chr1:13711460', 'chr1:13711...              3
# 10781  ['chr1:13711468', 'chr1:13711310', 'chr1:13711...              4
# 10782  ['chr1:13711468', 'chr1:13711310', 'chr1:13711...              4
# 10783  ['chr1:13711468', 'chr1:13711310', 'chr1:13711...              4
#
#       allnotmatched  len_allnotmatched  fraglength intersection_ofhypohyper  \
# 10779            []                  0         0.0                       []
# 10780            []                  0         0.0                       []
# 10781            []                  0         0.0                       []
# 10782            []                  0         0.0                       []
# 10783            []                  0         0.0                       []
#
#        len_intersection_ofhypohyper
# 10779                             0
# 10780                             0
# 10781                             0
# 10782                             0
# 10783                             0

# %%
def CountFrequency(my_list):
 
    # Creating an empty dictionary
    freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
    return freq

def fullcount(cpglist):
    cpglist_flat=[item for sublist in cpglist for item in sublist]
    cpglist_flat=list(map(eval,cpglist_flat))
    cpglist_flat=[i for i in cpglist_flat if i]
    cpglist_flat_freq=CountFrequency(cpglist_flat)
    return cpglist_flat_freq

# %%
pos_cpg=indf['acceptedCpG'].tolist()
pos_cpg_freq=fullcount(pos_cpg)
len(pos_cpg_freq)
# Out:
# 399
