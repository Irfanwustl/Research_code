# %%
import pandas as pd
mincpg1file='/Users/irffanalahi/Research/Research_code/MHB_per_read/ideas_to_improve_LOD/debug/mNeuallrange_NR_1000000_insilmix43_sorted_howsm_single_mode_pp_masterdf.txt_rej-99999.0_mincpg1_rejmode_nov_final.txt'
mincpg5file='/Users/irffanalahi/Research/Research_code/MHB_per_read/ideas_to_improve_LOD/debug/mNeuallrange_NR_1000000_insilmix43_sorted_howsm_single_mode_pp_masterdf.txt_rej-99999.0_mincpg5_rejmode_nov_final.txt'
celltype='mNeu'

# %%
mincpg1df=pd.read_csv(mincpg1file,sep="\t")
mincpg1df['acceptedCpG']=mincpg1df.acceptedCpG.apply(lambda x: x[1:-1].split(','))
mincpg1df.head()
# Out:
#                                            ReadName allcelltype ucelltype  \
# 0            CD8.HWI-ST699_224:4:1108:8636:83001#19          []      ['']
# 1       nB.HWI-ST539_192:2:1113:13739:98748#24nfmet          []      ['']
# 2  Mn.HWI-ST700660:315:C8FCFACXX:7:2110:19921:91086          []      ['']
# 3       m4.D6L3XBQ1:317:C6CGAACXX:1:1310:15611:9676          []      ['']
# 4            NK.HWI-ST699_221:8:1313:16002:30299#18          []      ['']
#
#   assignedcelltype CheckedCpG mismatchCpG notacceptedCpG acceptedCpG  \
# 0      NotAssigned         []        ['']           ['']        ['']
# 1      NotAssigned         []        ['']           ['']        ['']
# 2      NotAssigned         []        ['']           ['']        ['']
# 3      NotAssigned         []        ['']           ['']        ['']
# 4      NotAssigned         []        ['']           ['']        ['']
#
#   finalacceptedfor finalrejectedfor MateCIGARok hypolist  len_hypolist  \
# ...

# %%
mincpg5df=pd.read_csv(mincpg5file,sep="\t")
mincpg5df['acceptedCpG']=mincpg5df.acceptedCpG.apply(lambda x: x[1:-1].split(','))
mincpg5df.head()
# Out:
#                                            ReadName allcelltype ucelltype  \
# 0            CD8.HWI-ST699_224:4:1108:8636:83001#19          []      ['']
# 1       nB.HWI-ST539_192:2:1113:13739:98748#24nfmet          []      ['']
# 2  Mn.HWI-ST700660:315:C8FCFACXX:7:2110:19921:91086          []      ['']
# 3       m4.D6L3XBQ1:317:C6CGAACXX:1:1310:15611:9676          []      ['']
# 4            NK.HWI-ST699_221:8:1313:16002:30299#18          []      ['']
#
#   assignedcelltype CheckedCpG mismatchCpG notacceptedCpG acceptedCpG  \
# 0      NotAssigned         []        ['']           ['']        ['']
# 1      NotAssigned         []        ['']           ['']        ['']
# 2      NotAssigned         []        ['']           ['']        ['']
# 3      NotAssigned         []        ['']           ['']        ['']
# 4      NotAssigned         []        ['']           ['']        ['']
#
#   finalacceptedfor finalrejectedfor MateCIGARok hypolist  len_hypolist  \
# ...

# %%
min1accepteddf=(mincpg1df[mincpg1df['finalacceptedfor']==celltype]).copy()

# %%
min5accepteddf=(mincpg5df[mincpg5df['finalacceptedfor']==celltype]).copy()

# %%
FPdfmin1=min1accepteddf[~min1accepteddf['ReadName'].str.contains(celltype)]

# %%
FPdfmin5=min5accepteddf[~min5accepteddf['ReadName'].str.contains(celltype)]

# %%
FPdfmin1rread=set(FPdfmin1['ReadName'].tolist())

# %%
FPdfmin5rread=set(FPdfmin5['ReadName'].tolist())

# %%
FPdfmin5rreadadditionalread=FPdfmin5rread-FPdfmin1rread

# %%
FPdfmin5rreadadditionalread
# Out:
# set()

# %%
len(FPdfmin5rread)
# Out:
# 56

# %%
len(FPdfmin1rread)
# Out:
# 2185

# %%
FPdfmin5.to_csv(mincpg5file+"_mNeu_FP.txt",sep="\t",index=False)
