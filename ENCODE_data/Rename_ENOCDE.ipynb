# %%
import pandas as pd
import glob
import os
import sys
import shutil
infofile='/Users/irffanalahi/Research/Research_update/opensource_data/ENCODE/downloadtest/?status=released&internal_tags=ENTEx&assay_title=WGBS&type=Experiment&files.analyses.status=released&files.preferred_default=true.txt'


indir='/Users/irffanalahi/Research/Research_update/opensource_data/ENCODE/downloadtest/formapping'

outdir=indir+"_renamed"

os.mkdir(outdir)

infodf=pd.read_csv(infofile,sep='\t')
infodf.head()
# Out:
#   File accession   File format File type File format type  \
# 0    ENCFF206XGR        bigWig    bigWig              NaN
# 1    ENCFF440OPK  bigBed bed9+    bigBed            bed9+
# 2    ENCFF586VVJ     bed bed9+       bed            bed9+
# 3    ENCFF391LLV        bigWig    bigWig              NaN
# 4    ENCFF911ZIV     bed bed9+       bed            bed9+
#
#                              Output type File assembly Experiment accession  \
# 0  minus strand methylation state at CpG        GRCh38          ENCSR598OBF
# 1               methylation state at CpG        GRCh38          ENCSR598OBF
# 2               methylation state at CpG        GRCh38          ENCSR598OBF
# 3   plus strand methylation state at CpG        GRCh38          ENCSR598OBF
# 4               methylation state at CpG        GRCh38          ENCSR156JXJ
#
#   Assay                    Donor(s) Biosample term id  ... Genome annotation  \
# 0  WGBS  /human-donors/ENCDO271OUW/    UBERON:0000945  ...               NaN
# 1  WGBS  /human-donors/ENCDO271OUW/    UBERON:0000945  ...               NaN
# 2  WGBS  /human-donors/ENCDO271OUW/    UBERON:0000945  ...               NaN
# 3  WGBS  /human-donors/ENCDO271OUW/    UBERON:0000945  ...               NaN
# 4  WGBS  /human-donors/ENCDO451RUA/    UBERON:0001157  ...               NaN
#
#   Platform Controlled by  File Status  \
# 0      NaN           NaN     released
# 1      NaN           NaN     released
# 2      NaN           NaN     released
# 3      NaN           NaN     released
# 4      NaN           NaN     released
#
#                                               s3_uri    File analysis title  \
# 0  s3://encode-public/2021/03/01/43af69c3-9a4d-4f...  ENCODE4 v1.1.5 GRCh38
# 1  s3://encode-public/2021/03/01/7750e89a-88c1-4e...  ENCODE4 v1.1.5 GRCh38
# 2  s3://encode-public/2021/03/01/7ed38569-2c8c-4d...  ENCODE4 v1.1.5 GRCh38
# 3  s3://encode-public/2021/03/01/20e8a590-28d8-4e...  ENCODE4 v1.1.5 GRCh38
# 4  s3://encode-public/2021/03/03/65470b4e-cb8b-45...  ENCODE4 v1.1.5 GRCh38
#
#    File analysis status  Audit WARNING  Audit NOT_COMPLIANT  Audit ERROR
# 0              released            NaN                  NaN          NaN
# 1              released            NaN                  NaN          NaN
# 2              released            NaN                  NaN          NaN
# 3              released            NaN                  NaN          NaN
# 4              released   low coverage                  NaN          NaN
#
# [5 rows x 58 columns]

# %%
def listdir_nohidden(path):
    return glob.glob(os.path.join(path, '*'))

# %%
allfiles=listdir_nohidden(indir)

# %%
for afile in allfiles:
    corresrow=infodf[infodf['File accession']==os.path.basename(afile).split('.')[0]]
    if corresrow.shape[0]==0:
        print(afile)
        print("NOT found. But not exiting")
        continue
    
    termname=corresrow['Biosample term name'].tolist()
    if len(termname)!=1:
        print(afile)
        print('len(termname)!=1')
        sys.exit(1)
    termname=termname[0].replace(" ", "_")
    
    newname=termname+"_"+os.path.basename(afile)
    shutil.copy(afile,outdir+"/"+newname)
