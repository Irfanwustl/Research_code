# %%
import pandas as pd
import sys

# %%
infilename="/Users/irffanalahi/Research/weekly/for_8_27_20/MONOD_analysis/result/realMONOD2/downstreamanalysis2withcpgthresholed/blueourPBMCcomparison/for_correlation/beautification/pairwise_figure/blueour_combinednona_shortname.txt"
df=pd.read_csv(infilename,sep="\t",index_col=0)
wanttochangecollabel=["S01MAPA1_mono.bw.bg","S01E03A1_mono.bw.bg","S01BHIA1_mono.bw.bg","NBC_NC11_83_naiveb.bw.bg","C003N351_memb.bw.bg","NBC_NC11_41_naiveb.bw.bg","S01ECGA1_naiveb.bw.bg","S017RE51_memb.bw.bg","S009W451_CD4.bw.bg","S008H151_CD4.bw.bg","C00256A1bs_CD8.bw.bg","C003VO55_CD8.bw.bg","S00C2F51_CD8.bw.bg","C0066P51_CD8.bw.bg","S01E8O51_cytnk.bw.bg","C0067N51_cytnk.bw.bg","C006G551_cytnk.bw.bg","C002CTA1bs_cytnk.bw.bg"]
newcollabel=["Mono (S01MAPA1)","Mono (S01E03A1)","Mono (S01BHIA1)","B Cell (NBC_NC11_83)","B Cell (C003N351)","B Cell (NBC_NC11_41)","B Cell (S01ECGA1)","B Cell (S017RE51)","CD4 (S009W451)","CD4 (S008H151)","CD8 (C00256A1bs)","CD8 (C003VO55)","CD8 (S00C2F51)","CD8 (C0066P51)","NK (S01E8O51)","NK (C0067N51)","NK (C006G551)","NK (C002CTA1bs)"]

# %%
if len(wanttochangecollabel)!=len(newcollabel):
    print("want and new collabel length does not match")
    sys.exit(1)

print("length macthed")
# Out:
# length macthed

# %%
for i in range(len(wanttochangecollabel)):
    df = df.rename(columns={wanttochangecollabel[i]: newcollabel[i]})

# %%
df.head()
# Out:
#                     Mono (S01MAPA1)  CD8-PBMC-1382.bg  Mono (S01E03A1)  \
# chr1:629090-629153         0.024495          0.030400         0.024983
# chr1:870055-870086         0.011314          0.017569         0.020270
# chr1:904742-904796         0.000000          0.123842         0.009591
# chr1:904799-904829         0.000000          0.137558         0.000000
# chr1:904835-904858         0.017680          0.124847         0.012298
#
#                     B Cell (NBC_NC11_83)  C001UYA1bs_matneu.bw.bg  \
# chr1:629090-629153              0.031833                 0.025995
# chr1:870055-870086              0.000000                 0.006600
# chr1:904742-904796              0.003307                 0.006461
# chr1:904799-904829              0.004400                 0.005600
# chr1:904835-904858              0.004845                 0.000000
#
#                     CD56-PBMC-1389.bg  Mono (S01BHIA1)  B Cell (C003N351)  \
# ...

# %%
df.to_csv(infilename+"_renamed"+".txt",sep="\t")
print("done")
# Out:
# done
