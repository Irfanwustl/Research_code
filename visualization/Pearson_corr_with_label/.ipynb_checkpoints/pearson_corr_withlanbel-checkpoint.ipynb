# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x='accflow'
y='pyg50'
df=pd.read_csv("acc_reinpyg50_onlyhypo.txt",sep="\t")

# %%
df.corr()
# Out:
#              cand     pyg50   accflow
# cand     1.000000  0.984903  0.974149
# pyg50    0.984903  1.000000  0.981910
# accflow  0.974149  0.981910  1.000000

# %%
text='R=%s, P=%s' % (corr[0], corr[1])
sns.scatterplot(df[x], df[y],hue=df['celltype'])
sns.regplot(df[x], df[y],scatter=False)
ax.text(4, 30, text, fontsize=12)
#sns.jointplot(data=df, x=x, y=y, kind='reg', hue=df['celltype'])

# %%
sns.pairplot(df, hue = 'celltype')

# %%
sns.lmplot(x=x, y=y,
           hue='celltype', data=df)
