# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt
infile="/Users/irffanalahi/Research/Research_update/SM/melcfdref/LargerLTME/BluOurPBL/RD/forfinalcollect/allfinals/BlOurPBLourCD8TIL_maxcompperc75percetile/getAUC/dashboard/AUC_and_Region/prepare_regionfile/shortname_reversedprioritization2/plot/compartmentCD8TIL_response.txt_PreTxDCBvsNDB_AUC_othersRevePrio2.txt"
outfile=infile+"_corr.pdf"
droplist=[]

indf=pd.read_csv(infile,sep="\t")

# %%
plt.figure(figsize=(12,10))
cor = indf.corr()

ax=sns.heatmap(cor, center=0)
#plt.xlim(0,10.0)
#plt.ylim(0,10.0)
#bottom, top = ax.get_ylim()
#ax.set_ylim(bottom + 0.5, top - 0.5)
#heatname=filename+"_heat"+".pdf"
#plt.savefig(heatname,bbox_inches = "tight")
#plt.show()

# %%
cor['c']
# Out:
# start                         0.019875
# end                           0.019875
# c                             1.000000
# q                            -0.005019
# diff                          0.095479
# #cpg                          0.081924
# p(MWU)                        0.074287
# p(2dks)                      -0.008661
# CD8TIL                        0.043891
# others                       -0.163094
# CD4bluourPBL                 -0.024403
# CD8bluourPBL                 -0.083695
# nB                           -0.141536
# NK                           -0.087616
# MnbluourPBL                  -0.114430
# iDC                          -0.102574
# mDC                          -0.105719
# mNeu                         -0.080395
# cB                           -0.075715
# CD8TIL.1                      0.043892
# MEL_TUMOR                    -0.099674
# mycpgcount                    0.081924
# CD8TIL-CD4bluourPBL           0.072084
# CD8TIL-CD8bluourPBL           0.128564
# ...
