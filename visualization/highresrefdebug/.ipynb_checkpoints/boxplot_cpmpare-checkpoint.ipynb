# %%
# %matplotlib inline
import pandas as pd
import itertools

from matplotlib import pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation

datatypelist=[]
f1="/Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/myversion/HealthycfDNAandWBQC-072721_cfdonly.txt"
df1=pd.read_csv(f1,sep="\t")
tmpdata='New healthy'
df1['data']=tmpdata
datatypelist.append(tmpdata)

f2="/Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/myversion/HealthycfDNAWGBS.txt"
df2=pd.read_csv(f2,sep="\t")
tmpdata='Previous healthy'
df2['data']=tmpdata
datatypelist.append(tmpdata)

f3="/Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/myversion/CRC_cfDNA_072821.txt"
df3=pd.read_csv(f3,sep="\t")
tmpdata='CRC'
df3['data']=tmpdata
datatypelist.append(tmpdata)


outputfile=f3

dflist=[df1,df2,df3] ###########


#valuevars=['cB','CD4','CD8','iDC','M0','M1','M2','mDC','Mn','mNeu','nB','NK','PC']
valuevars=['Plasma vol. (ml)','Total cfDNA amount (ng)','cfDNA amount/ml plasma (ng/ml)','cfDNA used for Lib prep (ng)','cfDNA (ng) for BS conversion','BA percentage  70bp-450bp','0.5% Lambda DNA spike-in (ng)','Indexing PCR cycles','Final Lib. Conc. (ng/ul)','Elution vol. (ul)','Total amount of Lib (ng)','Library Avg. Fragment size (Bioanalyzer)','dsDNA-MW (660) x Avg. Fragment size','nM of Library/ul']
#valuevars=['Plasma vol. (ml)','cfDNA amount (ng)','cfDNA amount (ng/ml)','Total cfDNA amt (ng) including previous extractions','Bioanalyzer 70bp-450bp percentage']#	'Indexing PCR cycles'	Final Lib. Conc. (ng/ul)	Elution vol. (ul)	Total amount of Lib (ng)

# %%
alldf = pd.concat(dflist)
alldf.to_csv(f1+"_alldf.txt",sep="\t",index=False)
alldf.head()
# Out:
#      Sample ID Pateint vs. Healthy Category  Plasma vol. (ml)  \
# 0  NU-05-cfDNA             Healthy   Plasma               8.0
# 1  NU-14-cfDNA             Healthy   Plasma               9.0
# 2  NU-31-cfDNA             Healthy   Plasma              10.0
# 3  NU-24-cfDNA             Healthy   Plasma               6.0
# 4  NU-35-cfDNA             Healthy   Plasma               7.0
#
#    cfDNA con. QUBIT (ng/ul)  Total cfDNA amount (ng)  \
# 0                      1.74                    130.8
# 1                      1.44                    108.0
# 2                      1.56                    117.0
# 3                      0.88                     66.0
# 4                      0.81                     61.0
#
#    cfDNA amount/ml plasma (ng/ml)  BA percentage  70bp-450bp  \
# 0                            16.3                       87.0
# 1                            12.0                       76.0
# 2                            11.7                       80.0
# 3                            11.0                       83.0
# 4                             8.7                       69.0
#
#    cfDNA amount (ng) scaled to 75% BA 70-450bp   cfDNA used for Lib prep (ng)  \
# 0                                           NaN                          90.0
# 1                                           NaN                          90.0
# 2                                           NaN                          90.0
# 3                                           NaN                          66.0
# 4                                         97.83                          61.0
#
#    ...  Median Depth  Median Fragment length         data Time Point Pre/Post  \
# 0  ...           NaN                     NaN  New healthy                 NaN
# 1  ...           NaN                     NaN  New healthy                 NaN
# 2  ...           NaN                     NaN  New healthy                 NaN
# 3  ...           NaN                     NaN  New healthy                 NaN
# 4  ...           NaN                     NaN  New healthy                 NaN
#
#   Total cfDNA amt (ng) including previous extractions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   BA percentage  70bp-650bp Unnamed: 20 Response?  \
# 0                       NaN         NaN       NaN
# 1                       NaN         NaN       NaN
# 2                       NaN         NaN       NaN
# 3                       NaN         NaN       NaN
# 4                       NaN         NaN       NaN
#
#   Bioanalyzer done on extracted cfDNA  Unnamed: 19
# 0                                 NaN          NaN
# 1                                 NaN          NaN
# 2                                 NaN          NaN
# 3                                 NaN          NaN
# 4                                 NaN          NaN
#
# [5 rows x 36 columns]

# %%
mdf = pd.melt(alldf, id_vars=['data'], value_vars=valuevars)

# %%
def combine_box_pairs(samples, cell_types):
    box_pairs = []
    for cell in cell_types:
        pairs = []
        for sample in samples:
            pairs.append((cell, sample))
        for i in range(len(samples)):
            try:
                box_pairs.append((pairs[i], pairs[i + 1]))
            except IndexError:
                box_pairs.append((pairs[i], pairs[0]))
    return box_pairs

Box_pairs = combine_box_pairs(datatypelist, valuevars)

# %%
plt.figure(figsize=(20,10))
ax = sns.boxplot(x="variable", y="value", hue="data", data=mdf,palette="Set3") 

# Box_pairs=[(("cB","New healthy"),("cB","CRC"))]

test_results = add_stat_annotation(ax,data=mdf, x="variable", y="value", hue="data",box_pairs=Box_pairs,
                                   test='Mann-Whitney', text_format='star', comparisons_correction=None)

plt.show()

#ax.figure.savefig(outputfile+".pdf",dpi=300, bbox_inches='tight')
#plt.savefig('example_non-hue_outside.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-65e56e9dbe3b> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 ax = sns.boxplot(x="variable", y="value", hue="data", data=mdf,palette="Set3")
#       3
#       4 # Box_pairs=[(("cB","New healthy"),("cB","CRC"))]
#       5
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# --> 446         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     447         self.establish_colors(color, palette, saturation)
#     448
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     156
#     157             # Figure out the plotting orientation
# --> 158             orient = self.infer_orient(x, y, orient)
#     159
#     160             # Option 2a:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/seaborn/categorical.py in infer_orient(self, x, y, orient)
#     359         elif is_not_numeric(y):
#     360             if is_not_numeric(x):
# --> 361                 raise ValueError(no_numeric)
#     362             else:
#     363                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.
