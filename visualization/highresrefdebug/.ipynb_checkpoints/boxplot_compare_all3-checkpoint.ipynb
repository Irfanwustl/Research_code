# %%
# %matplotlib inline
import pandas as pd
import itertools

from matplotlib import pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation
import sys
import os
import shutil

datatypelist=[]

f1="/Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/WB_PBMC/Drylab/prevpbmc_column_combined.txt"
df1=pd.read_csv(f1,sep="\t")
tmpdata='CRC PBMC (n=' + str(len(df1)) + ')'
df1['data']=tmpdata
datatypelist.append(tmpdata)

f2="/Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/WB_PBMC/Drylab/mellaneBULKPBMC_column_combined.txt"
df2=pd.read_csv(f2,sep="\t")
tmpdata='SKCM PBMC (n=' + str(len(df2)) + ')'
df2['data']=tmpdata
datatypelist.append(tmpdata)

f3="/Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/WB_PBMC/Drylab/WB_and_cfDNA_column_combined_onlyWB.txt"
df3=pd.read_csv(f3,sep="\t")
tmpdata='Healthy WB (n=' + str(len(df3)) + ')'
df3['data']=tmpdata
datatypelist.append(tmpdata)



outputfile=f3
outputfolder=os.path.dirname(outputfile)

dflist=[df1,df2,df3] ###########


######duplication_rate####
valuevars=['d50th_ptle','50th_ptle','total','secondary','supplementary','duplicates','mapped','mapped_percent','paired_in_sequencing','read1','read2','properly_paired','properly_paired_percentage','with_itself_and_mate_mapped','singletons','with_mate_mapped_to_a_different_chr','with_mate_mapped_to_a_different_chr_mapQ>=5','duplication_rate']

#valuevars=['rc1','rc1_stdev','rc2','rc2_stdev','rc3','rc3_stdev','1 - rc1','1-rc1_stdev','1 - rc2','1-rc2_stdev','1 - rc3','1-rc3_stdev','1 - mean(rc)','1-mean(rc)_stdev','BCR']
#valuevars=['Total DNA amount (ng)','gDNA used for Lib prep (ng)','Unmethylated Lambda DNA- 0.5% (ng)','gDNA (ng) for BS conversion','Indexing PCR cycles','Target sequencing Depth','Library Avg. Fragment size (Bioanalyzer)','Final Lib. Conc. (ng/ul)','Elution vol. (ul)','Total amount of Lib (ng)','dsDNA-MW (660) x Avg. Fragment size','nM of Library/ul']
#valuevars=['Plasma vol. (ml)','cfDNA amount (ng)','cfDNA amount (ng/ml)','Total cfDNA amt (ng) including previous extractions','Bioanalyzer 70bp-450bp percentage']#	'Indexing PCR cycles'	Final Lib. Conc. (ng/ul)	Elution vol. (ul)	Total amount of Lib (ng)

print(outputfolder)
len(valuevars)
# Out:
# /Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/WB_PBMC/Drylab
# 17

# %%
alldf = pd.concat(dflist)
alldf.head()
# Out:
#                  Unnamed: 0  01st_ptle  05th_ptle  25th_ptle  d50th_ptle  \
# 0  TWCY-1389-1389-BULK-PBMC   3.000000   7.000000    13.0000     17.0000
# 1  TWCY-1382-1382-BULK-PBMC   3.000000   7.000000    12.0000     16.0000
# 2  TWCY-1313-1313-BULK-PBMC   2.000000   5.000000    10.0000     15.0000
# 0            mel-159-P-Bulk  20.658080  31.382440    34.7473     35.9582
# 1            mel-123-P-Bulk  20.045187  30.788265    35.4158     36.9232
#
#    75th_ptle  95th_ptle  99th_ptle      total  secondary  ...  \
# 0    21.0000    28.0000  39.000000  479478857    2580853  ...
# 1    20.0000    28.0000  37.000000  455176820    2749845  ...
# 2    19.0000    27.0000  37.000000  439296503    2102836  ...
# 0    37.0603    39.0003  62.928752  911458506    5535738  ...
# 1    38.1721    40.1697  61.757051  919236819   13655179  ...
#
#    with_mate_mapped_to_a_different_chr  \
# 0                              3781878
# 1                              4054460
# 2                              2920154
# 0                              8119048
# 1                             11240060
#
#    with_mate_mapped_to_a_different_chr_mapQ>=5  01st_ptle.1  05th_ptle.1  \
# 0                                      1704891         39.0         95.0
# 1                                      1770839         34.0         97.0
# 2                                      1309959         36.0        106.0
# 0                                      3793752         59.0        100.0
# 1                                      5080345         50.0        110.0
#
#    25th_ptle.1  50th_ptle  75th_ptle.1  95th_ptle.1  99th_ptle.1  \
# 0        159.0        215        289.0        430.0        559.0
# 1        156.0        207        284.0        447.0        605.0
# 2        152.0        194        257.0        395.0        532.0
# 0        153.0        194        245.0        342.0        428.0
# 1        173.0        218        271.0        368.0        460.0
#
#               data
# 0   CRC PBMC (n=3)
# 1   CRC PBMC (n=3)
# 2   CRC PBMC (n=3)
# 0  SKCM PBMC (n=2)
# 1  SKCM PBMC (n=2)
#
# [5 rows x 31 columns]

# %%
alldf[valuevars]
# Out:
#     d50th_ptle  50th_ptle      total  secondary  supplementary  duplicates  \
# 0     17.00000        215  479478857    2580853        6813284    95004825
# 1     16.00000        207  455176820    2749845        6060731    88383509
# 2     15.00000        194  439296503    2102836        6190149    94484102
# 0     35.95820        194  911458506    5535738       11083018   135169601
# 1     36.92320        218  919236819   13655179       11182382   123476938
# 0     26.65300        204  714321977    5054531        8989420   151452340
# 1     31.02880        198  842553139    5973325       10554966   187493421
# 2     31.90550        202  917004614    6377782       11014726   240771773
# 3     26.88820        196  726833762    5033918        9418550   153473614
# 4     25.57550        193  718660686    4915979        9351833   169297170
# 5     30.00830        195  814196486    5622754        9114312   175167505
# 6     30.24410        203  826581591    5510844       10485715   187158667
# 7     28.29160        197  812200636    5263273        8934981   202063606
# 8     27.63270        207  784849958    5299966        9678588   199673818
# 9     26.06740        207  761549778    5205421        8924149   206682467
# 10    25.59800        217  748606805    4967678        9170871   201300187
# 11    25.82475        203  746733791    4950321        7216980   195731276
#
#        mapped  mapped_percent  paired_in_sequencing      read1      read2  \
# 0   472326001       98.508202             470084720  235042360  235042360
# 1   452961401       99.513284             446366244  223183122  223183122
# 2   429399167       97.747003             431003518  215501759  215501759
# 0   906857463       99.495200             894839750  447419875  447419875
# 1   915693414       99.614528             894399258  447199629  447199629
# 0   709747939       99.359667             700278026  350139013  350139013
# 1   838575679       99.527928             826024848  413012424  413012424
# 2   911909210       99.444343             899612106  449806053  449806053
# 3   721557495       99.274075             712381294  356190647  356190647
# 4   713817432       99.326072             704392874  352196437  352196437
# 5   808984398       99.359849             799459420  399729710  399729710
# 6   823091532       99.577772             810585032  405292516  405292516
# 7   808388375       99.530626             798002382  399001191  399001191
# 8   782321266       99.677812             769871404  384935702  384935702
# 9   757166176       99.424384             747420208  373710104  373710104
# 10  746097606       99.664817             734468256  367234128  367234128
# 11  743385364       99.551590             734566490  367283245  367283245
#
#     properly_paired  properly_paired_percentage  with_itself_and_mate_mapped  \
# 0         456676152                   97.147627                    462582896
# 1         436472022                   97.783385                    443891196
# 2         414210950                   96.103844                    420591606
# 0         878239434                   98.144884                    889829750
# 1         873672776                   97.682636                    890075714
# 0         684770416                   97.785507                    695154678
# 1         809240026                   97.968000                    821551472
# 2         880767706                   97.905275                    893894210
# 3         696250544                   97.735658                    706523572
# 4         688680390                   97.769358                    699062962
# 5         782114480                   97.830416                    793649628
# 6         795100670                   98.089730                    806627530
# 7         782708062                   98.083424                    793730392
# 8         755728736                   98.162983                    766976968
# 9         730907280                   97.790677                    742481320
# 10        720771762                   98.135182                    731545010
# 11        720590712                   98.097411                    730790760
#
#     singletons  with_mate_mapped_to_a_different_chr  \
# 0       348968                              3781878
# 1       259629                              4054460
# 2       514576                              2920154
# 0       408957                              8119048
# 1       780139                             11240060
# 0       549310                              7672678
# 1       495916                              8868752
# 2       622492                              9385908
# 3       581455                              7498292
# 4       486658                              7494882
# 5       597704                              8338140
# 6       467443                              8383856
# 7       459729                              7911018
# 8       365744                              7917622
# 9       555286                              7642732
# 10      414047                              7665318
# 11      427303                              6867428
#
#     with_mate_mapped_to_a_different_chr_mapQ>=5
# 0                                       1704891
# 1                                       1770839
# 2                                       1309959
# 0                                       3793752
# 1                                       5080345
# 0                                       3377667
# 1                                       4063219
# 2                                       4310723
# 3                                       3292716
# 4                                       3330950
# 5                                       3747450
# 6                                       3897142
# 7                                       3742254
# 8                                       3781309
# 9                                       3516240
# 10                                      3527533
# 11                                      3303628

# %%
mdf = pd.melt(alldf, id_vars=['data'], value_vars=valuevars)
mdf
# Out:
#                   data                                     variable  \
# 0       CRC PBMC (n=3)                                   d50th_ptle
# 1       CRC PBMC (n=3)                                   d50th_ptle
# 2       CRC PBMC (n=3)                                   d50th_ptle
# 3      SKCM PBMC (n=2)                                   d50th_ptle
# 4      SKCM PBMC (n=2)                                   d50th_ptle
# ..                 ...                                          ...
# 284  Healthy WB (n=12)  with_mate_mapped_to_a_different_chr_mapQ>=5
# 285  Healthy WB (n=12)  with_mate_mapped_to_a_different_chr_mapQ>=5
# 286  Healthy WB (n=12)  with_mate_mapped_to_a_different_chr_mapQ>=5
# 287  Healthy WB (n=12)  with_mate_mapped_to_a_different_chr_mapQ>=5
# 288  Healthy WB (n=12)  with_mate_mapped_to_a_different_chr_mapQ>=5
#
#             value
# 0    1.700000e+01
# 1    1.600000e+01
# 2    1.500000e+01
# 3    3.595820e+01
# 4    3.692320e+01
# ..            ...
# 284  3.742254e+06
# 285  3.781309e+06
# 286  3.516240e+06
# 287  3.527533e+06
# 288  3.303628e+06
#
# [289 rows x 3 columns]

# %%
def combine_box_pairs(samples, cell_types):
    box_pairs = []
    for cell in cell_types:
        pairs = []
        for sample in samples:
            pairs.append((cell, sample))
        for i in range(len(samples)):
            try:
                box_pairs.append((pairs[i], pairs[i + 1]))
            except IndexError:
                box_pairs.append((pairs[i], pairs[0]))
    return box_pairs

combine_box_pairs(datatypelist, valuevars)
# Out:
# [(('d50th_ptle', 'CRC PBMC (n=3)'), ('d50th_ptle', 'SKCM PBMC (n=2)')),
#  (('d50th_ptle', 'SKCM PBMC (n=2)'), ('d50th_ptle', 'Healthy WB (n=12)')),
#  (('d50th_ptle', 'Healthy WB (n=12)'), ('d50th_ptle', 'CRC PBMC (n=3)')),
#  (('50th_ptle', 'CRC PBMC (n=3)'), ('50th_ptle', 'SKCM PBMC (n=2)')),
#  (('50th_ptle', 'SKCM PBMC (n=2)'), ('50th_ptle', 'Healthy WB (n=12)')),
#  (('50th_ptle', 'Healthy WB (n=12)'), ('50th_ptle', 'CRC PBMC (n=3)')),
#  (('total', 'CRC PBMC (n=3)'), ('total', 'SKCM PBMC (n=2)')),
#  (('total', 'SKCM PBMC (n=2)'), ('total', 'Healthy WB (n=12)')),
#  (('total', 'Healthy WB (n=12)'), ('total', 'CRC PBMC (n=3)')),
#  (('secondary', 'CRC PBMC (n=3)'), ('secondary', 'SKCM PBMC (n=2)')),
#  (('secondary', 'SKCM PBMC (n=2)'), ('secondary', 'Healthy WB (n=12)')),
#  (('secondary', 'Healthy WB (n=12)'), ('secondary', 'CRC PBMC (n=3)')),
#  (('supplementary', 'CRC PBMC (n=3)'), ('supplementary', 'SKCM PBMC (n=2)')),
#  (('supplementary', 'SKCM PBMC (n=2)'),
#   ('supplementary', 'Healthy WB (n=12)')),
#  (('supplementary', 'Healthy WB (n=12)'), ('supplementary', 'CRC PBMC (n=3)')),
#  (('duplicates', 'CRC PBMC (n=3)'), ('duplicates', 'SKCM PBMC (n=2)')),
#  (('duplicates', 'SKCM PBMC (n=2)'), ('duplicates', 'Healthy WB (n=12)')),
#  (('duplicates', 'Healthy WB (n=12)'), ('duplicates', 'CRC PBMC (n=3)')),
#  (('mapped', 'CRC PBMC (n=3)'), ('mapped', 'SKCM PBMC (n=2)')),
#  (('mapped', 'SKCM PBMC (n=2)'), ('mapped', 'Healthy WB (n=12)')),
#  (('mapped', 'Healthy WB (n=12)'), ('mapped', 'CRC PBMC (n=3)')),
#  (('mapped_percent', 'CRC PBMC (n=3)'), ('mapped_percent', 'SKCM PBMC (n=2)')),
#  (('mapped_percent', 'SKCM PBMC (n=2)'),
#   ('mapped_percent', 'Healthy WB (n=12)')),
#  (('mapped_percent', 'Healthy WB (n=12)'),
#   ('mapped_percent', 'CRC PBMC (n=3)')),
#  (('paired_in_sequencing', 'CRC PBMC (n=3)'),
#   ('paired_in_sequencing', 'SKCM PBMC (n=2)')),
#  (('paired_in_sequencing', 'SKCM PBMC (n=2)'),
#   ('paired_in_sequencing', 'Healthy WB (n=12)')),
#  (('paired_in_sequencing', 'Healthy WB (n=12)'),
#   ('paired_in_sequencing', 'CRC PBMC (n=3)')),
#  (('read1', 'CRC PBMC (n=3)'), ('read1', 'SKCM PBMC (n=2)')),
#  (('read1', 'SKCM PBMC (n=2)'), ('read1', 'Healthy WB (n=12)')),
#  (('read1', 'Healthy WB (n=12)'), ('read1', 'CRC PBMC (n=3)')),
#  (('read2', 'CRC PBMC (n=3)'), ('read2', 'SKCM PBMC (n=2)')),
#  (('read2', 'SKCM PBMC (n=2)'), ('read2', 'Healthy WB (n=12)')),
#  (('read2', 'Healthy WB (n=12)'), ('read2', 'CRC PBMC (n=3)')),
#  (('properly_paired', 'CRC PBMC (n=3)'),
#   ('properly_paired', 'SKCM PBMC (n=2)')),
#  (('properly_paired', 'SKCM PBMC (n=2)'),
#   ('properly_paired', 'Healthy WB (n=12)')),
#  (('properly_paired', 'Healthy WB (n=12)'),
#   ('properly_paired', 'CRC PBMC (n=3)')),
#  (('properly_paired_percentage', 'CRC PBMC (n=3)'),
#   ('properly_paired_percentage', 'SKCM PBMC (n=2)')),
#  (('properly_paired_percentage', 'SKCM PBMC (n=2)'),
#   ('properly_paired_percentage', 'Healthy WB (n=12)')),
#  (('properly_paired_percentage', 'Healthy WB (n=12)'),
#   ('properly_paired_percentage', 'CRC PBMC (n=3)')),
#  (('with_itself_and_mate_mapped', 'CRC PBMC (n=3)'),
#   ('with_itself_and_mate_mapped', 'SKCM PBMC (n=2)')),
#  (('with_itself_and_mate_mapped', 'SKCM PBMC (n=2)'),
#   ('with_itself_and_mate_mapped', 'Healthy WB (n=12)')),
#  (('with_itself_and_mate_mapped', 'Healthy WB (n=12)'),
#   ('with_itself_and_mate_mapped', 'CRC PBMC (n=3)')),
#  (('singletons', 'CRC PBMC (n=3)'), ('singletons', 'SKCM PBMC (n=2)')),
#  (('singletons', 'SKCM PBMC (n=2)'), ('singletons', 'Healthy WB (n=12)')),
#  (('singletons', 'Healthy WB (n=12)'), ('singletons', 'CRC PBMC (n=3)')),
#  (('with_mate_mapped_to_a_different_chr', 'CRC PBMC (n=3)'),
#   ('with_mate_mapped_to_a_different_chr', 'SKCM PBMC (n=2)')),
#  (('with_mate_mapped_to_a_different_chr', 'SKCM PBMC (n=2)'),
#   ('with_mate_mapped_to_a_different_chr', 'Healthy WB (n=12)')),
#  (('with_mate_mapped_to_a_different_chr', 'Healthy WB (n=12)'),
#   ('with_mate_mapped_to_a_different_chr', 'CRC PBMC (n=3)')),
#  (('with_mate_mapped_to_a_different_chr_mapQ>=5', 'CRC PBMC (n=3)'),
#   ('with_mate_mapped_to_a_different_chr_mapQ>=5', 'SKCM PBMC (n=2)')),
#  (('with_mate_mapped_to_a_different_chr_mapQ>=5', 'SKCM PBMC (n=2)'),
#   ('with_mate_mapped_to_a_different_chr_mapQ>=5', 'Healthy WB (n=12)')),
#  (('with_mate_mapped_to_a_different_chr_mapQ>=5', 'Healthy WB (n=12)'),
#   ('with_mate_mapped_to_a_different_chr_mapQ>=5', 'CRC PBMC (n=3)'))]

# %%
fig, axs = plt.subplots(1, len(valuevars), figsize=(len(valuevars)*5, 10))

p_vals_fol = outputfolder + '/p_vals'
print(p_vals_fol)
os.mkdir(outputfolder + '/p_vals')

for i in range(len(valuevars)):
    axs[i] = sns.boxplot(x="variable", y="value", hue="data", data=mdf[mdf['variable'] == valuevars[i]],palette="Set3", ax = axs[i])
    axs[i].legend([],[], frameon=False)
    Box_pairs=combine_box_pairs(datatypelist, [valuevars[i]])
    original_stdout = sys.stdout

    with open(p_vals_fol + '/p_vals' + str(i) + '.txt', 'w') as f:
        sys.stdout = f # Change the standard output to the file we created.
        test_results = add_stat_annotation(axs[i],data=mdf[mdf['variable'] == valuevars[i]], x="variable", y="value", hue="data",box_pairs=Box_pairs,
                                   test='Mann-Whitney', text_format='star', comparisons_correction=None)
        sys.stdout = original_stdout # Reset the standard output to its original value
        f.close()

lines, labels = axs[0].get_legend_handles_labels()
fig.legend(lines, labels, loc=(0.933, 0.86))
plt.show()

fig.savefig(outputfile+"_all_separate.pdf",dpi=300, bbox_inches='tight')
#plt.savefig('separate_example_non-hue_outside_all.png', dpi=300, bbox_inches='tight')
# Out:
# /Users/irffanalahi/Research/Research_update/Dataqc/allqc_together/WB_PBMC/Drylab/p_vals

# %%
sig_comparison = []

for i in range(len(valuevars)):
    file_out = open(p_vals_fol + '/p_vals' + str(i) + '.txt', 'r')
    Lines = file_out.readlines()
    file_out.close()

    sig_list = []

    for line in Lines:
        if 'P_val' in line:
            split = line.split(' ')
            for name in split:
                if 'P_val' in name:
                    res = name.split('=')
                    if float(res[1]) < 0.05:
                        new_line = line.split('_')
                        if 'stdev' not in new_line:
                            cell = new_line[0]
                            val1 = new_line[1].split(' v.s.')[0]
                            val2 = new_line[2].split(':')[0]
                            print(cell, val1, val2)
                        else: 
                            cell = new_line[0] + '_' + new_line[1]
                            val1 = new_line[2].split(' v.s.')[0]
                            val2 = new_line[4].split(':')[0]
                            print(cell, val1, val2)
                        sig_list.append(((cell, val1), (cell, val2)))
    sig_comparison.append(sig_list)
    
print(sig_comparison)
# Out:
# d50th ptle SKCM PBMC (n=2) v.s. d50th
# d50th ptle CRC PBMC (n=3) v.s. d50th
# total CRC PBMC (n=3) Healthy WB (n=12)
# secondary CRC PBMC (n=3) Healthy WB (n=12)
# supplementary SKCM PBMC (n=2) Healthy WB (n=12)
# supplementary CRC PBMC (n=3) Healthy WB (n=12)
# duplicates SKCM PBMC (n=2) Healthy WB (n=12)
# duplicates CRC PBMC (n=3) Healthy WB (n=12)
# mapped CRC PBMC (n=3) Healthy WB (n=12)
# paired in sequencing
# read1 CRC PBMC (n=3) Healthy WB (n=12)
# read2 CRC PBMC (n=3) Healthy WB (n=12)
# properly paired CRC PBMC (n=3) v.s. properly
# properly paired percentage
# with itself and
# with mate mapped
# with mate mapped
# [[(('d50th', 'ptle'), ('d50th', 'SKCM PBMC (n=2) v.s. d50th')), (('d50th', 'ptle'), ('d50th', 'CRC PBMC (n=3) v.s. d50th'))], [], [(('total', 'CRC PBMC (n=3)'), ('total', 'Healthy WB (n=12)'))], [(('secondary', 'CRC PBMC (n=3)'), ('secondary', 'Healthy WB (n=12)'))], [(('supplementary', 'SKCM PBMC (n=2)'), ('supplementary', 'Healthy WB (n=12)')), (('supplementary', 'CRC PBMC (n=3)'), ('supplementary', 'Healthy WB (n=12)'))], [(('duplicates', 'SKCM PBMC (n=2)'), ('duplicates', 'Healthy WB (n=12)')), (('duplicates', 'CRC PBMC (n=3)'), ('duplicates', 'Healthy WB (n=12)'))], [(('mapped', 'CRC PBMC (n=3)'), ('mapped', 'Healthy WB (n=12)'))], [], [(('paired', 'in'), ('paired', 'sequencing'))], [(('read1', 'CRC PBMC (n=3)'), ('read1', 'Healthy WB (n=12)'))], [(('read2', 'CRC PBMC (n=3)'), ('read2', 'Healthy WB (n=12)'))], [(('properly', 'paired'), ('properly', 'CRC PBMC (n=3) v.s. properly'))], [(('properly', 'paired'), ('properly', 'percentage'))], [(('with', 'itself'), ('with', 'and'))], [], [(('with', 'mate'), ('with', 'mapped'))], [(('with', 'mate'), ('with', 'mapped'))]]

# %%
fig, axs = plt.subplots(1, len(valuevars), figsize=(len(valuevars)*5, 10))

for i in range(len(valuevars)):
    axs[i] = sns.boxplot(x="variable", y="value", hue="data", data=mdf[mdf['variable'] == valuevars[i]],palette="Set3", ax = axs[i])
    axs[i].legend([],[], frameon=False)
    Box_pairs=sig_comparison[i]
    print(Box_pairs)
    if len(Box_pairs) != 0:
        test_results = add_stat_annotation(axs[i],data=mdf[mdf['variable'] == valuevars[i]], x="variable", y="value", hue="data",box_pairs=Box_pairs,
                                    test='Mann-Whitney', text_format='star', comparisons_correction=None)

lines, labels = axs[0].get_legend_handles_labels()
fig.legend(lines, labels, loc=(0.933, 0.86))
plt.show()

fig.savefig(outputfile+"_significant_separate.pdf",dpi=300, bbox_inches='tight')
#plt.savefig('separate_example_non-hue_outside_significant.png', dpi=300, bbox_inches='tight')
# Out:
# [(('d50th', 'ptle'), ('d50th', 'SKCM PBMC (n=2) v.s. d50th')), (('d50th', 'ptle'), ('d50th', 'CRC PBMC (n=3) v.s. d50th'))]
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-697b6165372d> in <module>
#       8     if len(Box_pairs) != 0:
#       9         test_results = add_stat_annotation(axs[i],data=mdf[mdf['variable'] == valuevars[i]], x="variable", y="value", hue="data",box_pairs=Box_pairs,
# ---> 10                                     test='Mann-Whitney', text_format='star', comparisons_correction=None)
#      11
#      12 lines, labels = axs[0].get_legend_handles_labels()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statannot/statannot.py in add_stat_annotation(ax, plot, data, x, y, hue, units, order, hue_order, box_pairs, width, perform_stat_test, pvalues, test_short_name, test, text_format, pvalue_format_string, text_annot_custom, loc, show_test_name, pvalue_thresholds, stats_params, comparisons_correction, use_fixed_offset, line_offset_to_box, line_offset, line_height, text_offset, color, linewidth, fontsize, verbose)
#     471         valid = box1 in box_names and box2 in box_names
#     472         if not valid:
# --> 473             raise ValueError("box_pairs contains an invalid box pair.")
#     474             pass
#     475         # i_box_pair will keep track of the original order of the box pairs.
#
# ValueError: box_pairs contains an invalid box pair.

# %%
plt.figure(figsize=(20,10))
ax = sns.boxplot(x="variable", y="value", hue="data", data=mdf,palette="Set3") 

Box_pairs = combine_box_pairs(datatypelist, valuevars)

original_stdout = sys.stdout

with open(outputfolder + '/p_vals.txt', 'w') as f:
    sys.stdout = f # Change the standard output to the file we created.
    test_results = add_stat_annotation(ax,data=mdf, x="variable", y="value", hue="data",box_pairs=Box_pairs,
                                   test='Mann-Whitney', text_format='star', comparisons_correction=None)
    sys.stdout = original_stdout # Reset the standard output to its original value
    f.close()

plt.show()

ax.figure.savefig(outputfile+"_all_combined.pdf",dpi=300, bbox_inches='tight')
#plt.savefig('example_non-hue_outside_all.png', dpi=300, bbox_inches='tight')

# %%
file_out = open(outputfolder + '/p_vals.txt', 'r')
Lines = file_out.readlines()
file_out.close()

sig_list = []

for line in Lines:
    if 'P_val' in line:
        split = line.split(' ')
        for name in split:
            if 'P_val' in name:
                res = name.split('=')
                if float(res[1]) < 0.05:
                    new_line = line.split('_')
                    if 'stdev' not in new_line:
                        cell = new_line[0]
                        val1 = new_line[1].split(' v.s.')[0]
                        val2 = new_line[2].split(':')[0]
                    else: 
                        cell = new_line[0] + '_' + new_line[1]
                        val1 = new_line[2].split(' v.s.')[0]
                        val2 = new_line[4].split(':')[0]
                    sig_list.append(((cell, val1), (cell, val2)))

sig_list

# %%
plt.figure(figsize=(20,10))
ax = sns.boxplot(x="variable", y="value", hue="data", data=mdf,palette="Set3") 

# Box_pairs=[(("cB","New healthy"),("cB","CRC"))]

test_results = add_stat_annotation(ax,data=mdf, x="variable", y="value", hue="data",box_pairs=sig_list,
                                   test='Mann-Whitney', text_format='star', comparisons_correction=None)

plt.show()

ax.figure.savefig(outputfile+"_significant_combined.pdf",dpi=300, bbox_inches='tight')
#plt.savefig('example_non-hue_outside_significant.png', dpi=300, bbox_inches='tight')

# %%
shutil.rmtree(p_vals_fol)
