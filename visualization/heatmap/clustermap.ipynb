# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
file="/Users/irffanalahi/Research/weekly/for_2_11_21/readcounting_onyale/forpreprocess/SMfromserver/Diagnosticsofref/plot/promdataready_all_matrixCin_nr0.5_imputed_subseted.txt"
outref=file+"_ref.txt"
df=pd.read_csv(file,sep="\t",index_col=0)
trans=False
df.head()
# Out:
#                amel-139-P-CD14.bedgraph_rolled  \
# position
# chr1:40386919                            0.742
# chr1:40387009                            0.800
# chr1:40387072                            0.889
# chr1:40387104                            0.857
# chr1:40387112                            0.960
#
#                amel-167-P-CD14.bedgraph_rolled  \
# position
# chr1:40386919                            0.710
# chr1:40387009                            0.523
# chr1:40387072                            0.874
# chr1:40387104                            0.949
# chr1:40387112                            0.977
#
#                bmel-1254-T-CD14.bedgraph_rolled  \
# position
# chr1:40386919                             0.314
# chr1:40387009                             0.500
# chr1:40387072                             0.606
# chr1:40387104                             0.693
# chr1:40387112                             0.820
#
#                bmel-1457-T-CD14.bedgraph_rolled  \
# position
# chr1:40386919                             0.436
# chr1:40387009                             0.262
# chr1:40387072                             0.501
# chr1:40387104                             0.599
# chr1:40387112                             0.555
#
#                bmel-960-T-CD14.bedgraph_rolled  \
# position
# chr1:40386919                            0.167
# chr1:40387009                            0.064
# chr1:40387072                            0.415
# chr1:40387104                            0.301
# chr1:40387112                            0.500
#
#                cmel-139-P-CD4.bedgraph_rolled  cmel-167-P-CD4.bedgraph_rolled  \
# position
# chr1:40386919                           0.465                           0.430
# chr1:40387009                           0.291                           0.100
# chr1:40387072                           0.528                           0.460
# chr1:40387104                           0.694                           0.603
# chr1:40387112                           0.686                           0.566
#
#                dmel-1254-T-CD4.bedgraph_rolled  \
# position
# chr1:40386919                            0.349
# chr1:40387009                            0.040
# chr1:40387072                            0.268
# chr1:40387104                            0.407
# chr1:40387112                            0.391
#
#                dmel-1457-T-CD4.bedgraph_rolled  \
# position
# chr1:40386919                            0.349
# chr1:40387009                            0.065
# chr1:40387072                            0.558
# chr1:40387104                            0.498
# chr1:40387112                            0.608
#
#                dmel-960-T-CD4.bedgraph_rolled  emel-139-P-CD8.bedgraph_rolled  \
# position
# chr1:40386919                           0.284                           0.501
# chr1:40387009                           0.085                           0.224
# chr1:40387072                           0.300                           0.650
# chr1:40387104                           0.436                           0.778
# chr1:40387112                           0.441                           0.836
#
#                emel-167-P-CD8.bedgraph_rolled  \
# position
# chr1:40386919                           0.481
# chr1:40387009                           0.193
# chr1:40387072                           0.700
# chr1:40387104                           0.667
# chr1:40387112                           0.723
#
#                fmel-1254-T-CD8.bedgraph_rolled  \
# position
# chr1:40386919                            0.381
# chr1:40387009                            0.069
# chr1:40387072                            0.402
# chr1:40387104                            0.278
# chr1:40387112                            0.442
#
#                fmel-1457-T-CD8.bedgraph_rolled  \
# position
# chr1:40386919                            0.330
# chr1:40387009                            0.257
# chr1:40387072                            0.359
# chr1:40387104                            0.250
# chr1:40387112                            0.289
#
#                fmel-960-T-CD8.bedgraph_rolled  \
# position
# chr1:40386919                           0.400
# chr1:40387009                           0.040
# chr1:40387072                           0.270
# chr1:40387104                           0.428
# chr1:40387112                           0.488
#
#                gmel-1254-T-CD45-Negative.bedgraph_rolled  \
# position
# chr1:40386919                                      0.958
# chr1:40387009                                      0.728
# chr1:40387072                                      0.900
# chr1:40387104                                      0.933
# chr1:40387112                                      0.903
#
#                gmel-1340-T-CD45-Negative.bedgraph_rolled  \
# position
# chr1:40386919                                      0.767
# chr1:40387009                                      0.797
# chr1:40387072                                      0.953
# chr1:40387104                                      0.877
# chr1:40387112                                      0.866
#
#                gmel-1457-T-CD45-Negative.bedgraph_rolled
# position
# chr1:40386919                                      0.897
# chr1:40387009                                      0.887
# chr1:40387072                                      1.000
# chr1:40387104                                      0.960
# chr1:40387112                                      1.000

# %%
plt.figure(figsize=(12,10))

mycmap = plt.cm.viridis

mycmap.set_bad("dimgrey")

cg = sns.clustermap(df,cmap=mycmap,method='centroid')
#cg=sns.clustermap(df, cmap="viridis")
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)

# %%
outdf=df.iloc[cg.dendrogram_row.reordered_ind,:]
outdf.to_csv(outref,sep="\t")
