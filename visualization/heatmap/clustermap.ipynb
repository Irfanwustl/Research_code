# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
file="/Users/irffanalahi/Research/weekly/for_9_24_20/preparation/SM/traditional_decon/result/CpgTileup/onlysm_bg_allmat_cyberin_header"
outref=file+"_ref.txt"
df=pd.read_csv(file,sep="\t",index_col=0)
trans=False
df.head()
# Out:
#                C00256A1bs_CD8.bw.bg  C002CTA1bs_cytnk.bw.bg  \
# position
# chr1:1764476                   0.95                2.800000
# chr1:2252000                  68.00               13.100000
# chr1:6670100                  14.65               35.800000
# chr1:8970609                  83.30               13.666667
# chr1:15407486                 19.10               90.900000
#
#                C003VO55_CD8.bw.bg  C0066P51_CD8.bw.bg  C0067N51_cytnk.bw.bg  \
# position
# chr1:1764476                 4.65            5.400000              0.800000
# chr1:2252000                91.30           86.550000              4.350000
# chr1:6670100                 1.65            4.900000             23.300000
# chr1:8970609                93.55           82.133333              1.900000
# chr1:15407486                1.00            2.966667             98.966667
#
#                NBC_NC11_41_naiveb.bw.bg  S008H151_CD4.bw.bg  \
# position
# chr1:1764476                   5.700000            3.950000
# chr1:2252000                   9.100000           85.750000
# chr1:6670100                   2.250000            1.500000
# chr1:8970609                   3.533333           70.850000
# chr1:15407486                  2.233333            5.566667
#
#                S009W451_CD4.bw.bg  S017RE51_memb.bw.bg  S01BHIA1_mono.bw.bg  \
# position
# chr1:1764476             0.950000             1.900000            96.900000
# chr1:2252000            91.750000            12.950000             5.100000
# chr1:6670100             0.000000             0.900000             0.000000
# chr1:8970609            77.333333             3.866667             2.966667
# chr1:15407486            6.066667             9.833333             7.333333
#
#                S01E03A1_mono.bw.bg  S01E8O51_cytnk.bw.bg  \
# position
# chr1:1764476            100.000000              0.000000
# chr1:2252000              2.350000             10.250000
# chr1:6670100              0.000000             27.300000
# chr1:8970609              3.866667              3.300000
# chr1:15407486             3.233333             97.833333
#
#                S01ECGA1_naiveb.bw.bg  S01MAPA1_mono.bw.bg
# position
# chr1:1764476                     2.4           100.000000
# chr1:2252000                     2.1             5.150000
# chr1:6670100                     0.0             4.500000
# chr1:8970609                     4.5             5.300000
# chr1:15407486                    7.7             6.366667

# %%
plt.figure(figsize=(12,10))

mycmap = plt.cm.viridis

mycmap.set_bad("dimgrey")

cg = sns.clustermap(df,cmap=mycmap,method='centroid')
#cg=sns.clustermap(df, cmap="viridis")
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)

# %%
outdf=df.iloc[cg.dendrogram_row.reordered_ind,:]
outdf.to_csv(outref,sep="\t")
