# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
file="/Users/irffanalahi/Research/weekly/for_12_31_20/decon/result/downstream/purified/TIL_all_matrix_NO_NA_mat_Ciberin_scaled_inverted_subseted.txt"
outref=file+"_ref.txt"
df=pd.read_csv(file,sep="\t",index_col=0)
trans=False
df.head()
# Out:
#                  bmel-1254-T-CD14.bedgraph_rolled  \
# position
# chr1:244955351                                0.0
# chr10:9931027                                25.0
# chr10:119099752                               0.0
# chr11:96559802                               50.0
# chr13:101605205                              12.5
#
#                  bmel-1457-T-CD14.bedgraph_rolled  \
# position
# chr1:244955351                                0.0
# chr10:9931027                                25.0
# chr10:119099752                               0.0
# chr11:96559802                               50.0
# chr13:101605205                              12.5
#
#                  bmel-960-T-CD14.bedgraph_rolled  \
# position
# chr1:244955351                               0.0
# chr10:9931027                               25.0
# chr10:119099752                              0.0
# chr11:96559802                              50.0
# chr13:101605205                             12.5
#
#                  dmel-1254-T-CD4.bedgraph_rolled  \
# position
# chr1:244955351                               0.0
# chr10:9931027                                0.0
# chr10:119099752                              0.0
# chr11:96559802                               0.0
# chr13:101605205                              0.0
#
#                  dmel-1457-T-CD4.bedgraph_rolled  \
# position
# chr1:244955351                               0.0
# chr10:9931027                                0.0
# chr10:119099752                              0.0
# chr11:96559802                               0.0
# chr13:101605205                              0.0
#
#                  dmel-960-T-CD4.bedgraph_rolled  \
# position
# chr1:244955351                              0.0
# chr10:9931027                               0.0
# chr10:119099752                             0.0
# chr11:96559802                              0.0
# chr13:101605205                             0.0
#
#                  fmel-1254-T-CD8.bedgraph_rolled  \
# position
# chr1:244955351                               6.2
# chr10:9931027                                0.0
# chr10:119099752                              5.2
# chr11:96559802                               0.0
# chr13:101605205                              0.0
#
#                  fmel-1457-T-CD8.bedgraph_rolled  \
# position
# chr1:244955351                               6.2
# chr10:9931027                                0.0
# chr10:119099752                              5.2
# chr11:96559802                               0.0
# chr13:101605205                              0.0
#
#                  fmel-960-T-CD8.bedgraph_rolled
# position
# chr1:244955351                              6.2
# chr10:9931027                               0.0
# chr10:119099752                             5.2
# chr11:96559802                              0.0
# chr13:101605205                             0.0

# %%
plt.figure(figsize=(12,10))

mycmap = plt.cm.viridis

mycmap.set_bad("dimgrey")

cg = sns.clustermap(df,cmap=mycmap,method='centroid')
#cg=sns.clustermap(df, cmap="viridis")
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)

# %%
outdf=df.iloc[cg.dendrogram_row.reordered_ind,:]
outdf.to_csv(outref,sep="\t")
