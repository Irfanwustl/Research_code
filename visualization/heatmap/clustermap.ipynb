# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
file="/Users/irffanalahi/Research/weekly/for_12_23_20/traditional_decon_result/downstream/tileup/sigtileup/blnoneu_all_matrix_NO_NA_mat_Ciberin_scaled_inverted_subseted.txt"
outref=file+"_ref.txt"
df=pd.read_csv(file,sep="\t",index_col=0)
trans=False
df.head()
# Out:
#                aS01BHIA1_mono.bw.bedgraph_rolled  \
# position
# chr1:8419860                                 0.0
# chr1:9632930                                 0.0
# chr1:12404196                                1.8
# chr1:15572099                                0.0
# chr1:24862196                                0.0
#
#                aS01E03A1_mono.bw.bedgraph_rolled  \
# position
# chr1:8419860                                 0.0
# chr1:9632930                                 0.0
# chr1:12404196                                0.0
# chr1:15572099                                0.0
# chr1:24862196                                2.8
#
#                aS01MAPA1_mono.bw.bedgraph_rolled  \
# position
# chr1:8419860                                 2.9
# chr1:9632930                                 0.0
# chr1:12404196                                0.0
# chr1:15572099                                4.2
# chr1:24862196                                0.0
#
#                bNBC_NC11_41_naiveb.bw.bedgraph_rolled  \
# position
# chr1:8419860                                      5.3
# chr1:9632930                                      0.0
# chr1:12404196                                     1.9
# chr1:15572099                                   100.0
# chr1:24862196                                     0.0
#
#                bS017RE51_memb.bw.bedgraph_rolled  \
# position
# chr1:8419860                                 0.0
# chr1:9632930                                 7.1
# chr1:12404196                                1.9
# chr1:15572099                              100.0
# chr1:24862196                                0.0
#
#                bS01ECGA1_naiveb.bw.bedgraph_rolled  \
# position
# chr1:8419860                                   5.6
# chr1:9632930                                   0.0
# chr1:12404196                                  4.8
# chr1:15572099                                100.0
# chr1:24862196                                  0.0
#
#                cS008H151_CD4.bw.bedgraph_rolled  \
# position
# chr1:8419860                               56.2
# chr1:9632930                                8.3
# chr1:12404196                              65.2
# chr1:15572099                               0.0
# chr1:24862196                               0.0
#
#                cS009W451_CD4.bw.bedgraph_rolled  \
# position
# chr1:8419860                               71.4
# chr1:9632930                                7.7
# chr1:12404196                              68.2
# chr1:15572099                               0.0
# chr1:24862196                               0.0
#
#                dC00256A1bs_CD8.bw.bedgraph_rolled  \
# position
# chr1:8419860                                  3.1
# chr1:9632930                                 64.7
# chr1:12404196                                 9.1
# chr1:15572099                                 0.0
# chr1:24862196                                 0.0
#
#                dC003VO55_CD8.bw.bedgraph_rolled  \
# position
# chr1:8419860                                0.0
# chr1:9632930                               57.1
# chr1:12404196                               6.7
# chr1:15572099                               0.0
# chr1:24862196                               0.0
#
#                dC0066P51_CD8.bw.bedgraph_rolled  \
# position
# chr1:8419860                                8.3
# chr1:9632930                               54.5
# chr1:12404196                               0.0
# chr1:15572099                               0.0
# chr1:24862196                              15.4
#
#                eC002CTA1bs_cytnk.bw.bedgraph_rolled  \
# position
# chr1:8419860                                    0.0
# chr1:9632930                                    0.0
# chr1:12404196                                   0.0
# chr1:15572099                                   1.6
# chr1:24862196                                  88.2
#
#                eC0067N51_cytnk.bw.bedgraph_rolled  \
# position
# chr1:8419860                                  5.7
# chr1:9632930                                  4.3
# chr1:12404196                                 5.6
# chr1:15572099                                 8.9
# chr1:24862196                                59.1
#
#                eS01E8O51_cytnk.bw.bedgraph_rolled
# position
# chr1:8419860                                  0.0
# chr1:9632930                                  0.0
# chr1:12404196                                 0.0
# chr1:15572099                                 0.0
# chr1:24862196                                80.6

# %%
plt.figure(figsize=(12,10))

mycmap = plt.cm.viridis

mycmap.set_bad("dimgrey")

cg = sns.clustermap(df,cmap=mycmap,method='centroid')
#cg=sns.clustermap(df, cmap="viridis")
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)

# %%
outdf=df.iloc[cg.dendrogram_row.reordered_ind,:]
outdf.to_csv(outref,sep="\t")
