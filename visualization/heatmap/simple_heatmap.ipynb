# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
file="/Users/irffanalahi/Research/weekly/for_9_3_20/changing_value/result/downanalysis/visualization/step1/ourpbmc_usingMeanBasedRule.py_minCpG3_minval0.25_maxval0.75_sorted_all_matrix_NO_NA_mat_Ciberin_pearson.txt"
df=pd.read_csv(file,sep="\t",index_col=0)
trans=False
df.head()
# Out:
#                                 C00184A3bs_matneu.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                              0.975845
# CD14-PBMC-1382.bedgraph_rolled                              0.975845
# CD14-PBMC-1389.bedgraph_rolled                              0.975204
# CD19-PBMC-1313.bedgraph_rolled                              0.966805
# CD19-PBMC-1382.bedgraph_rolled                              0.966805
#
#                                 C001UYA1bs_matneu.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                              0.982003
# CD14-PBMC-1382.bedgraph_rolled                              0.982003
# CD14-PBMC-1389.bedgraph_rolled                              0.981765
# CD19-PBMC-1313.bedgraph_rolled                              0.972268
# CD19-PBMC-1382.bedgraph_rolled                              0.972274
#
#                                 C00256A1bs_CD8.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                           0.986042
# CD14-PBMC-1382.bedgraph_rolled                           0.986042
# CD14-PBMC-1389.bedgraph_rolled                           0.985141
# CD19-PBMC-1313.bedgraph_rolled                           0.995955
# CD19-PBMC-1382.bedgraph_rolled                           0.995987
#
#                                 C002CTA1bs_cytnk.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                             0.983959
# CD14-PBMC-1382.bedgraph_rolled                             0.983959
# CD14-PBMC-1389.bedgraph_rolled                             0.983317
# CD19-PBMC-1313.bedgraph_rolled                             0.993982
# CD19-PBMC-1382.bedgraph_rolled                             0.993991
#
#                                 C003N351_memb.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                          0.977922
# CD14-PBMC-1382.bedgraph_rolled                          0.977922
# CD14-PBMC-1389.bedgraph_rolled                          0.976920
# CD19-PBMC-1313.bedgraph_rolled                          0.988358
# CD19-PBMC-1382.bedgraph_rolled                          0.988386
#
#                                 C003VO55_CD8.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                         0.984844
# CD14-PBMC-1382.bedgraph_rolled                         0.984844
# CD14-PBMC-1389.bedgraph_rolled                         0.983924
# CD19-PBMC-1313.bedgraph_rolled                         0.994611
# CD19-PBMC-1382.bedgraph_rolled                         0.994622
#
#                                 C004GD51_matneu.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                            0.975266
# CD14-PBMC-1382.bedgraph_rolled                            0.975266
# CD14-PBMC-1389.bedgraph_rolled                            0.974939
# CD19-PBMC-1313.bedgraph_rolled                            0.966021
# CD19-PBMC-1382.bedgraph_rolled                            0.966021
#
#                                 C0066P51_CD8.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                         0.973862
# CD14-PBMC-1382.bedgraph_rolled                         0.973862
# CD14-PBMC-1389.bedgraph_rolled                         0.972876
# CD19-PBMC-1313.bedgraph_rolled                         0.982184
# CD19-PBMC-1382.bedgraph_rolled                         0.982183
#
#                                 C0067N51_cytnk.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                           0.970955
# CD14-PBMC-1382.bedgraph_rolled                           0.970955
# CD14-PBMC-1389.bedgraph_rolled                           0.970123
# CD19-PBMC-1313.bedgraph_rolled                           0.980771
# CD19-PBMC-1382.bedgraph_rolled                           0.980771
#
#                                 C006G551_cytnk.bw.bedgraph_rolled  ...  \
# CD14-PBMC-1313.bedgraph_rolled                           0.982225  ...
# CD14-PBMC-1382.bedgraph_rolled                           0.982225  ...
# CD14-PBMC-1389.bedgraph_rolled                           0.981610  ...
# CD19-PBMC-1313.bedgraph_rolled                           0.992170  ...
# CD19-PBMC-1382.bedgraph_rolled                           0.992170  ...
#
#                                 NBC_NC11_83_naiveb.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                               0.969818
# CD14-PBMC-1382.bedgraph_rolled                               0.969818
# CD14-PBMC-1389.bedgraph_rolled                               0.968993
# CD19-PBMC-1313.bedgraph_rolled                               0.979224
# CD19-PBMC-1382.bedgraph_rolled                               0.979224
#
#                                 S008H151_CD4.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                         0.985980
# CD14-PBMC-1382.bedgraph_rolled                         0.985980
# CD14-PBMC-1389.bedgraph_rolled                         0.985110
# CD19-PBMC-1313.bedgraph_rolled                         0.995533
# CD19-PBMC-1382.bedgraph_rolled                         0.995539
#
#                                 S009W451_CD4.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                         0.986529
# CD14-PBMC-1382.bedgraph_rolled                         0.986529
# CD14-PBMC-1389.bedgraph_rolled                         0.985582
# CD19-PBMC-1313.bedgraph_rolled                         0.996436
# CD19-PBMC-1382.bedgraph_rolled                         0.996457
#
#                                 S00C2F51_CD8.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                         0.975930
# CD14-PBMC-1382.bedgraph_rolled                         0.975930
# CD14-PBMC-1389.bedgraph_rolled                         0.975049
# CD19-PBMC-1313.bedgraph_rolled                         0.984797
# CD19-PBMC-1382.bedgraph_rolled                         0.984806
#
#                                 S017RE51_memb.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                          0.980466
# CD14-PBMC-1382.bedgraph_rolled                          0.980466
# CD14-PBMC-1389.bedgraph_rolled                          0.979606
# CD19-PBMC-1313.bedgraph_rolled                          0.990739
# CD19-PBMC-1382.bedgraph_rolled                          0.990829
#
#                                 S01BHIA1_mono.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                          0.993063
# CD14-PBMC-1382.bedgraph_rolled                          0.993063
# CD14-PBMC-1389.bedgraph_rolled                          0.992754
# CD19-PBMC-1313.bedgraph_rolled                          0.981202
# CD19-PBMC-1382.bedgraph_rolled                          0.981209
#
#                                 S01E03A1_mono.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                          0.991962
# CD14-PBMC-1382.bedgraph_rolled                          0.991962
# CD14-PBMC-1389.bedgraph_rolled                          0.991872
# CD19-PBMC-1313.bedgraph_rolled                          0.980144
# CD19-PBMC-1382.bedgraph_rolled                          0.980144
#
#                                 S01E8O51_cytnk.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                           0.969737
# CD14-PBMC-1382.bedgraph_rolled                           0.969737
# CD14-PBMC-1389.bedgraph_rolled                           0.968810
# CD19-PBMC-1313.bedgraph_rolled                           0.979519
# CD19-PBMC-1382.bedgraph_rolled                           0.979519
#
#                                 S01ECGA1_naiveb.bw.bedgraph_rolled  \
# CD14-PBMC-1313.bedgraph_rolled                            0.984735
# CD14-PBMC-1382.bedgraph_rolled                            0.984735
# CD14-PBMC-1389.bedgraph_rolled                            0.984211
# CD19-PBMC-1313.bedgraph_rolled                            0.993104
# CD19-PBMC-1382.bedgraph_rolled                            0.993104
#
#                                 S01MAPA1_mono.bw.bedgraph_rolled
# CD14-PBMC-1313.bedgraph_rolled                          0.992395
# CD14-PBMC-1382.bedgraph_rolled                          0.992395
# CD14-PBMC-1389.bedgraph_rolled                          0.992293
# CD19-PBMC-1313.bedgraph_rolled                          0.980651
# CD19-PBMC-1382.bedgraph_rolled                          0.980651
#
# [5 rows x 21 columns]

# %%
if trans==True:
    df=df.T

# %%
#ax=sns.heatmap(df, annot=True, center=0, cmap=sns.diverging_palette(220, 20, as_cmap=True))
#plt.pcolor(df)
sns.set(font_scale=2.5)
mycmap = plt.cm.viridis


plt.rcParams['font.family']='sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
mycmap.set_bad("dimgrey")

plt.figure(figsize=(35,25))
aaa=sns.heatmap(df, annot=True,cmap=mycmap,fmt=".3f",annot_kws={"size": 20})
aaa.set_xticklabels(aaa.get_xticklabels(), rotation=90)
aaa.set_yticklabels(aaa.get_yticklabels(), rotation=0)

plt.ylabel("This Study (PBMC)",fontweight='bold',labelpad=50)
plt.xlabel("Blueprint (PBMC)",fontweight='bold')

cbar = aaa.collections[0].colorbar#.set_label('# of contacts', horizontalalignment='left')
cbar.ax.set_title('R',pad=20)

heatname=file+"_heat"+".pdf"
plt.savefig(heatname,bbox_inches = "tight")
plt.show()

# %%
plt.figure(figsize=(12,10))
cg=sns.clustermap(df, annot=True,cmap="viridis")
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)
clustername=file+"_heat_clustered"+".pdf"
plt.savefig(clustername,bbox_inches = "tight")
plt.show()
