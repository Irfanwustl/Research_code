# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
file="/Users/irffanalahi/Research/weekly/for_10_15_20/analyse/downstream/Alldivout/corr/seperate_NA/heat/nodropoutheat.txt"
df=pd.read_csv(file,sep="\t",index_col=0)
trans=False
df.head()
# Out:
#          50       100       150       200       250       300       350  \
# 2  0.923017  0.921704  0.927777  0.923293  0.923358  0.921115  0.917638
# 3  0.923883  0.936914  0.934397  0.927277  0.923919  0.926430  0.919337
# 4  0.892332  0.920651  0.918261  0.915583  0.914010  0.916685  0.910599
# 5  0.883165  0.921448  0.913368  0.904667  0.917242  0.922463  0.907569
# 6  0.798826  0.887864  0.886798  0.888970  0.901435  0.905583  0.895638
#
#         400       450  50_nodropout  100_nodropout  150_nodropout  \
# 2  0.917478  0.914987      0.923017       0.921704       0.927777
# 3  0.919644  0.919151      0.923883       0.936914       0.934397
# 4  0.912018  0.911705      0.892332       0.920651       0.918261
# 5  0.909080  0.909506      0.883165       0.921448       0.913368
# 6  0.904268  0.904838      0.871627       0.887864       0.886798
#
#    200_nodropout  250_nodropout  300_nodropout  350_nodropout  400_nodropout  \
# 2       0.923293       0.923358       0.921115       0.917638       0.917478
# 3       0.927277       0.923919       0.926430       0.919337       0.919644
# 4       0.915583       0.914010       0.916685       0.910599       0.912018
# 5       0.904667       0.917242       0.922463       0.907569       0.909080
# 6       0.888970       0.901435       0.905583       0.895638       0.904268
#
#    450_nodropout
# 2       0.914987
# 3       0.919151
# 4       0.911705
# 5       0.909506
# 6       0.904838

# %%
if trans==True:
    df=df.T

# %%
#ax=sns.heatmap(df, annot=True, center=0, cmap=sns.diverging_palette(220, 20, as_cmap=True))
#plt.pcolor(df)
sns.set(font_scale=2.5)
mycmap = plt.cm.viridis


plt.rcParams['font.family']='sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
mycmap.set_bad("dimgrey")

plt.figure(figsize=(35,25))
aaa=sns.heatmap(df, annot=True,cmap=mycmap,fmt=".3f",annot_kws={"size": 20})
aaa.set_xticklabels(aaa.get_xticklabels(), rotation=90)
aaa.set_yticklabels(aaa.get_yticklabels(), rotation=0)

plt.ylabel("#CpG within 150 bp",fontweight='bold',labelpad=50)
plt.xlabel("#pivotal CpG",fontweight='bold')

cbar = aaa.collections[0].colorbar#.set_label('# of contacts', horizontalalignment='left')
cbar.ax.set_title('R',pad=20)

heatname=file+"_heat"+".pdf"
plt.savefig(heatname,bbox_inches = "tight")
plt.show()

# %%
plt.figure(figsize=(12,10))
cg=sns.clustermap(df, annot=True,cmap="viridis")
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)
clustername=file+"_heat_clustered"+".pdf"
plt.savefig(clustername,bbox_inches = "tight")
plt.show()
