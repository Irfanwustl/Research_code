# %%
import pandas as pd
import seaborn as sns; sns.set()
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
file="/Users/irffanalahi/Research/weekly/for_8_6_20/rondrobin_fullresult/analysis/v1/heatmap/masterperf_CSxout_notrainingdata_bothnormnotnorm_gtmoreextended_merged_rename.txt"
df=pd.read_csv(file,sep="\t",index_col=0)
trans=True
df.head()
# Out:
#                   CRC_pbmc_subsetgt_scaled.txt  Accgt_noneu.txt  \
# Sm
# Cand                                  0.385205         0.565374
# Cand_norm                             0.374980         0.678317
# bl_no_Neu                             0.524568         0.065702
# bl_with_Neu                           0.530864         0.387823
# bl_with_Neu_norm                      0.520217         0.516287
#
#                   rendata_gt3_noneu.txt  Accgt_asabul.txt  \
# Sm
# Cand                           0.146234          0.707402
# Cand_norm                      0.070770          0.635578
# bl_no_Neu                     -0.118351          0.052461
# bl_with_Neu                    0.365550          0.466677
# bl_with_Neu_norm               0.547874          0.416746
#
#                   rendata_gt3_neuscaled_wb.txt  rendata_gt3_noneu_pbmc.txt  \
# Sm
# Cand                                  0.478053                    0.391981
# Cand_norm                             0.429606                    0.391693
# bl_no_Neu                             0.051415                    0.348891
# bl_with_Neu                           0.746432                    0.668535
# bl_with_Neu_norm                      0.717346                    0.677354
#
#                   rendata_gt3_neuscaled_pbmc.txt  rendata_gt3.txt  \
# Sm
# Cand                                    0.391096         0.664021
# Cand_norm                               0.389345         0.154434
# bl_no_Neu                               0.348275         0.048119
# bl_with_Neu                             0.664203         0.795426
# bl_with_Neu_norm                        0.669783         0.293043
#
#                   Accgt_neuscaled.txt  CRC_pbmc_subsetgt_scaled_f3cfd.txt  \
# Sm
# Cand                         0.720436                            0.410964
# Cand_norm                    0.626159                            0.424268
# bl_no_Neu                    0.050514                            0.587874
# bl_with_Neu                  0.471599                            0.565748
# bl_with_Neu_norm             0.401453                            0.551126
#
#                   bulk_pbmc_gt_scaled.txt  CRC_pbmc_subsetgt.txt  \
# Sm
# Cand                             0.392384               0.386580
# Cand_norm                        0.552000               0.370514
# bl_no_Neu                        0.947643               0.529131
# bl_with_Neu                      0.455183               0.542155
# bl_with_Neu_norm                 0.862831               0.527050
#
#                   rendata_gt3_neuscaled.txt  rendata_gt3_noneu_wb.txt  \
# Sm
# Cand                               0.662185                  0.449921
# Cand_norm                          0.155111                  0.499860
# bl_no_Neu                          0.047625                  0.029926
# bl_with_Neu                        0.794680                  0.718594
# bl_with_Neu_norm                   0.296562                  0.760588
#
#                   bulk_tumor_gt_scaled.txt  pbmc_tum_bulk_scaled.txt  \
# Sm
# Cand                              0.333083                  0.364484
# Cand_norm                         0.368745                  0.443800
# bl_no_Neu                         0.221370                  0.586200
# bl_with_Neu                       0.199147                  0.261479
# bl_with_Neu_norm                  0.192052                  0.333039
#
#                   blueprint_rein_our_pbmc_puregt.txt  \
# Sm
# Cand                                        0.933527
# Cand_norm                                   0.935464
# bl_no_Neu                                   0.919428
# bl_with_Neu                                 0.915789
# bl_with_Neu_norm                            0.919276
#
#                   rendata_gt3_noneu_gran.txt  rendata_gt3_neuscaled_gran.txt
# Sm
# Cand                               -0.197452                       -0.085044
# Cand_norm                          -0.204009                       -0.153445
# bl_no_Neu                          -0.300691                       -0.268500
# bl_with_Neu                         0.298126                        0.320576
# bl_with_Neu_norm                    0.413875                        0.291484

# %%
if trans==True:
    df=df.T

# %%
#ax=sns.heatmap(df, annot=True, center=0, cmap=sns.diverging_palette(220, 20, as_cmap=True))
#plt.pcolor(df)
plt.figure(figsize=(12,10))
sns.heatmap(df, annot=True,cmap="viridis")

heatname=file+"_heat"+".pdf"
plt.savefig(heatname,bbox_inches = "tight")
plt.show()

# %%
plt.figure(figsize=(12,10))
cg=sns.clustermap(df, annot=True,cmap="viridis")
cg.ax_row_dendrogram.set_visible(False)
cg.ax_col_dendrogram.set_visible(False)
clustername=file+"_heat_clustered"+".pdf"
plt.savefig(clustername,bbox_inches = "tight")
plt.show()
