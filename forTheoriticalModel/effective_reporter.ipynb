# %%
import pandas as pd
infile='/Users/irffanalahi/Research/Research_update/in-silico/theoritical_model/depth_30x/mNeuallrange_NR_81205_insilmix1_sorted_howsm_single_mode_pp_masterdf.txt_rej-99999.0_mincpg5_rejmode_nov_final.txt'
outfile=infile+"_effectiveReporter"


indf=pd.read_csv(infile,sep='\t')
indf['CheckedCpG']=indf.CheckedCpG.apply(lambda x: x[1:-1].split(','))
indf.head()
# Out:
#                                            ReadName allcelltype ucelltype  \
# 0     m4.HWI-ST537:240:C6B3NACXX:3:2310:15483:54518          []      ['']
# 1       Tr.D6L3XBQ1:317:C6CGAACXX:6:2114:7476:15608      ['NK']    ['NK']
# 2  Tr.HWI-ST700660:293:C737DACXX:6:2209:17216:67776      ['NK']    ['NK']
# 3             m8.HWI-ST459_146:6:2202:16994:34072#5      ['NK']    ['NK']
# 4            CD8.HWI-ST459_145:7:2107:11193:80423#4      ['NK']    ['NK']
#
#   assignedcelltype        CheckedCpG mismatchCpG    notacceptedCpG  \
# 0      NotAssigned                []        ['']              ['']
# 1      NotAssigned  ['chr1:1221863']        ['']  ['chr1:1221863']
# 2      NotAssigned  ['chr1:1221863']        ['']  ['chr1:1221863']
# 3      NotAssigned                []        ['']              ['']
# 4      NotAssigned  ['chr1:1221863']        ['']  ['chr1:1221863']
#
#   acceptedCpG finalacceptedfor finalrejectedfor MateCIGARok          hypolist  \
# ...

# %%
indf=indf[(indf['finalacceptedfor']=='mNeu') |  (indf['finalrejectedfor'].str.contains('mNeu'))] 
indf.head()
# Out:
#                                            ReadName  \
# 3068          m8.HWI-ST537_195:3:1214:3459:74825#14
# 3074            nB.HWI-ST858_121:5:2205:6444:3614#7
# 4005          CD8.HWI-ST459_145:6:2207:3323:95826#4
# 4006  m4.HWI-ST539:218:C47JJACXX:4:2106:16304:34836
# 4008          Er.HWI-ST699_225:4:2116:15943:64880#9
#
#                                             allcelltype ucelltype  \
# 3068           ['mNeu', 'mNeu', 'mNeu', 'mNeu', 'mNeu']  ['mNeu']
# 3074           ['mNeu', 'mNeu', 'mNeu', 'mNeu', 'mNeu']  ['mNeu']
# 4005           ['mNeu', 'mNeu', 'mNeu', 'mNeu', 'mNeu']  ['mNeu']
# 4006           ['mNeu', 'mNeu', 'mNeu', 'mNeu', 'mNeu']  ['mNeu']
# 4008  ['mNeu', 'mNeu', 'mNeu', 'mNeu', 'mNeu', 'mNeu...  ['mNeu']
#
#      assignedcelltype                                         CheckedCpG  \
# 3068      NotAssigned  ['chr1:233257871',  'chr1:233258005',  'chr1:2...
# 3074      NotAssigned  ['chr1:233258005',  'chr1:233258029',  'chr1:2...
# ...

# %%
indf.shape
# Out:
# (491, 20)

# %%
checked_reporter=indf['CheckedCpG'].tolist()
len(checked_reporter)
# Out:
# 491

# %%
checked_reporter_set=list(map(frozenset,checked_reporter))

textfile = open(outfile+"_allreporter.txt", "w")
for element in checked_reporter_set:
    textfile.write(str(element) + "\n")
textfile.close()



print(len(set(checked_reporter_set)))
# Out:
# 186

# %%
def CountFrequency(my_list):
     
    # Creating an empty dictionary
    freq = {}
    for items in my_list:
        freq[items] = my_list.count(items)
     
    sorteddict=dict(sorted(freq.items(), key=lambda item: item[1],reverse=True))
    
    for key, value in sorteddict.items():
        print ("% s : % d"%(key, value))

# %%
CountFrequency(checked_reporter_set)
# Out:
# frozenset({" 'chr15:101056982'", "'chr15:101056999'", " 'chr15:101057012'", " 'chr15:101056967'", " 'chr15:101057002'", " 'chr15:101056963'"}) :  19
# frozenset({" 'chr9:131123450'", " 'chr9:131123434'", "'chr9:131123383'", " 'chr9:131123430'", " 'chr9:131123438'", " 'chr9:131123440'"}) :  13
# frozenset({" 'chr3:153067202'", "'chr3:153067257'", " 'chr3:153067235'", " 'chr3:153067207'", " 'chr3:153067225'", " 'chr3:153067222'", " 'chr3:153067189'", " 'chr3:153067237'", " 'chr3:153067270'"}) :  11
# frozenset({"'chr5:88745472'", " 'chr5:88745494'", " 'chr5:88745530'", " 'chr5:88745476'", " 'chr5:88745546'"}) :  11
# frozenset({" 'chr12:8128598'", " 'chr12:8128534'", " 'chr12:8128566'", " 'chr12:8128561'", "'chr12:8128629'"}) :  11
# frozenset({" 'chr19:48175904'", " 'chr19:48175942'", "'chr19:48175926'", " 'chr19:48175932'", " 'chr19:48175970'"}) :  11
# frozenset({"'chr2:46407066'", " 'chr2:46407042'", " 'chr2:46407074'", " 'chr2:46407032'", " 'chr2:46407072'"}) :  9
# ...
